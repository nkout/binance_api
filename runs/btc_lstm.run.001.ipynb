# %% [markdown]
# # BTC Orderbook LSTM — Microstructure Direction Prediction
#
# **Best parameters from XGBoost sweep:** `--threshold 50 --horizon 8` (2-minute horizon)
#
# **Architecture:** LSTM over a sliding window of the last N bars, predicting UP/DOWN/FLAT at horizon=8 bars ahead.
#
# **Same feature pipeline and bias rules as `btc_signal_analysis.py` — no lookahead.**
#
# ## Setup
# 1. Runtime → Change runtime type → **T4 GPU**
# 2. Mount Google Drive (Cell 2) and set `DATA_DIR` to your CSV/CSV.GZ folder
# 3. Run all cells in order
#
# ## Key design decisions
# - **Sequence length = 32 bars (8 minutes):** captures sustained imbalance patterns
# - **Chronological train/val/test split** — no shuffling, no future leakage
# - **Class weights** to handle FLAT dominance (~55%)
# - **Same backtest** as XGBoost: win rate, avg P&L per trade, after-fee comparison

# %%
#!apt install sshpass -y && sshpass -p XXXXXXXXX sftp -r -o "StrictHostKeyChecking no" scpuser@155.207.120.2:btc_data.tar.xz .

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#!ls
#!mv btc_data.tar.xz /content/drive/MyDrive/
#!ls /content/drive/MyDrive/ -l

# %%
#drive.flush_and_unmount()

# %%
# ── Cell 1: Install and imports ───────────────────────────────────────────
import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'torch', 'scikit-learn', 'pandas', 'numpy', 'matplotlib'], check=True)

import os, glob, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
warnings.filterwarnings('ignore')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Device: {device}')
if device.type == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# Device: cuda
# GPU: Tesla T4

# %%
# !cd ~ && pwd
#!cd ~ && mkdir btc_data
# !cd ~ && mkdir btc_lstm
# !cd ~ && df -h .
# Out:
# /root
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         113G   47G   66G  42% /

# %%
# ── Cell 2: Mount Google Drive ────────────────────────────────────────────
from google.colab import drive
drive.mount('/content/drive')

#!cd ~ && cd ./btc_data && tar xJvf /content/drive/MyDrive/btc_data.tar.xz
# !cd ~ && tar xJvf /content/drive/MyDrive/btc_data.tar.xz

drive.flush_and_unmount()

# ── CONFIGURE THESE ───────────────────────────────────────────────────────
DATA_DIR   = '/root/btc_data'  # folder with your CSV/CSV.GZ files
OUTPUT_DIR = '/root/btc_lstm'  # where to save model and charts
THRESHOLD  = 50.0    # USD — same as best XGBoost run
HORIZON    = 8       # bars ahead = 2 minutes
SEQ_LEN    = 32      # bars of history fed to LSTM = 8 minutes
BATCH_SIZE = 2048
EPOCHS     = 40
LR         = 1e-3
HIDDEN_DIM = 128
NUM_LAYERS = 2
DROPOUT    = 0.3
TRAIN_FRAC = 0.70    # chronological split
VAL_FRAC   = 0.15    # validation (early stopping)
# TEST_FRAC  = 0.15  # remainder used for backtest
# ─────────────────────────────────────────────────────────────────────────

os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f'Data dir:   {DATA_DIR}')
print(f'Output dir: {OUTPUT_DIR}')
# Out:
# Mounted at /content/drive
# btc_data/
# btc_data/out.odtgk.00380.251117.csv
# btc_data/out.odtgk.00313.251106.csv
# btc_data/out.pjhsr.00321.260122.csv
# btc_data/out.pjhsr.00284.260116.csv
# btc_data/out.zyzjh.00032.260315.csv
# btc_data/out.odtgk.00233.251023.csv
# btc_data/out.rzeac.00017.260624.csv
# btc_data/out.nsgpe.00524.260614.csv
# btc_data/out.odtgk.00405.251121.csv
# btc_data/out.mrfni.00086.260214.csv
# btc_data/out.odtgk.00331.251109.csv
# btc_data/out.rzeac.00006.260622.csv
# btc_data/out.pjhsr.00235.260107.csv
# btc_data/out.mrfni.00162.260227.csv
# btc_data/out.rzeac.00069.260703.csv
# btc_data/out.pjhsr.00022.251203.csv
# btc_data/out.odtgk.00399.251120.csv
# btc_data/out.pjhsr.00341.260125.csv
# btc_data/out.nsgpe.00121.260407.csv
# btc_data/out.nsgpe.00220.260423.csv
# btc_data/out.nsgpe.00002.260318.csv
# btc_data/out.nsgpe.00521.260613.csv
# btc_data/out.nsgpe.00390.260522.csv
# btc_data/out.pjhsr.00153.251225.csv
# btc_data/out.pjhsr.00116.251218.csv
# btc_data/out.nsgpe.00490.260608.csv
# btc_data/out.nsgpe.00125.260408.csv
# btc_data/out.mcxci.00001.260617.csv
# btc_data/out.nsgpe.00361.260517.csv
# btc_data/out.nsgpe.00375.260520.csv
# btc_data/out.nsgpe.00336.260513.csv
# btc_data/out.mrfni.00015.260202.csv
# btc_data/out.nsgpe.00443.260531.csv
# btc_data/out.odtgk.00285.251101.csv
# btc_data/out.pjhsr.00017.251202.csv
# btc_data/out.mrfni.00128.260221.csv
# btc_data/out.nsgpe.00344.260514.csv
# btc_data/out.nsgpe.00160.260413.csv
# btc_data/out.pjhsr.00028.251204.csv
# btc_data/out.mrfni.00013.260202.csv
# btc_data/out.nsgpe.00511.260611.csv
# btc_data/out.mcxci.00008.260619.csv
# btc_data/out.nsgpe.00193.260419.csv
# btc_data/out.pjhsr.00196.260101.csv
# btc_data/out.mrfni.00127.260221.csv
# btc_data/out.pjhsr.00053.251208.csv
# btc_data/out.odtgk.00159.251011.csv
# btc_data/out.pjhsr.00102.251216.csv
# btc_data/out.zyzjh.00018.260313.csv
# btc_data/out.nsgpe.00495.260609.csv
# btc_data/out.nsgpe.00513.260612.csv
# btc_data/out.odtgk.00391.251119.csv
# btc_data/out.odtgk.00406.251121.csv
# btc_data/out.odtgk.00018.250917.csv
# btc_data/out.odtgk.00260.251028.csv
# btc_data/out.nsgpe.00465.260604.csv
# btc_data/out.pjhsr.00227.260106.csv
# btc_data/out.mrfni.00018.260202.csv
# btc_data/out.mrfni.00103.260217.csv
# btc_data/out.odtgk.00230.251023.csv
# btc_data/out.nsgpe.00245.260428.csv
# btc_data/out.nsgpe.00280.260504.csv
# btc_data/out.odtgk.00397.251120.csv
# btc_data/out.nsgpe.00431.260529.csv
# btc_data/out.mrfni.00178.260302.csv
# btc_data/out.nsgpe.00042.260325.csv
# btc_data/out.pjhsr.00174.251228.csv
# btc_data/out.odtgk.00191.251016.csv
# btc_data/out.pjhsr.00150.251224.csv
# btc_data/out.nsgpe.00529.260615.csv
# btc_data/out.zyzjh.00011.260312.csv
# btc_data/out.nsgpe.00064.260328.csv
# btc_data/out.nsgpe.00326.260511.csv
# btc_data/out.odtgk.00229.251023.csv
# btc_data/out.nsgpe.00422.260528.csv
# btc_data/out.pjhsr.00088.251214.csv
# btc_data/out.nsgpe.00346.260515.csv
# btc_data/out.pjhsr.00066.251210.csv
# btc_data/out.mrfni.00173.260301.csv
# btc_data/out.pjhsr.00068.251210.csv
# btc_data/out.pjhsr.00012.251201.csv
# btc_data/out.nsgpe.00259.260430.csv
# btc_data/out.nsgpe.00342.260514.csv
# btc_data/out.pjhsr.00305.260119.csv
# btc_data/out.odtgk.00258.251028.csv
# btc_data/out.zyzjh.00007.260311.csv
# btc_data/out.nsgpe.00543.260617.csv
# btc_data/out.mrfni.00199.260305.csv
# btc_data/out.pjhsr.00276.260114.csv
# btc_data/out.rzeac.00066.260702.csv
# btc_data/out.nsgpe.00290.260505.csv
# btc_data/out.pjhsr.00168.251227.csv
# btc_data/out.mcxci.00002.260618.csv
# btc_data/out.nsgpe.00109.260405.csv
# btc_data/out.nsgpe.00393.260523.csv
# btc_data/out.pjhsr.00199.260101.csv
# btc_data/out.odtgk.00202.251018.csv
# btc_data/out.rzeac.00034.260627.csv
# btc_data/out.nsgpe.00082.260331.csv
# btc_data/out.nsgpe.00330.260512.csv
# btc_data/out.odtgk.00225.251022.csv
# btc_data/out.mrfni.00045.260207.csv
# btc_data/out.pjhsr.00031.251204.csv
# btc_data/out.odtgk.00016.250917.csv
# btc_data/out.pjhsr.00170.251228.csv
# btc_data/out.nsgpe.00188.260418.csv
# btc_data/out.nsgpe.00217.260423.csv
# btc_data/out.nsgpe.00224.260424.csv
# btc_data/out.nsgpe.00386.260521.csv
# btc_data/out.mrfni.00166.260228.csv
# btc_data/out.nsgpe.00071.260329.csv
# btc_data/out.pjhsr.00340.260125.csv
# btc_data/out.nsgpe.00171.260415.csv
# btc_data/out.odtgk.00138.251007.csv
# btc_data/out.nsgpe.00208.260421.csv
# btc_data/out.mrfni.00009.260201.csv
# btc_data/out.odtgk.00304.251104.csv
# btc_data/out.pjhsr.00057.251209.csv
# btc_data/out.mrfni.00119.260220.csv
# btc_data/out.nsgpe.00409.260525.csv
# btc_data/out.rzeac.00029.260626.csv
# btc_data/out.nsgpe.00392.260523.csv
# btc_data/out.pjhsr.00245.260109.csv
# btc_data/out.pjhsr.00135.251222.csv
# btc_data/out.odtgk.00425.251125.csv
# btc_data/out.pjhsr.00107.251217.csv
# btc_data/out.pjhsr.00230.260107.csv
# btc_data/out.mrfni.00069.260211.csv
# btc_data/out.nsgpe.00340.260514.csv
# btc_data/out.nsgpe.00264.260501.csv
# btc_data/out.odtgk.00434.251126.csv
# btc_data/out.mrfni.00130.260222.csv
# btc_data/out.pjhsr.00337.260125.csv
# btc_data/out.nsgpe.00372.260519.csv
# btc_data/out.mrfni.00079.260213.csv
# btc_data/out.nsgpe.00090.260402.csv
# btc_data/out.pjhsr.00316.260121.csv
# btc_data/out.nsgpe.00041.260324.csv
# btc_data/out.nsgpe.00273.260502.csv
# btc_data/out.mrfni.00110.260218.csv
# btc_data/out.odtgk.00089.250929.csv
# btc_data/out.mrfni.00000.260130.csv
# btc_data/out.nsgpe.00311.260509.csv
# btc_data/out.nsgpe.00136.260409.csv
# btc_data/out.nsgpe.00283.260504.csv
# btc_data/out.odtgk.00181.251015.csv
# btc_data/out.mcxci.00014.260620.csv
# btc_data/out.odtgk.00102.251001.csv
# btc_data/out.mcxci.00013.260619.csv
# btc_data/out.odtgk.00351.251112.csv
# btc_data/out.odtgk.00027.250919.csv
# btc_data/out.odtgk.00155.251010.csv
# btc_data/out.odtgk.00182.251015.csv
# btc_data/out.odtgk.00024.250918.csv
# btc_data/out.zyzjh.00003.260310.csv
# btc_data/out.odtgk.00282.251101.csv
# btc_data/out.mrfni.00185.260303.csv
# btc_data/out.nsgpe.00181.260417.csv
# btc_data/out.odtgk.00428.251125.csv
# btc_data/out.mrfni.00070.260212.csv
# btc_data/out.nsgpe.00320.260510.csv
# btc_data/out.pjhsr.00090.251214.csv
# btc_data/out.odtgk.00409.251122.csv
# btc_data/out.odtgk.00188.251016.csv
# btc_data/out.odtgk.00330.251109.csv
# btc_data/out.pjhsr.00351.260127.csv
# btc_data/out.odtgk.00433.251126.csv
# btc_data/out.odtgk.00293.251103.csv
# btc_data/out.odtgk.00121.251005.csv
# btc_data/out.nsgpe.00352.260516.csv
# btc_data/out.pjhsr.00190.251231.csv
# btc_data/out.nsgpe.00141.260410.csv
# btc_data/out.nsgpe.00289.260505.csv
# btc_data/out.nsgpe.00539.260616.csv
# btc_data/out.odtgk.00332.251109.csv
# btc_data/out.odtgk.00252.251027.csv
# btc_data/out.nsgpe.00080.260331.csv
# btc_data/out.mrfni.00141.260223.csv
# btc_data/out.pjhsr.00222.260105.csv
# btc_data/out.odtgk.00028.250919.csv
# btc_data/out.mrfni.00032.260205.csv
# btc_data/out.odtgk.00203.251018.csv
# btc_data/out.nsgpe.00282.260504.csv
# btc_data/out.nsgpe.00360.260517.csv
# btc_data/out.nsgpe.00017.260320.csv
# btc_data/out.odtgk.00236.251024.csv
# btc_data/out.odtgk.00139.251008.csv
# btc_data/out.mcxci.00000.260617.csv
# btc_data/out.pjhsr.00071.251211.csv
# btc_data/out.pjhsr.00308.260120.csv
# btc_data/out.mrfni.00048.260207.csv
# btc_data/out.mrfni.00024.260203.csv
# btc_data/out.nsgpe.00172.260415.csv
# btc_data/out.nsgpe.00118.260406.csv
# btc_data/out.mcxci.00010.260619.csv
# btc_data/out.pjhsr.00293.260117.csv
# btc_data/out.nsgpe.00507.260611.csv
# btc_data/out.nsgpe.00506.260611.csv
# btc_data/out.rzeac.00052.260630.csv
# btc_data/out.nsgpe.00200.260420.csv
# btc_data/out.odtgk.00324.251108.csv
# btc_data/out.odtgk.00020.250918.csv
# btc_data/out.zyzjh.00028.260315.csv
# btc_data/out.odtgk.00403.251121.csv
# btc_data/out.pjhsr.00207.260103.csv
# btc_data/out.zyzjh.00012.260312.csv
# btc_data/out.nsgpe.00036.260324.csv
# btc_data/out.odtgk.00015.250917.csv
# btc_data/out.nsgpe.00092.260402.csv
# btc_data/out.nsgpe.00371.260519.csv
# btc_data/out.nsgpe.00107.260405.csv
# btc_data/out.pjhsr.00291.260117.csv
# btc_data/out.pjhsr.00155.251225.csv
# btc_data/out.odtgk.00303.251104.csv
# btc_data/out.nsgpe.00284.260504.csv
# btc_data/out.rzeac.00054.260630.csv
# btc_data/out.pjhsr.00079.251212.csv
# btc_data/out.nsgpe.00192.260419.csv
# btc_data/out.nsgpe.00024.260321.csv
# btc_data/out.pjhsr.00298.260118.csv
# btc_data/out.mrfni.00176.260301.csv
# btc_data/out.pjhsr.00032.251204.csv
# btc_data/out.nsgpe.00149.260412.csv
# btc_data/out.odtgk.00349.251112.csv
# btc_data/out.nsgpe.00435.260530.csv
# btc_data/out.nsgpe.00315.260510.csv
# btc_data/out.nsgpe.00116.260406.csv
# btc_data/out.rzeac.00067.260703.csv
# btc_data/out.odtgk.00131.251006.csv
# btc_data/out.pjhsr.00198.260101.csv
# btc_data/out.nsgpe.00049.260326.csv
# btc_data/out.mrfni.00187.260303.csv
# btc_data/out.nsgpe.00487.260607.csv
# btc_data/out.odtgk.00002.250915.csv
# btc_data/out.nsgpe.00074.260330.csv
# btc_data/out.pjhsr.00302.260119.csv
# btc_data/out.pjhsr.00105.251217.csv
# btc_data/out.pjhsr.00099.251216.csv
# btc_data/out.pjhsr.00325.260123.csv
# btc_data/out.mrfni.00106.260218.csv
# btc_data/out.odtgk.00200.251018.csv
# btc_data/out.odtgk.00389.251119.csv
# btc_data/out.nsgpe.00501.260610.csv
# btc_data/out.pjhsr.00197.260101.csv
# btc_data/out.pjhsr.00109.251217.csv
# btc_data/out.pjhsr.00052.251208.csv
# btc_data/out.odtgk.00328.251108.csv
# btc_data/out.odtgk.00411.251122.csv
# btc_data/out.mrfni.00062.260210.csv
# btc_data/out.zyzjh.00001.260310.csv
# btc_data/out.odtgk.00325.251108.csv
# btc_data/out.mrfni.00160.260227.csv
# btc_data/out.mrfni.00151.260225.csv
# btc_data/out.pjhsr.00139.251222.csv
# btc_data/out.rzeac.00031.260626.csv
# btc_data/out.odtgk.00345.251111.csv
# btc_data/out.nsgpe.00426.260528.csv
# btc_data/out.nsgpe.00253.260429.csv
# btc_data/out.odtgk.00176.251014.csv
# btc_data/out.pjhsr.00299.260118.csv
# btc_data/out.pjhsr.00318.260121.csv
# btc_data/out.odtgk.00097.251001.csv
# btc_data/out.nsgpe.00134.260409.csv
# btc_data/out.zyzjh.00017.260313.csv
# btc_data/out.odtgk.00257.251028.csv
# btc_data/out.odtgk.00334.251109.csv
# btc_data/out.odtgk.00276.251031.csv
# btc_data/out.nsgpe.00444.260531.csv
# btc_data/out.odtgk.00115.251004.csv
# btc_data/out.odtgk.00135.251007.csv
# btc_data/out.mrfni.00169.260228.csv
# btc_data/out.pjhsr.00092.251214.csv
# btc_data/out.mrfni.00200.260305.csv
# btc_data/out.nsgpe.00029.260322.csv
# btc_data/out.nsgpe.00219.260423.csv
# btc_data/out.nsgpe.00175.260416.csv
# btc_data/out.nsgpe.00345.260515.csv
# btc_data/out.odtgk.00061.250925.csv
# btc_data/out.zyzjh.00005.260311.csv
# btc_data/out.mrfni.00121.260220.csv
# btc_data/out.nsgpe.00011.260319.csv
# btc_data/out.odtgk.00289.251102.csv
# btc_data/out.pjhsr.00205.260102.csv
# btc_data/out.nsgpe.00099.260403.csv
# btc_data/out.nsgpe.00221.260424.csv
# btc_data/out.nsgpe.00127.260408.csv
# btc_data/out.nsgpe.00401.260524.csv
# btc_data/out.pjhsr.00127.251220.csv
# btc_data/out.odtgk.00327.251108.csv
# btc_data/out.mcxci.00017.260620.csv
# btc_data/out.pjhsr.00093.251215.csv
# btc_data/out.mrfni.00184.260303.csv
# btc_data/out.pjhsr.00015.251202.csv
# btc_data/out.odtgk.00222.251022.csv
# btc_data/out.odtgk.00251.251027.csv
# btc_data/out.rzeac.00027.260626.csv
# btc_data/out.odtgk.00350.251112.csv
# btc_data/out.pjhsr.00283.260116.csv
# btc_data/out.nsgpe.00295.260506.csv
# btc_data/out.nsgpe.00535.260616.csv
# btc_data/out.odtgk.00277.251031.csv
# btc_data/out.pjhsr.00144.251223.csv
# btc_data/out.pjhsr.00133.251221.csv
# btc_data/out.odtgk.00179.251014.csv
# btc_data/out.nsgpe.00000.260317.csv
# btc_data/out.nsgpe.00227.260425.csv
# btc_data/out.nsgpe.00430.260529.csv
# btc_data/out.pjhsr.00009.251201.csv
# btc_data/out.pjhsr.00141.251223.csv
# btc_data/out.pjhsr.00221.260105.csv
# btc_data/out.mrfni.00056.260209.csv
# btc_data/out.nsgpe.00237.260426.csv
# btc_data/out.pjhsr.00085.251213.csv
# btc_data/out.odtgk.00420.251124.csv
# btc_data/out.nsgpe.00120.260407.csv
# btc_data/out.odtgk.00009.250916.csv
# btc_data/out.pjhsr.00077.251212.csv
# btc_data/out.nsgpe.00104.260404.csv
# btc_data/out.nsgpe.00117.260406.csv
# btc_data/out.nsgpe.00198.260420.csv
# btc_data/out.odtgk.00152.251010.csv
# btc_data/out.pjhsr.00120.251219.csv
# btc_data/out.odtgk.00090.250929.csv
# btc_data/out.pjhsr.00261.260112.csv
# btc_data/out.pjhsr.00281.260115.csv
# btc_data/out.odtgk.00134.251007.csv
# btc_data/out.zyzjh.00026.260314.csv
# btc_data/out.mrfni.00190.260304.csv
# btc_data/out.odtgk.00193.251017.csv
# btc_data/out.odtgk.00296.251103.csv
# btc_data/out.odtgk.00386.251118.csv
# btc_data/out.rzeac.00011.260623.csv
# btc_data/out.nsgpe.00164.260414.csv
# btc_data/out.nsgpe.00406.260525.csv
# btc_data/out.pjhsr.00034.251205.csv
# btc_data/out.pjhsr.00106.251217.csv
# btc_data/out.mrfni.00014.260202.csv
# btc_data/out.pjhsr.00176.251229.csv
# btc_data/out.pjhsr.00179.251229.csv
# btc_data/out.rzeac.00048.260629.csv
# btc_data/out.nsgpe.00162.260414.csv
# btc_data/out.mrfni.00123.260220.csv
# btc_data/out.odtgk.00275.251031.csv
# btc_data/out.odtgk.00178.251014.csv
# btc_data/out.zyzjh.00021.260313.csv
# btc_data/out.pjhsr.00343.260126.csv
# btc_data/out.nsgpe.00148.260411.csv
# btc_data/out.rzeac.00005.260622.csv
# btc_data/out.nsgpe.00532.260615.csv
# btc_data/out.nsgpe.00473.260605.csv
# btc_data/out.pjhsr.00003.251130.csv
# btc_data/out.nsgpe.00275.260503.csv
# btc_data/out.pjhsr.00292.260117.csv
# btc_data/out.odtgk.00366.251115.csv
# btc_data/out.odtgk.00111.251003.csv
# btc_data/out.pjhsr.00164.251227.csv
# btc_data/out.pjhsr.00237.260108.csv
# btc_data/out.nsgpe.00174.260416.csv
# btc_data/out.nsgpe.00114.260406.csv
# btc_data/out.mrfni.00101.260217.csv
# btc_data/out.pjhsr.00243.260109.csv
# btc_data/out.pjhsr.00265.260112.csv
# btc_data/out.nsgpe.00471.260605.csv
# btc_data/out.nsgpe.00241.260427.csv
# btc_data/out.pjhsr.00145.251223.csv
# btc_data/out.pjhsr.00350.260127.csv
# btc_data/out.nsgpe.00423.260528.csv
# btc_data/out.mrfni.00111.260218.csv
# btc_data/out.odtgk.00036.250920.csv
# btc_data/out.nsgpe.00438.260530.csv
# btc_data/out.odtgk.00211.251020.csv
# btc_data/out.odtgk.00436.251126.csv
# btc_data/out.pjhsr.00342.260125.csv
# btc_data/out.rzeac.00013.260623.csv
# btc_data/out.nsgpe.00503.260610.csv
# btc_data/out.nsgpe.00421.260527.csv
# btc_data/out.pjhsr.00166.251227.csv
# btc_data/out.odtgk.00373.251116.csv
# btc_data/out.odtgk.00241.251025.csv
# btc_data/out.nsgpe.00226.260425.csv
# btc_data/out.rzeac.00044.260629.csv
# btc_data/out.odtgk.00314.251106.csv
# btc_data/out.zyzjh.00016.260313.csv
# btc_data/out.pjhsr.00108.251217.csv
# btc_data/out.mrfni.00182.260302.csv
# btc_data/out.nsgpe.00415.260526.csv
# btc_data/out.nsgpe.00485.260607.csv
# btc_data/out.nsgpe.00296.260506.csv
# btc_data/out.nsgpe.00530.260615.csv
# btc_data/out.nsgpe.00154.260412.csv
# btc_data/out.odtgk.00294.251103.csv
# btc_data/out.odtgk.00410.251122.csv
# btc_data/out.pjhsr.00333.260124.csv
# btc_data/out.odtgk.00095.250930.csv
# btc_data/out.pjhsr.00007.251130.csv
# btc_data/out.odtgk.00137.251007.csv
# btc_data/out.odtgk.00108.251002.csv
# btc_data/out.odtgk.00014.250917.csv
# btc_data/out.pjhsr.00134.251222.csv
# btc_data/out.odtgk.00295.251103.csv
# btc_data/out.mrfni.00099.260216.csv
# btc_data/out.odtgk.00290.251102.csv
# btc_data/out.nsgpe.00194.260419.csv
# btc_data/out.odtgk.00322.251107.csv
# btc_data/out.mrfni.00025.260204.csv
# btc_data/out.nsgpe.00366.260518.csv
# btc_data/out.mrfni.00155.260226.csv
# btc_data/out.pjhsr.00087.251214.csv
# btc_data/out.pjhsr.00123.251220.csv
# btc_data/out.odtgk.00058.250924.csv
# btc_data/out.nsgpe.00302.260507.csv
# btc_data/out.odtgk.00204.251019.csv
# btc_data/out.odtgk.00206.251019.csv
# btc_data/out.odtgk.00186.251016.csv
# btc_data/out.nsgpe.00335.260513.csv
# btc_data/out.odtgk.00342.251111.csv
# btc_data/out.odtgk.00237.251024.csv
# btc_data/out.mrfni.00008.260201.csv
# btc_data/out.rzeac.00010.260623.csv
# btc_data/out.nsgpe.00105.260404.csv
# btc_data/out.pjhsr.00253.260110.csv
# btc_data/out.nsgpe.00250.260429.csv
# btc_data/out.mrfni.00057.260209.csv
# btc_data/out.odtgk.00286.251101.csv
# btc_data/out.nsgpe.00008.260319.csv
# btc_data/out.nsgpe.00126.260408.csv
# btc_data/out.odtgk.00054.250923.csv
# btc_data/out.odtgk.00052.250923.csv
# btc_data/out.pjhsr.00025.251203.csv
# btc_data/out.nsgpe.00510.260611.csv
# btc_data/out.pjhsr.00289.260117.csv
# btc_data/out.pjhsr.00023.251203.csv
# btc_data/out.nsgpe.00447.260601.csv
# btc_data/out.odtgk.00141.251008.csv
# btc_data/out.odtgk.00057.250924.csv
# btc_data/out.mrfni.00021.260203.csv
# btc_data/out.nsgpe.00190.260418.csv
# btc_data/out.zyzjh.00025.260314.csv
# btc_data/out.pjhsr.00086.251213.csv
# btc_data/out.odtgk.00311.251106.csv
# btc_data/out.odtgk.00401.251121.csv
# btc_data/out.odtgk.00109.251003.csv
# btc_data/out.odtgk.00124.251005.csv
# btc_data/out.odtgk.00269.251030.csv
# btc_data/out.nsgpe.00028.260322.csv
# btc_data/out.pjhsr.00272.260114.csv
# btc_data/out.pjhsr.00266.260113.csv
# btc_data/out.odtgk.00369.251115.csv
# btc_data/out.odtgk.00007.250916.csv
# btc_data/out.odtgk.00400.251120.csv
# btc_data/out.mrfni.00107.260218.csv
# btc_data/out.pjhsr.00026.251203.csv
# btc_data/out.nsgpe.00281.260504.csv
# btc_data/out.odtgk.00012.250916.csv
# btc_data/out.odtgk.00117.251004.csv
# btc_data/out.nsgpe.00001.260318.csv
# btc_data/out.pjhsr.00084.251213.csv
# btc_data/out.nsgpe.00242.260427.csv
# btc_data/out.pjhsr.00229.260106.csv
# btc_data/out.mrfni.00202.260306.csv
# btc_data/out.nsgpe.00178.260416.csv
# btc_data/out.odtgk.00372.251116.csv
# btc_data/out.nsgpe.00313.260509.csv
# btc_data/out.nsgpe.00318.260510.csv
# btc_data/out.nsgpe.00207.260421.csv
# btc_data/out.mrfni.00150.260225.csv
# btc_data/out.pjhsr.00277.260115.csv
# btc_data/out.nsgpe.00518.260613.csv
# btc_data/out.nsgpe.00189.260418.csv
# btc_data/out.pjhsr.00046.251207.csv
# btc_data/out.pjhsr.00234.260107.csv
# btc_data/out.nsgpe.00262.260501.csv
# btc_data/out.pjhsr.00013.251201.csv
# btc_data/out.nsgpe.00075.260330.csv
# btc_data/out.rzeac.00032.260627.csv
# btc_data/out.pjhsr.00064.251210.csv
# btc_data/out.odtgk.00281.251101.csv
# btc_data/out.odtgk.00074.250927.csv
# btc_data/out.mrfni.00168.260228.csv
# btc_data/out.pjhsr.00074.251211.csv
# btc_data/out.mrfni.00138.260223.csv
# btc_data/out.nsgpe.00108.260405.csv
# btc_data/out.pjhsr.00136.251222.csv
# btc_data/out.odtgk.00228.251023.csv
# btc_data/out.mrfni.00157.260226.csv
# btc_data/out.nsgpe.00299.260507.csv
# btc_data/out.odtgk.00127.251006.csv
# btc_data/out.nsgpe.00012.260319.csv
# btc_data/out.nsgpe.00057.260327.csv
# btc_data/out.nsgpe.00309.260509.csv
# btc_data/out.pjhsr.00182.251230.csv
# btc_data/out.nsgpe.00437.260530.csv
# btc_data/out.odtgk.00157.251011.csv
# btc_data/out.zyzjh.00029.260315.csv
# btc_data/out.odtgk.00023.250918.csv
# btc_data/out.nsgpe.00467.260604.csv
# btc_data/out.odtgk.00221.251021.csv
# btc_data/out.nsgpe.00538.260616.csv
# btc_data/out.odtgk.00301.251104.csv
# btc_data/out.odtgk.00310.251105.csv
# btc_data/out.odtgk.00374.251116.csv
# btc_data/out.nsgpe.00021.260321.csv
# btc_data/out.pjhsr.00295.260118.csv
# btc_data/out.nsgpe.00337.260513.csv
# btc_data/out.zyzjh.00022.260314.csv
# btc_data/out.pjhsr.00020.251202.csv
# btc_data/out.nsgpe.00173.260416.csv
# btc_data/out.nsgpe.00211.260422.csv
# btc_data/out.pjhsr.00255.260111.csv
# btc_data/out.pjhsr.00210.260103.csv
# btc_data/out.odtgk.00382.251117.csv
# btc_data/out.odtgk.00384.251118.csv
# btc_data/out.pjhsr.00195.260101.csv
# btc_data/out.pjhsr.00315.260121.csv
# btc_data/out.nsgpe.00343.260514.csv
# btc_data/out.nsgpe.00470.260605.csv
# btc_data/out.nsgpe.00137.260410.csv
# btc_data/out.pjhsr.00296.260118.csv
# btc_data/out.nsgpe.00424.260528.csv
# btc_data/out.nsgpe.00015.260320.csv
# btc_data/out.nsgpe.00405.260525.csv
# btc_data/out.odtgk.00080.250928.csv
# btc_data/out.nsgpe.00268.260502.csv
# btc_data/out.pjhsr.00138.251222.csv
# btc_data/out.rzeac.00053.260630.csv
# btc_data/out.mrfni.00191.260304.csv
# btc_data/out.pjhsr.00119.251219.csv
# btc_data/out.odtgk.00070.250926.csv
# btc_data/out.nsgpe.00534.260615.csv
# btc_data/out.rzeac.00020.260625.csv
# btc_data/out.zyzjh.00006.260311.csv
# btc_data/out.nsgpe.00379.260520.csv
# btc_data/out.pjhsr.00223.260105.csv
# btc_data/out.odtgk.00412.251122.csv
# btc_data/out.nsgpe.00068.260329.csv
# btc_data/out.mrfni.00142.260224.csv
# btc_data/out.nsgpe.00428.260529.csv
# btc_data/out.mcxci.00006.260618.csv
# btc_data/out.nsgpe.00347.260515.csv
# btc_data/out.nsgpe.00009.260319.csv
# btc_data/out.pjhsr.00125.251220.csv
# btc_data/out.pjhsr.00334.260124.csv
# btc_data/out.odtgk.00214.251020.csv
# btc_data/out.rzeac.00059.260701.csv
# btc_data/out.odtgk.00093.250930.csv
# btc_data/out.odtgk.00347.251112.csv
# btc_data/out.pjhsr.00244.260109.csv
# btc_data/out.rzeac.00003.260622.csv
# btc_data/out.odtgk.00173.251013.csv
# btc_data/out.mrfni.00065.260211.csv
# btc_data/out.nsgpe.00142.260410.csv
# btc_data/out.odtgk.00227.251022.csv
# btc_data/out.pjhsr.00201.260102.csv
# btc_data/out.nsgpe.00054.260327.csv
# btc_data/out.odtgk.00404.251121.csv
# btc_data/out.nsgpe.00145.260411.csv
# btc_data/out.pjhsr.00004.251130.csv
# btc_data/out.odtgk.00143.251008.csv
# btc_data/out.nsgpe.00135.260409.csv
# btc_data/out.nsgpe.00478.260606.csv
# btc_data/out.odtgk.00006.250915.csv
# btc_data/out.odtgk.00352.251112.csv
# btc_data/out.odtgk.00166.251012.csv
# btc_data/out.nsgpe.00249.260428.csv
# btc_data/out.pjhsr.00336.260124.csv
# btc_data/out.pjhsr.00126.251220.csv
# btc_data/out.pjhsr.00000.251129.csv
# btc_data/out.pjhsr.00258.260111.csv
# btc_data/out.odtgk.00274.251030.csv
# btc_data/out.mcxci.00009.260619.csv
# btc_data/out.pjhsr.00163.251226.csv
# btc_data/out.nsgpe.00451.260601.csv
# btc_data/out.nsgpe.00052.260326.csv
# btc_data/out.nsgpe.00061.260328.csv
# btc_data/out.nsgpe.00153.260412.csv
# btc_data/out.nsgpe.00434.260530.csv
# btc_data/out.pjhsr.00326.260123.csv
# btc_data/out.nsgpe.00459.260603.csv
# btc_data/out.nsgpe.00331.260512.csv
# btc_data/out.nsgpe.00032.260323.csv
# btc_data/out.nsgpe.00060.260328.csv
# btc_data/out.nsgpe.00440.260531.csv
# btc_data/out.pjhsr.00191.251231.csv
# btc_data/out.rzeac.00071.260703.csv
# btc_data/out.nsgpe.00355.260516.csv
# btc_data/out.odtgk.00037.250921.csv
# btc_data/out.odtgk.00060.250924.csv
# btc_data/out.nsgpe.00349.260515.csv
# btc_data/out.nsgpe.00370.260519.csv
# btc_data/out.pjhsr.00156.251225.csv
# btc_data/out.odtgk.00321.251107.csv
# btc_data/out.mrfni.00011.260201.csv
# btc_data/out.rzeac.00014.260624.csv
# btc_data/out.mcxci.00019.260621.csv
# btc_data/out.odtgk.00326.251108.csv
# btc_data/out.nsgpe.00123.260407.csv
# btc_data/out.rzeac.00009.260623.csv
# btc_data/out.mrfni.00049.260208.csv
# btc_data/out.odtgk.00388.251118.csv
# btc_data/out.nsgpe.00225.260424.csv
# btc_data/out.mrfni.00131.260222.csv
# btc_data/out.pjhsr.00183.251230.csv
# btc_data/out.nsgpe.00325.260511.csv
# btc_data/out.pjhsr.00130.251221.csv
# btc_data/out.nsgpe.00373.260519.csv
# btc_data/out.odtgk.00082.250928.csv
# btc_data/out.odtgk.00393.251119.csv
# btc_data/out.odtgk.00010.250916.csv
# btc_data/out.pjhsr.00332.260124.csv
# btc_data/out.nsgpe.00077.260330.csv
# btc_data/out.nsgpe.00391.260522.csv
# btc_data/out.odtgk.00083.250928.csv
# btc_data/out.odtgk.00055.250924.csv
# btc_data/out.odtgk.00368.251115.csv
# btc_data/out.nsgpe.00441.260531.csv
# btc_data/out.nsgpe.00475.260605.csv
# btc_data/out.rzeac.00033.260627.csv
# btc_data/out.odtgk.00209.251019.csv
# btc_data/out.nsgpe.00265.260501.csv
# btc_data/out.nsgpe.00403.260524.csv
# btc_data/out.nsgpe.00230.260425.csv
# btc_data/out.nsgpe.00182.260417.csv
# btc_data/out.pjhsr.00307.260120.csv
# btc_data/out.nsgpe.00027.260322.csv
# btc_data/out.nsgpe.00256.260430.csv
# btc_data/out.pjhsr.00225.260106.csv
# btc_data/out.mrfni.00090.260215.csv
# btc_data/out.mrfni.00097.260216.csv
# btc_data/out.rzeac.00063.260702.csv
# btc_data/out.odtgk.00119.251004.csv
# btc_data/out.mrfni.00122.260220.csv
# btc_data/out.pjhsr.00301.260119.csv
# btc_data/out.pjhsr.00232.260107.csv
# btc_data/out.nsgpe.00497.260609.csv
# btc_data/out.pjhsr.00238.260108.csv
# btc_data/out.mcxci.00016.260620.csv
# btc_data/out.nsgpe.00231.260425.csv
# btc_data/out.odtgk.00253.251027.csv
# btc_data/out.rzeac.00024.260625.csv
# btc_data/out.nsgpe.00420.260527.csv
# btc_data/out.nsgpe.00152.260412.csv
# btc_data/out.nsgpe.00056.260327.csv
# btc_data/out.pjhsr.00177.251229.csv
# btc_data/out.nsgpe.00457.260602.csv
# btc_data/out.nsgpe.00494.260609.csv
# btc_data/out.mrfni.00196.260305.csv
# btc_data/out.odtgk.00343.251111.csv
# btc_data/out.nsgpe.00364.260518.csv
# btc_data/out.nsgpe.00209.260422.csv
# btc_data/out.nsgpe.00085.260401.csv
# btc_data/out.odtgk.00387.251118.csv
# btc_data/out.rzeac.00004.260622.csv
# btc_data/out.pjhsr.00279.260115.csv
# btc_data/out.mrfni.00167.260228.csv
# btc_data/out.nsgpe.00442.260531.csv
# btc_data/out.pjhsr.00254.260111.csv
# btc_data/out.pjhsr.00219.260105.csv
# btc_data/out.nsgpe.00332.260512.csv
# btc_data/out.odtgk.00039.250921.csv
# btc_data/out.pjhsr.00274.260114.csv
# btc_data/out.mrfni.00188.260303.csv
# btc_data/out.odtgk.00429.251125.csv
# btc_data/out.odtgk.00031.250920.csv
# btc_data/out.mrfni.00094.260216.csv
# btc_data/out.nsgpe.00522.260613.csv
# btc_data/out.odtgk.00073.250927.csv
# btc_data/out.pjhsr.00124.251220.csv
# btc_data/out.rzeac.00016.260624.csv
# btc_data/out.mrfni.00075.260212.csv
# btc_data/out.pjhsr.00122.251219.csv
# btc_data/out.odtgk.00156.251011.csv
# btc_data/out.pjhsr.00294.260117.csv
# btc_data/out.rzeac.00023.260625.csv
# btc_data/out.mrfni.00143.260224.csv
# btc_data/out.pjhsr.00058.251209.csv
# btc_data/out.mrfni.00137.260223.csv
# btc_data/out.mrfni.00102.260217.csv
# btc_data/out.nsgpe.00096.260403.csv
# btc_data/out.nsgpe.00338.260513.csv
# btc_data/out.nsgpe.00322.260511.csv
# btc_data/out.nsgpe.00384.260521.csv
# btc_data/out.odtgk.00335.251110.csv
# btc_data/out.pjhsr.00171.251228.csv
# btc_data/out.mrfni.00082.260214.csv
# btc_data/out.nsgpe.00119.260407.csv
# btc_data/out.odtgk.00353.251113.csv
# btc_data/out.nsgpe.00458.260603.csv
# btc_data/out.mrfni.00154.260226.csv
# btc_data/out.mrfni.00042.260206.csv
# btc_data/out.nsgpe.00252.260429.csv
# btc_data/out.odtgk.00205.251019.csv
# btc_data/out.mrfni.00192.260304.csv
# btc_data/out.pjhsr.00329.260123.csv
# btc_data/out.nsgpe.00285.260505.csv
# btc_data/out.zyzjh.00002.260310.csv
# btc_data/out.odtgk.00085.250929.csv
# btc_data/out.odtgk.00361.251114.csv
# btc_data/out.odtgk.00365.251115.csv
# btc_data/out.odtgk.00243.251025.csv
# btc_data/out.mrfni.00198.260305.csv
# btc_data/out.mrfni.00145.260224.csv
# btc_data/out.nsgpe.00450.260601.csv
# btc_data/out.nsgpe.00277.260503.csv
# btc_data/out.nsgpe.00402.260524.csv
# btc_data/out.nsgpe.00328.260512.csv
# btc_data/out.odtgk.00145.251009.csv
# btc_data/out.nsgpe.00500.260610.csv
# btc_data/out.nsgpe.00488.260608.csv
# btc_data/out.odtgk.00122.251005.csv
# btc_data/out.mrfni.00163.260227.csv
# btc_data/out.nsgpe.00334.260513.csv
# btc_data/out.mrfni.00063.260210.csv
# btc_data/out.nsgpe.00065.260328.csv
# btc_data/out.pjhsr.00075.251212.csv
# btc_data/out.nsgpe.00480.260606.csv
# btc_data/out.nsgpe.00257.260430.csv
# btc_data/out.nsgpe.00404.260525.csv
# btc_data/out.nsgpe.00098.260403.csv
# btc_data/out.odtgk.00339.251110.csv
# btc_data/out.rzeac.00065.260702.csv
# btc_data/out.rzeac.00000.260621.csv
# btc_data/out.pjhsr.00160.251226.csv
# btc_data/out.nsgpe.00502.260610.csv
# btc_data/out.odtgk.00144.251009.csv
# btc_data/out.nsgpe.00376.260520.csv
# btc_data/out.pjhsr.00297.260118.csv
# btc_data/out.rzeac.00018.260624.csv
# btc_data/out.pjhsr.00059.251209.csv
# btc_data/out.mrfni.00091.260215.csv
# btc_data/out.nsgpe.00308.260508.csv
# btc_data/out.odtgk.00375.251116.csv
# btc_data/out.nsgpe.00276.260503.csv
# btc_data/out.nsgpe.00131.260409.csv
# btc_data/out.odtgk.00212.251020.csv
# btc_data/out.pjhsr.00151.251224.csv
# btc_data/out.pjhsr.00110.251217.csv
# btc_data/out.nsgpe.00410.260526.csv
# btc_data/out.odtgk.00088.250929.csv
# btc_data/out.pjhsr.00251.260110.csv
# btc_data/out.odtgk.00302.251104.csv
# btc_data/out.odtgk.00142.251008.csv
# btc_data/out.nsgpe.00266.260501.csv
# btc_data/out.odtgk.00319.251107.csv
# btc_data/out.pjhsr.00076.251212.csv
# btc_data/out.rzeac.00001.260621.csv
# btc_data/out.nsgpe.00307.260508.csv
# btc_data/out.nsgpe.00213.260422.csv
# btc_data/out.odtgk.00423.251124.csv
# btc_data/out.odtgk.00167.251012.csv
# btc_data/out.pjhsr.00338.260125.csv
# btc_data/out.mcxci.00012.260619.csv
# btc_data/out.odtgk.00171.251013.csv
# btc_data/out.pjhsr.00310.260120.csv
# btc_data/out.odtgk.00266.251029.csv
# btc_data/out.nsgpe.00248.260428.csv
# btc_data/out.pjhsr.00355.260128.csv
# btc_data/out.nsgpe.00168.260415.csv
# btc_data/out.nsgpe.00385.260521.csv
# btc_data/out.nsgpe.00023.260321.csv
# btc_data/out.mrfni.00109.260218.csv
# btc_data/out.rzeac.00026.260626.csv
# btc_data/out.mrfni.00164.260227.csv
# btc_data/out.pjhsr.00050.251207.csv
# btc_data/out.nsgpe.00066.260329.csv
# btc_data/out.mrfni.00115.260219.csv
# btc_data/out.mrfni.00061.260210.csv
# btc_data/out.pjhsr.00311.260120.csv
# btc_data/out.odtgk.00116.251004.csv
# btc_data/out.nsgpe.00301.260507.csv
# btc_data/out.mrfni.00030.260204.csv
# btc_data/out.nsgpe.00492.260608.csv
# btc_data/out.nsgpe.00323.260511.csv
# btc_data/out.mrfni.00083.260214.csv
# btc_data/out.mrfni.00165.260227.csv
# btc_data/out.pjhsr.00352.260127.csv
# btc_data/out.pjhsr.00356.260128.csv
# btc_data/out.mrfni.00016.260202.csv
# btc_data/out.mrfni.00047.260207.csv
# btc_data/out.odtgk.00426.251125.csv
# btc_data/out.nsgpe.00240.260427.csv
# btc_data/out.nsgpe.00512.260612.csv
# btc_data/out.mrfni.00100.260217.csv
# btc_data/out.rzeac.00035.260627.csv
# btc_data/out.odtgk.00272.251030.csv
# btc_data/out.odtgk.00363.251114.csv
# btc_data/out.odtgk.00050.250923.csv
# btc_data/out.wiccu.00000.250914.csv
# btc_data/out.rzeac.00041.260628.csv
# btc_data/out.odtgk.00044.250922.csv
# btc_data/out.pjhsr.00270.260113.csv
# btc_data/out.nsgpe.00050.260326.csv
# btc_data/out.mrfni.00175.260301.csv
# btc_data/out.nsgpe.00062.260328.csv
# btc_data/out.nsgpe.00161.260414.csv
# btc_data/out.nsgpe.00531.260615.csv
# btc_data/out.rzeac.00050.260630.csv
# btc_data/out.nsgpe.00089.260401.csv
# btc_data/out.pjhsr.00185.251230.csv
# btc_data/out.pjhsr.00306.260119.csv
# btc_data/out.pjhsr.00214.260104.csv
# btc_data/out.rzeac.00060.260701.csv
# btc_data/out.odtgk.00273.251030.csv
# btc_data/out.odtgk.00346.251111.csv
# btc_data/out.odtgk.00149.251009.csv
# btc_data/out.odtgk.00383.251118.csv
# btc_data/out.odtgk.00123.251005.csv
# btc_data/out.pjhsr.00231.260107.csv
# btc_data/out.nsgpe.00069.260329.csv
# btc_data/out.mcxci.00003.260618.csv
# btc_data/out.pjhsr.00054.251208.csv
# btc_data/out.odtgk.00125.251005.csv
# btc_data/out.mrfni.00053.260209.csv
# btc_data/out.mrfni.00195.260304.csv
# btc_data/out.rzeac.00051.260630.csv
# btc_data/out.nsgpe.00147.260411.csv
# btc_data/out.odtgk.00022.250918.csv
# btc_data/out.nsgpe.00031.260323.csv
# btc_data/out.nsgpe.00413.260526.csv
# btc_data/out.nsgpe.00464.260604.csv
# btc_data/out.odtgk.00246.251026.csv
# btc_data/out.odtgk.00008.250916.csv
# btc_data/out.odtgk.00213.251020.csv
# btc_data/out.nsgpe.00476.260606.csv
# btc_data/out.pjhsr.00239.260108.csv
# btc_data/out.pjhsr.00048.251207.csv
# btc_data/out.odtgk.00042.250921.csv
# btc_data/out.odtgk.00396.251120.csv
# btc_data/out.pjhsr.00184.251230.csv
# btc_data/out.pjhsr.00233.260107.csv
# btc_data/out.nsgpe.00086.260401.csv
# btc_data/out.nsgpe.00246.260428.csv
# btc_data/out.odtgk.00153.251010.csv
# btc_data/out.nsgpe.00272.260502.csv
# btc_data/out.pjhsr.00100.251216.csv
# btc_data/out.nsgpe.00479.260606.csv
# btc_data/out.pjhsr.00194.260101.csv
# btc_data/out.nsgpe.00079.260331.csv
# btc_data/out.pjhsr.00128.251220.csv
# btc_data/out.odtgk.00378.251117.csv
# btc_data/out.pjhsr.00098.251215.csv
# btc_data/out.nsgpe.00201.260420.csv
# btc_data/out.pjhsr.00282.260115.csv
# btc_data/out.nsgpe.00321.260511.csv
# btc_data/out.rzeac.00056.260701.csv
# btc_data/out.rzeac.00002.260622.csv
# btc_data/out.nsgpe.00167.260415.csv
# btc_data/out.nsgpe.00026.260322.csv
# btc_data/out.mrfni.00071.260212.csv
# btc_data/out.pjhsr.00204.260102.csv
# btc_data/out.mrfni.00204.260307.csv
# btc_data/out.pjhsr.00248.260110.csv
# btc_data/out.odtgk.00239.251024.csv
# btc_data/out.rzeac.00039.260628.csv
# btc_data/out.odtgk.00105.251002.csv
# btc_data/out.nsgpe.00445.260531.csv
# btc_data/out.nsgpe.00454.260602.csv
# btc_data/out.nsgpe.00045.260325.csv
# btc_data/out.odtgk.00359.251114.csv
# btc_data/out.nsgpe.00263.260501.csv
# btc_data/out.pjhsr.00062.251209.csv
# btc_data/out.nsgpe.00515.260612.csv
# btc_data/out.pjhsr.00186.251230.csv
# btc_data/out.odtgk.00163.251012.csv
# btc_data/out.pjhsr.00348.260126.csv
# btc_data/out.nsgpe.00232.260426.csv
# btc_data/out.odtgk.00075.250927.csv
# btc_data/out.odtgk.00003.250915.csv
# btc_data/out.nsgpe.00455.260602.csv
# btc_data/out.nsgpe.00088.260401.csv
# btc_data/out.pjhsr.00161.251226.csv
# btc_data/out.rzeac.00064.260702.csv
# btc_data/out.nsgpe.00169.260415.csv
# btc_data/out.pjhsr.00173.251228.csv
# btc_data/out.odtgk.00318.251107.csv
# btc_data/out.pjhsr.00175.251228.csv
# btc_data/out.mrfni.00170.260228.csv
# btc_data/out.pjhsr.00192.251231.csv
# btc_data/out.odtgk.00298.251103.csv
# btc_data/out.odtgk.00177.251014.csv
# btc_data/out.pjhsr.00322.260122.csv
# btc_data/out.mrfni.00033.260205.csv
# btc_data/out.pjhsr.00030.251204.csv
# btc_data/out.pjhsr.00216.260104.csv
# btc_data/out.pjhsr.00241.260108.csv
# btc_data/out.pjhsr.00154.251225.csv
# btc_data/out.nsgpe.00186.260418.csv
# btc_data/out.odtgk.00232.251023.csv
# btc_data/out.mrfni.00085.260214.csv
# btc_data/out.nsgpe.00411.260526.csv
# btc_data/out.nsgpe.00293.260506.csv
# btc_data/out.odtgk.00379.251117.csv
# btc_data/out.odtgk.00033.250920.csv
# btc_data/out.zyzjh.00030.260315.csv
# btc_data/out.nsgpe.00448.260601.csv
# btc_data/out.mrfni.00112.260219.csv
# btc_data/out.nsgpe.00388.260522.csv
# btc_data/out.odtgk.00026.250919.csv
# btc_data/out.rzeac.00055.260701.csv
# btc_data/out.nsgpe.00544.260617.csv
# btc_data/out.odtgk.00107.251002.csv
# btc_data/out.zyzjh.00020.260313.csv
# btc_data/out.odtgk.00407.251122.csv
# btc_data/out.nsgpe.00505.260610.csv
# btc_data/out.rzeac.00040.260628.csv
# btc_data/out.mrfni.00019.260203.csv
# btc_data/out.nsgpe.00222.260424.csv
# btc_data/out.odtgk.00218.251021.csv
# btc_data/out.odtgk.00249.251026.csv
# btc_data/out.odtgk.00392.251119.csv
# btc_data/out.pjhsr.00067.251210.csv
# btc_data/out.nsgpe.00112.260405.csv
# btc_data/out.odtgk.00059.250924.csv
# btc_data/out.odtgk.00183.251015.csv
# btc_data/out.nsgpe.00202.260420.csv
# btc_data/out.nsgpe.00339.260514.csv
# btc_data/out.odtgk.00370.251115.csv
# btc_data/out.rzeac.00019.260624.csv
# btc_data/out.pjhsr.00208.260103.csv
# btc_data/out.mrfni.00194.260304.csv
# btc_data/out.odtgk.00071.250926.csv
# btc_data/out.odtgk.00416.251123.csv
# btc_data/out.odtgk.00091.250930.csv
# btc_data/out.odtgk.00414.251123.csv
# btc_data/out.nsgpe.00286.260505.csv
# btc_data/out.zyzjh.00009.260311.csv
# btc_data/out.nsgpe.00067.260329.csv
# btc_data/out.mrfni.00035.260205.csv
# btc_data/out.odtgk.00219.251021.csv
# btc_data/out.zyzjh.00013.260312.csv
# btc_data/out.nsgpe.00204.260421.csv
# btc_data/out.pjhsr.00040.251206.csv
# btc_data/out.mrfni.00153.260225.csv
# btc_data/out.nsgpe.00111.260405.csv
# btc_data/out.nsgpe.00474.260605.csv
# btc_data/out.pjhsr.00118.251219.csv
# btc_data/out.odtgk.00148.251009.csv
# btc_data/out.nsgpe.00084.260401.csv
# btc_data/out.odtgk.00056.250924.csv
# btc_data/out.nsgpe.00416.260527.csv
# btc_data/out.pjhsr.00011.251201.csv
# btc_data/out.odtgk.00192.251017.csv
# btc_data/out.mrfni.00064.260211.csv
# btc_data/out.nsgpe.00482.260607.csv
# btc_data/out.nsgpe.00020.260321.csv
# btc_data/out.odtgk.00066.250925.csv
# btc_data/out.pjhsr.00189.251231.csv
# btc_data/out.nsgpe.00462.260603.csv
# btc_data/out.mrfni.00197.260305.csv
# btc_data/out.nsgpe.00452.260602.csv
# btc_data/out.pjhsr.00287.260116.csv
# btc_data/out.odtgk.00271.251030.csv
# btc_data/out.zyzjh.00015.260312.csv
# btc_data/out.mrfni.00017.260202.csv
# btc_data/out.nsgpe.00269.260502.csv
# btc_data/out.nsgpe.00419.260527.csv
# btc_data/out.odtgk.00098.251001.csv
# btc_data/out.nsgpe.00228.260425.csv
# btc_data/out.nsgpe.00542.260617.csv
# btc_data/out.odtgk.00265.251029.csv
# btc_data/out.odtgk.00336.251110.csv
# btc_data/out.nsgpe.00446.260601.csv
# btc_data/out.mrfni.00023.260203.csv
# btc_data/out.pjhsr.00051.251208.csv
# btc_data/out.pjhsr.00080.251212.csv
# btc_data/out.nsgpe.00129.260408.csv
# btc_data/out.pjhsr.00082.251213.csv
# btc_data/out.pjhsr.00304.260119.csv
# btc_data/out.nsgpe.00093.260402.csv
# btc_data/out.zyzjh.00019.260313.csv
# btc_data/out.odtgk.00005.250915.csv
# btc_data/out.odtgk.00235.251024.csv
# btc_data/out.odtgk.00421.251124.csv
# btc_data/out.mrfni.00114.260219.csv
# btc_data/out.pjhsr.00049.251207.csv
# btc_data/out.odtgk.00051.250923.csv
# btc_data/out.pjhsr.00345.260126.csv
# btc_data/out.nsgpe.00151.260412.csv
# btc_data/out.nsgpe.00433.260529.csv
# btc_data/out.pjhsr.00010.251201.csv
# btc_data/out.odtgk.00032.250920.csv
# btc_data/out.odtgk.00197.251017.csv
# btc_data/out.pjhsr.00236.260108.csv
# btc_data/out.odtgk.00001.250914.csv
# btc_data/out.nsgpe.00499.260609.csv
# btc_data/out.nsgpe.00010.260319.csv
# btc_data/out.odtgk.00172.251013.csv
# btc_data/out.nsgpe.00381.260521.csv
# btc_data/out.nsgpe.00395.260523.csv
# btc_data/out.rzeac.00042.260628.csv
# btc_data/out.pjhsr.00016.251202.csv
# btc_data/out.nsgpe.00533.260615.csv
# btc_data/out.odtgk.00011.250916.csv
# btc_data/out.odtgk.00035.250920.csv
# btc_data/out.nsgpe.00496.260609.csv
# btc_data/out.nsgpe.00238.260427.csv
# btc_data/out.rzeac.00046.260629.csv
# btc_data/out.odtgk.00208.251019.csv
# btc_data/out.odtgk.00158.251011.csv
# btc_data/out.nsgpe.00278.260503.csv
# btc_data/out.pjhsr.00252.260110.csv
# btc_data/out.mrfni.00161.260227.csv
# btc_data/out.pjhsr.00226.260106.csv
# btc_data/out.pjhsr.00014.251201.csv
# btc_data/out.nsgpe.00095.260402.csv
# btc_data/out.pjhsr.00275.260114.csv
# btc_data/out.pjhsr.00285.260116.csv
# btc_data/out.mrfni.00201.260305.csv
# btc_data/out.rzeac.00036.260627.csv
# btc_data/out.odtgk.00092.250930.csv
# btc_data/out.mrfni.00029.260204.csv
# btc_data/out.odtgk.00417.251123.csv
# btc_data/out.mrfni.00076.260213.csv
# btc_data/out.pjhsr.00044.251206.csv
# btc_data/out.odtgk.00019.250918.csv
# btc_data/out.odtgk.00264.251029.csv
# btc_data/out.zyzjh.00027.260314.csv
# btc_data/out.odtgk.00094.250930.csv
# btc_data/out.mrfni.00177.260301.csv
# btc_data/out.nsgpe.00362.260517.csv
# btc_data/out.nsgpe.00310.260509.csv
# btc_data/out.odtgk.00306.251105.csv
# btc_data/out.nsgpe.00130.260408.csv
# btc_data/out.pjhsr.00060.251209.csv
# btc_data/out.mrfni.00134.260222.csv
# btc_data/out.pjhsr.00041.251206.csv
# btc_data/out.odtgk.00081.250928.csv
# btc_data/out.mrfni.00158.260226.csv
# btc_data/out.nsgpe.00177.260416.csv
# btc_data/out.nsgpe.00170.260415.csv
# btc_data/out.nsgpe.00514.260612.csv
# btc_data/out.pjhsr.00117.251219.csv
# btc_data/out.nsgpe.00244.260428.csv
# btc_data/out.nsgpe.00094.260402.csv
# btc_data/out.odtgk.00356.251113.csv
# btc_data/out.nsgpe.00396.260523.csv
# btc_data/out.mrfni.00147.260224.csv
# btc_data/out.rzeac.00028.260626.csv
# btc_data/out.pjhsr.00249.260110.csv
# btc_data/out.odtgk.00435.251126.csv
# btc_data/out.odtgk.00164.251012.csv
# btc_data/out.nsgpe.00271.260502.csv
# btc_data/out.nsgpe.00504.260610.csv
# btc_data/out.nsgpe.00279.260504.csv
# btc_data/out.pjhsr.00146.251224.csv
# btc_data/out.pjhsr.00200.260102.csv
# btc_data/out.mrfni.00001.260131.csv
# btc_data/out.odtgk.00068.250926.csv
# btc_data/out.odtgk.00126.251005.csv
# btc_data/out.pjhsr.00038.251205.csv
# btc_data/out.odtgk.00045.250922.csv
# btc_data/out.nsgpe.00006.260318.csv
# btc_data/out.odtgk.00371.251116.csv
# btc_data/out.nsgpe.00051.260326.csv
# btc_data/out.mrfni.00096.260216.csv
# btc_data/out.pjhsr.00323.260122.csv
# btc_data/out.pjhsr.00331.260124.csv
# btc_data/out.mrfni.00148.260225.csv
# btc_data/out.pjhsr.00180.251229.csv
# btc_data/out.nsgpe.00528.260614.csv
# btc_data/out.odtgk.00207.251019.csv
# btc_data/out.pjhsr.00002.251129.csv
# btc_data/out.nsgpe.00327.260512.csv
# btc_data/out.pjhsr.00061.251209.csv
# btc_data/out.pjhsr.00181.251229.csv
# btc_data/out.nsgpe.00044.260325.csv
# btc_data/out.nsgpe.00319.260510.csv
# btc_data/out.odtgk.00217.251021.csv
# btc_data/out.pjhsr.00131.251221.csv
# btc_data/out.mrfni.00010.260201.csv
# btc_data/out.odtgk.00101.251001.csv
# btc_data/out.nsgpe.00461.260603.csv
# btc_data/out.nsgpe.00536.260616.csv
# btc_data/out.nsgpe.00304.260508.csv
# btc_data/out.pjhsr.00206.260103.csv
# btc_data/out.odtgk.00439.251127.csv
# btc_data/out.odtgk.00320.251107.csv
# btc_data/out.pjhsr.00073.251211.csv
# btc_data/out.nsgpe.00187.260418.csv
# btc_data/out.odtgk.00333.251109.csv
# btc_data/out.odtgk.00220.251021.csv
# btc_data/out.nsgpe.00291.260506.csv
# btc_data/out.odtgk.00118.251004.csv
# btc_data/out.mrfni.00181.260302.csv
# btc_data/out.pjhsr.00269.260113.csv
# btc_data/out.nsgpe.00210.260422.csv
# btc_data/out.pjhsr.00312.260120.csv
# btc_data/out.odtgk.00307.251105.csv
# btc_data/out.nsgpe.00456.260602.csv
# btc_data/out.mrfni.00095.260216.csv
# btc_data/out.nsgpe.00115.260406.csv
# btc_data/out.odtgk.00063.250925.csv
# btc_data/out.odtgk.00256.251027.csv
# btc_data/out.mrfni.00113.260219.csv
# btc_data/out.odtgk.00270.251030.csv
# btc_data/out.odtgk.00408.251122.csv
# btc_data/out.pjhsr.00162.251226.csv
# btc_data/out.pjhsr.00327.260123.csv
# btc_data/out.nsgpe.00255.260429.csv
# btc_data/out.mrfni.00027.260204.csv
# btc_data/out.odtgk.00224.251022.csv
# btc_data/out.nsgpe.00341.260514.csv
# btc_data/out.pjhsr.00039.251206.csv
# btc_data/out.nsgpe.00070.260329.csv
# btc_data/out.nsgpe.00477.260606.csv
# btc_data/out.rzeac.00030.260626.csv
# btc_data/out.rzeac.00025.260625.csv
# btc_data/out.pjhsr.00111.251218.csv
# btc_data/out.pjhsr.00309.260120.csv
# btc_data/out.odtgk.00017.250917.csv
# btc_data/out.odtgk.00175.251014.csv
# btc_data/out.nsgpe.00316.260510.csv
# btc_data/out.nsgpe.00214.260422.csv
# btc_data/out.rzeac.00068.260703.csv
# btc_data/out.nsgpe.00124.260407.csv
# btc_data/out.nsgpe.00039.260324.csv
# btc_data/out.nsgpe.00270.260502.csv
# btc_data/out.odtgk.00013.250917.csv
# btc_data/out.odtgk.00064.250925.csv
# btc_data/out.nsgpe.00414.260526.csv
# btc_data/out.odtgk.00279.251031.csv
# btc_data/out.nsgpe.00046.260325.csv
# btc_data/out.pjhsr.00339.260125.csv
# btc_data/out.nsgpe.00374.260519.csv
# btc_data/out.nsgpe.00258.260430.csv
# btc_data/out.pjhsr.00300.260118.csv
# btc_data/out.odtgk.00072.250926.csv
# btc_data/out.nsgpe.00491.260608.csv
# btc_data/out.mrfni.00084.260214.csv
# btc_data/out.mrfni.00179.260302.csv
# btc_data/out.nsgpe.00216.260423.csv
# btc_data/out.odtgk.00261.251028.csv
# btc_data/out.mrfni.00080.260213.csv
# btc_data/out.mrfni.00146.260224.csv
# btc_data/out.nsgpe.00156.260413.csv
# btc_data/out.mrfni.00203.260306.csv
# btc_data/out.mrfni.00180.260302.csv
# btc_data/out.pjhsr.00027.251204.csv
# btc_data/out.nsgpe.00367.260518.csv
# btc_data/out.odtgk.00133.251007.csv
# btc_data/out.pjhsr.00353.260127.csv
# btc_data/out.odtgk.00329.251109.csv
# btc_data/out.nsgpe.00196.260419.csv
# btc_data/out.odtgk.00087.250929.csv
# btc_data/out.nsgpe.00236.260426.csv
# btc_data/out.mrfni.00077.260213.csv
# btc_data/out.mrfni.00149.260225.csv
# btc_data/out.mcxci.00018.260620.csv
# btc_data/out.nsgpe.00138.260410.csv
# btc_data/out.pjhsr.00047.251207.csv
# btc_data/out.nsgpe.00350.260515.csv
# btc_data/out.mrfni.00129.260221.csv
# btc_data/out.nsgpe.00059.260327.csv
# btc_data/out.odtgk.00357.251113.csv
# btc_data/out.nsgpe.00398.260524.csv
# btc_data/out.nsgpe.00516.260612.csv
# btc_data/out.odtgk.00169.251013.csv
# btc_data/out.pjhsr.00036.251205.csv
# btc_data/out.odtgk.00067.250926.csv
# btc_data/out.nsgpe.00073.260330.csv
# btc_data/out.odtgk.00078.250927.csv
# btc_data/out.odtgk.00160.251011.csv
# btc_data/out.nsgpe.00333.260513.csv
# btc_data/out.pjhsr.00220.260105.csv
# btc_data/out.odtgk.00084.250928.csv
# btc_data/out.mcxci.00015.260620.csv
# btc_data/out.nsgpe.00048.260326.csv
# btc_data/out.pjhsr.00140.251223.csv
# btc_data/out.nsgpe.00526.260614.csv
# btc_data/out.odtgk.00043.250922.csv
# btc_data/out.odtgk.00244.251025.csv
# btc_data/out.odtgk.00184.251015.csv
# btc_data/out.odtgk.00053.250923.csv
# btc_data/out.odtgk.00362.251114.csv
# btc_data/out.pjhsr.00043.251206.csv
# btc_data/out.odtgk.00040.250921.csv
# btc_data/out.mrfni.00186.260303.csv
# btc_data/out.mrfni.00073.260212.csv
# btc_data/out.mrfni.00028.260204.csv
# btc_data/out.mrfni.00034.260205.csv
# btc_data/out.rzeac.00070.260703.csv
# btc_data/out.nsgpe.00140.260410.csv
# btc_data/out.odtgk.00337.251110.csv
# btc_data/out.odtgk.00291.251102.csv
# btc_data/out.mrfni.00038.260206.csv
# btc_data/out.rzeac.00047.260629.csv
# btc_data/out.nsgpe.00417.260527.csv
# btc_data/out.nsgpe.00243.260427.csv
# btc_data/out.nsgpe.00150.260412.csv
# btc_data/out.pjhsr.00159.251226.csv
# btc_data/out.pjhsr.00157.251225.csv
# btc_data/out.pjhsr.00257.260111.csv
# btc_data/out.pjhsr.00149.251224.csv
# btc_data/out.odtgk.00250.251026.csv
# btc_data/out.odtgk.00146.251009.csv
# btc_data/out.odtgk.00168.251013.csv
# btc_data/out.odtgk.00170.251013.csv
# btc_data/out.pjhsr.00319.260122.csv
# btc_data/out.nsgpe.00468.260604.csv
# btc_data/out.nsgpe.00058.260327.csv
# btc_data/out.odtgk.00161.251011.csv
# btc_data/out.mrfni.00052.260209.csv
# btc_data/out.odtgk.00174.251014.csv
# btc_data/out.pjhsr.00264.260112.csv
# btc_data/out.nsgpe.00520.260613.csv
# btc_data/out.nsgpe.00300.260507.csv
# btc_data/out.mrfni.00159.260226.csv
# btc_data/out.pjhsr.00320.260122.csv
# btc_data/out.odtgk.00046.250922.csv
# btc_data/out.odtgk.00136.251007.csv
# btc_data/out.odtgk.00086.250929.csv
# btc_data/out.odtgk.00354.251113.csv
# btc_data/out.pjhsr.00169.251227.csv
# btc_data/out.odtgk.00259.251028.csv
# btc_data/out.mrfni.00055.260209.csv
# btc_data/out.rzeac.00043.260628.csv
# btc_data/out.odtgk.00312.251106.csv
# btc_data/out.pjhsr.00250.260110.csv
# btc_data/out.nsgpe.00087.260401.csv
# btc_data/out.odtgk.00034.250920.csv
# btc_data/out.pjhsr.00260.260112.csv
# btc_data/out.nsgpe.00408.260525.csv
# btc_data/out.odtgk.00114.251003.csv
# btc_data/out.pjhsr.00218.260105.csv
# btc_data/out.pjhsr.00045.251207.csv
# btc_data/out.odtgk.00431.251126.csv
# btc_data/out.pjhsr.00209.260103.csv
# btc_data/out.pjhsr.00143.251223.csv
# btc_data/out.pjhsr.00228.260106.csv
# btc_data/out.pjhsr.00063.251210.csv
# btc_data/out.mrfni.00003.260131.csv
# btc_data/out.nsgpe.00348.260515.csv
# btc_data/out.nsgpe.00481.260606.csv
# btc_data/out.nsgpe.00110.260405.csv
# btc_data/out.odtgk.00069.250926.csv
# btc_data/out.odtgk.00288.251102.csv
# btc_data/out.mrfni.00174.260301.csv
# btc_data/out.pjhsr.00069.251211.csv
# btc_data/out.pjhsr.00242.260109.csv
# btc_data/out.rzeac.00045.260629.csv
# btc_data/out.pjhsr.00137.251222.csv
# btc_data/out.nsgpe.00489.260608.csv
# btc_data/out.odtgk.00254.251027.csv
# btc_data/out.pjhsr.00024.251203.csv
# btc_data/out.mrfni.00067.260211.csv
# btc_data/out.mrfni.00005.260131.csv
# btc_data/out.pjhsr.00203.260102.csv
# btc_data/out.nsgpe.00091.260402.csv
# btc_data/out.odtgk.00162.251012.csv
# btc_data/out.nsgpe.00005.260318.csv
# btc_data/out.nsgpe.00180.260417.csv
# btc_data/out.odtgk.00190.251016.csv
# btc_data/out.nsgpe.00185.260418.csv
# btc_data/out.rzeac.00007.260622.csv
# btc_data/out.nsgpe.00003.260318.csv
# btc_data/out.odtgk.00263.251029.csv
# btc_data/out.odtgk.00047.250922.csv
# btc_data/out.pjhsr.00021.251203.csv
# btc_data/out.odtgk.00438.251127.csv
# btc_data/out.odtgk.00283.251101.csv
# btc_data/out.odtgk.00240.251025.csv
# btc_data/out.pjhsr.00317.260121.csv
# btc_data/out.odtgk.00038.250921.csv
# btc_data/out.odtgk.00194.251017.csv
# btc_data/out.nsgpe.00483.260607.csv
# btc_data/out.nsgpe.00394.260523.csv
# btc_data/out.odtgk.00226.251022.csv
# btc_data/out.pjhsr.00172.251228.csv
# btc_data/out.odtgk.00360.251114.csv
# btc_data/out.nsgpe.00509.260611.csv
# btc_data/out.pjhsr.00187.251230.csv
# btc_data/out.zyzjh.00031.260315.csv
# btc_data/out.nsgpe.00113.260406.csv
# btc_data/out.nsgpe.00083.260331.csv
# btc_data/out.nsgpe.00436.260530.csv
# btc_data/out.odtgk.00394.251119.csv
# btc_data/out.pjhsr.00313.260121.csv
# btc_data/out.pjhsr.00288.260116.csv
# btc_data/out.odtgk.00381.251117.csv
# btc_data/out.odtgk.00432.251126.csv
# btc_data/out.mrfni.00012.260201.csv
# btc_data/out.nsgpe.00425.260528.csv
# btc_data/out.mrfni.00004.260131.csv
# btc_data/out.nsgpe.00517.260612.csv
# btc_data/out.nsgpe.00034.260323.csv
# btc_data/out.nsgpe.00018.260320.csv
# btc_data/out.nsgpe.00274.260503.csv
# btc_data/out.rzeac.00049.260630.csv
# btc_data/out.pjhsr.00001.251129.csv
# btc_data/out.odtgk.00210.251020.csv
# btc_data/out.mrfni.00031.260205.csv
# btc_data/out.nsgpe.00019.260321.csv
# btc_data/out.odtgk.00000.250914.csv
# btc_data/out.odtgk.00262.251028.csv
# btc_data/out.nsgpe.00486.260607.csv
# btc_data/out.pjhsr.00121.251219.csv
# btc_data/out.odtgk.00196.251017.csv
# btc_data/out.pjhsr.00095.251215.csv
# btc_data/out.nsgpe.00132.260409.csv
# btc_data/out.mcxci.00022.260621.csv
# btc_data/out.nsgpe.00106.260404.csv
# btc_data/out.mrfni.00139.260223.csv
# btc_data/out.mrfni.00117.260219.csv
# btc_data/out.rzeac.00038.260628.csv
# btc_data/out.nsgpe.00144.260411.csv
# btc_data/out.nsgpe.00233.260426.csv
# btc_data/out.odtgk.00049.250923.csv
# btc_data/out.pjhsr.00078.251212.csv
# btc_data/out.nsgpe.00037.260324.csv
# btc_data/out.nsgpe.00357.260517.csv
# btc_data/out.pjhsr.00246.260109.csv
# btc_data/out.rzeac.00072.260703.csv
# btc_data/out.odtgk.00364.251114.csv
# btc_data/out.nsgpe.00378.260520.csv
# btc_data/out.odtgk.00096.250930.csv
# btc_data/out.nsgpe.00466.260604.csv
# btc_data/out.mrfni.00120.260220.csv
# btc_data/out.mrfni.00156.260226.csv
# btc_data/out.odtgk.00297.251103.csv
# btc_data/out.nsgpe.00179.260417.csv
# btc_data/out.nsgpe.00545.260617.csv
# btc_data/out.pjhsr.00202.260102.csv
# btc_data/out.mrfni.00039.260206.csv
# btc_data/out.pjhsr.00314.260121.csv
# btc_data/out.pjhsr.00103.251216.csv
# btc_data/out.odtgk.00112.251003.csv
# btc_data/out.pjhsr.00070.251211.csv
# btc_data/out.nsgpe.00356.260516.csv
# btc_data/out.mrfni.00060.260210.csv
# btc_data/out.mrfni.00105.260217.csv
# btc_data/out.mcxci.00020.260621.csv
# btc_data/out.mcxci.00007.260618.csv
# btc_data/out.pjhsr.00158.251226.csv
# btc_data/out.odtgk.00113.251003.csv
# btc_data/out.nsgpe.00317.260510.csv
# btc_data/out.odtgk.00248.251026.csv
# btc_data/out.odtgk.00376.251116.csv
# btc_data/out.nsgpe.00223.260424.csv
# btc_data/out.nsgpe.00076.260330.csv
# btc_data/out.mrfni.00189.260303.csv
# btc_data/out.nsgpe.00484.260607.csv
# btc_data/out.nsgpe.00525.260614.csv
# btc_data/out.nsgpe.00055.260327.csv
# btc_data/out.pjhsr.00328.260123.csv
# btc_data/out.nsgpe.00205.260421.csv
# btc_data/out.nsgpe.00176.260416.csv
# btc_data/out.nsgpe.00527.260614.csv
# btc_data/out.nsgpe.00354.260516.csv
# btc_data/out.nsgpe.00432.260529.csv
# btc_data/out.pjhsr.00268.260113.csv
# btc_data/out.nsgpe.00519.260613.csv
# btc_data/out.pjhsr.00211.260103.csv
# btc_data/out.nsgpe.00143.260411.csv
# btc_data/out.nsgpe.00165.260414.csv
# btc_data/out.pjhsr.00217.260104.csv
# btc_data/out.nsgpe.00314.260509.csv
# btc_data/out.pjhsr.00089.251214.csv
# btc_data/out.odtgk.00077.250927.csv
# btc_data/out.nsgpe.00013.260320.csv
# btc_data/out.nsgpe.00439.260530.csv
# btc_data/out.mrfni.00135.260222.csv
# btc_data/out.nsgpe.00287.260505.csv
# btc_data/out.odtgk.00180.251015.csv
# btc_data/out.odtgk.00128.251006.csv
# btc_data/out.mrfni.00059.260210.csv
# btc_data/out.pjhsr.00259.260111.csv
# btc_data/out.nsgpe.00100.260403.csv
# btc_data/out.pjhsr.00167.251227.csv
# btc_data/out.mrfni.00152.260225.csv
# btc_data/out.nsgpe.00399.260524.csv
# btc_data/out.pjhsr.00165.251227.csv
# btc_data/out.pjhsr.00113.251218.csv
# btc_data/out.pjhsr.00263.260112.csv
# btc_data/out.nsgpe.00523.260613.csv
# btc_data/out.pjhsr.00344.260126.csv
# btc_data/out.odtgk.00385.251118.csv
# btc_data/out.odtgk.00430.251125.csv
# btc_data/out.nsgpe.00043.260325.csv
# btc_data/out.odtgk.00377.251117.csv
# btc_data/out.nsgpe.00203.260421.csv
# btc_data/out.nsgpe.00298.260507.csv
# btc_data/out.pjhsr.00101.251216.csv
# btc_data/out.odtgk.00110.251003.csv
# btc_data/out.mrfni.00144.260224.csv
# btc_data/out.nsgpe.00215.260423.csv
# btc_data/out.mrfni.00072.260212.csv
# btc_data/out.nsgpe.00541.260617.csv
# btc_data/out.nsgpe.00469.260604.csv
# btc_data/out.nsgpe.00303.260508.csv
# btc_data/out.odtgk.00305.251105.csv
# btc_data/out.odtgk.00419.251124.csv
# btc_data/out.nsgpe.00139.260410.csv
# btc_data/out.mrfni.00172.260301.csv
# btc_data/out.odtgk.00187.251016.csv
# btc_data/out.nsgpe.00365.260518.csv
# btc_data/out.nsgpe.00097.260403.csv
# btc_data/out.nsgpe.00146.260411.csv
# btc_data/out.pjhsr.00029.251204.csv
# btc_data/out.odtgk.00316.251106.csv
# btc_data/out.nsgpe.00199.260420.csv
# btc_data/out.mrfni.00088.260215.csv
# btc_data/out.nsgpe.00429.260529.csv
# btc_data/out.pjhsr.00330.260123.csv
# btc_data/out.nsgpe.00397.260523.csv
# btc_data/out.odtgk.00344.251111.csv
# btc_data/out.odtgk.00340.251110.csv
# btc_data/out.mrfni.00089.260215.csv
# btc_data/out.odtgk.00103.251002.csv
# btc_data/out.zyzjh.00008.260311.csv
# btc_data/out.pjhsr.00114.251218.csv
# btc_data/out.nsgpe.00016.260320.csv
# btc_data/out.nsgpe.00418.260527.csv
# btc_data/out.odtgk.00065.250925.csv
# btc_data/out.pjhsr.00256.260111.csv
# btc_data/out.mrfni.00066.260211.csv
# btc_data/out.nsgpe.00382.260521.csv
# btc_data/out.odtgk.00195.251017.csv
# btc_data/out.odtgk.00130.251006.csv
# btc_data/out.nsgpe.00453.260602.csv
# btc_data/out.nsgpe.00239.260427.csv
# btc_data/out.odtgk.00245.251026.csv
# btc_data/out.pjhsr.00354.260127.csv
# btc_data/out.nsgpe.00493.260608.csv
# btc_data/out.odtgk.00129.251006.csv
# btc_data/out.pjhsr.00091.251214.csv
# btc_data/out.pjhsr.00215.260104.csv
# btc_data/out.pjhsr.00094.251215.csv
# btc_data/out.nsgpe.00254.260429.csv
# btc_data/out.odtgk.00398.251120.csv
# btc_data/out.nsgpe.00234.260426.csv
# btc_data/out.zyzjh.00014.260312.csv
# btc_data/out.pjhsr.00346.260126.csv
# btc_data/out.nsgpe.00053.260326.csv
# btc_data/out.nsgpe.00035.260323.csv
# btc_data/out.nsgpe.00103.260404.csv
# btc_data/out.pjhsr.00347.260126.csv
# btc_data/out.nsgpe.00133.260409.csv
# btc_data/out.odtgk.00132.251006.csv
# btc_data/out.pjhsr.00286.260116.csv
# btc_data/out.odtgk.00309.251105.csv
# btc_data/out.mrfni.00104.260217.csv
# btc_data/out.odtgk.00358.251113.csv
# btc_data/out.nsgpe.00159.260413.csv
# btc_data/out.odtgk.00120.251004.csv
# btc_data/out.pjhsr.00096.251215.csv
# btc_data/out.rzeac.00022.260625.csv
# btc_data/out.mrfni.00093.260215.csv
# btc_data/out.mrfni.00074.260212.csv
# btc_data/out.pjhsr.00349.260127.csv
# btc_data/out.nsgpe.00292.260506.csv
# btc_data/out.nsgpe.00014.260320.csv
# btc_data/out.nsgpe.00369.260519.csv
# btc_data/out.mrfni.00133.260222.csv
# btc_data/out.odtgk.00323.251108.csv
# btc_data/out.odtgk.00100.251001.csv
# btc_data/out.pjhsr.00147.251224.csv
# btc_data/out.mrfni.00126.260221.csv
# btc_data/out.odtgk.00367.251115.csv
# btc_data/out.nsgpe.00312.260509.csv
# btc_data/out.rzeac.00037.260627.csv
# btc_data/out.odtgk.00422.251124.csv
# btc_data/out.odtgk.00154.251010.csv
# btc_data/out.odtgk.00427.251125.csv
# btc_data/out.mrfni.00171.260228.csv
# btc_data/out.pjhsr.00273.260114.csv
# btc_data/out.nsgpe.00537.260616.csv
# btc_data/out.odtgk.00348.251112.csv
# btc_data/out.nsgpe.00383.260521.csv
# btc_data/out.mrfni.00078.260213.csv
# btc_data/out.mrfni.00002.260131.csv
# btc_data/out.odtgk.00004.250915.csv
# btc_data/out.odtgk.00076.250927.csv
# btc_data/out.odtgk.00104.251002.csv
# btc_data/out.pjhsr.00148.251224.csv
# btc_data/out.pjhsr.00033.251205.csv
# btc_data/out.nsgpe.00363.260518.csv
# btc_data/out.mrfni.00050.260208.csv
# btc_data/out.odtgk.00216.251021.csv
# btc_data/out.odtgk.00062.250925.csv
# btc_data/out.odtgk.00234.251024.csv
# btc_data/out.odtgk.00424.251124.csv
# btc_data/out.odtgk.00315.251106.csv
# btc_data/out.pjhsr.00280.260115.csv
# btc_data/out.nsgpe.00324.260511.csv
# btc_data/out.mrfni.00068.260211.csv
# btc_data/out.pjhsr.00290.260117.csv
# btc_data/out.odtgk.00418.251123.csv
# btc_data/out.odtgk.00223.251022.csv
# btc_data/out.pjhsr.00065.251210.csv
# btc_data/out.odtgk.00308.251105.csv
# btc_data/out.zyzjh.00004.260311.csv
# btc_data/out.odtgk.00199.251018.csv
# btc_data/out.nsgpe.00247.260428.csv
# btc_data/out.pjhsr.00193.251231.csv
# btc_data/out.odtgk.00048.250922.csv
# btc_data/out.odtgk.00151.251010.csv
# btc_data/out.odtgk.00231.251023.csv
# btc_data/out.pjhsr.00247.260109.csv
# btc_data/out.nsgpe.00218.260423.csv
# btc_data/out.odtgk.00140.251008.csv
# btc_data/out.odtgk.00215.251020.csv
# btc_data/out.odtgk.00395.251120.csv
# btc_data/out.nsgpe.00047.260325.csv
# btc_data/out.odtgk.00415.251123.csv
# btc_data/out.nsgpe.00359.260517.csv
# btc_data/out.pjhsr.00188.251231.csv
# btc_data/out.pjhsr.00278.260115.csv
# btc_data/out.nsgpe.00267.260501.csv
# btc_data/out.nsgpe.00358.260517.csv
# btc_data/out.mrfni.00087.260214.csv
# btc_data/out.rzeac.00057.260701.csv
# btc_data/out.pjhsr.00132.251221.csv
# btc_data/out.pjhsr.00335.260124.csv
# btc_data/out.nsgpe.00400.260524.csv
# btc_data/out.nsgpe.00166.260414.csv
# btc_data/out.pjhsr.00262.260112.csv
# btc_data/out.pjhsr.00212.260104.csv
# btc_data/out.odtgk.00021.250918.csv
# btc_data/out.pjhsr.00042.251206.csv
# btc_data/out.nsgpe.00540.260616.csv
# btc_data/out.rzeac.00012.260623.csv
# btc_data/out.zyzjh.00024.260314.csv
# btc_data/out.mcxci.00004.260618.csv
# btc_data/out.mrfni.00118.260220.csv
# btc_data/out.nsgpe.00007.260319.csv
# btc_data/out.pjhsr.00303.260119.csv
# btc_data/out.mcxci.00021.260621.csv
# btc_data/out.nsgpe.00353.260516.csv
# btc_data/out.nsgpe.00081.260331.csv
# btc_data/out.rzeac.00008.260623.csv
# btc_data/out.mrfni.00037.260206.csv
# btc_data/out.odtgk.00280.251031.csv
# btc_data/out.odtgk.00278.251031.csv
# btc_data/out.mcxci.00023.260621.csv
# btc_data/out.odtgk.00437.251127.csv
# btc_data/out.zyzjh.00010.260312.csv
# btc_data/out.odtgk.00079.250928.csv
# btc_data/out.odtgk.00099.251001.csv
# btc_data/out.odtgk.00247.251026.csv
# btc_data/out.odtgk.00292.251102.csv
# btc_data/out.mrfni.00022.260203.csv
# btc_data/out.odtgk.00165.251012.csv
# btc_data/out.mrfni.00081.260213.csv
# btc_data/out.mrfni.00006.260131.csv
# btc_data/out.odtgk.00238.251024.csv
# btc_data/out.nsgpe.00427.260528.csv
# btc_data/out.nsgpe.00407.260525.csv
# btc_data/out.pjhsr.00005.251130.csv
# btc_data/out.nsgpe.00078.260331.csv
# btc_data/out.odtgk.00341.251111.csv
# btc_data/out.nsgpe.00387.260522.csv
# btc_data/out.nsgpe.00294.260506.csv
# btc_data/out.nsgpe.00072.260330.csv
# btc_data/out.mrfni.00124.260221.csv
# btc_data/out.mrfni.00054.260209.csv
# btc_data/out.odtgk.00106.251002.csv
# btc_data/out.nsgpe.00183.260417.csv
# btc_data/out.pjhsr.00081.251213.csv
# btc_data/out.nsgpe.00033.260323.csv
# btc_data/out.nsgpe.00498.260609.csv
# btc_data/out.odtgk.00338.251110.csv
# btc_data/out.odtgk.00147.251009.csv
# btc_data/out.odtgk.00355.251113.csv
# btc_data/out.odtgk.00413.251123.csv
# btc_data/out.pjhsr.00240.260108.csv
# btc_data/out.mrfni.00040.260206.csv
# btc_data/out.odtgk.00299.251104.csv
# btc_data/out.nsgpe.00508.260611.csv
# btc_data/out.mrfni.00125.260221.csv
# btc_data/out.nsgpe.00463.260603.csv
# btc_data/out.mrfni.00043.260207.csv
# btc_data/out.mrfni.00020.260203.csv
# btc_data/out.zyzjh.00000.260310.csv
# btc_data/out.odtgk.00390.251119.csv
# btc_data/out.mrfni.00007.260201.csv
# btc_data/out.nsgpe.00306.260508.csv
# btc_data/out.odtgk.00150.251010.csv
# btc_data/out.nsgpe.00122.260407.csv
# btc_data/out.odtgk.00267.251029.csv
# btc_data/out.nsgpe.00329.260512.csv
# btc_data/out.odtgk.00201.251018.csv
# btc_data/out.odtgk.00242.251025.csv
# btc_data/out.nsgpe.00212.260422.csv
# btc_data/out.odtgk.00284.251101.csv
# btc_data/out.nsgpe.00206.260421.csv
# btc_data/out.pjhsr.00072.251211.csv
# btc_data/out.zyzjh.00023.260314.csv
# btc_data/out.odtgk.00255.251027.csv
# btc_data/out.nsgpe.00368.260518.csv
# btc_data/out.nsgpe.00235.260426.csv
# btc_data/out.nsgpe.00288.260505.csv
# btc_data/out.nsgpe.00377.260520.csv
# btc_data/out.mrfni.00051.260208.csv
# btc_data/out.pjhsr.00324.260122.csv
# btc_data/out.nsgpe.00412.260526.csv
# btc_data/out.nsgpe.00197.260420.csv
# btc_data/out.mrfni.00193.260304.csv
# btc_data/out.pjhsr.00178.251229.csv
# btc_data/out.pjhsr.00129.251221.csv
# btc_data/out.pjhsr.00056.251208.csv
# btc_data/out.nsgpe.00163.260414.csv
# btc_data/out.mrfni.00136.260223.csv
# btc_data/out.nsgpe.00449.260601.csv
# btc_data/out.mrfni.00132.260222.csv
# btc_data/out.odtgk.00041.250921.csv
# btc_data/out.mrfni.00036.260205.csv
# btc_data/out.odtgk.00317.251107.csv
# btc_data/out.rzeac.00062.260702.csv
# btc_data/out.nsgpe.00063.260328.csv
# btc_data/out.nsgpe.00025.260322.csv
# btc_data/out.nsgpe.00460.260603.csv
# btc_data/out.nsgpe.00229.260425.csv
# btc_data/out.odtgk.00030.250919.csv
# btc_data/out.mrfni.00116.260219.csv
# btc_data/out.odtgk.00402.251121.csv
# btc_data/out.pjhsr.00142.251223.csv
# btc_data/out.odtgk.00029.250919.csv
# btc_data/out.odtgk.00268.251029.csv
# btc_data/out.pjhsr.00213.260104.csv
# btc_data/out.mcxci.00005.260618.csv
# btc_data/out.mrfni.00108.260218.csv
# btc_data/out.mrfni.00026.260204.csv
# btc_data/out.pjhsr.00115.251218.csv
# btc_data/out.pjhsr.00152.251225.csv
# btc_data/out.mrfni.00046.260207.csv
# btc_data/out.rzeac.00021.260625.csv
# btc_data/out.mcxci.00011.260619.csv
# btc_data/out.nsgpe.00351.260516.csv
# btc_data/out.rzeac.00058.260701.csv
# btc_data/out.odtgk.00025.250919.csv
# btc_data/out.nsgpe.00195.260419.csv
# btc_data/out.nsgpe.00260.260430.csv
# btc_data/out.pjhsr.00083.251213.csv
# btc_data/out.nsgpe.00157.260413.csv
# btc_data/out.nsgpe.00184.260417.csv
# btc_data/out.mrfni.00041.260206.csv
# btc_data/out.nsgpe.00261.260430.csv
# btc_data/out.pjhsr.00104.251216.csv
# btc_data/out.nsgpe.00389.260522.csv
# btc_data/out.odtgk.00185.251015.csv
# btc_data/out.mrfni.00183.260302.csv
# btc_data/out.nsgpe.00380.260520.csv
# btc_data/out.pjhsr.00019.251202.csv
# btc_data/out.nsgpe.00101.260403.csv
# btc_data/out.nsgpe.00022.260321.csv
# btc_data/out.nsgpe.00030.260323.csv
# btc_data/out.nsgpe.00128.260408.csv
# btc_data/out.nsgpe.00004.260318.csv
# btc_data/out.pjhsr.00055.251208.csv
# btc_data/out.rzeac.00061.260702.csv
# btc_data/out.nsgpe.00472.260605.csv
# btc_data/out.nsgpe.00191.260419.csv
# btc_data/out.nsgpe.00158.260413.csv
# btc_data/out.pjhsr.00008.251130.csv
# btc_data/out.nsgpe.00297.260507.csv
# btc_data/out.rzeac.00015.260624.csv
# btc_data/out.mrfni.00140.260223.csv
# btc_data/out.pjhsr.00006.251130.csv
# btc_data/out.nsgpe.00305.260508.csv
# btc_data/out.pjhsr.00112.251218.csv
# btc_data/out.nsgpe.00251.260429.csv
# btc_data/out.mrfni.00058.260210.csv
# btc_data/out.nsgpe.00038.260324.csv
# btc_data/out.pjhsr.00035.251205.csv
# btc_data/out.pjhsr.00037.251205.csv
# btc_data/out.pjhsr.00267.260113.csv
# btc_data/out.pjhsr.00018.251202.csv
# btc_data/out.odtgk.00198.251018.csv
# btc_data/out.mrfni.00044.260207.csv
# btc_data/out.mrfni.00098.260216.csv
# btc_data/out.pjhsr.00271.260114.csv
# btc_data/out.nsgpe.00102.260404.csv
# btc_data/out.pjhsr.00224.260106.csv
# btc_data/out.mrfni.00092.260215.csv
# btc_data/out.nsgpe.00040.260324.csv
# btc_data/out.odtgk.00189.251016.csv
# btc_data/out.odtgk.00287.251102.csv
# btc_data/out.nsgpe.00155.260413.csv
# btc_data/out.odtgk.00300.251104.csv
# btc_data/out.pjhsr.00097.251215.csv
# Data dir:   /root/btc_data
# Output dir: /root/btc_lstm

# %%
#!cd ~ && mv btc_data btc_data_
#!cd ~ && mv btc_data_/btc_data .

# %%
# !cd ~ && ls -l && ls -l btc_data/ | head
# Out:
# total 84
# drwxr-xr-x 2 root root 81920 Jul  5 14:41 btc_data
# drwxr-xr-x 2 root root  4096 Jul  6 14:25 btc_lstm
# total 12038708
# -r--r--r-- 1 root root 7298743 Jul  5 13:58 out.mcxci.00000.260617.csv
# -r--r--r-- 1 root root 7348290 Jul  5 13:58 out.mcxci.00001.260617.csv
# -r--r--r-- 1 root root 7347534 Jul  5 13:58 out.mcxci.00002.260618.csv
# -r--r--r-- 1 root root 7319984 Jul  5 13:58 out.mcxci.00003.260618.csv
# -r--r--r-- 1 root root 7306218 Jul  5 13:58 out.mcxci.00004.260618.csv
# -r--r--r-- 1 root root 7293078 Jul  5 13:58 out.mcxci.00005.260618.csv
# -r--r--r-- 1 root root 7265035 Jul  5 13:58 out.mcxci.00006.260618.csv
# -r--r--r-- 1 root root 7356007 Jul  5 13:58 out.mcxci.00007.260618.csv
# -r--r--r-- 1 root root 7327603 Jul  5 13:58 out.mcxci.00008.260619.csv

# %%
# ── Cell 3: Feature pipeline — exact copy from btc_signal_analysis.py ────
#
# All feature definitions and bias rules are preserved.
# Only the columns needed are read from CSV (memory optimisation).

SEPARATOR = ';'
WINDOW_SEC = 15

COLS_NEEDED_BASE = {
    'spot_datetime', 'future_datetime', 'spot_timestamp', 'future_timestamp',
    'future_bid_close', 'future_ask_close',
    'future_bid_open', 'future_bid_max', 'future_bid_min',
    'future_bid_median', 'future_ask_median',
    'future_spread_open', 'future_spread_max',
    'future_buy_qty', 'future_sell_qty',
    'future_buy_samples', 'future_sell_samples',
    'future_buy_vwap', 'future_sell_vwap', 'future_price_diff',
    'future_bid_liq_0.0_median', 'future_ask_liq_0.0_median',
    'spot_buy_qty', 'spot_sell_qty',
    'opt_open_interest_sample', 'opt_funding_rate_sample',
    'opt_est_funding_rate_sample', 'opt_remaining_time_sample',
    'opt_long_force_exit_qty_sum', 'opt_short_force_exit_qty_sum',
    'future_first_trade_side', 'future_last_trade_side',
    'future_largest_trade_qty', 'future_largest_trade_side',
    'future_buy_count_early', 'future_buy_count_late',
    'future_sell_count_early', 'future_sell_count_late',
    'future_buy_qty_early', 'future_buy_qty_late',
    'future_sell_qty_early', 'future_sell_qty_late',
}
COLS_NEEDED_LIQ_DEEP  = [
    'future_bid_liq_0.04_median', 'future_ask_liq_0.04_median',
    'future_bid_liq_0.05_median', 'future_ask_liq_0.05_median',
    'future_bid_liq_0.06_median', 'future_ask_liq_0.06_median',
]
COLS_NEEDED_LIQ_TOTAL = [
    'future_bid_liq_0.1_median',  'future_ask_liq_0.1_median',
    'future_bid_liq_0.2_median',  'future_ask_liq_0.2_median',
    'future_bid_liq_0.3_median',  'future_ask_liq_0.3_median',
    'future_bid_liq_0.4_median',  'future_ask_liq_0.4_median',
]

ALL_FEATURES = [
    # Original 25
    'book_imbalance', 'flow_imbalance', 'momentum', 'book_imbal_deep',
    'flow_imbal_roll4', 'flow_imbal_roll8', 'book_imbal_roll4', 'book_imbal_roll8',
    'vwap_spread', 'liq_flag', 'stochastic', 'spread_expansion', 'sample_imbalance',
    'flow_agreement', 'oi_change', 'size_imbalance', 'liq_conc_bid', 'liq_conc_ask',
    'hour_sin', 'hour_cos', 'minute_sin', 'minute_cos',
    'near_funding', 'funding_pressure', 'vol_norm',
    # Sub-bar (if available)
    'trade_side_open', 'trade_side_close', 'trade_side_momentum',
    'largest_trade_side', 'largest_trade_rel',
    'buy_accel', 'sell_accel', 'flow_accel', 'buy_count_accel', 'late_imbalance',
]


def load_files(files):
    all_needed = COLS_NEEDED_BASE | set(COLS_NEEDED_LIQ_DEEP) | set(COLS_NEEDED_LIQ_TOTAL)
    frames = []
    for path in files:
        try:
            hdr = pd.read_csv(path, sep=SEPARATOR, nrows=0)
            usecols = sorted(all_needed & set(hdr.columns))
            if 'spot_datetime' not in usecols:
                print(f'  SKIP {os.path.basename(path)}: missing spot_datetime')
                continue
            df = pd.read_csv(path, sep=SEPARATOR, usecols=usecols, low_memory=False)
            df = df[df['spot_datetime'] != 'spot_datetime']
            frames.append(df)
            print(f'  Loaded {os.path.basename(path):45s}  {len(df):>7,} rows  ({len(usecols)} cols)')
        except Exception as e:
            print(f'  SKIP {os.path.basename(path)}: {e}')
    if not frames:
        raise RuntimeError('No valid CSV files found.')
    return pd.concat(frames, ignore_index=True)


def prepare(df, threshold, horizon):
    """Exact feature pipeline from btc_signal_analysis.py. No lookahead bias."""
    df['dt'] = pd.to_datetime(df['spot_datetime'], errors='coerce')
    df = df.dropna(subset=['dt']).sort_values('dt').reset_index(drop=True)
    n_before = len(df)
    df = df.drop_duplicates(subset='dt', keep='first').reset_index(drop=True)
    if len(df) < n_before:
        print(f'  Dropped {n_before - len(df)} duplicate timestamps')

    skip = {'spot_datetime', 'future_datetime', 'dt'}
    for col in df.columns:
        if col not in skip:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    for col in [c for c in df.columns if c.startswith('opt_')]:
        df[col] = df[col].replace(-1, np.nan)

    if 'future_bid_close' in df.columns and 'future_ask_close' in df.columns:
        df['close_price'] = (df['future_bid_close'] + df['future_ask_close']) / 2.0
    else:
        df['close_price'] = (df['future_bid_median'] + df['future_ask_median']) / 2.0

    next_close   = df['close_price'].shift(-horizon)
    delta        = next_close - df['close_price']
    df['target'] = np.where(delta > threshold, 1, np.where(delta < -threshold, -1, 0))
    df['delta_usd'] = delta

    eps = 1e-9

    df['flow_imbalance'] = ((df['future_buy_qty'] - df['future_sell_qty']) /
                            (df['future_buy_qty'] + df['future_sell_qty'] + eps))
    bid0 = df['future_bid_liq_0.0_median']
    ask0 = df['future_ask_liq_0.0_median']
    df['book_imbalance'] = (bid0 - ask0) / (bid0 + ask0 + eps)
    df['momentum'] = df['future_price_diff']

    deep_col = None
    for lvl in ['0.05', '0.04', '0.06']:
        b, a = f'future_bid_liq_{lvl}_median', f'future_ask_liq_{lvl}_median'
        if b in df.columns and a in df.columns:
            deep_col = (b, a); break
    df['book_imbal_deep'] = ((df[deep_col[0]] - df[deep_col[1]]) /
                             (df[deep_col[0]] + df[deep_col[1]] + eps)) if deep_col else np.nan

    df['flow_imbal_roll4'] = df['flow_imbalance'].rolling(4, min_periods=2).mean()
    df['flow_imbal_roll8'] = df['flow_imbalance'].rolling(8, min_periods=4).mean()
    df['book_imbal_roll4'] = df['book_imbalance'].rolling(4, min_periods=2).mean()
    df['book_imbal_roll8'] = df['book_imbalance'].rolling(8, min_periods=4).mean()

    df['vwap_spread'] = (df['future_buy_vwap'] - df['future_sell_vwap']
                         if 'future_buy_vwap' in df.columns else np.nan)
    liq_long  = df.get('opt_long_force_exit_qty_sum',  pd.Series(0, index=df.index))
    liq_short = df.get('opt_short_force_exit_qty_sum', pd.Series(0, index=df.index))
    df['liq_flag'] = ((liq_long + liq_short) > 0).astype(float)

    if all(c in df.columns for c in ['future_bid_max', 'future_bid_min', 'future_bid_close']):
        rng = df['future_bid_max'] - df['future_bid_min']
        df['stochastic'] = np.where(rng > 0, (df['future_bid_close'] - df['future_bid_min']) / rng, 0.5)
    else:
        df['stochastic'] = np.nan

    df['spread_expansion'] = (df['future_spread_max'] - df['future_spread_open']
                              if all(c in df.columns for c in ['future_spread_max', 'future_spread_open'])
                              else np.nan)

    if all(c in df.columns for c in ['future_buy_samples', 'future_sell_samples']):
        bs, ss = df['future_buy_samples'], df['future_sell_samples']
        df['sample_imbalance'] = (bs - ss) / (bs + ss + eps)
    else:
        df['sample_imbalance'] = np.nan

    if all(c in df.columns for c in ['spot_buy_qty', 'spot_sell_qty']):
        spot_flow = ((df['spot_buy_qty'] - df['spot_sell_qty']) /
                     (df['spot_buy_qty'] + df['spot_sell_qty'] + eps))
        df['flow_agreement'] = df['flow_imbalance'] * spot_flow
    else:
        df['flow_agreement'] = np.nan

    df['oi_change'] = df['opt_open_interest_sample'].diff() if 'opt_open_interest_sample' in df.columns else np.nan

    if all(c in df.columns for c in ['future_buy_samples', 'future_sell_samples',
                                      'future_buy_qty', 'future_sell_qty']):
        df['size_imbalance'] = (df['future_buy_qty']  / (df['future_buy_samples']  + eps) -
                                df['future_sell_qty'] / (df['future_sell_samples'] + eps))
    else:
        df['size_imbalance'] = np.nan

    # Sub-bar features
    sub_cols = ['future_first_trade_side', 'future_last_trade_side',
                'future_largest_trade_qty', 'future_largest_trade_side',
                'future_buy_count_early', 'future_buy_count_late',
                'future_sell_count_early', 'future_sell_count_late',
                'future_buy_qty_early', 'future_buy_qty_late',
                'future_sell_qty_early', 'future_sell_qty_late']
    if all(c in df.columns for c in sub_cols):
        bqe, bql = df['future_buy_qty_early'],  df['future_buy_qty_late']
        sqe, sql = df['future_sell_qty_early'],  df['future_sell_qty_late']
        fts, lts = df['future_first_trade_side'], df['future_last_trade_side']
        lq,  ls  = df['future_largest_trade_qty'], df['future_largest_trade_side']
        bce, bcl = df['future_buy_count_early'], df['future_buy_count_late']
        total_vol = bqe + bql + sqe + sql
        df['trade_side_open']     = fts
        df['trade_side_close']    = lts
        df['trade_side_momentum'] = lts - fts
        df['largest_trade_side']  = ls
        df['largest_trade_rel']   = lq / (total_vol + eps)
        df['buy_accel']           = bql - bqe
        df['sell_accel']          = sql - sqe
        df['flow_accel']          = (bql - sql) - (bqe - sqe)
        df['buy_count_accel']     = bcl - bce
        df['late_imbalance']      = (bql - sql) / (bql + sql + eps)
    else:
        for c in ['trade_side_open','trade_side_close','trade_side_momentum',
                  'largest_trade_side','largest_trade_rel','buy_accel','sell_accel',
                  'flow_accel','buy_count_accel','late_imbalance']:
            df[c] = np.nan

    # Book shape
    deep_bid = next((c for c in ['future_bid_liq_0.4_median','future_bid_liq_0.3_median',
                                  'future_bid_liq_0.2_median','future_bid_liq_0.1_median']
                     if c in df.columns), None)
    deep_ask = next((c for c in ['future_ask_liq_0.4_median','future_ask_liq_0.3_median',
                                  'future_ask_liq_0.2_median','future_ask_liq_0.1_median']
                     if c in df.columns), None)
    df['liq_conc_bid'] = (df['future_bid_liq_0.0_median'] / (df[deep_bid] + eps)
                          if deep_bid else np.nan)
    df['liq_conc_ask'] = (df['future_ask_liq_0.0_median'] / (df[deep_ask] + eps)
                          if deep_ask else np.nan)

    # Time features
    hour, minute = df['dt'].dt.hour, df['dt'].dt.minute
    df['hour_sin']   = np.sin(2 * np.pi * hour   / 24)
    df['hour_cos']   = np.cos(2 * np.pi * hour   / 24)
    df['minute_sin'] = np.sin(2 * np.pi * minute / 60)
    df['minute_cos'] = np.cos(2 * np.pi * minute / 60)

    secs = (hour * 3600 + minute * 60 + df['dt'].dt.second) % (8 * 3600)
    df['near_funding'] = ((8 * 3600 - secs) < 900).astype(float)
    if 'opt_funding_rate_sample' in df.columns:
        funding = df['opt_funding_rate_sample'].replace(-1, np.nan).fillna(0)
        df['funding_pressure'] = funding * df['near_funding']
    else:
        df['funding_pressure'] = np.nan

    # Volatility
    df['volatility'] = df['close_price'].diff().abs().rolling(16, min_periods=4).mean()
    df['vol_norm']   = (df['volatility'] /
                        df['volatility'].rolling(5760, min_periods=96).mean()
                       ).replace([np.inf, -np.inf], np.nan)

    df = df.iloc[:-horizon].copy()
    return df

print('Feature pipeline loaded.')
# Out:
# Feature pipeline loaded.

# %%
# ── Cell 4: Load and prepare data ────────────────────────────────────────
files = sorted(glob.glob(os.path.join(DATA_DIR, '*.csv')) +
               glob.glob(os.path.join(DATA_DIR, '*.csv.gz')))
print(f'Found {len(files)} files')

raw = load_files(files)
print(f'\nTotal rows loaded: {len(raw):,}')

df = prepare(raw, THRESHOLD, HORIZON)
del raw  # free memory

# Select available features
features = [f for f in ALL_FEATURES if f in df.columns and df[f].notna().sum() > 100]
print(f'\nFeatures available: {len(features)}/35')
print(f'Date range: {df["dt"].iloc[0]} → {df["dt"].iloc[-1]}')
print(f'Total rows after prepare: {len(df):,}')

# Class distribution
vc = df['target'].value_counts().sort_index()
for k, v in vc.items():
    label = {-1: 'DOWN', 0: 'FLAT', 1: 'UP'}[k]
    print(f'  {label}: {v:,} ({v/len(df)*100:.1f}%)')
# Out:
# Found 1679 files
#   Loaded out.mcxci.00000.260617.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00001.260617.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00002.260618.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00003.260618.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00004.260618.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00005.260618.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00006.260618.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00007.260618.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00008.260619.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00009.260619.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00010.260619.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00011.260619.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00012.260619.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00013.260619.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00014.260620.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00015.260620.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00016.260620.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00017.260620.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00018.260620.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00019.260621.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00020.260621.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00021.260621.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00022.260621.csv                         960 rows  (44 cols)
#   Loaded out.mcxci.00023.260621.csv                         299 rows  (44 cols)
#   Loaded out.mrfni.00000.260130.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00001.260131.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00002.260131.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00003.260131.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00004.260131.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00005.260131.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00006.260131.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00007.260201.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00008.260201.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00009.260201.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00010.260201.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00011.260201.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00012.260201.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00013.260202.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00014.260202.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00015.260202.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00016.260202.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00017.260202.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00018.260202.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00019.260203.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00020.260203.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00021.260203.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00022.260203.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00023.260203.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00024.260203.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00025.260204.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00026.260204.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00027.260204.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00028.260204.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00029.260204.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00030.260204.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00031.260205.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00032.260205.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00033.260205.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00034.260205.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00035.260205.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00036.260205.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00037.260206.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00038.260206.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00039.260206.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00040.260206.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00041.260206.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00042.260206.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00043.260207.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00044.260207.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00045.260207.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00046.260207.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00047.260207.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00048.260207.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00049.260208.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00050.260208.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00051.260208.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00052.260209.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00053.260209.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00054.260209.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00055.260209.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00056.260209.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00057.260209.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00058.260210.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00059.260210.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00060.260210.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00061.260210.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00062.260210.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00063.260210.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00064.260211.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00065.260211.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00066.260211.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00067.260211.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00068.260211.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00069.260211.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00070.260212.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00071.260212.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00072.260212.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00073.260212.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00074.260212.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00075.260212.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00076.260213.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00077.260213.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00078.260213.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00079.260213.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00080.260213.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00081.260213.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00082.260214.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00083.260214.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00084.260214.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00085.260214.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00086.260214.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00087.260214.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00088.260215.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00089.260215.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00090.260215.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00091.260215.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00092.260215.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00093.260215.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00094.260216.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00095.260216.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00096.260216.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00097.260216.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00098.260216.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00099.260216.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00100.260217.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00101.260217.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00102.260217.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00103.260217.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00104.260217.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00105.260217.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00106.260218.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00107.260218.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00108.260218.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00109.260218.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00110.260218.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00111.260218.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00112.260219.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00113.260219.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00114.260219.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00115.260219.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00116.260219.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00117.260219.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00118.260220.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00119.260220.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00120.260220.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00121.260220.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00122.260220.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00123.260220.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00124.260221.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00125.260221.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00126.260221.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00127.260221.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00128.260221.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00129.260221.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00130.260222.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00131.260222.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00132.260222.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00133.260222.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00134.260222.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00135.260222.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00136.260223.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00137.260223.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00138.260223.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00139.260223.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00140.260223.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00141.260223.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00142.260224.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00143.260224.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00144.260224.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00145.260224.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00146.260224.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00147.260224.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00148.260225.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00149.260225.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00150.260225.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00151.260225.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00152.260225.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00153.260225.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00154.260226.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00155.260226.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00156.260226.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00157.260226.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00158.260226.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00159.260226.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00160.260227.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00161.260227.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00162.260227.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00163.260227.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00164.260227.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00165.260227.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00166.260228.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00167.260228.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00168.260228.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00169.260228.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00170.260228.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00171.260228.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00172.260301.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00173.260301.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00174.260301.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00175.260301.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00176.260301.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00177.260301.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00178.260302.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00179.260302.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00180.260302.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00181.260302.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00182.260302.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00183.260302.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00184.260303.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00185.260303.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00186.260303.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00187.260303.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00188.260303.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00189.260303.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00190.260304.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00191.260304.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00192.260304.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00193.260304.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00194.260304.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00195.260304.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00196.260305.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00197.260305.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00198.260305.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00199.260305.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00200.260305.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00201.260305.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00202.260306.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00203.260306.csv                         960 rows  (44 cols)
#   Loaded out.mrfni.00204.260307.csv                          86 rows  (44 cols)
#   Loaded out.nsgpe.00000.260317.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00001.260318.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00002.260318.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00003.260318.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00004.260318.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00005.260318.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00006.260318.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00007.260319.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00008.260319.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00009.260319.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00010.260319.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00011.260319.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00012.260319.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00013.260320.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00014.260320.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00015.260320.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00016.260320.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00017.260320.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00018.260320.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00019.260321.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00020.260321.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00021.260321.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00022.260321.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00023.260321.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00024.260321.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00025.260322.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00026.260322.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00027.260322.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00028.260322.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00029.260322.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00030.260323.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00031.260323.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00032.260323.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00033.260323.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00034.260323.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00035.260323.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00036.260324.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00037.260324.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00038.260324.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00039.260324.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00040.260324.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00041.260324.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00042.260325.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00043.260325.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00044.260325.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00045.260325.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00046.260325.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00047.260325.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00048.260326.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00049.260326.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00050.260326.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00051.260326.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00052.260326.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00053.260326.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00054.260327.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00055.260327.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00056.260327.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00057.260327.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00058.260327.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00059.260327.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00060.260328.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00061.260328.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00062.260328.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00063.260328.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00064.260328.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00065.260328.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00066.260329.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00067.260329.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00068.260329.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00069.260329.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00070.260329.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00071.260329.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00072.260330.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00073.260330.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00074.260330.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00075.260330.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00076.260330.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00077.260330.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00078.260331.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00079.260331.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00080.260331.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00081.260331.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00082.260331.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00083.260331.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00084.260401.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00085.260401.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00086.260401.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00087.260401.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00088.260401.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00089.260401.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00090.260402.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00091.260402.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00092.260402.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00093.260402.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00094.260402.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00095.260402.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00096.260403.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00097.260403.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00098.260403.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00099.260403.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00100.260403.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00101.260403.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00102.260404.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00103.260404.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00104.260404.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00105.260404.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00106.260404.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00107.260405.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00108.260405.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00109.260405.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00110.260405.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00111.260405.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00112.260405.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00113.260406.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00114.260406.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00115.260406.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00116.260406.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00117.260406.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00118.260406.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00119.260407.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00120.260407.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00121.260407.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00122.260407.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00123.260407.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00124.260407.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00125.260408.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00126.260408.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00127.260408.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00128.260408.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00129.260408.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00130.260408.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00131.260409.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00132.260409.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00133.260409.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00134.260409.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00135.260409.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00136.260409.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00137.260410.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00138.260410.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00139.260410.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00140.260410.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00141.260410.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00142.260410.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00143.260411.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00144.260411.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00145.260411.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00146.260411.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00147.260411.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00148.260411.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00149.260412.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00150.260412.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00151.260412.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00152.260412.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00153.260412.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00154.260412.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00155.260413.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00156.260413.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00157.260413.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00158.260413.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00159.260413.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00160.260413.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00161.260414.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00162.260414.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00163.260414.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00164.260414.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00165.260414.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00166.260414.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00167.260415.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00168.260415.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00169.260415.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00170.260415.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00171.260415.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00172.260415.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00173.260416.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00174.260416.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00175.260416.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00176.260416.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00177.260416.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00178.260416.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00179.260417.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00180.260417.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00181.260417.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00182.260417.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00183.260417.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00184.260417.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00185.260418.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00186.260418.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00187.260418.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00188.260418.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00189.260418.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00190.260418.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00191.260419.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00192.260419.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00193.260419.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00194.260419.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00195.260419.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00196.260419.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00197.260420.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00198.260420.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00199.260420.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00200.260420.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00201.260420.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00202.260420.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00203.260421.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00204.260421.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00205.260421.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00206.260421.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00207.260421.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00208.260421.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00209.260422.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00210.260422.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00211.260422.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00212.260422.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00213.260422.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00214.260422.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00215.260423.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00216.260423.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00217.260423.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00218.260423.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00219.260423.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00220.260423.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00221.260424.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00222.260424.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00223.260424.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00224.260424.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00225.260424.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00226.260425.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00227.260425.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00228.260425.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00229.260425.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00230.260425.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00231.260425.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00232.260426.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00233.260426.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00234.260426.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00235.260426.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00236.260426.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00237.260426.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00238.260427.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00239.260427.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00240.260427.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00241.260427.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00242.260427.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00243.260427.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00244.260428.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00245.260428.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00246.260428.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00247.260428.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00248.260428.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00249.260428.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00250.260429.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00251.260429.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00252.260429.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00253.260429.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00254.260429.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00255.260429.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00256.260430.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00257.260430.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00258.260430.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00259.260430.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00260.260430.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00261.260430.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00262.260501.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00263.260501.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00264.260501.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00265.260501.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00266.260501.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00267.260501.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00268.260502.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00269.260502.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00270.260502.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00271.260502.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00272.260502.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00273.260502.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00274.260503.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00275.260503.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00276.260503.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00277.260503.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00278.260503.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00279.260504.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00280.260504.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00281.260504.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00282.260504.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00283.260504.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00284.260504.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00285.260505.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00286.260505.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00287.260505.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00288.260505.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00289.260505.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00290.260505.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00291.260506.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00292.260506.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00293.260506.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00294.260506.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00295.260506.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00296.260506.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00297.260507.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00298.260507.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00299.260507.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00300.260507.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00301.260507.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00302.260507.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00303.260508.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00304.260508.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00305.260508.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00306.260508.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00307.260508.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00308.260508.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00309.260509.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00310.260509.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00311.260509.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00312.260509.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00313.260509.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00314.260509.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00315.260510.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00316.260510.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00317.260510.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00318.260510.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00319.260510.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00320.260510.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00321.260511.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00322.260511.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00323.260511.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00324.260511.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00325.260511.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00326.260511.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00327.260512.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00328.260512.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00329.260512.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00330.260512.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00331.260512.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00332.260512.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00333.260513.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00334.260513.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00335.260513.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00336.260513.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00337.260513.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00338.260513.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00339.260514.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00340.260514.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00341.260514.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00342.260514.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00343.260514.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00344.260514.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00345.260515.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00346.260515.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00347.260515.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00348.260515.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00349.260515.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00350.260515.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00351.260516.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00352.260516.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00353.260516.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00354.260516.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00355.260516.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00356.260516.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00357.260517.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00358.260517.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00359.260517.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00360.260517.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00361.260517.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00362.260517.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00363.260518.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00364.260518.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00365.260518.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00366.260518.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00367.260518.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00368.260518.csv                         960 rows  (44 cols)
#   Loaded out.nsgpe.00369.260519.csv                         960 rows  (44 cols)
# ...
#   Loaded out.pjhsr.00267.260113.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00268.260113.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00269.260113.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00270.260113.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00271.260114.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00272.260114.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00273.260114.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00274.260114.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00275.260114.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00276.260114.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00277.260115.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00278.260115.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00279.260115.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00280.260115.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00281.260115.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00282.260115.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00283.260116.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00284.260116.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00285.260116.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00286.260116.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00287.260116.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00288.260116.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00289.260117.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00290.260117.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00291.260117.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00292.260117.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00293.260117.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00294.260117.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00295.260118.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00296.260118.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00297.260118.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00298.260118.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00299.260118.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00300.260118.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00301.260119.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00302.260119.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00303.260119.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00304.260119.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00305.260119.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00306.260119.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00307.260120.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00308.260120.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00309.260120.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00310.260120.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00311.260120.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00312.260120.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00313.260121.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00314.260121.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00315.260121.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00316.260121.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00317.260121.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00318.260121.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00319.260122.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00320.260122.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00321.260122.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00322.260122.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00323.260122.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00324.260122.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00325.260123.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00326.260123.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00327.260123.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00328.260123.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00329.260123.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00330.260123.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00331.260124.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00332.260124.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00333.260124.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00334.260124.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00335.260124.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00336.260124.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00337.260125.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00338.260125.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00339.260125.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00340.260125.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00341.260125.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00342.260125.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00343.260126.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00344.260126.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00345.260126.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00346.260126.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00347.260126.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00348.260126.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00349.260127.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00350.260127.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00351.260127.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00352.260127.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00353.260127.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00354.260127.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00355.260128.csv                         960 rows  (44 cols)
#   Loaded out.pjhsr.00356.260128.csv                         524 rows  (44 cols)
#   Loaded out.rzeac.00000.260621.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00001.260621.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00002.260622.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00003.260622.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00004.260622.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00005.260622.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00006.260622.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00007.260622.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00008.260623.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00009.260623.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00010.260623.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00011.260623.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00012.260623.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00013.260623.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00014.260624.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00015.260624.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00016.260624.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00017.260624.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00018.260624.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00019.260624.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00020.260625.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00021.260625.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00022.260625.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00023.260625.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00024.260625.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00025.260625.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00026.260626.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00027.260626.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00028.260626.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00029.260626.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00030.260626.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00031.260626.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00032.260627.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00033.260627.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00034.260627.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00035.260627.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00036.260627.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00037.260627.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00038.260628.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00039.260628.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00040.260628.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00041.260628.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00042.260628.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00043.260628.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00044.260629.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00045.260629.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00046.260629.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00047.260629.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00048.260629.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00049.260630.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00050.260630.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00051.260630.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00052.260630.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00053.260630.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00054.260630.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00055.260701.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00056.260701.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00057.260701.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00058.260701.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00059.260701.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00060.260701.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00061.260702.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00062.260702.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00063.260702.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00064.260702.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00065.260702.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00066.260702.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00067.260703.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00068.260703.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00069.260703.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00070.260703.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00071.260703.csv                         960 rows  (44 cols)
#   Loaded out.rzeac.00072.260703.csv                         960 rows  (44 cols)
#   Loaded out.wiccu.00000.250914.csv                         788 rows  (32 cols)
#   Loaded out.zyzjh.00000.260310.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00001.260310.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00002.260310.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00003.260310.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00004.260311.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00005.260311.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00006.260311.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00007.260311.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00008.260311.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00009.260311.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00010.260312.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00011.260312.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00012.260312.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00013.260312.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00014.260312.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00015.260312.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00016.260313.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00017.260313.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00018.260313.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00019.260313.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00020.260313.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00021.260313.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00022.260314.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00023.260314.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00024.260314.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00025.260314.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00026.260314.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00027.260314.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00028.260315.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00029.260315.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00030.260315.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00031.260315.csv                         960 rows  (44 cols)
#   Loaded out.zyzjh.00032.260315.csv                         940 rows  (44 cols)
#
# Total rows loaded: 1,608,951
#
# Features available: 25/35
# Date range: 2025-09-14 16:36:30 → 2026-07-04 00:34:15
# Total rows after prepare: 1,608,943
#   DOWN: 267,996 (16.7%)
#   FLAT: 1,078,415 (67.0%)
#   UP: 262,532 (16.3%)

# %%
# ── Cell 5: Build sequences ───────────────────────────────────────────────
#
# For each row N, the input is [bar_{N-SEQ_LEN+1}, ..., bar_N] — SEQ_LEN bars
# of feature history. The label is target[N].
#
# Bias guarantee: sequence[i] for position N uses only rows 0..N.
# Same truncation test as btc_signal_analysis.py verifies this.
#
# Rows with ANY NaN feature are excluded (model can't handle NaN).
# This removes warm-up rows at the start and sub-bar NaN rows from old files.

clean = df[features + ['target', 'close_price', 'dt']].dropna().reset_index(drop=True)
print(f'Clean rows (no NaN in any feature): {len(clean):,}  '
      f'({len(clean)/len(df)*100:.1f}% of prepared data)')

X_all = clean[features].values.astype(np.float32)
y_all = clean['target'].values
price_all = clean['close_price'].values
dt_all    = clean['dt'].values

# Scale features BEFORE building sequences — scaler fitted on train only
n         = len(clean)
train_end = int(n * TRAIN_FRAC)
val_end   = int(n * (TRAIN_FRAC + VAL_FRAC))

scaler = StandardScaler()
X_all[:train_end] = scaler.fit_transform(X_all[:train_end])
X_all[train_end:] = scaler.transform(X_all[train_end:])
print(f'Scaler fitted on {train_end:,} training rows')

# Build sliding window sequences
def make_sequences(X, y, seq_len):
    """Return (sequences, labels) arrays with shape (N-seq_len, seq_len, F) and (N-seq_len,)."""
    N, F = X.shape
    seqs   = np.lib.stride_tricks.sliding_window_view(X, (seq_len, F)).reshape(-1, seq_len, F)
    labels = y[seq_len - 1:]  # label is at the LAST bar of each window
    return seqs.astype(np.float32), labels

# Build sequences per split to avoid cross-split contamination
X_train_seq, y_train = make_sequences(X_all[:train_end], y_all[:train_end], SEQ_LEN)
X_val_seq,   y_val   = make_sequences(X_all[train_end:val_end], y_all[train_end:val_end], SEQ_LEN)
X_test_seq,  y_test  = make_sequences(X_all[val_end:], y_all[val_end:], SEQ_LEN)
price_test            = price_all[val_end + SEQ_LEN - 1:]
dt_test               = dt_all[val_end + SEQ_LEN - 1:]

print(f'\nSequences built (seq_len={SEQ_LEN} bars = {SEQ_LEN*WINDOW_SEC}s):')
print(f'  Train: {len(X_train_seq):,}  Val: {len(X_val_seq):,}  Test: {len(X_test_seq):,}')
print(f'  Input shape: {X_train_seq.shape}  (samples, seq_len, features)')
# Out:
# Clean rows (no NaN in any feature): 1,607,007  (99.9% of prepared data)
# Scaler fitted on 1,124,904 training rows
#
# Sequences built (seq_len=32 bars = 480s):
#   Train: 1,124,873  Val: 241,020  Test: 241,021
#   Input shape: (1124873, 32, 25)  (samples, seq_len, features)

# %%
# ── Cell 6: Dataset and DataLoader ───────────────────────────────────────

class SeqDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X)
        # Map -1→0, 0→1, 1→2 for CrossEntropyLoss
        self.y = torch.tensor(y + 1, dtype=torch.long)
    def __len__(self):  return len(self.X)
    def __getitem__(self, i): return self.X[i], self.y[i]

train_ds = SeqDataset(X_train_seq, y_train)
val_ds   = SeqDataset(X_val_seq,   y_val)
test_ds  = SeqDataset(X_test_seq,  y_test)

train_dl = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2, pin_memory=True)
val_dl   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_dl  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

# Class weights to handle FLAT dominance
cw = compute_class_weight('balanced', classes=np.array([-1, 0, 1]), y=y_train)
class_weights = torch.tensor(cw, dtype=torch.float32).to(device)
print(f'Class weights: DOWN={cw[0]:.2f}  FLAT={cw[1]:.2f}  UP={cw[2]:.2f}')
# Out:
# Class weights: DOWN=1.80  FLAT=0.53  UP=1.83

# %%
# ── Cell 7: LSTM model ────────────────────────────────────────────────────

class BtcLSTM(nn.Module):
    """
    Stacked LSTM with:
      - Layer norm on input (stabilises training on heterogeneous features)
      - Dropout between layers
      - Linear classifier on final hidden state
    """
    def __init__(self, input_dim, hidden_dim, num_layers, dropout, num_classes=3):
        super().__init__()
        self.input_norm = nn.LayerNorm(input_dim)
        self.lstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0.0,
            bidirectional=False,  # causal: can only see past bars
        )
        self.dropout  = nn.Dropout(dropout)
        self.fc       = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        # x: (batch, seq_len, features)
        x   = self.input_norm(x)
        out, _ = self.lstm(x)
        # Use only the last timestep's hidden state
        last = out[:, -1, :]  # (batch, hidden)
        return self.fc(self.dropout(last))  # (batch, 3)


model = BtcLSTM(
    input_dim=len(features),
    hidden_dim=HIDDEN_DIM,
    num_layers=NUM_LAYERS,
    dropout=DROPOUT,
).to(device)

total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'Model parameters: {total_params:,}')
print(model)
# Out:
# Model parameters: 211,893
# BtcLSTM(
#   (input_norm): LayerNorm((25,), eps=1e-05, elementwise_affine=True)
#   (lstm): LSTM(25, 128, num_layers=2, batch_first=True, dropout=0.3)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=128, out_features=3, bias=True)
# )

# %%
# ── Cell 8: Training ──────────────────────────────────────────────────────

criterion  = nn.CrossEntropyLoss(weight=class_weights)
optimizer  = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=1e-4)
scheduler  = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS)

best_val_loss = float('inf')
best_state    = None
patience      = 8
wait          = 0

train_losses, val_losses, val_accs = [], [], []

for epoch in range(1, EPOCHS + 1):
    # ── Train
    model.train()
    running_loss = 0.0
    for X_b, y_b in train_dl:
        X_b, y_b = X_b.to(device), y_b.to(device)
        optimizer.zero_grad()
        loss = criterion(model(X_b), y_b)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        running_loss += loss.item() * len(X_b)
    train_loss = running_loss / len(train_ds)

    # ── Validate
    model.eval()
    val_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for X_b, y_b in val_dl:
            X_b, y_b = X_b.to(device), y_b.to(device)
            logits = model(X_b)
            val_loss += criterion(logits, y_b).item() * len(X_b)
            preds    = logits.argmax(1)
            correct += (preds == y_b).sum().item()
            total   += len(y_b)
    val_loss /= len(val_ds)
    val_acc   = correct / total
    scheduler.step()

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    val_accs.append(val_acc)

    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state    = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        wait          = 0
        flag = '  ← best'
    else:
        wait += 1
        flag  = f'  (patience {wait}/{patience})'

    if epoch % 5 == 0 or epoch == 1:
        lr_now = optimizer.param_groups[0]['lr']
        print(f'Epoch {epoch:3d}  train={train_loss:.4f}  val={val_loss:.4f}  '
              f'val_acc={val_acc*100:.2f}%  lr={lr_now:.2e}{flag}')

    if wait >= patience:
        print(f'\nEarly stopping at epoch {epoch} (patience={patience})')
        break

# Restore best weights
model.load_state_dict(best_state)
print(f'\nBest val loss: {best_val_loss:.4f}')
# Out:
# Epoch   1  train=1.0201  val=0.9477  val_acc=70.98%  lr=9.98e-04  ← best
# Epoch   5  train=0.9968  val=0.9456  val_acc=69.72%  lr=9.62e-04  (patience 1/8)
# Epoch  10  train=0.8996  val=1.0313  val_acc=63.61%  lr=8.54e-04  (patience 6/8)
#
# Early stopping at epoch 12 (patience=8)
#
# Best val loss: 0.9393

# %%
# ── Cell 9: Evaluation and backtest ──────────────────────────────────────

le_inv = {0: -1, 1: 0, 2: 1}  # class index → target value

model.eval()
all_logits, all_labels = [], []
with torch.no_grad():
    for X_b, y_b in test_dl:
        logits = model(X_b.to(device)).cpu()
        all_logits.append(logits)
        all_labels.append(y_b)

logits_all = torch.cat(all_logits)
proba_all  = torch.softmax(logits_all, dim=1).numpy()   # (N, 3)
pred_enc   = logits_all.argmax(1).numpy()               # 0/1/2
preds      = np.array([le_inv[p] for p in pred_enc])    # -1/0/1
confidence = proba_all.max(axis=1)                      # max class prob

y_test_orig = np.array([le_inv[l.item()] for l in all_labels[0].unbind()] +
                        [le_inv[l.item()] for lb in all_labels[1:] for l in lb.unbind()])

# Accuracy
dummy_acc = max(np.bincount(pred_enc + 1) / len(pred_enc))
acc       = (preds == y_test_orig).mean()
dummy_acc = max(np.bincount([{-1:0,0:1,1:2}[v] for v in y_test_orig]) / len(y_test_orig))
print(f'Test accuracy : {acc*100:.2f}%')
print(f'Dummy baseline: {dummy_acc*100:.2f}%')
print(f'Lift          : {(acc - dummy_acc)*100:+.2f}%')

# Backtest: same method as btc_signal_analysis.py
# price_test[i] = close price at bar i of the test set
# trade P&L = predicted direction × next bar price move
price_moves = np.diff(price_test, prepend=price_test[0])
# For bar N: if we enter at close_price[N] and exit at close_price[N+1],
# P&L = preds[N] * (close_price[N+1] - close_price[N])
# We use the actual next-bar price move (price_moves[N+1])
# Note: last bar has no exit — drop it
trade_pnl = np.where(preds[:-1] ==  1,  np.diff(price_test),
            np.where(preds[:-1] == -1, -np.diff(price_test), 0.0))

bnh_pnl    = price_test[-1] - price_test[0]
strat_pnl  = trade_pnl.sum()
n_trades   = (preds[:-1] != 0).sum()
n_long     = (preds[:-1] ==  1).sum()
n_short    = (preds[:-1] == -1).sum()
trades_pnl = trade_pnl[preds[:-1] != 0]
win_rate   = (trades_pnl > 0).mean() if len(trades_pnl) > 0 else 0
avg_win    = trades_pnl[trades_pnl > 0].mean() if (trades_pnl > 0).any() else 0
avg_loss   = trades_pnl[trades_pnl < 0].mean() if (trades_pnl < 0).any() else 0

avg_price  = price_test.mean()
maker_fee  = avg_price * 0.0004  # 0.02% per side
taker_fee  = avg_price * 0.0010  # 0.05% per side

print(f'\n{'─'*60}')
print(f'BACKTEST (test set, zero fees)')
print(f'{'─'*60}')
print(f'Test period  : {pd.Timestamp(dt_test[0])} → {pd.Timestamp(dt_test[-1])}')
print(f'BTC price    : ${price_test[0]:,.0f} → ${price_test[-1]:,.0f}  (Δ${price_test[-1]-price_test[0]:+,.0f})')
print(f'Total signals: {n_trades:,}  ({n_trades/len(preds)*100:.1f}% of bars)')
print(f'Long / Short : {n_long:,} / {n_short:,}')
print(f'Strategy P&L : ${strat_pnl:+,.2f}  (vs B&H ${bnh_pnl:+,.2f})')
print(f'Win rate     : {win_rate*100:.2f}%  over {n_trades:,} trades')
print(f'Avg win/trade: ${avg_win:.2f}  |  Avg loss: ${avg_loss:.2f}')
print(f'Expected P&L/trade: ${win_rate*avg_win + (1-win_rate)*avg_loss:.2f}')
print(f'Maker fee/trade  : ${maker_fee:.2f}')
print(f'After maker fees : ${strat_pnl - n_trades*maker_fee:+,.2f}')
print(f'After taker fees : ${strat_pnl - n_trades*taker_fee:+,.2f}')

# Confidence threshold sweep
print(f'\nConfidence threshold sweep (maker fee = ${maker_fee:.0f}/trade):')
print(f'  {"Threshold":>10}  {"Trades":>7}  {"WinRate":>8}  {"AvgP&L":>8}  {"After maker":>12}')
for thresh in [0.33, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70]:
    mask   = confidence[:-1] >= thresh
    fp     = np.where(mask & (preds[:-1] ==  1),  np.diff(price_test),
             np.where(mask & (preds[:-1] == -1), -np.diff(price_test), 0.0))
    nt     = mask.sum()
    if nt == 0:
        print(f'  {thresh:>10.0%}  {0:>7,}  {"":>8}  {"":>8}  {"":>12}')
        continue
    tp     = fp[mask]
    wr     = (tp > 0).mean()
    avg    = fp.sum() / nt
    after  = fp.sum() - nt * maker_fee
    ok     = '✓' if after > 0 else '✗'
    print(f'  {thresh:>10.0%}  {nt:>7,}  {wr*100:>7.2f}%  {avg:>+8.2f}  {after:>+12,.0f}  {ok}')

# Binomial test
try:
    from scipy.stats import binomtest
    n_wins = int(n_trades * win_rate)
    p = binomtest(n_wins, n_trades, 0.5, alternative='greater').pvalue
    print(f'\nBinomial test: win rate {win_rate*100:.2f}% over {n_trades:,} trades → p={p:.4f} '
          f'{"✓ significant" if p < 0.05 else "✗ not significant"}')
except:
    pass
# Out:
# Test accuracy : 63.18%
# Dummy baseline: 74.11%
# Lift          : -10.93%
#
# ────────────────────────────────────────────────────────────
# BACKTEST (test set, zero fees)
# ────────────────────────────────────────────────────────────
# Test period  : 2026-05-22 19:51:45 → 2026-07-04 00:34:15
# BTC price    : $76,948 → $62,533  (Δ$-14,415)
# Total signals: 84,533  (35.1% of bars)
# Long / Short : 49,701 / 34,832
# Strategy P&L : $+12,869.55  (vs B&H $-14,415.00)
# Win rate     : 50.11%  over 84,533 trades
# Avg win/trade: $21.15  |  Avg loss: $-21.67
# Expected P&L/trade: $-0.21
# Maker fee/trade  : $26.28
# After maker fees : $-2,208,920.97
# After taker fees : $-5,541,606.74
#
# Confidence threshold sweep (maker fee = $26/trade):
#    Threshold   Trades   WinRate    AvgP&L   After maker
#          33%  241,020    17.57%     +0.05    -6,321,887  ✗
#          40%  187,935    13.25%     +0.01    -4,938,230  ✗
#          45%  136,682     6.34%     -0.00    -3,592,519  ✗
#          50%  101,720     1.42%     +0.06    -2,667,728  ✗
#          55%   79,583     0.24%     +0.02    -2,090,174  ✗
#          60%   62,083     0.04%     -0.00    -1,631,945  ✗
#          65%   47,604     0.00%     +0.00    -1,251,156  ✗
#          70%   35,984     0.00%     +0.00      -945,772  ✗
#
# Binomial test: win rate 50.11% over 84,533 trades → p=0.2634 ✗ not significant

# %%
# ── Cell 10: Plots ────────────────────────────────────────────────────────

DARK, PANEL, GRID = '#0d1117', '#161b22', '#21262d'
TEXT, UP, DOWN, ACC = '#e6edf3', '#3fb950', '#f85149', '#58a6ff'
GOLD = '#f0883e'

fig = plt.figure(figsize=(18, 14), facecolor=DARK)
gs  = gridspec.GridSpec(3, 2, figure=fig, hspace=0.40, wspace=0.30,
                        left=0.07, right=0.97, top=0.93, bottom=0.07)

def style(ax, title):
    ax.set_facecolor(PANEL)
    ax.tick_params(colors=TEXT, labelsize=8)
    ax.set_title(title, color=TEXT, fontsize=9, fontweight='bold', pad=6)
    for sp in ax.spines.values(): sp.set_edgecolor(GRID)
    ax.grid(color=GRID, linewidth=0.5, alpha=0.7)
    ax.yaxis.label.set_color(TEXT)
    ax.xaxis.label.set_color(TEXT)

# 1. Training curves
ax1 = fig.add_subplot(gs[0, 0])
ep = range(1, len(train_losses) + 1)
ax1.plot(ep, train_losses, color=ACC, label='Train loss')
ax1.plot(ep, val_losses,   color=GOLD, label='Val loss')
ax1.legend(facecolor=PANEL, labelcolor=TEXT, edgecolor=GRID, fontsize=8)
ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss')
style(ax1, 'Training / Validation Loss')

ax1b = fig.add_subplot(gs[0, 1])
ax1b.plot(ep, [v*100 for v in val_accs], color=UP)
ax1b.axhline(dummy_acc*100, color=GRID, linestyle='--', label='Dummy baseline')
ax1b.legend(facecolor=PANEL, labelcolor=TEXT, edgecolor=GRID, fontsize=8)
ax1b.set_xlabel('Epoch'); ax1b.set_ylabel('Accuracy (%)')
style(ax1b, 'Validation Accuracy')

# 2. Cumulative P&L
ax2 = fig.add_subplot(gs[1, :])
cum_strat = np.cumsum(trade_pnl)
cum_bnh   = price_test[1:] - price_test[0]
x_idx     = np.arange(len(cum_strat))
ax2.plot(x_idx, cum_strat, color=ACC, linewidth=1.2, label=f'LSTM (zero fees)')
ax2.plot(x_idx, cum_bnh,   color=GOLD, linewidth=1.0, linestyle='--', label='Buy & Hold')
ax2.axhline(0, color=GRID, linewidth=0.8)
ax2.fill_between(x_idx, cum_strat, 0, where=cum_strat >= 0, alpha=0.12, color=UP)
ax2.fill_between(x_idx, cum_strat, 0, where=cum_strat <  0, alpha=0.12, color=DOWN)
ax2.set_ylabel('Cumulative P&L (USD)')
ax2.legend(facecolor=PANEL, labelcolor=TEXT, edgecolor=GRID, fontsize=9)
ax2.set_title(f'Backtest: LSTM ${strat_pnl:+,.0f} vs B&H ${bnh_pnl:+,.0f}  |  '
              f'WR {win_rate*100:.2f}%  |  {n_trades:,} trades',
              color=TEXT, fontsize=10, fontweight='bold')
for sp in ax2.spines.values(): sp.set_edgecolor(GRID)
ax2.set_facecolor(PANEL)
ax2.tick_params(colors=TEXT)
ax2.grid(color=GRID, linewidth=0.5, alpha=0.7)

# 3. Confidence distribution
ax3 = fig.add_subplot(gs[2, 0])
ax3.hist(confidence[preds != 0], bins=50, color=ACC, alpha=0.7, density=True, label='Signalled')
ax3.hist(confidence[preds == 0], bins=50, color=GRID, alpha=0.5, density=True, label='Flat')
ax3.legend(facecolor=PANEL, labelcolor=TEXT, edgecolor=GRID, fontsize=8)
ax3.set_xlabel('Confidence (max class prob)')
style(ax3, 'Confidence Distribution')

# 4. Win rate vs confidence
ax4 = fig.add_subplot(gs[2, 1])
threshs = np.arange(0.33, 0.81, 0.01)
wr_curve, n_curve = [], []
for t in threshs:
    mask = (confidence[:-1] >= t) & (preds[:-1] != 0)
    if mask.sum() < 10:
        wr_curve.append(np.nan); n_curve.append(0)
    else:
        tp = trade_pnl[mask]
        wr_curve.append((tp > 0).mean() * 100)
        n_curve.append(mask.sum())
ax4.plot(threshs * 100, wr_curve, color=ACC, linewidth=2)
ax4.axhline(50, color=GRID, linestyle='--', linewidth=0.8)
ax4.axhline(52, color=UP,   linestyle=':',  linewidth=0.8, label='~52% maker b/e')
ax4.set_xlabel('Confidence threshold (%)')
ax4.set_ylabel('Win rate (%)')
ax4.legend(facecolor=PANEL, labelcolor=TEXT, edgecolor=GRID, fontsize=8)
ax4b = ax4.twinx()
ax4b.bar(threshs * 100, n_curve, width=0.8, alpha=0.25, color=GOLD)
ax4b.set_ylabel('# trades', color=GOLD)
ax4b.tick_params(colors=GOLD, labelsize=7)
style(ax4, 'Win Rate vs Confidence Threshold')

fig.suptitle(f'LSTM — threshold=${THRESHOLD:.0f}  horizon={HORIZON} bars ({HORIZON*WINDOW_SEC}s)  seq={SEQ_LEN} bars',
             color=TEXT, fontsize=12, fontweight='bold')
plt.savefig(os.path.join(OUTPUT_DIR, 'lstm_results.png'), dpi=150, bbox_inches='tight', facecolor=DARK)
plt.show()
print(f'Chart saved.')
# Out:
# Chart saved.

# %%
# ── Cell 11: Save model ───────────────────────────────────────────────────
import pickle

save_path = os.path.join(OUTPUT_DIR, f'lstm_t{THRESHOLD:.0f}_h{HORIZON}.pt')
torch.save({
    'model_state':  model.state_dict(),
    'scaler':       scaler,
    'features':     features,
    'seq_len':      SEQ_LEN,
    'hidden_dim':   HIDDEN_DIM,
    'num_layers':   NUM_LAYERS,
    'dropout':      DROPOUT,
    'threshold':    THRESHOLD,
    'horizon':      HORIZON,
    'val_acc':      max(val_accs),
    'test_win_rate': win_rate,
    'n_test_trades': n_trades,
}, save_path)
print(f'Model saved → {save_path}')
print(f'\nSummary:')
print(f'  Features      : {len(features)}')
print(f'  Sequence length: {SEQ_LEN} bars ({SEQ_LEN*WINDOW_SEC}s)')
print(f'  Val accuracy  : {max(val_accs)*100:.2f}%')
print(f'  Test win rate : {win_rate*100:.2f}%  ({n_trades:,} trades)')
print(f'  Strategy P&L  : ${strat_pnl:+,.2f}  (zero fees)')
print(f'  After maker   : ${strat_pnl - n_trades*maker_fee:+,.2f}')
# Out:
# Model saved → /root/btc_lstm/lstm_t50_h8.pt
#
# Summary:
#   Features      : 25
#   Sequence length: 32 bars (480s)
#   Val accuracy  : 70.98%
#   Test win rate : 50.11%  (84,533 trades)
#   Strategy P&L  : $+12,869.55  (zero fees)
#   After maker   : $-2,208,920.97

# %%
# ── Cell 12: Load saved model (run this to resume without retraining) ─────
#
# checkpoint = torch.load(save_path, map_location=device)
# features   = checkpoint['features']
# scaler     = checkpoint['scaler']
# model      = BtcLSTM(len(features), checkpoint['hidden_dim'],
#                       checkpoint['num_layers'], checkpoint['dropout']).to(device)
# model.load_state_dict(checkpoint['model_state'])
# model.eval()
# print('Model loaded. Val acc:', checkpoint['val_acc']*100, '%')
print('Uncomment the block above to load a saved model.')
# Out:
# Uncomment the block above to load a saved model.
