# %% [markdown]
# # BTC Orderbook LSTM — run.012 (v5 event-level features: the sub-second follow-through)
#
# **Why:** the bar-level programme closed across runs 008–011 — pooled OOF AUC ~0.51–0.52 on every observable bar-level feature, and run.011's causal maker/skip router found max +0.00 bps/trig (its fill-timing signal was real but too weak to clear fees). The v5 collector docstring named the remaining lever: **event-level order flow** — the sub-bar timing and per-message granularity that 5s bars average away. v5 captures exactly that: verbatim `@depth@100ms` + `@trade` for both markets in `events.<sd|st|fd|ft>.w5.<YYMMDD_HH>.jsonl.gz`. run.012 is the first run that reads it.
#
# **One variable per run.** Bar grid (5s), horizons, targets, folds, model, training loop, calibration, trigger rules, sims, router, and the gate are run.011 **unchanged**. New: **20 event-derived features** (`ev_*`, cell 4) parsed from the raw fd/ft/st streams, and an **events-era slice** (cell 5). Everything the model, router, and gate consume flows through the existing `features` list — the router's inputs (`X_raw`) pick up the ev_* columns automatically.
#
# ## What the events add that bars cannot express
#
# Per 5s bar, from the verbatim streams (all strictly intra-bar → causal by construction):
#
# - **Sub-bar timing:** qty-weighted buy-vs-sell flow-time asymmetry (`ev_ft_time_imb`, `ev_st_time_imb`), first/last-1s volume shares, largest-trade position inside the bar, depth-msg timing imbalance (bid-side vs ask-side updates), late-bar depth-activity share.
# - **Wall-clock burstiness:** min inter-trade / inter-depth-msg gaps (ms); a TRUE 1s same-side sweep share (the bar schema's run-length proxy is trade-COUNT-based — this one is TIME-based).
# - **Per-message granularity:** mean levels touched per depth msg, max single-level qty, pull share (qty=0 removals), exact trade count, exact max/median trade-size ratio.
# - **Feed integrity as signal:** missed-sequence events (`ev_fd_missed`) and book resyncs (`ev_fd_resync`) — overload moments ARE adverse-selection moments.
#
# `sd` (spot depth) is skipped on purpose: marginal value over `fd`, and skipping it halves parse time.
#
# ## The no-bias contract (run.011's six rules, plus two event rules)
#
# Rules 1–6 are run.011's verbatim: walk-forward only; τ on val only then frozen; train-only scaling refit per step; causal rolling triggers (1% train / 0.1% apply); labels are targets never inputs; pre-registered starvation abstention. New:
#
# 7. **Event causality:** every `ev_*` aggregate uses only events with receive time inside the bar's own [t, t+5s) window — no forward or neighbour information. The bar merge key is the collector's epoch `spot_timestamp`, never parsed datetime strings (tz-free, per the v5 docstring).
# 8. **Era honesty:** the analysis window starts at the first event-covered bar (`EVENTS_ERA_ONLY`). Holes inside the era are quantified against the bar's own `depth_msg_count` and printed, then sentinel-filled (gap → bar length, maxrel → 1, everything else → 0) — never silently dropped. Reconnect replays are deduped on update/trade id per the v5 docstring.
#
# ## GATE (pre-registered; identical to run.011)
#
# A∧B∧C on either side (routed maker sim > 0 with day-bootstrap CI excluding 0; routed label lift ≥ 3× pooled and ≥ 2× in ≥ 3/4 folds; routed fill ≥ FILL_MIN and per-fold routed sim > 0 in ≥ 3/4 folds). D info-only.
#
# **Pre-registered diagnostic reads (the actual point of this run):**
#
# - cell 10D FAVOURABLE pooled OOF AUC **with** ev_* features vs run.011's bar-level benchmark (0.610 on the old window).
# - cell 10D univariate top-6: does any `ev_*` feature appear there at all?
#
# ## Read-out (pre-registered)
#
# - **PASS** → event-level flow is the fill-timing lever; carry the `ev_*` block into the long-window run.
# - **AUC < 0.58 with events** → adverse selection is not observable in order flow at any captured resolution; the remaining levers are queue-position modelling / execution mechanics, not prediction.
# - **Aborts at the era guard** → not enough days captured yet; rerun when the collector has ≥ `MIN_EVENTS_DAYS`. The fold printer warns on <7-day test folds: below ~2 weeks of events this run is a pipeline check, not a verdict.
#
# ## Setup
# 1. Runtime → Change runtime type → **T4 GPU**
# 2. Build the events tar on the server (cell 2 comment) and place BOTH tars in Drive
# 3. Run all cells in order. Event parsing adds ~1–3 min per captured day (orjson).

# %%
# ── Cell 1: Install and imports ───────────────────────────────────────────
import subprocess, sys
subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'torch',
                'scikit-learn', 'pandas', 'numpy', 'matplotlib', 'scipy', 'orjson'],
               check=True)

import os, glob, gc, math, random, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import average_precision_score
from scipy.stats import spearmanr
warnings.filterwarnings('ignore')

SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.backends.cudnn.benchmark = True
print(f'Device: {device}')
if device.type == 'cuda':
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB')
# Out:
# Device: cuda
# GPU: Tesla T4
# VRAM: 15.6 GB

# %%
#drive.mount('/content/drive')
#! ([ -f /content/drive/MyDrive/35day_btc_data.tar.gz ] || (apt install sshpass -y && cd /content/drive/MyDrive/ && sshpass -p '' sftp -r -o "StrictHostKeyChecking no" scpuser@155.207.120.2:35day_btc_data.tar.gz . )) && cp -v /content/drive/MyDrive/35day_btc_data.tar.gz ~
#! ([ -f /content/drive/MyDrive/btc_events_w5.tar.gz ] || (apt install sshpass -y && cd /content/drive/MyDrive/ && sshpass -p '' sftp -r -o "StrictHostKeyChecking no" scpuser@155.207.120.2:btc_events_w5.tar.gz . )) && cp -v /content/drive/MyDrive/btc_events_w5.tar.gz ~
#!cd ~ mkdir && tar xvf /content/drive/MyDrive/raw_data.tar
#drive.flush_and_unmount()

# %%
# ── Cell 2: (optional) data transfer helpers — uncomment what you need ────
# run.012 needs the W5 bars tar AND the v5 events tar — build on the server:
#   tar czf 20day_btc_data_w5.tar.gz out5.w5.*.csv*
#   cd events && tar czf ../btc_events_w5.tar.gz . && cd ..
# (the event loader globs **/events.<tag>.w5.*.jsonl.gz recursively, so either
#  tar layout works)
#!apt install sshpass -y && cd ~ && sshpass -p '' sftp -r -o "StrictHostKeyChecking no" scpuser@155.207.120.2:35day_btc_data.tar.gz .
#from google.colab import drive
#drive.mount('/content/drive')
#!mv btc_data.tar.xz /content/drive/MyDrive/
#!ls /content/drive/MyDrive/ -l
#drive.flush_and_unmount()

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cd ~ && mkdir -p btc_lstm_v2 && mkdir -p btc_data && mkdir -p btc_events
# !cd ~/btc_data && tar xvf /content/drive/MyDrive/raw_data.tar
# !cd ~/btc_data && mv -v events/* ~/btc_events
# !cd ~/btc_events ; for x in ft fd st sd ; do ls |grep -P 'events\.'$x | tail -n 1 | xargs rm -v ; done
#drive.flush_and_unmount()
# Out:
# Mounted at /content/drive
# events/
# events/events.ft.w5.260821_12.jsonl.gz
# events/events.ft.w5.260820_10.jsonl.gz
# events/events.st.w5.260825_04.jsonl.gz
# events/events.st.w5.260829_02.jsonl.gz
# events/events.sd.w5.260822_13.jsonl.gz
# events/events.ft.w5.260822_03.jsonl.gz
# events/events.sd.w5.260826_22.jsonl.gz
# events/events.st.w5.260829_07.jsonl.gz
# events/events.fd.w5.260826_09.jsonl.gz
# events/events.sd.w5.260825_14.jsonl.gz
# events/events.ft.w5.260829_01.jsonl.gz
# events/events.fd.w5.260825_18.jsonl.gz
# events/events.fd.w5.260830_08.jsonl.gz
# events/events.st.w5.260824_12.jsonl.gz
# events/events.ft.w5.260826_07.jsonl.gz
# events/events.st.w5.260825_17.jsonl.gz
# events/events.ft.w5.260822_16.jsonl.gz
# events/events.ft.w5.260823_07.jsonl.gz
# events/events.ft.w5.260822_17.jsonl.gz
# events/events.st.w5.260828_05.jsonl.gz
# events/events.sd.w5.260825_21.jsonl.gz
# events/events.fd.w5.260828_00.jsonl.gz
# events/events.sd.w5.260820_02.jsonl.gz
# events/events.st.w5.260825_22.jsonl.gz
# events/events.ft.w5.260823_12.jsonl.gz
# events/events.sd.w5.260823_14.jsonl.gz
# events/events.fd.w5.260827_22.jsonl.gz
# events/events.st.w5.260819_22.jsonl.gz
# events/events.fd.w5.260822_22.jsonl.gz
# events/events.sd.w5.260825_04.jsonl.gz
# events/events.sd.w5.260828_10.jsonl.gz
# events/events.st.w5.260820_01.jsonl.gz
# events/events.st.w5.260824_15.jsonl.gz
# events/events.ft.w5.260822_01.jsonl.gz
# events/events.st.w5.260821_13.jsonl.gz
# events/events.st.w5.260827_04.jsonl.gz
# events/events.st.w5.260828_17.jsonl.gz
# events/events.st.w5.260821_18.jsonl.gz
# events/events.fd.w5.260829_11.jsonl.gz
# events/events.sd.w5.260824_15.jsonl.gz
# events/events.ft.w5.260829_07.jsonl.gz
# events/events.sd.w5.260819_21.jsonl.gz
# events/events.sd.w5.260828_13.jsonl.gz
# events/events.sd.w5.260826_23.jsonl.gz
# events/events.sd.w5.260821_14.jsonl.gz
# events/events.ft.w5.260819_23.jsonl.gz
# events/events.st.w5.260825_03.jsonl.gz
# events/events.fd.w5.260821_18.jsonl.gz
# events/events.ft.w5.260826_02.jsonl.gz
# events/events.st.w5.260820_19.jsonl.gz
# events/events.sd.w5.260819_19.jsonl.gz
# events/events.st.w5.260824_09.jsonl.gz
# events/events.ft.w5.260828_14.jsonl.gz
# events/events.st.w5.260829_06.jsonl.gz
# events/events.sd.w5.260830_02.jsonl.gz
# events/events.fd.w5.260819_20.jsonl.gz
# events/events.ft.w5.260821_23.jsonl.gz
# events/events.st.w5.260828_08.jsonl.gz
# events/events.st.w5.260825_01.jsonl.gz
# events/events.fd.w5.260823_17.jsonl.gz
# events/events.fd.w5.260824_06.jsonl.gz
# events/events.fd.w5.260828_13.jsonl.gz
# events/events.fd.w5.260820_23.jsonl.gz
# events/events.st.w5.260820_21.jsonl.gz
# events/events.sd.w5.260821_06.jsonl.gz
# events/events.st.w5.260823_12.jsonl.gz
# events/events.fd.w5.260823_12.jsonl.gz
# events/events.ft.w5.260824_17.jsonl.gz
# events/events.ft.w5.260824_16.jsonl.gz
# events/events.sd.w5.260823_15.jsonl.gz
# events/events.st.w5.260827_06.jsonl.gz
# events/events.fd.w5.260827_11.jsonl.gz
# events/events.sd.w5.260825_22.jsonl.gz
# events/events.st.w5.260826_22.jsonl.gz
# events/events.fd.w5.260826_10.jsonl.gz
# events/events.ft.w5.260827_01.jsonl.gz
# events/events.fd.w5.260829_03.jsonl.gz
# events/events.st.w5.260820_13.jsonl.gz
# events/events.fd.w5.260823_22.jsonl.gz
# events/events.sd.w5.260822_03.jsonl.gz
# events/events.st.w5.260821_03.jsonl.gz
# events/events.fd.w5.260820_09.jsonl.gz
# events/events.ft.w5.260825_23.jsonl.gz
# events/events.fd.w5.260823_04.jsonl.gz
# events/events.st.w5.260823_02.jsonl.gz
# events/events.st.w5.260820_16.jsonl.gz
# events/events.fd.w5.260822_23.jsonl.gz
# events/events.ft.w5.260827_00.jsonl.gz
# events/events.sd.w5.260825_13.jsonl.gz
# events/events.fd.w5.260826_15.jsonl.gz
# events/events.sd.w5.260822_06.jsonl.gz
# events/events.st.w5.260830_08.jsonl.gz
# events/events.fd.w5.260825_20.jsonl.gz
# events/events.st.w5.260820_07.jsonl.gz
# events/events.sd.w5.260821_21.jsonl.gz
# events/events.sd.w5.260825_16.jsonl.gz
# events/events.sd.w5.260828_23.jsonl.gz
# events/events.ft.w5.260830_10.jsonl.gz
# events/events.st.w5.260825_18.jsonl.gz
# events/events.sd.w5.260827_20.jsonl.gz
# events/events.fd.w5.260823_06.jsonl.gz
# events/events.sd.w5.260828_04.jsonl.gz
# events/events.st.w5.260822_17.jsonl.gz
# events/events.sd.w5.260821_00.jsonl.gz
# events/events.sd.w5.260824_10.jsonl.gz
# events/events.st.w5.260819_20.jsonl.gz
# events/events.st.w5.260824_14.jsonl.gz
# events/events.ft.w5.260823_09.jsonl.gz
# events/events.ft.w5.260825_04.jsonl.gz
# events/events.st.w5.260820_22.jsonl.gz
# events/events.ft.w5.260826_21.jsonl.gz
# events/events.fd.w5.260827_00.jsonl.gz
# events/events.st.w5.260827_18.jsonl.gz
# events/events.fd.w5.260826_22.jsonl.gz
# events/events.fd.w5.260829_20.jsonl.gz
# events/events.ft.w5.260826_19.jsonl.gz
# events/events.ft.w5.260824_18.jsonl.gz
# events/events.st.w5.260826_07.jsonl.gz
# events/events.ft.w5.260826_10.jsonl.gz
# events/events.ft.w5.260825_11.jsonl.gz
# events/events.sd.w5.260829_14.jsonl.gz
# events/events.ft.w5.260829_12.jsonl.gz
# events/events.ft.w5.260819_16.jsonl.gz
# events/events.fd.w5.260821_05.jsonl.gz
# events/events.fd.w5.260822_19.jsonl.gz
# events/events.ft.w5.260823_00.jsonl.gz
# events/events.ft.w5.260821_22.jsonl.gz
# events/events.ft.w5.260819_18.jsonl.gz
# events/events.sd.w5.260822_02.jsonl.gz
# events/events.ft.w5.260828_22.jsonl.gz
# events/events.fd.w5.260820_10.jsonl.gz
# events/events.fd.w5.260827_07.jsonl.gz
# events/events.ft.w5.260827_03.jsonl.gz
# events/events.ft.w5.260826_13.jsonl.gz
# events/events.fd.w5.260828_09.jsonl.gz
# events/events.ft.w5.260827_23.jsonl.gz
# events/events.st.w5.260819_14.jsonl.gz
# events/events.sd.w5.260827_22.jsonl.gz
# events/events.ft.w5.260820_14.jsonl.gz
# events/events.sd.w5.260829_19.jsonl.gz
# events/events.fd.w5.260825_07.jsonl.gz
# events/events.ft.w5.260820_18.jsonl.gz
# events/events.fd.w5.260822_15.jsonl.gz
# events/events.sd.w5.260827_17.jsonl.gz
# events/events.ft.w5.260829_20.jsonl.gz
# events/events.sd.w5.260826_19.jsonl.gz
# events/events.sd.w5.260829_20.jsonl.gz
# events/events.fd.w5.260828_12.jsonl.gz
# events/events.ft.w5.260823_20.jsonl.gz
# events/events.st.w5.260829_13.jsonl.gz
# events/events.st.w5.260824_04.jsonl.gz
# events/events.ft.w5.260820_15.jsonl.gz
# events/events.ft.w5.260827_18.jsonl.gz
# events/events.fd.w5.260826_12.jsonl.gz
# events/events.fd.w5.260820_02.jsonl.gz
# events/events.sd.w5.260827_03.jsonl.gz
# events/events.st.w5.260820_10.jsonl.gz
# events/events.sd.w5.260826_14.jsonl.gz
# events/events.fd.w5.260820_22.jsonl.gz
# events/events.st.w5.260826_15.jsonl.gz
# events/events.sd.w5.260822_16.jsonl.gz
# events/events.ft.w5.260819_20.jsonl.gz
# events/events.fd.w5.260827_01.jsonl.gz
# events/events.sd.w5.260830_13.jsonl.gz
# events/events.fd.w5.260821_09.jsonl.gz
# events/events.sd.w5.260820_11.jsonl.gz
# events/events.fd.w5.260829_04.jsonl.gz
# events/events.fd.w5.260822_11.jsonl.gz
# events/events.sd.w5.260823_10.jsonl.gz
# events/events.ft.w5.260828_11.jsonl.gz
# events/events.fd.w5.260823_14.jsonl.gz
# events/events.fd.w5.260825_23.jsonl.gz
# events/events.ft.w5.260828_09.jsonl.gz
# events/events.sd.w5.260824_17.jsonl.gz
# events/events.st.w5.260822_14.jsonl.gz
# events/events.sd.w5.260829_10.jsonl.gz
# events/events.sd.w5.260820_23.jsonl.gz
# events/events.st.w5.260826_11.jsonl.gz
# events/events.ft.w5.260819_21.jsonl.gz
# events/events.fd.w5.260829_08.jsonl.gz
# events/events.sd.w5.260826_13.jsonl.gz
# events/events.fd.w5.260820_05.jsonl.gz
# events/events.ft.w5.260819_22.jsonl.gz
# events/events.st.w5.260821_23.jsonl.gz
# events/events.sd.w5.260825_01.jsonl.gz
# events/events.ft.w5.260821_04.jsonl.gz
# events/events.st.w5.260829_17.jsonl.gz
# events/events.ft.w5.260825_07.jsonl.gz
# events/events.sd.w5.260827_05.jsonl.gz
# events/events.fd.w5.260826_19.jsonl.gz
# events/events.sd.w5.260825_17.jsonl.gz
# events/events.st.w5.260828_23.jsonl.gz
# events/events.fd.w5.260821_16.jsonl.gz
# events/events.sd.w5.260819_13.jsonl.gz
# events/events.ft.w5.260820_19.jsonl.gz
# events/events.st.w5.260822_19.jsonl.gz
# events/events.sd.w5.260820_17.jsonl.gz
# events/events.fd.w5.260823_10.jsonl.gz
# events/events.st.w5.260823_23.jsonl.gz
# events/events.st.w5.260822_06.jsonl.gz
# events/events.st.w5.260821_21.jsonl.gz
# events/events.sd.w5.260829_03.jsonl.gz
# events/events.fd.w5.260819_23.jsonl.gz
# events/events.fd.w5.260824_13.jsonl.gz
# events/events.fd.w5.260824_03.jsonl.gz
# events/events.sd.w5.260822_05.jsonl.gz
# events/events.fd.w5.260825_05.jsonl.gz
# events/events.ft.w5.260822_20.jsonl.gz
# events/events.fd.w5.260821_23.jsonl.gz
# events/events.st.w5.260820_23.jsonl.gz
# events/events.sd.w5.260823_19.jsonl.gz
# events/events.sd.w5.260827_00.jsonl.gz
# events/events.st.w5.260827_08.jsonl.gz
# events/events.sd.w5.260829_04.jsonl.gz
# events/events.sd.w5.260824_14.jsonl.gz
# events/events.ft.w5.260826_16.jsonl.gz
# events/events.st.w5.260822_22.jsonl.gz
# events/events.st.w5.260819_13.jsonl.gz
# events/events.fd.w5.260826_17.jsonl.gz
# events/events.ft.w5.260830_05.jsonl.gz
# events/events.st.w5.260823_19.jsonl.gz
# events/events.ft.w5.260826_06.jsonl.gz
# events/events.sd.w5.260821_04.jsonl.gz
# events/events.st.w5.260824_05.jsonl.gz
# events/events.ft.w5.260828_01.jsonl.gz
# events/events.sd.w5.260826_11.jsonl.gz
# events/events.sd.w5.260823_01.jsonl.gz
# events/events.st.w5.260826_00.jsonl.gz
# events/events.st.w5.260827_17.jsonl.gz
# events/events.ft.w5.260824_10.jsonl.gz
# events/events.sd.w5.260824_01.jsonl.gz
# events/events.st.w5.260826_21.jsonl.gz
# events/events.fd.w5.260820_04.jsonl.gz
# events/events.fd.w5.260829_15.jsonl.gz
# events/events.st.w5.260827_22.jsonl.gz
# events/events.fd.w5.260822_16.jsonl.gz
# events/events.fd.w5.260821_11.jsonl.gz
# events/events.st.w5.260821_15.jsonl.gz
# events/events.st.w5.260830_12.jsonl.gz
# events/events.fd.w5.260823_07.jsonl.gz
# events/events.fd.w5.260820_11.jsonl.gz
# events/events.st.w5.260828_14.jsonl.gz
# events/events.ft.w5.260822_00.jsonl.gz
# events/events.sd.w5.260819_18.jsonl.gz
# events/events.ft.w5.260829_23.jsonl.gz
# events/events.st.w5.260827_02.jsonl.gz
# events/events.fd.w5.260829_19.jsonl.gz
# events/events.fd.w5.260828_18.jsonl.gz
# events/events.fd.w5.260821_12.jsonl.gz
# events/events.sd.w5.260823_09.jsonl.gz
# events/events.sd.w5.260829_21.jsonl.gz
# events/events.fd.w5.260829_12.jsonl.gz
# events/events.ft.w5.260825_08.jsonl.gz
# events/events.ft.w5.260824_23.jsonl.gz
# events/events.ft.w5.260830_02.jsonl.gz
# events/events.ft.w5.260826_11.jsonl.gz
# events/events.sd.w5.260830_04.jsonl.gz
# events/events.sd.w5.260826_16.jsonl.gz
# events/events.ft.w5.260826_12.jsonl.gz
# events/events.fd.w5.260823_23.jsonl.gz
# events/events.sd.w5.260824_00.jsonl.gz
# events/events.sd.w5.260828_08.jsonl.gz
# events/events.fd.w5.260825_08.jsonl.gz
# events/events.st.w5.260823_06.jsonl.gz
# events/events.fd.w5.260822_01.jsonl.gz
# events/events.st.w5.260823_09.jsonl.gz
# events/events.sd.w5.260828_03.jsonl.gz
# events/events.st.w5.260826_09.jsonl.gz
# events/events.st.w5.260828_19.jsonl.gz
# events/events.ft.w5.260820_08.jsonl.gz
# events/events.sd.w5.260823_03.jsonl.gz
# events/events.ft.w5.260822_04.jsonl.gz
# events/events.st.w5.260829_20.jsonl.gz
# events/events.sd.w5.260828_12.jsonl.gz
# events/events.fd.w5.260821_06.jsonl.gz
# events/events.fd.w5.260819_15.jsonl.gz
# events/events.sd.w5.260824_23.jsonl.gz
# events/events.ft.w5.260821_08.jsonl.gz
# events/events.sd.w5.260822_17.jsonl.gz
# events/events.ft.w5.260830_03.jsonl.gz
# events/events.sd.w5.260822_20.jsonl.gz
# events/events.fd.w5.260826_00.jsonl.gz
# events/events.st.w5.260824_23.jsonl.gz
# events/events.sd.w5.260829_02.jsonl.gz
# events/events.st.w5.260822_01.jsonl.gz
# events/events.st.w5.260827_12.jsonl.gz
# events/events.ft.w5.260825_15.jsonl.gz
# events/events.ft.w5.260823_01.jsonl.gz
# events/events.st.w5.260829_08.jsonl.gz
# events/events.st.w5.260828_11.jsonl.gz
# events/events.ft.w5.260821_21.jsonl.gz
# events/events.st.w5.260825_08.jsonl.gz
# events/events.ft.w5.260822_21.jsonl.gz
# events/events.fd.w5.260827_03.jsonl.gz
# events/events.st.w5.260829_01.jsonl.gz
# events/events.fd.w5.260820_19.jsonl.gz
# events/events.ft.w5.260821_02.jsonl.gz
# events/events.st.w5.260829_10.jsonl.gz
# events/events.fd.w5.260823_00.jsonl.gz
# events/events.sd.w5.260821_20.jsonl.gz
# events/events.fd.w5.260822_21.jsonl.gz
# events/events.sd.w5.260822_14.jsonl.gz
# events/events.st.w5.260824_08.jsonl.gz
# events/events.sd.w5.260825_19.jsonl.gz
# events/events.st.w5.260829_15.jsonl.gz
# events/events.sd.w5.260827_18.jsonl.gz
# events/events.ft.w5.260821_05.jsonl.gz
# events/events.fd.w5.260828_05.jsonl.gz
# events/events.sd.w5.260820_16.jsonl.gz
# events/events.st.w5.260820_18.jsonl.gz
# events/events.sd.w5.260822_23.jsonl.gz
# events/events.st.w5.260822_08.jsonl.gz
# events/events.sd.w5.260826_10.jsonl.gz
# events/events.fd.w5.260830_10.jsonl.gz
# events/events.fd.w5.260829_10.jsonl.gz
# events/events.sd.w5.260824_12.jsonl.gz
# events/events.st.w5.260823_01.jsonl.gz
# events/events.ft.w5.260829_13.jsonl.gz
# events/events.ft.w5.260830_11.jsonl.gz
# events/events.st.w5.260822_21.jsonl.gz
# events/events.ft.w5.260827_02.jsonl.gz
# events/events.fd.w5.260827_12.jsonl.gz
# events/events.ft.w5.260828_17.jsonl.gz
# events/events.sd.w5.260820_04.jsonl.gz
# events/events.ft.w5.260825_12.jsonl.gz
# events/events.st.w5.260823_05.jsonl.gz
# events/events.ft.w5.260827_12.jsonl.gz
# events/events.fd.w5.260823_08.jsonl.gz
# events/events.st.w5.260825_07.jsonl.gz
# events/events.sd.w5.260821_23.jsonl.gz
# events/events.st.w5.260821_20.jsonl.gz
# events/events.fd.w5.260825_04.jsonl.gz
# events/events.ft.w5.260824_00.jsonl.gz
# events/events.st.w5.260826_01.jsonl.gz
# events/events.fd.w5.260823_11.jsonl.gz
# events/events.st.w5.260826_03.jsonl.gz
# events/events.st.w5.260827_03.jsonl.gz
# events/events.sd.w5.260825_09.jsonl.gz
# events/events.st.w5.260820_15.jsonl.gz
# events/events.ft.w5.260820_13.jsonl.gz
# events/events.fd.w5.260830_05.jsonl.gz
# events/events.sd.w5.260823_04.jsonl.gz
# events/events.sd.w5.260829_13.jsonl.gz
# events/events.st.w5.260820_00.jsonl.gz
# events/events.ft.w5.260825_18.jsonl.gz
# events/events.fd.w5.260822_04.jsonl.gz
# events/events.sd.w5.260826_07.jsonl.gz
# events/events.fd.w5.260828_15.jsonl.gz
# events/events.st.w5.260828_13.jsonl.gz
# events/events.sd.w5.260820_15.jsonl.gz
# events/events.fd.w5.260826_21.jsonl.gz
# events/events.fd.w5.260823_13.jsonl.gz
# events/events.ft.w5.260820_09.jsonl.gz
# events/events.ft.w5.260830_00.jsonl.gz
# events/events.sd.w5.260822_08.jsonl.gz
# events/events.ft.w5.260827_11.jsonl.gz
# events/events.st.w5.260824_18.jsonl.gz
# events/events.st.w5.260823_00.jsonl.gz
# events/events.ft.w5.260825_01.jsonl.gz
# events/events.st.w5.260827_11.jsonl.gz
# events/events.st.w5.260824_19.jsonl.gz
# events/events.sd.w5.260821_13.jsonl.gz
# events/events.st.w5.260821_00.jsonl.gz
# events/events.sd.w5.260825_12.jsonl.gz
# events/events.sd.w5.260821_19.jsonl.gz
# events/events.st.w5.260820_06.jsonl.gz
# events/events.sd.w5.260825_20.jsonl.gz
# events/events.fd.w5.260821_13.jsonl.gz
# events/events.sd.w5.260829_15.jsonl.gz
# events/events.fd.w5.260825_09.jsonl.gz
# events/events.sd.w5.260829_18.jsonl.gz
# events/events.sd.w5.260824_08.jsonl.gz
# events/events.sd.w5.260821_08.jsonl.gz
# events/events.sd.w5.260828_05.jsonl.gz
# events/events.fd.w5.260820_13.jsonl.gz
# events/events.ft.w5.260820_21.jsonl.gz
# events/events.ft.w5.260823_10.jsonl.gz
# events/events.sd.w5.260824_20.jsonl.gz
# events/events.fd.w5.260821_07.jsonl.gz
# events/events.ft.w5.260823_03.jsonl.gz
# events/events.sd.w5.260830_06.jsonl.gz
# events/events.fd.w5.260828_11.jsonl.gz
# events/events.fd.w5.260824_09.jsonl.gz
# events/events.st.w5.260823_18.jsonl.gz
# events/events.st.w5.260819_16.jsonl.gz
# events/events.ft.w5.260820_02.jsonl.gz
# events/events.ft.w5.260826_14.jsonl.gz
# events/events.sd.w5.260827_02.jsonl.gz
# events/events.ft.w5.260827_14.jsonl.gz
# events/events.fd.w5.260820_03.jsonl.gz
# events/events.fd.w5.260821_01.jsonl.gz
# events/events.fd.w5.260819_18.jsonl.gz
# events/events.ft.w5.260827_04.jsonl.gz
# events/events.ft.w5.260826_09.jsonl.gz
# events/events.st.w5.260829_12.jsonl.gz
# events/events.sd.w5.260820_20.jsonl.gz
# events/events.sd.w5.260823_11.jsonl.gz
# events/events.sd.w5.260827_23.jsonl.gz
# events/events.sd.w5.260830_09.jsonl.gz
# events/events.fd.w5.260826_18.jsonl.gz
# events/events.sd.w5.260821_05.jsonl.gz
# events/events.fd.w5.260819_19.jsonl.gz
# events/events.fd.w5.260827_09.jsonl.gz
# events/events.sd.w5.260824_02.jsonl.gz
# events/events.st.w5.260827_20.jsonl.gz
# events/events.ft.w5.260821_18.jsonl.gz
# events/events.fd.w5.260828_01.jsonl.gz
# events/events.fd.w5.260824_07.jsonl.gz
# events/events.fd.w5.260824_08.jsonl.gz
# events/events.st.w5.260828_06.jsonl.gz
# events/events.fd.w5.260826_20.jsonl.gz
# events/events.ft.w5.260821_10.jsonl.gz
# events/events.st.w5.260819_15.jsonl.gz
# events/events.ft.w5.260823_21.jsonl.gz
# events/events.sd.w5.260820_14.jsonl.gz
# events/events.fd.w5.260821_00.jsonl.gz
# events/events.ft.w5.260821_00.jsonl.gz
# events/events.sd.w5.260825_08.jsonl.gz
# events/events.fd.w5.260821_19.jsonl.gz
# events/events.st.w5.260824_00.jsonl.gz
# events/events.fd.w5.260824_22.jsonl.gz
# events/events.fd.w5.260827_23.jsonl.gz
# events/events.st.w5.260828_20.jsonl.gz
# events/events.sd.w5.260824_18.jsonl.gz
# events/events.st.w5.260826_20.jsonl.gz
# events/events.sd.w5.260827_04.jsonl.gz
# events/events.ft.w5.260823_06.jsonl.gz
# events/events.st.w5.260829_19.jsonl.gz
# events/events.st.w5.260829_18.jsonl.gz
# events/events.ft.w5.260827_09.jsonl.gz
# events/events.st.w5.260829_22.jsonl.gz
# events/events.ft.w5.260822_10.jsonl.gz
# events/events.sd.w5.260820_19.jsonl.gz
# events/events.st.w5.260820_12.jsonl.gz
# events/events.st.w5.260819_21.jsonl.gz
# events/events.fd.w5.260825_15.jsonl.gz
# events/events.sd.w5.260824_05.jsonl.gz
# events/events.ft.w5.260824_11.jsonl.gz
# events/events.fd.w5.260821_20.jsonl.gz
# events/events.sd.w5.260826_01.jsonl.gz
# events/events.fd.w5.260825_02.jsonl.gz
# events/events.sd.w5.260828_22.jsonl.gz
# events/events.st.w5.260824_21.jsonl.gz
# events/events.ft.w5.260828_03.jsonl.gz
# events/events.sd.w5.260822_22.jsonl.gz
# events/events.sd.w5.260821_09.jsonl.gz
# events/events.ft.w5.260820_20.jsonl.gz
# events/events.fd.w5.260820_12.jsonl.gz
# events/events.st.w5.260822_18.jsonl.gz
# events/events.fd.w5.260822_09.jsonl.gz
# events/events.ft.w5.260825_13.jsonl.gz
# events/events.fd.w5.260824_23.jsonl.gz
# events/events.st.w5.260825_21.jsonl.gz
# events/events.fd.w5.260821_03.jsonl.gz
# events/events.ft.w5.260824_08.jsonl.gz
# events/events.ft.w5.260829_18.jsonl.gz
# events/events.st.w5.260821_22.jsonl.gz
# events/events.st.w5.260829_00.jsonl.gz
# events/events.st.w5.260825_10.jsonl.gz
# events/events.sd.w5.260826_12.jsonl.gz
# events/events.ft.w5.260829_21.jsonl.gz
# events/events.fd.w5.260822_07.jsonl.gz
# events/events.st.w5.260826_19.jsonl.gz
# events/events.st.w5.260824_06.jsonl.gz
# events/events.st.w5.260821_14.jsonl.gz
# events/events.ft.w5.260822_08.jsonl.gz
# events/events.ft.w5.260821_20.jsonl.gz
# events/events.fd.w5.260830_03.jsonl.gz
# events/events.ft.w5.260829_09.jsonl.gz
# events/events.sd.w5.260822_04.jsonl.gz
# events/events.sd.w5.260822_15.jsonl.gz
# events/events.st.w5.260828_21.jsonl.gz
# events/events.st.w5.260828_00.jsonl.gz
# events/events.st.w5.260829_05.jsonl.gz
# events/events.fd.w5.260826_03.jsonl.gz
# events/events.fd.w5.260822_02.jsonl.gz
# events/events.st.w5.260822_02.jsonl.gz
# events/events.sd.w5.260830_03.jsonl.gz
# events/events.fd.w5.260826_02.jsonl.gz
# events/events.fd.w5.260820_21.jsonl.gz
# events/events.st.w5.260826_12.jsonl.gz
# events/events.fd.w5.260829_06.jsonl.gz
# events/events.ft.w5.260825_00.jsonl.gz
# events/events.st.w5.260819_18.jsonl.gz
# events/events.ft.w5.260828_04.jsonl.gz
# events/events.st.w5.260828_16.jsonl.gz
# events/events.st.w5.260829_11.jsonl.gz
# events/events.ft.w5.260820_11.jsonl.gz
# events/events.sd.w5.260823_00.jsonl.gz
# events/events.st.w5.260822_03.jsonl.gz
# events/events.sd.w5.260824_22.jsonl.gz
# events/events.ft.w5.260829_14.jsonl.gz
# events/events.sd.w5.260823_20.jsonl.gz
# events/events.ft.w5.260830_07.jsonl.gz
# events/events.ft.w5.260825_17.jsonl.gz
# events/events.ft.w5.260819_17.jsonl.gz
# events/events.fd.w5.260819_16.jsonl.gz
# events/events.fd.w5.260822_03.jsonl.gz
# events/events.sd.w5.260823_08.jsonl.gz
# events/events.sd.w5.260824_21.jsonl.gz
# events/events.sd.w5.260823_13.jsonl.gz
# events/events.fd.w5.260824_14.jsonl.gz
# events/events.fd.w5.260830_02.jsonl.gz
# events/events.st.w5.260820_02.jsonl.gz
# events/events.st.w5.260826_10.jsonl.gz
# events/events.sd.w5.260830_10.jsonl.gz
# events/events.fd.w5.260829_02.jsonl.gz
# events/events.st.w5.260821_09.jsonl.gz
# events/events.st.w5.260821_12.jsonl.gz
# events/events.ft.w5.260823_22.jsonl.gz
# events/events.sd.w5.260820_08.jsonl.gz
# events/events.ft.w5.260824_21.jsonl.gz
# events/events.fd.w5.260824_04.jsonl.gz
# events/events.sd.w5.260820_01.jsonl.gz
# events/events.sd.w5.260827_08.jsonl.gz
# events/events.fd.w5.260826_01.jsonl.gz
# events/events.ft.w5.260825_19.jsonl.gz
# events/events.fd.w5.260819_17.jsonl.gz
# events/events.st.w5.260822_20.jsonl.gz
# events/events.st.w5.260827_10.jsonl.gz
# events/events.sd.w5.260824_03.jsonl.gz
# events/events.fd.w5.260825_01.jsonl.gz
# events/events.st.w5.260828_07.jsonl.gz
# events/events.sd.w5.260822_11.jsonl.gz
# events/events.ft.w5.260829_15.jsonl.gz
# events/events.ft.w5.260821_16.jsonl.gz
# events/events.sd.w5.260829_23.jsonl.gz
# events/events.ft.w5.260827_07.jsonl.gz
# events/events.st.w5.260822_23.jsonl.gz
# events/events.sd.w5.260821_16.jsonl.gz
# events/events.fd.w5.260827_20.jsonl.gz
# events/events.ft.w5.260820_05.jsonl.gz
# events/events.sd.w5.260820_03.jsonl.gz
# events/events.ft.w5.260827_13.jsonl.gz
# events/events.sd.w5.260820_07.jsonl.gz
# events/events.ft.w5.260824_20.jsonl.gz
# events/events.sd.w5.260828_16.jsonl.gz
# events/events.sd.w5.260819_22.jsonl.gz
# events/events.ft.w5.260828_16.jsonl.gz
# events/events.ft.w5.260828_19.jsonl.gz
# events/events.fd.w5.260821_22.jsonl.gz
# events/events.ft.w5.260822_14.jsonl.gz
# events/events.st.w5.260824_10.jsonl.gz
# events/events.sd.w5.260825_18.jsonl.gz
# events/events.sd.w5.260824_04.jsonl.gz
# events/events.ft.w5.260823_04.jsonl.gz
# events/events.ft.w5.260820_23.jsonl.gz
# events/events.sd.w5.260830_12.jsonl.gz
# events/events.st.w5.260820_11.jsonl.gz
# events/events.sd.w5.260823_06.jsonl.gz
# events/events.ft.w5.260827_06.jsonl.gz
# events/events.sd.w5.260828_20.jsonl.gz
# events/events.st.w5.260820_08.jsonl.gz
# events/events.sd.w5.260823_07.jsonl.gz
# events/events.fd.w5.260825_03.jsonl.gz
# events/events.fd.w5.260827_14.jsonl.gz
# events/events.st.w5.260828_18.jsonl.gz
# events/events.sd.w5.260830_00.jsonl.gz
# events/events.st.w5.260830_11.jsonl.gz
# events/events.st.w5.260830_05.jsonl.gz
# events/events.st.w5.260822_07.jsonl.gz
# events/events.fd.w5.260828_07.jsonl.gz
# events/events.ft.w5.260825_09.jsonl.gz
# events/events.sd.w5.260823_16.jsonl.gz
# events/events.ft.w5.260820_16.jsonl.gz
# events/events.st.w5.260820_20.jsonl.gz
# events/events.sd.w5.260819_20.jsonl.gz
# events/events.sd.w5.260828_18.jsonl.gz
# events/events.sd.w5.260829_09.jsonl.gz
# events/events.sd.w5.260827_06.jsonl.gz
# events/events.fd.w5.260821_21.jsonl.gz
# events/events.fd.w5.260826_04.jsonl.gz
# events/events.sd.w5.260820_09.jsonl.gz
# events/events.st.w5.260827_14.jsonl.gz
# events/events.fd.w5.260827_04.jsonl.gz
# events/events.fd.w5.260821_04.jsonl.gz
# events/events.st.w5.260828_04.jsonl.gz
# events/events.st.w5.260822_16.jsonl.gz
# events/events.fd.w5.260821_08.jsonl.gz
# events/events.ft.w5.260823_18.jsonl.gz
# events/events.ft.w5.260827_17.jsonl.gz
# events/events.st.w5.260824_22.jsonl.gz
# events/events.st.w5.260830_13.jsonl.gz
# events/events.fd.w5.260829_05.jsonl.gz
# events/events.sd.w5.260830_01.jsonl.gz
# events/events.sd.w5.260822_10.jsonl.gz
# events/events.fd.w5.260829_00.jsonl.gz
# events/events.ft.w5.260826_00.jsonl.gz
# events/events.ft.w5.260827_10.jsonl.gz
# events/events.st.w5.260821_08.jsonl.gz
# events/events.sd.w5.260828_15.jsonl.gz
# events/events.st.w5.260822_15.jsonl.gz
# events/events.ft.w5.260820_07.jsonl.gz
# events/events.fd.w5.260829_09.jsonl.gz
# events/events.sd.w5.260822_09.jsonl.gz
# events/events.ft.w5.260829_02.jsonl.gz
# events/events.fd.w5.260827_17.jsonl.gz
# events/events.st.w5.260827_05.jsonl.gz
# events/events.st.w5.260821_05.jsonl.gz
# events/events.fd.w5.260824_10.jsonl.gz
# events/events.ft.w5.260828_02.jsonl.gz
# events/events.st.w5.260829_03.jsonl.gz
# events/events.st.w5.260825_02.jsonl.gz
# events/events.ft.w5.260828_20.jsonl.gz
# events/events.ft.w5.260827_05.jsonl.gz
# events/events.ft.w5.260825_03.jsonl.gz
# events/events.sd.w5.260820_06.jsonl.gz
# events/events.ft.w5.260827_22.jsonl.gz
# events/events.ft.w5.260824_13.jsonl.gz
# events/events.fd.w5.260821_10.jsonl.gz
# events/events.sd.w5.260824_11.jsonl.gz
# events/events.ft.w5.260829_05.jsonl.gz
# events/events.sd.w5.260826_00.jsonl.gz
# events/events.st.w5.260826_04.jsonl.gz
# events/events.fd.w5.260826_07.jsonl.gz
# events/events.sd.w5.260827_09.jsonl.gz
# events/events.ft.w5.260830_12.jsonl.gz
# events/events.sd.w5.260826_17.jsonl.gz
# events/events.st.w5.260820_04.jsonl.gz
# events/events.sd.w5.260826_06.jsonl.gz
# events/events.ft.w5.260828_08.jsonl.gz
# events/events.st.w5.260826_16.jsonl.gz
# events/events.sd.w5.260826_02.jsonl.gz
# events/events.fd.w5.260826_06.jsonl.gz
# events/events.fd.w5.260828_14.jsonl.gz
# events/events.fd.w5.260826_13.jsonl.gz
# events/events.fd.w5.260821_15.jsonl.gz
# events/events.st.w5.260828_15.jsonl.gz
# events/events.st.w5.260825_13.jsonl.gz
# events/events.sd.w5.260821_03.jsonl.gz
# events/events.sd.w5.260820_00.jsonl.gz
# events/events.st.w5.260829_09.jsonl.gz
# events/events.sd.w5.260829_22.jsonl.gz
# events/events.sd.w5.260825_23.jsonl.gz
# events/events.ft.w5.260829_22.jsonl.gz
# events/events.sd.w5.260820_22.jsonl.gz
# events/events.sd.w5.260822_12.jsonl.gz
# events/events.sd.w5.260825_06.jsonl.gz
# events/events.fd.w5.260827_16.jsonl.gz
# events/events.fd.w5.260830_11.jsonl.gz
# events/events.sd.w5.260830_05.jsonl.gz
# events/events.ft.w5.260824_05.jsonl.gz
# events/events.fd.w5.260829_01.jsonl.gz
# events/events.ft.w5.260827_19.jsonl.gz
# events/events.sd.w5.260825_10.jsonl.gz
# events/events.sd.w5.260824_19.jsonl.gz
# events/events.fd.w5.260824_16.jsonl.gz
# events/events.st.w5.260822_09.jsonl.gz
# events/events.st.w5.260824_07.jsonl.gz
# events/events.ft.w5.260823_23.jsonl.gz
# events/events.ft.w5.260829_19.jsonl.gz
# events/events.sd.w5.260826_08.jsonl.gz
# events/events.ft.w5.260826_17.jsonl.gz
# events/events.st.w5.260828_01.jsonl.gz
# events/events.ft.w5.260819_14.jsonl.gz
# events/events.sd.w5.260821_02.jsonl.gz
# events/events.st.w5.260821_06.jsonl.gz
# events/events.fd.w5.260825_10.jsonl.gz
# events/events.st.w5.260828_03.jsonl.gz
# events/events.ft.w5.260828_07.jsonl.gz
# events/events.fd.w5.260823_20.jsonl.gz
# events/events.st.w5.260828_10.jsonl.gz
# events/events.ft.w5.260823_05.jsonl.gz
# events/events.fd.w5.260829_18.jsonl.gz
# events/events.fd.w5.260826_05.jsonl.gz
# events/events.sd.w5.260824_16.jsonl.gz
# events/events.sd.w5.260819_15.jsonl.gz
# events/events.st.w5.260824_11.jsonl.gz
# events/events.ft.w5.260822_02.jsonl.gz
# events/events.fd.w5.260827_05.jsonl.gz
# events/events.sd.w5.260819_23.jsonl.gz
# events/events.sd.w5.260819_14.jsonl.gz
# events/events.ft.w5.260825_05.jsonl.gz
# events/events.fd.w5.260829_14.jsonl.gz
# events/events.sd.w5.260829_16.jsonl.gz
# events/events.ft.w5.260825_14.jsonl.gz
# events/events.st.w5.260830_00.jsonl.gz
# events/events.st.w5.260820_05.jsonl.gz
# events/events.sd.w5.260826_21.jsonl.gz
# events/events.st.w5.260823_04.jsonl.gz
# events/events.sd.w5.260828_14.jsonl.gz
# events/events.fd.w5.260826_08.jsonl.gz
# events/events.sd.w5.260830_07.jsonl.gz
# events/events.sd.w5.260828_06.jsonl.gz
# events/events.ft.w5.260828_12.jsonl.gz
# events/events.fd.w5.260822_13.jsonl.gz
# events/events.ft.w5.260823_02.jsonl.gz
# events/events.sd.w5.260828_07.jsonl.gz
# events/events.sd.w5.260826_18.jsonl.gz
# events/events.sd.w5.260827_19.jsonl.gz
# events/events.st.w5.260830_01.jsonl.gz
# events/events.ft.w5.260821_01.jsonl.gz
# events/events.st.w5.260820_14.jsonl.gz
# events/events.ft.w5.260822_12.jsonl.gz
# events/events.fd.w5.260827_06.jsonl.gz
# events/events.sd.w5.260826_04.jsonl.gz
# events/events.fd.w5.260828_06.jsonl.gz
# events/events.st.w5.260825_15.jsonl.gz
# events/events.ft.w5.260821_03.jsonl.gz
# events/events.st.w5.260820_03.jsonl.gz
# events/events.st.w5.260830_03.jsonl.gz
# events/events.fd.w5.260821_14.jsonl.gz
# events/events.fd.w5.260822_18.jsonl.gz
# events/events.sd.w5.260819_17.jsonl.gz
# events/events.fd.w5.260827_13.jsonl.gz
# events/events.st.w5.260823_16.jsonl.gz
# events/events.fd.w5.260824_19.jsonl.gz
# events/events.fd.w5.260823_02.jsonl.gz
# events/events.ft.w5.260824_22.jsonl.gz
# events/events.ft.w5.260821_07.jsonl.gz
# events/events.ft.w5.260820_01.jsonl.gz
# events/events.ft.w5.260825_16.jsonl.gz
# events/events.st.w5.260827_09.jsonl.gz
# events/events.fd.w5.260827_02.jsonl.gz
# events/events.sd.w5.260826_03.jsonl.gz
# events/events.st.w5.260826_23.jsonl.gz
# events/events.st.w5.260821_17.jsonl.gz
# events/events.ft.w5.260827_21.jsonl.gz
# events/events.ft.w5.260830_01.jsonl.gz
# events/events.ft.w5.260826_20.jsonl.gz
# events/events.st.w5.260828_22.jsonl.gz
# events/events.ft.w5.260828_23.jsonl.gz
# events/events.st.w5.260829_23.jsonl.gz
# events/events.st.w5.260826_05.jsonl.gz
# events/events.st.w5.260825_19.jsonl.gz
# events/events.fd.w5.260824_00.jsonl.gz
# events/events.ft.w5.260828_15.jsonl.gz
# events/events.st.w5.260823_20.jsonl.gz
# events/events.ft.w5.260823_13.jsonl.gz
# events/events.fd.w5.260823_09.jsonl.gz
# events/events.fd.w5.260823_05.jsonl.gz
# events/events.st.w5.260830_02.jsonl.gz
# events/events.fd.w5.260822_10.jsonl.gz
# events/events.st.w5.260829_21.jsonl.gz
# events/events.st.w5.260822_05.jsonl.gz
# events/events.ft.w5.260824_03.jsonl.gz
# events/events.ft.w5.260820_12.jsonl.gz
# events/events.ft.w5.260825_02.jsonl.gz
# events/events.fd.w5.260826_11.jsonl.gz
# events/events.st.w5.260823_03.jsonl.gz
# events/events.ft.w5.260828_18.jsonl.gz
# events/events.st.w5.260826_02.jsonl.gz
# events/events.ft.w5.260819_15.jsonl.gz
# events/events.fd.w5.260824_18.jsonl.gz
# events/events.fd.w5.260827_08.jsonl.gz
# events/events.sd.w5.260822_00.jsonl.gz
# events/events.fd.w5.260824_17.jsonl.gz
# events/events.sd.w5.260821_07.jsonl.gz
# events/events.st.w5.260821_19.jsonl.gz
# events/events.sd.w5.260827_13.jsonl.gz
# events/events.fd.w5.260824_02.jsonl.gz
# events/events.ft.w5.260821_11.jsonl.gz
# events/events.st.w5.260825_06.jsonl.gz
# events/events.st.w5.260819_19.jsonl.gz
# events/events.ft.w5.260826_03.jsonl.gz
# events/events.ft.w5.260823_19.jsonl.gz
# events/events.st.w5.260823_17.jsonl.gz
# events/events.st.w5.260826_14.jsonl.gz
# events/events.st.w5.260825_14.jsonl.gz
# events/events.ft.w5.260823_15.jsonl.gz
# events/events.sd.w5.260825_11.jsonl.gz
# events/events.sd.w5.260829_00.jsonl.gz
# events/events.sd.w5.260824_06.jsonl.gz
# events/events.fd.w5.260821_17.jsonl.gz
# events/events.ft.w5.260830_13.jsonl.gz
# events/events.ft.w5.260828_05.jsonl.gz
# events/events.st.w5.260821_01.jsonl.gz
# events/events.st.w5.260821_16.jsonl.gz
# events/events.st.w5.260827_01.jsonl.gz
# events/events.fd.w5.260829_22.jsonl.gz
# events/events.st.w5.260826_08.jsonl.gz
# events/events.fd.w5.260827_21.jsonl.gz
# events/events.sd.w5.260830_08.jsonl.gz
# events/events.fd.w5.260823_18.jsonl.gz
# events/events.ft.w5.260828_13.jsonl.gz
# events/events.fd.w5.260819_13.jsonl.gz
# events/events.ft.w5.260824_02.jsonl.gz
# events/events.sd.w5.260827_10.jsonl.gz
# events/events.fd.w5.260822_00.jsonl.gz
# events/events.st.w5.260828_02.jsonl.gz
# events/events.sd.w5.260822_01.jsonl.gz
# events/events.sd.w5.260829_06.jsonl.gz
# events/events.fd.w5.260825_14.jsonl.gz
# events/events.fd.w5.260819_22.jsonl.gz
# events/events.st.w5.260821_02.jsonl.gz
# events/events.ft.w5.260829_17.jsonl.gz
# events/events.st.w5.260823_13.jsonl.gz
# events/events.ft.w5.260822_06.jsonl.gz
# events/events.fd.w5.260825_06.jsonl.gz
# events/events.ft.w5.260830_08.jsonl.gz
# events/events.ft.w5.260823_16.jsonl.gz
# events/events.st.w5.260827_16.jsonl.gz
# events/events.ft.w5.260821_19.jsonl.gz
# events/events.st.w5.260828_09.jsonl.gz
# events/events.ft.w5.260824_04.jsonl.gz
# events/events.fd.w5.260827_19.jsonl.gz
# events/events.st.w5.260829_04.jsonl.gz
# events/events.fd.w5.260827_18.jsonl.gz
# events/events.ft.w5.260829_03.jsonl.gz
# events/events.sd.w5.260821_17.jsonl.gz
# events/events.fd.w5.260829_23.jsonl.gz
# events/events.sd.w5.260827_12.jsonl.gz
# events/events.fd.w5.260828_16.jsonl.gz
# events/events.fd.w5.260820_17.jsonl.gz
# events/events.fd.w5.260821_02.jsonl.gz
# events/events.st.w5.260830_04.jsonl.gz
# events/events.sd.w5.260819_16.jsonl.gz
# events/events.fd.w5.260829_21.jsonl.gz
# events/events.ft.w5.260827_08.jsonl.gz
# events/events.fd.w5.260828_22.jsonl.gz
# events/events.sd.w5.260828_17.jsonl.gz
# events/events.ft.w5.260828_00.jsonl.gz
# events/events.fd.w5.260829_07.jsonl.gz
# events/events.fd.w5.260828_10.jsonl.gz
# events/events.sd.w5.260826_05.jsonl.gz
# events/events.ft.w5.260823_17.jsonl.gz
# events/events.fd.w5.260819_21.jsonl.gz
# events/events.st.w5.260827_13.jsonl.gz
# events/events.ft.w5.260821_09.jsonl.gz
# events/events.fd.w5.260823_01.jsonl.gz
# events/events.st.w5.260825_09.jsonl.gz
# events/events.ft.w5.260822_09.jsonl.gz
# events/events.fd.w5.260824_11.jsonl.gz
# events/events.st.w5.260827_07.jsonl.gz
# events/events.st.w5.260819_23.jsonl.gz
# events/events.sd.w5.260827_16.jsonl.gz
# events/events.st.w5.260825_00.jsonl.gz
# events/events.st.w5.260825_23.jsonl.gz
# events/events.st.w5.260823_10.jsonl.gz
# events/events.sd.w5.260828_09.jsonl.gz
# events/events.sd.w5.260821_12.jsonl.gz
# events/events.ft.w5.260822_19.jsonl.gz
# events/events.ft.w5.260829_10.jsonl.gz
# events/events.sd.w5.260826_09.jsonl.gz
# events/events.ft.w5.260828_21.jsonl.gz
# events/events.fd.w5.260822_06.jsonl.gz
# events/events.fd.w5.260825_13.jsonl.gz
# events/events.fd.w5.260825_12.jsonl.gz
# events/events.fd.w5.260825_21.jsonl.gz
# events/events.ft.w5.260822_13.jsonl.gz
# events/events.fd.w5.260828_17.jsonl.gz
# events/events.fd.w5.260820_06.jsonl.gz
# events/events.ft.w5.260828_10.jsonl.gz
# events/events.ft.w5.260827_20.jsonl.gz
# events/events.ft.w5.260826_04.jsonl.gz
# events/events.ft.w5.260829_04.jsonl.gz
# events/events.ft.w5.260828_06.jsonl.gz
# events/events.ft.w5.260821_14.jsonl.gz
# events/events.sd.w5.260825_03.jsonl.gz
# events/events.fd.w5.260820_07.jsonl.gz
# events/events.ft.w5.260820_17.jsonl.gz
# events/events.ft.w5.260821_17.jsonl.gz
# events/events.st.w5.260821_04.jsonl.gz
# events/events.sd.w5.260829_12.jsonl.gz
# events/events.sd.w5.260830_11.jsonl.gz
# events/events.fd.w5.260829_17.jsonl.gz
# events/events.fd.w5.260820_01.jsonl.gz
# events/events.st.w5.260821_11.jsonl.gz
# events/events.sd.w5.260825_05.jsonl.gz
# events/events.ft.w5.260822_18.jsonl.gz
# events/events.sd.w5.260828_01.jsonl.gz
# events/events.fd.w5.260820_15.jsonl.gz
# events/events.st.w5.260822_00.jsonl.gz
# events/events.ft.w5.260821_06.jsonl.gz
# events/events.sd.w5.260823_23.jsonl.gz
# events/events.ft.w5.260822_11.jsonl.gz
# events/events.sd.w5.260820_13.jsonl.gz
# events/events.st.w5.260825_20.jsonl.gz
# events/events.sd.w5.260829_07.jsonl.gz
# events/events.ft.w5.260829_06.jsonl.gz
# events/events.sd.w5.260825_00.jsonl.gz
# events/events.ft.w5.260829_08.jsonl.gz
# events/events.st.w5.260825_05.jsonl.gz
# events/events.fd.w5.260822_12.jsonl.gz
# events/events.fd.w5.260830_04.jsonl.gz
# events/events.fd.w5.260819_14.jsonl.gz
# events/events.fd.w5.260824_05.jsonl.gz
# events/events.ft.w5.260823_14.jsonl.gz
# events/events.ft.w5.260829_11.jsonl.gz
# events/events.sd.w5.260828_19.jsonl.gz
# events/events.ft.w5.260829_00.jsonl.gz
# events/events.fd.w5.260824_01.jsonl.gz
# events/events.sd.w5.260828_02.jsonl.gz
# events/events.sd.w5.260821_01.jsonl.gz
# events/events.fd.w5.260822_05.jsonl.gz
# events/events.st.w5.260822_04.jsonl.gz
# events/events.fd.w5.260826_16.jsonl.gz
# events/events.ft.w5.260820_22.jsonl.gz
# events/events.fd.w5.260827_15.jsonl.gz
# events/events.ft.w5.260825_22.jsonl.gz
# events/events.st.w5.260826_06.jsonl.gz
# events/events.ft.w5.260826_15.jsonl.gz
# events/events.sd.w5.260827_11.jsonl.gz
# events/events.fd.w5.260823_19.jsonl.gz
# events/events.fd.w5.260830_09.jsonl.gz
# events/events.ft.w5.260821_15.jsonl.gz
# events/events.st.w5.260820_17.jsonl.gz
# events/events.fd.w5.260825_16.jsonl.gz
# events/events.sd.w5.260826_15.jsonl.gz
# events/events.st.w5.260824_16.jsonl.gz
# events/events.ft.w5.260821_13.jsonl.gz
# events/events.sd.w5.260820_18.jsonl.gz
# events/events.fd.w5.260824_12.jsonl.gz
# events/events.fd.w5.260829_13.jsonl.gz
# events/events.ft.w5.260829_16.jsonl.gz
# events/events.sd.w5.260823_22.jsonl.gz
# events/events.sd.w5.260828_00.jsonl.gz
# events/events.sd.w5.260827_15.jsonl.gz
# events/events.ft.w5.260826_18.jsonl.gz
# events/events.sd.w5.260823_02.jsonl.gz
# events/events.st.w5.260827_21.jsonl.gz
# events/events.fd.w5.260822_17.jsonl.gz
# events/events.fd.w5.260823_15.jsonl.gz
# events/events.st.w5.260827_00.jsonl.gz
# events/events.fd.w5.260828_21.jsonl.gz
# events/events.sd.w5.260828_11.jsonl.gz
# events/events.st.w5.260826_13.jsonl.gz
# events/events.ft.w5.260824_06.jsonl.gz
# events/events.st.w5.260823_08.jsonl.gz
# events/events.sd.w5.260822_18.jsonl.gz
# events/events.fd.w5.260830_01.jsonl.gz
# events/events.fd.w5.260828_20.jsonl.gz
# events/events.fd.w5.260823_16.jsonl.gz
# events/events.ft.w5.260830_09.jsonl.gz
# events/events.st.w5.260830_10.jsonl.gz
# events/events.fd.w5.260822_14.jsonl.gz
# events/events.st.w5.260827_23.jsonl.gz
# events/events.sd.w5.260825_07.jsonl.gz
# events/events.ft.w5.260826_08.jsonl.gz
# events/events.sd.w5.260823_21.jsonl.gz
# events/events.ft.w5.260819_13.jsonl.gz
# events/events.ft.w5.260824_14.jsonl.gz
# events/events.sd.w5.260822_07.jsonl.gz
# events/events.sd.w5.260828_21.jsonl.gz
# events/events.ft.w5.260825_10.jsonl.gz
# events/events.ft.w5.260825_20.jsonl.gz
# events/events.ft.w5.260822_23.jsonl.gz
# events/events.ft.w5.260820_04.jsonl.gz
# events/events.fd.w5.260822_20.jsonl.gz
# events/events.fd.w5.260823_03.jsonl.gz
# events/events.fd.w5.260823_21.jsonl.gz
# events/events.ft.w5.260820_06.jsonl.gz
# events/events.fd.w5.260830_12.jsonl.gz
# events/events.sd.w5.260821_15.jsonl.gz
# events/events.ft.w5.260822_22.jsonl.gz
# events/events.st.w5.260823_14.jsonl.gz
# events/events.st.w5.260826_18.jsonl.gz
# events/events.sd.w5.260822_19.jsonl.gz
# events/events.sd.w5.260824_07.jsonl.gz
# events/events.fd.w5.260826_14.jsonl.gz
# events/events.ft.w5.260827_15.jsonl.gz
# events/events.sd.w5.260825_02.jsonl.gz
# events/events.sd.w5.260827_07.jsonl.gz
# events/events.fd.w5.260830_07.jsonl.gz
# events/events.sd.w5.260823_05.jsonl.gz
# events/events.ft.w5.260826_23.jsonl.gz
# events/events.fd.w5.260820_18.jsonl.gz
# events/events.st.w5.260825_11.jsonl.gz
# events/events.fd.w5.260824_20.jsonl.gz
# events/events.fd.w5.260828_02.jsonl.gz
# events/events.ft.w5.260825_21.jsonl.gz
# events/events.fd.w5.260825_22.jsonl.gz
# events/events.st.w5.260824_13.jsonl.gz
# events/events.fd.w5.260825_11.jsonl.gz
# events/events.ft.w5.260826_22.jsonl.gz
# events/events.st.w5.260829_16.jsonl.gz
# events/events.fd.w5.260828_23.jsonl.gz
# events/events.ft.w5.260824_15.jsonl.gz
# events/events.ft.w5.260820_00.jsonl.gz
# events/events.sd.w5.260821_10.jsonl.gz
# events/events.sd.w5.260825_15.jsonl.gz
# events/events.fd.w5.260825_00.jsonl.gz
# events/events.st.w5.260822_12.jsonl.gz
# events/events.sd.w5.260829_11.jsonl.gz
# events/events.st.w5.260827_19.jsonl.gz
# events/events.fd.w5.260828_19.jsonl.gz
# events/events.st.w5.260823_11.jsonl.gz
# events/events.sd.w5.260829_01.jsonl.gz
# events/events.st.w5.260830_06.jsonl.gz
# events/events.st.w5.260821_07.jsonl.gz
# events/events.sd.w5.260820_12.jsonl.gz
# events/events.sd.w5.260827_14.jsonl.gz
# events/events.st.w5.260827_15.jsonl.gz
# events/events.st.w5.260825_12.jsonl.gz
# events/events.fd.w5.260830_00.jsonl.gz
# events/events.sd.w5.260820_05.jsonl.gz
# events/events.sd.w5.260824_13.jsonl.gz
# events/events.sd.w5.260821_11.jsonl.gz
# events/events.sd.w5.260824_09.jsonl.gz
# events/events.ft.w5.260824_09.jsonl.gz
# events/events.st.w5.260819_17.jsonl.gz
# events/events.sd.w5.260823_17.jsonl.gz
# events/events.fd.w5.260820_08.jsonl.gz
# events/events.ft.w5.260824_07.jsonl.gz
# events/events.st.w5.260822_11.jsonl.gz
# events/events.sd.w5.260829_08.jsonl.gz
# events/events.fd.w5.260825_17.jsonl.gz
# events/events.sd.w5.260822_21.jsonl.gz
# events/events.fd.w5.260820_16.jsonl.gz
# events/events.st.w5.260825_16.jsonl.gz
# events/events.fd.w5.260830_06.jsonl.gz
# events/events.sd.w5.260820_10.jsonl.gz
# events/events.st.w5.260823_21.jsonl.gz
# events/events.ft.w5.260830_06.jsonl.gz
# events/events.ft.w5.260827_16.jsonl.gz
# events/events.st.w5.260823_22.jsonl.gz
# events/events.ft.w5.260819_19.jsonl.gz
# events/events.fd.w5.260820_20.jsonl.gz
# events/events.sd.w5.260823_18.jsonl.gz
# events/events.ft.w5.260822_07.jsonl.gz
# events/events.st.w5.260824_02.jsonl.gz
# events/events.st.w5.260822_10.jsonl.gz
# events/events.st.w5.260824_01.jsonl.gz
# events/events.st.w5.260830_09.jsonl.gz
# events/events.ft.w5.260826_05.jsonl.gz
# events/events.fd.w5.260828_04.jsonl.gz
# events/events.fd.w5.260827_10.jsonl.gz
# events/events.fd.w5.260822_08.jsonl.gz
# events/events.ft.w5.260826_01.jsonl.gz
# events/events.st.w5.260823_15.jsonl.gz
# events/events.sd.w5.260821_22.jsonl.gz
# events/events.st.w5.260821_10.jsonl.gz
# events/events.ft.w5.260823_11.jsonl.gz
# events/events.ft.w5.260822_05.jsonl.gz
# events/events.sd.w5.260826_20.jsonl.gz
# events/events.fd.w5.260829_16.jsonl.gz
# events/events.st.w5.260822_13.jsonl.gz
# events/events.fd.w5.260825_19.jsonl.gz
# events/events.fd.w5.260820_14.jsonl.gz
# events/events.st.w5.260824_20.jsonl.gz
# events/events.ft.w5.260824_19.jsonl.gz
# events/events.sd.w5.260829_17.jsonl.gz
# events/events.ft.w5.260820_03.jsonl.gz
# events/events.st.w5.260820_09.jsonl.gz
# events/events.fd.w5.260828_08.jsonl.gz
# events/events.ft.w5.260824_01.jsonl.gz
# events/events.st.w5.260828_12.jsonl.gz
# events/events.fd.w5.260826_23.jsonl.gz
# events/events.sd.w5.260827_01.jsonl.gz
# events/events.sd.w5.260820_21.jsonl.gz
# events/events.sd.w5.260829_05.jsonl.gz
# events/events.st.w5.260823_07.jsonl.gz
# events/events.ft.w5.260823_08.jsonl.gz
# events/events.st.w5.260824_17.jsonl.gz
# events/events.ft.w5.260825_06.jsonl.gz
# events/events.fd.w5.260824_15.jsonl.gz
# events/events.fd.w5.260824_21.jsonl.gz
# events/events.st.w5.260826_17.jsonl.gz
# events/events.ft.w5.260822_15.jsonl.gz
# events/events.sd.w5.260827_21.jsonl.gz
# events/events.ft.w5.260830_04.jsonl.gz
# events/events.fd.w5.260820_00.jsonl.gz
# events/events.st.w5.260824_03.jsonl.gz
# events/events.sd.w5.260821_18.jsonl.gz
# events/events.sd.w5.260823_12.jsonl.gz
# events/events.st.w5.260829_14.jsonl.gz
# events/events.fd.w5.260830_13.jsonl.gz
# events/events.fd.w5.260828_03.jsonl.gz
# events/events.ft.w5.260824_12.jsonl.gz
# events/events.st.w5.260830_07.jsonl.gz
# out5.w5.slboy.00000.260819.csv.gz
# out5.w5.slboy.00001.260819.csv.gz
# out5.w5.slboy.00002.260820.csv.gz
# out5.w5.slboy.00003.260820.csv.gz
# out5.w5.slboy.00004.260820.csv.gz
# out5.w5.slboy.00005.260820.csv.gz
# out5.w5.slboy.00006.260820.csv.gz
# out5.w5.slboy.00007.260820.csv.gz
# out5.w5.slboy.00008.260821.csv.gz
# out5.w5.slboy.00009.260821.csv.gz
# out5.w5.slboy.00010.260821.csv.gz
# out5.w5.slboy.00011.260821.csv.gz
# out5.w5.slboy.00012.260821.csv.gz
# out5.w5.slboy.00013.260821.csv.gz
# out5.w5.slboy.00014.260822.csv.gz
# out5.w5.slboy.00015.260822.csv.gz
# out5.w5.slboy.00016.260822.csv.gz
# out5.w5.slboy.00017.260822.csv.gz
# out5.w5.slboy.00018.260822.csv.gz
# out5.w5.slboy.00019.260822.csv.gz
# out5.w5.slboy.00020.260823.csv.gz
# out5.w5.slboy.00021.260823.csv.gz
# out5.w5.slboy.00022.260823.csv.gz
# out5.w5.slboy.00023.260823.csv.gz
# out5.w5.slboy.00024.260823.csv.gz
# out5.w5.slboy.00025.260823.csv.gz
# out5.w5.slboy.00026.260824.csv.gz
# out5.w5.slboy.00027.260824.csv.gz
# out5.w5.slboy.00028.260824.csv.gz
# out5.w5.slboy.00029.260824.csv.gz
# out5.w5.slboy.00030.260824.csv.gz
# out5.w5.slboy.00031.260824.csv.gz
# out5.w5.slboy.00032.260825.csv.gz
# out5.w5.slboy.00033.260825.csv.gz
# out5.w5.slboy.00034.260825.csv.gz
# out5.w5.slboy.00035.260825.csv.gz
# out5.w5.slboy.00036.260825.csv.gz
# out5.w5.slboy.00037.260825.csv.gz
# out5.w5.slboy.00038.260826.csv.gz
# out5.w5.slboy.00039.260826.csv.gz
# out5.w5.slboy.00040.260826.csv.gz
# out5.w5.slboy.00041.260826.csv.gz
# out5.w5.slboy.00042.260826.csv.gz
# out5.w5.slboy.00043.260826.csv.gz
# out5.w5.slboy.00044.260827.csv.gz
# out5.w5.slboy.00045.260827.csv.gz
# out5.w5.slboy.00046.260827.csv.gz
# out5.w5.slboy.00047.260827.csv.gz
# out5.w5.slboy.00048.260827.csv.gz
# out5.w5.slboy.00049.260827.csv.gz
# out5.w5.slboy.00050.260828.csv.gz
# out5.w5.slboy.00051.260828.csv.gz
# out5.w5.slboy.00052.260828.csv.gz
# out5.w5.slboy.00053.260828.csv.gz
# out5.w5.slboy.00054.260828.csv.gz
# out5.w5.slboy.00055.260828.csv.gz
# out5.w5.slboy.00056.260829.csv.gz
# out5.w5.slboy.00057.260829.csv.gz
# out5.w5.slboy.00058.260829.csv.gz
# out5.w5.slboy.00059.260829.csv.gz
# out5.w5.slboy.00060.260829.csv.gz
# out5.w5.slboy.00061.260829.csv.gz
# out5.w5.slboy.00062.260830.csv.gz
# out5.w5.slboy.00063.260830.csv.gz
# out5.w5.slboy.00064.260830.csv.gz
# out5.w5.slboy.00065.260830.csv
# renamed 'events/events.fd.w5.260819_13.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_13.jsonl.gz'
# renamed 'events/events.fd.w5.260819_14.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_14.jsonl.gz'
# renamed 'events/events.fd.w5.260819_15.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_15.jsonl.gz'
# renamed 'events/events.fd.w5.260819_16.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_16.jsonl.gz'
# renamed 'events/events.fd.w5.260819_17.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_17.jsonl.gz'
# renamed 'events/events.fd.w5.260819_18.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_18.jsonl.gz'
# renamed 'events/events.fd.w5.260819_19.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_19.jsonl.gz'
# renamed 'events/events.fd.w5.260819_20.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_20.jsonl.gz'
# renamed 'events/events.fd.w5.260819_21.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_21.jsonl.gz'
# renamed 'events/events.fd.w5.260819_22.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_22.jsonl.gz'
# renamed 'events/events.fd.w5.260819_23.jsonl.gz' -> '/root/btc_events/events.fd.w5.260819_23.jsonl.gz'
# renamed 'events/events.fd.w5.260820_00.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_00.jsonl.gz'
# renamed 'events/events.fd.w5.260820_01.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_01.jsonl.gz'
# renamed 'events/events.fd.w5.260820_02.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_02.jsonl.gz'
# renamed 'events/events.fd.w5.260820_03.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_03.jsonl.gz'
# renamed 'events/events.fd.w5.260820_04.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_04.jsonl.gz'
# renamed 'events/events.fd.w5.260820_05.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_05.jsonl.gz'
# renamed 'events/events.fd.w5.260820_06.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_06.jsonl.gz'
# renamed 'events/events.fd.w5.260820_07.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_07.jsonl.gz'
# renamed 'events/events.fd.w5.260820_08.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_08.jsonl.gz'
# renamed 'events/events.fd.w5.260820_09.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_09.jsonl.gz'
# renamed 'events/events.fd.w5.260820_10.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_10.jsonl.gz'
# renamed 'events/events.fd.w5.260820_11.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_11.jsonl.gz'
# renamed 'events/events.fd.w5.260820_12.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_12.jsonl.gz'
# renamed 'events/events.fd.w5.260820_13.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_13.jsonl.gz'
# renamed 'events/events.fd.w5.260820_14.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_14.jsonl.gz'
# renamed 'events/events.fd.w5.260820_15.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_15.jsonl.gz'
# renamed 'events/events.fd.w5.260820_16.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_16.jsonl.gz'
# renamed 'events/events.fd.w5.260820_17.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_17.jsonl.gz'
# renamed 'events/events.fd.w5.260820_18.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_18.jsonl.gz'
# renamed 'events/events.fd.w5.260820_19.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_19.jsonl.gz'
# renamed 'events/events.fd.w5.260820_20.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_20.jsonl.gz'
# renamed 'events/events.fd.w5.260820_21.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_21.jsonl.gz'
# renamed 'events/events.fd.w5.260820_22.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_22.jsonl.gz'
# renamed 'events/events.fd.w5.260820_23.jsonl.gz' -> '/root/btc_events/events.fd.w5.260820_23.jsonl.gz'
# renamed 'events/events.fd.w5.260821_00.jsonl.gz' -> '/root/btc_events/events.fd.w5.260821_00.jsonl.gz'
# renamed 'events/events.fd.w5.260821_01.jsonl.gz' -> '/root/btc_events/events.fd.w5.260821_01.jsonl.gz'
# renamed 'events/events.fd.w5.260821_02.jsonl.gz' -> '/root/btc_events/events.fd.w5.260821_02.jsonl.gz'
# renamed 'events/events.fd.w5.260821_03.jsonl.gz' -> '/root/btc_events/events.fd.w5.260821_03.jsonl.gz'
# renamed 'events/events.fd.w5.260821_04.jsonl.gz' -> '/root/btc_events/events.fd.w5.260821_04.jsonl.gz'
# renamed 'events/events.fd.w5.260821_05.jsonl.gz' -> '/root/btc_events/events.fd.w5.260821_05.jsonl.gz'
# renamed 'events/events.fd.w5.260821_06.jsonl.gz' -> '/root/btc_events/events.fd.w5.260821_06.jsonl.gz'
# ...
# renamed 'events/events.st.w5.260824_05.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_05.jsonl.gz'
# renamed 'events/events.st.w5.260824_06.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_06.jsonl.gz'
# renamed 'events/events.st.w5.260824_07.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_07.jsonl.gz'
# renamed 'events/events.st.w5.260824_08.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_08.jsonl.gz'
# renamed 'events/events.st.w5.260824_09.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_09.jsonl.gz'
# renamed 'events/events.st.w5.260824_10.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_10.jsonl.gz'
# renamed 'events/events.st.w5.260824_11.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_11.jsonl.gz'
# renamed 'events/events.st.w5.260824_12.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_12.jsonl.gz'
# renamed 'events/events.st.w5.260824_13.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_13.jsonl.gz'
# renamed 'events/events.st.w5.260824_14.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_14.jsonl.gz'
# renamed 'events/events.st.w5.260824_15.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_15.jsonl.gz'
# renamed 'events/events.st.w5.260824_16.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_16.jsonl.gz'
# renamed 'events/events.st.w5.260824_17.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_17.jsonl.gz'
# renamed 'events/events.st.w5.260824_18.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_18.jsonl.gz'
# renamed 'events/events.st.w5.260824_19.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_19.jsonl.gz'
# renamed 'events/events.st.w5.260824_20.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_20.jsonl.gz'
# renamed 'events/events.st.w5.260824_21.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_21.jsonl.gz'
# renamed 'events/events.st.w5.260824_22.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_22.jsonl.gz'
# renamed 'events/events.st.w5.260824_23.jsonl.gz' -> '/root/btc_events/events.st.w5.260824_23.jsonl.gz'
# renamed 'events/events.st.w5.260825_00.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_00.jsonl.gz'
# renamed 'events/events.st.w5.260825_01.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_01.jsonl.gz'
# renamed 'events/events.st.w5.260825_02.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_02.jsonl.gz'
# renamed 'events/events.st.w5.260825_03.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_03.jsonl.gz'
# renamed 'events/events.st.w5.260825_04.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_04.jsonl.gz'
# renamed 'events/events.st.w5.260825_05.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_05.jsonl.gz'
# renamed 'events/events.st.w5.260825_06.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_06.jsonl.gz'
# renamed 'events/events.st.w5.260825_07.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_07.jsonl.gz'
# renamed 'events/events.st.w5.260825_08.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_08.jsonl.gz'
# renamed 'events/events.st.w5.260825_09.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_09.jsonl.gz'
# renamed 'events/events.st.w5.260825_10.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_10.jsonl.gz'
# renamed 'events/events.st.w5.260825_11.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_11.jsonl.gz'
# renamed 'events/events.st.w5.260825_12.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_12.jsonl.gz'
# renamed 'events/events.st.w5.260825_13.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_13.jsonl.gz'
# renamed 'events/events.st.w5.260825_14.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_14.jsonl.gz'
# renamed 'events/events.st.w5.260825_15.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_15.jsonl.gz'
# renamed 'events/events.st.w5.260825_16.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_16.jsonl.gz'
# renamed 'events/events.st.w5.260825_17.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_17.jsonl.gz'
# renamed 'events/events.st.w5.260825_18.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_18.jsonl.gz'
# renamed 'events/events.st.w5.260825_19.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_19.jsonl.gz'
# renamed 'events/events.st.w5.260825_20.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_20.jsonl.gz'
# renamed 'events/events.st.w5.260825_21.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_21.jsonl.gz'
# renamed 'events/events.st.w5.260825_22.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_22.jsonl.gz'
# renamed 'events/events.st.w5.260825_23.jsonl.gz' -> '/root/btc_events/events.st.w5.260825_23.jsonl.gz'
# renamed 'events/events.st.w5.260826_00.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_00.jsonl.gz'
# renamed 'events/events.st.w5.260826_01.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_01.jsonl.gz'
# renamed 'events/events.st.w5.260826_02.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_02.jsonl.gz'
# renamed 'events/events.st.w5.260826_03.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_03.jsonl.gz'
# renamed 'events/events.st.w5.260826_04.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_04.jsonl.gz'
# renamed 'events/events.st.w5.260826_05.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_05.jsonl.gz'
# renamed 'events/events.st.w5.260826_06.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_06.jsonl.gz'
# renamed 'events/events.st.w5.260826_07.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_07.jsonl.gz'
# renamed 'events/events.st.w5.260826_08.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_08.jsonl.gz'
# renamed 'events/events.st.w5.260826_09.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_09.jsonl.gz'
# renamed 'events/events.st.w5.260826_10.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_10.jsonl.gz'
# renamed 'events/events.st.w5.260826_11.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_11.jsonl.gz'
# renamed 'events/events.st.w5.260826_12.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_12.jsonl.gz'
# renamed 'events/events.st.w5.260826_13.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_13.jsonl.gz'
# renamed 'events/events.st.w5.260826_14.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_14.jsonl.gz'
# renamed 'events/events.st.w5.260826_15.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_15.jsonl.gz'
# renamed 'events/events.st.w5.260826_16.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_16.jsonl.gz'
# renamed 'events/events.st.w5.260826_17.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_17.jsonl.gz'
# renamed 'events/events.st.w5.260826_18.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_18.jsonl.gz'
# renamed 'events/events.st.w5.260826_19.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_19.jsonl.gz'
# renamed 'events/events.st.w5.260826_20.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_20.jsonl.gz'
# renamed 'events/events.st.w5.260826_21.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_21.jsonl.gz'
# renamed 'events/events.st.w5.260826_22.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_22.jsonl.gz'
# renamed 'events/events.st.w5.260826_23.jsonl.gz' -> '/root/btc_events/events.st.w5.260826_23.jsonl.gz'
# renamed 'events/events.st.w5.260827_00.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_00.jsonl.gz'
# renamed 'events/events.st.w5.260827_01.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_01.jsonl.gz'
# renamed 'events/events.st.w5.260827_02.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_02.jsonl.gz'
# renamed 'events/events.st.w5.260827_03.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_03.jsonl.gz'
# renamed 'events/events.st.w5.260827_04.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_04.jsonl.gz'
# renamed 'events/events.st.w5.260827_05.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_05.jsonl.gz'
# renamed 'events/events.st.w5.260827_06.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_06.jsonl.gz'
# renamed 'events/events.st.w5.260827_07.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_07.jsonl.gz'
# renamed 'events/events.st.w5.260827_08.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_08.jsonl.gz'
# renamed 'events/events.st.w5.260827_09.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_09.jsonl.gz'
# renamed 'events/events.st.w5.260827_10.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_10.jsonl.gz'
# renamed 'events/events.st.w5.260827_11.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_11.jsonl.gz'
# renamed 'events/events.st.w5.260827_12.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_12.jsonl.gz'
# renamed 'events/events.st.w5.260827_13.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_13.jsonl.gz'
# renamed 'events/events.st.w5.260827_14.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_14.jsonl.gz'
# renamed 'events/events.st.w5.260827_15.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_15.jsonl.gz'
# renamed 'events/events.st.w5.260827_16.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_16.jsonl.gz'
# renamed 'events/events.st.w5.260827_17.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_17.jsonl.gz'
# renamed 'events/events.st.w5.260827_18.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_18.jsonl.gz'
# renamed 'events/events.st.w5.260827_19.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_19.jsonl.gz'
# renamed 'events/events.st.w5.260827_20.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_20.jsonl.gz'
# renamed 'events/events.st.w5.260827_21.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_21.jsonl.gz'
# renamed 'events/events.st.w5.260827_22.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_22.jsonl.gz'
# renamed 'events/events.st.w5.260827_23.jsonl.gz' -> '/root/btc_events/events.st.w5.260827_23.jsonl.gz'
# renamed 'events/events.st.w5.260828_00.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_00.jsonl.gz'
# renamed 'events/events.st.w5.260828_01.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_01.jsonl.gz'
# renamed 'events/events.st.w5.260828_02.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_02.jsonl.gz'
# renamed 'events/events.st.w5.260828_03.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_03.jsonl.gz'
# renamed 'events/events.st.w5.260828_04.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_04.jsonl.gz'
# renamed 'events/events.st.w5.260828_05.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_05.jsonl.gz'
# renamed 'events/events.st.w5.260828_06.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_06.jsonl.gz'
# renamed 'events/events.st.w5.260828_07.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_07.jsonl.gz'
# renamed 'events/events.st.w5.260828_08.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_08.jsonl.gz'
# renamed 'events/events.st.w5.260828_09.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_09.jsonl.gz'
# renamed 'events/events.st.w5.260828_10.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_10.jsonl.gz'
# renamed 'events/events.st.w5.260828_11.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_11.jsonl.gz'
# renamed 'events/events.st.w5.260828_12.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_12.jsonl.gz'
# renamed 'events/events.st.w5.260828_13.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_13.jsonl.gz'
# renamed 'events/events.st.w5.260828_14.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_14.jsonl.gz'
# renamed 'events/events.st.w5.260828_15.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_15.jsonl.gz'
# renamed 'events/events.st.w5.260828_16.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_16.jsonl.gz'
# renamed 'events/events.st.w5.260828_17.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_17.jsonl.gz'
# renamed 'events/events.st.w5.260828_18.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_18.jsonl.gz'
# renamed 'events/events.st.w5.260828_19.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_19.jsonl.gz'
# renamed 'events/events.st.w5.260828_20.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_20.jsonl.gz'
# renamed 'events/events.st.w5.260828_21.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_21.jsonl.gz'
# renamed 'events/events.st.w5.260828_22.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_22.jsonl.gz'
# renamed 'events/events.st.w5.260828_23.jsonl.gz' -> '/root/btc_events/events.st.w5.260828_23.jsonl.gz'
# renamed 'events/events.st.w5.260829_00.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_00.jsonl.gz'
# renamed 'events/events.st.w5.260829_01.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_01.jsonl.gz'
# renamed 'events/events.st.w5.260829_02.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_02.jsonl.gz'
# renamed 'events/events.st.w5.260829_03.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_03.jsonl.gz'
# renamed 'events/events.st.w5.260829_04.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_04.jsonl.gz'
# renamed 'events/events.st.w5.260829_05.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_05.jsonl.gz'
# renamed 'events/events.st.w5.260829_06.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_06.jsonl.gz'
# renamed 'events/events.st.w5.260829_07.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_07.jsonl.gz'
# renamed 'events/events.st.w5.260829_08.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_08.jsonl.gz'
# renamed 'events/events.st.w5.260829_09.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_09.jsonl.gz'
# renamed 'events/events.st.w5.260829_10.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_10.jsonl.gz'
# renamed 'events/events.st.w5.260829_11.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_11.jsonl.gz'
# renamed 'events/events.st.w5.260829_12.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_12.jsonl.gz'
# renamed 'events/events.st.w5.260829_13.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_13.jsonl.gz'
# renamed 'events/events.st.w5.260829_14.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_14.jsonl.gz'
# renamed 'events/events.st.w5.260829_15.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_15.jsonl.gz'
# renamed 'events/events.st.w5.260829_16.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_16.jsonl.gz'
# renamed 'events/events.st.w5.260829_17.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_17.jsonl.gz'
# renamed 'events/events.st.w5.260829_18.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_18.jsonl.gz'
# renamed 'events/events.st.w5.260829_19.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_19.jsonl.gz'
# renamed 'events/events.st.w5.260829_20.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_20.jsonl.gz'
# renamed 'events/events.st.w5.260829_21.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_21.jsonl.gz'
# renamed 'events/events.st.w5.260829_22.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_22.jsonl.gz'
# renamed 'events/events.st.w5.260829_23.jsonl.gz' -> '/root/btc_events/events.st.w5.260829_23.jsonl.gz'
# renamed 'events/events.st.w5.260830_00.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_00.jsonl.gz'
# renamed 'events/events.st.w5.260830_01.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_01.jsonl.gz'
# renamed 'events/events.st.w5.260830_02.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_02.jsonl.gz'
# renamed 'events/events.st.w5.260830_03.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_03.jsonl.gz'
# renamed 'events/events.st.w5.260830_04.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_04.jsonl.gz'
# renamed 'events/events.st.w5.260830_05.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_05.jsonl.gz'
# renamed 'events/events.st.w5.260830_06.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_06.jsonl.gz'
# renamed 'events/events.st.w5.260830_07.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_07.jsonl.gz'
# renamed 'events/events.st.w5.260830_08.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_08.jsonl.gz'
# renamed 'events/events.st.w5.260830_09.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_09.jsonl.gz'
# renamed 'events/events.st.w5.260830_10.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_10.jsonl.gz'
# renamed 'events/events.st.w5.260830_11.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_11.jsonl.gz'
# renamed 'events/events.st.w5.260830_12.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_12.jsonl.gz'
# renamed 'events/events.st.w5.260830_13.jsonl.gz' -> '/root/btc_events/events.st.w5.260830_13.jsonl.gz'
# removed 'events.ft.w5.260830_13.jsonl.gz'
# removed 'events.fd.w5.260830_13.jsonl.gz'
# removed 'events.st.w5.260830_13.jsonl.gz'
# removed 'events.sd.w5.260830_13.jsonl.gz'

# %%
# ── Cell 3: Config ─────────────────────────────────────────────────────────

# ── CONFIGURE THESE ───────────────────────────────────────────────────────
DATA_DIR   = '/root/btc_data'
OUTPUT_DIR = '/root/btc_lstm_run012'

WINDOW_SEC  = 5           # run.010: the collector's w5 stream (v4.1 dual-
                          # writes w15+w5; the cell-5 loader filters on this)
HORIZONS    = [6, 9, 12, 15, 18, 24]
                          # run.010: 5s bars — run.009's [2,3,4,5,6,8] ×3, i.e.
                          # the SAME wall-clock horizons 30s–2min. h24 (2min) is
                          # the anchor (same θ → lup_24/ldn_24 comparable to
                          # run.009's lup_8/ldn_8).
H_TRADE     = 24          # importance sampling / Huber weighting / reference IC
                          # follow the least-noisy kept horizon (run.004's
                          # t=+4.8 edge was at h8@15s = 2min = h24@5s)
VOL_WINDOW  = 720         # 1h rolling window for target normalisation (5s bars)
TARGET_CLIP = 5.0         # clip |target| at 5 sigma

SEQ_LEN      = 192        # 16 min of context (unchanged wall-clock; 3× bars at 5s)
HIDDEN_DIM   = 128        # SMALL on purpose — capacity was cleared twice (run.002/003)
NUM_LAYERS   = 2
DROPOUT      = 0.3
LR           = 1e-3
WEIGHT_DECAY = 1e-4
BATCH_SIZE   = 2048
EPOCHS       = 12
WARMUP       = 2          # linear warmup epochs before cosine decay
PATIENCE     = 5          # early stop on val AP of the two H_SEL opportunity heads
EPOCH_SAMPLE_CAP = 600_000  # train sequences drawn per epoch (weighted, w/ replacement)

# ── run.003 (kept): focus training on directional bars ──
SAMPLE_W_BASE = 0.25      # epoch-draw probability ∝ SAMPLE_W_BASE + |y_trade|
LOSS_W_ALPHA  = 1.0       # per-sample Huber weight = min(1 + α·|y_trade|, cap)
LOSS_W_CAP    = 4.0

# ── run.004 (kept): multi-seed evaluation ──
SEEDS = [0, 1, 2]         # per-fold; test score/prob = seed-ensemble mean
MIN_DAY_SAMPLES = 500     # a test day needs this many samples to enter daily-IC stats

N_FOLDS         = 4       # walk-forward folds over the last 60% of the window
TEST_START_FRAC = 0.40    # first 40% is never tested (training warmup)
VAL_FRAC        = 0.12    # tail of each training range used for early stopping
COVERAGE_MIN    = 0.60    # features with lower non-NaN coverage are excluded

MAKER_FEE = 0.0002        # per side (Binance USDT-M futures maker)
TAKER_FEE = 0.0005        # per side

# ── run.006 (kept): schema-3/4 era handling ──
V3_ERA_ONLY  = True      # restrict the analysis window to schema-3+ rows
V3_MARKER    = 'future_ofi_sum'   # first non-NaN value of this = era start
MIN_ERA_DAYS = 6         # abort if less schema-3+ data than this has accumulated
WALL_BAND    = 0.30       # collector WALL_BAND_PCT — wall dist −1 (=absent) maps here

# ── run.007: short-horizon big-move heads ──
H_SEL        = 18         # primary selective horizon (90s), pre-registered:
                          # 18×5s = 90s = run.009's h6 — wall-clock-unchanged.
                          # Rationale (run.007): closest kept horizon to run.006's
                          # best-lift h8, θ=20bp base rate stays trainable, and
                          # ~90% of a θ-touch survives to the 90s endpoint.
THETA_BY_H   = {6: 0.0015, 9: 0.0015,   # 15 bps at 30–45s: a 20 bps move inside
                12: 0.0020, 15: 0.0020, #   30–45s is near-unreachable (base ≲0.3%)
                18: 0.0020, 24: 0.0020} # 20 bps at 60–120s — same wall-clock map as run.009
POS_W_CAP    = 20.0       # BCE pos_weight = neg/pos per head, capped here
BCE_W        = 1.0        # classification loss weight vs the (frozen-form) Huber part

# ── run.007: TP/SL exit simulation (run.006's #1 lever, untested there) ──
TP_MULT      = 1.0        # primary take-profit = TP_MULT·θ_h (limit, maker exit)
SL_MULT      = 1.0        # primary stop = SL_MULT·θ_h (taker exit at the
                          # breaching bar's CLOSE — gap-through conservative)
TP_SL_GRID   = [(1.0, 1.0), (1.0, 0.5), (1.0, np.inf), (1.5, 1.0), (1.5, 0.5)]
                          # exploratory grid; ONLY (TP_MULT, SL_MULT) is gated

# ── run.007: rolling-causal trigger calibration ──
ROLL_CAL_DAYS = 14        # τ for test day D = (1−rate)-quantile of the scores
                          # seen in [D−14d, D): val seeds the window, already-
                          # seen test scores join it. Deployable (past data
                          # only); fixes run.006's fold-1 zero-trigger pathology.
MIN_CAL_N     = 5000      # thinner window → expand to all past scores

TRIGGER_RATES = [0.0001, 0.001, 0.01]  # nominal trigger rates
PRIMARY_RATE  = 0.001     # pre-registered primary: top-0.1% ≈ a few signals/day
N_BOOT        = 2000      # day-cluster bootstrap draws for net-bps CIs

# ── run.008: maker-entry simulation (run.007's diagnosed remaining lever) ──
ENTRY_WAIT   = 6          # bars the entry limit may rest before cancel
                          # (primary, pre-registered): 6×5s = 30s = run.009's
                          # wait=2 at 15s — wall-clock-unchanged; the pullback
                          # timing rationale (30s scale) is unchanged
ENTRY_DELTA  = 0.0        # limit offset in θ_h units below (up) / above (dn)
                          # the trigger close; 0 = post AT the signal close
ENTRY_DELAY  = 0          # bars between signal and posting (1 = latency stress)

# ── run.011 router (cell 10R) ────────────────────────────────────────────
ROUTER_TRAIN_RATE = 0.01   # router TRAINS on the causal 1% triggers (sample
                           # size); it is APPLIED to the primary 0.1% triggers
ROUTER_MIN_POS    = 10     # fewer favourable train examples → abstain that day
ROUTER_TAU_GRID   = [round(0.05 * i, 2) for i in range(1, 20)]  # val-only pick
ROUTER_C          = 0.5    # logistic regularisation (matches cell 10D)
WAIT_GRID    = [3, 6, 12, 18]      # exploratory (15/30/60/90s at 5s = run.009's grid)
DELTA_GRID   = [0.0, 0.25, 0.5]    # exploratory, ·θ_h
FILL_MIN     = 0.25       # gate C: primary config must fill ≥ this share of
                          # triggers — a maker edge that almost never fills is
                          # a statistical fluke, not a strategy

# ── run.012: v5 raw event stream (loader in cell 4, era slice in cell 5) ────
EVENTS_DIR      = '/root/btc_events'  # events.<fd|ft|st>.w5.<YYMMDD_HH>.jsonl.gz
EVENTS_ERA_ONLY = True    # restrict the analysis window to event-covered bars
MIN_EVENTS_DAYS = 6       # abort below this — walk-forward needs days, not hours

DRIVE_SAVE_DIR = '/content/drive/MyDrive/btc_lstm_run012'
# ─────────────────────────────────────────────────────────────────────────

os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f'Data dir:   {DATA_DIR}')
print(f'Output dir: {OUTPUT_DIR}')
print('θ per horizon: ' + '  '.join(f'h{h}={t*1e4:.0f}bp' for h, t in THETA_BY_H.items()))
print(f'taker RT = {2*TAKER_FEE*1e4:.0f} bps   TP RT (taker in, maker out) = '
      f'{(TAKER_FEE+MAKER_FEE)*1e4:.0f} bps   full-maker RT = '
      f'{2*MAKER_FEE*1e4:.0f} bps')
# Out:
# Data dir:   /root/btc_data
# Output dir: /root/btc_lstm_run012
# θ per horizon: h6=15bp  h9=15bp  h12=20bp  h15=20bp  h18=20bp  h24=20bp
# taker RT = 10 bps   TP RT (taker in, maker out) = 7 bps   full-maker RT = 4 bps

# %%
# ── Cell 4: Feature pipeline ──────────────────────────────────────────────
SEPARATOR = ';'

COLS_NEEDED_BASE = {
    'spot_datetime', 'future_datetime', 'spot_timestamp', 'future_timestamp',
    'future_bid_close', 'future_ask_close',
    'future_bid_open', 'future_bid_max', 'future_bid_min',
    'future_bid_median', 'future_ask_median',
    'future_spread_open', 'future_spread_max',
    'future_buy_qty', 'future_sell_qty',
    'future_buy_samples', 'future_sell_samples',
    'future_buy_vwap', 'future_sell_vwap', 'future_price_diff',
    'future_bid_liq_0.0_median', 'future_ask_liq_0.0_median',
    'spot_buy_qty', 'spot_sell_qty',
    'spot_bid_close', 'spot_ask_close',
    'opt_open_interest_sample', 'opt_funding_rate_sample',
    'opt_est_funding_rate_sample', 'opt_remaining_time_sample',
    'opt_long_force_exit_qty_sum', 'opt_short_force_exit_qty_sum',
    'future_first_trade_side', 'future_last_trade_side',
    'future_largest_trade_qty', 'future_largest_trade_side',
    'future_buy_count_early', 'future_buy_count_late',
    'future_sell_count_early', 'future_sell_count_late',
    'future_buy_qty_early', 'future_buy_qty_late',
    'future_sell_qty_early', 'future_sell_qty_late',
}
COLS_NEEDED_LIQ_DEEP  = [
    'future_bid_liq_0.04_median', 'future_ask_liq_0.04_median',
    'future_bid_liq_0.05_median', 'future_ask_liq_0.05_median',
    'future_bid_liq_0.06_median', 'future_ask_liq_0.06_median',
]
COLS_NEEDED_LIQ_TOTAL = [
    'future_bid_liq_0.1_median',  'future_ask_liq_0.1_median',
    'future_bid_liq_0.2_median',  'future_ask_liq_0.2_median',
    'future_bid_liq_0.3_median',  'future_ask_liq_0.3_median',
    'future_bid_liq_0.4_median',  'future_ask_liq_0.4_median',
]
# run.006: schema-3/4 collector columns (out3/out4 files; NaN in older files)
COLS_NEEDED_V3 = [
    'future_mid_std', 'future_mid_rv', 'future_mid_flips',
    'future_micro_dev_close', 'future_micro_dev_median',
    'future_ofi_sum',
    'future_add_bid_near_sum', 'future_cancel_bid_near_sum',
    'future_add_ask_near_sum', 'future_cancel_ask_near_sum',
    'future_add_bid_wide_sum', 'future_cancel_bid_wide_sum',
    'future_add_ask_wide_sum', 'future_cancel_ask_wide_sum',
    'future_depth_msg_count', 'future_best_bid_move_count',
    'future_best_ask_move_count',
    'future_bid_depletion_count', 'future_ask_depletion_count',
    'future_buy_size_median', 'future_buy_size_p90',
    'future_sell_size_median', 'future_sell_size_p90',
    'future_bid_wall_qty_median', 'future_bid_wall_qty_max',
    'future_bid_wall_dist_median',
    'future_ask_wall_qty_median', 'future_ask_wall_qty_max',
    'future_ask_wall_dist_median',
    'future_max_batch_buy_qty', 'future_max_batch_sell_qty',
    'future_max_buy_run_qty', 'future_max_sell_run_qty',
    'opt_long_force_exit_cnt_sum', 'opt_short_force_exit_cnt_sum',
    'opt_long_force_exit_notional_sum', 'opt_short_force_exit_notional_sum',
    'opt_force_exit_notional_max',
    'opt_long_short_ratio_sample',
    'opt_eth_mid_open', 'opt_eth_mid_close',
    'schema_version',
]

# run.004: long-timescale context the 64-bar input window cannot see
NEW_FEATURES = [
    'ret_norm_1h', 'ret_norm_4h', 'ret_norm_24h',
    'ma_gap_1h', 'ma_gap_4h', 'ma_gap_24h',
    'vol_ratio_1h_24h', 'range_pos_24h',
    'basis_z_4h', 'basis_mom_1h',
    'dow_sin', 'dow_cos',
]

# run.006: engineered from the schema-3/4 columns. Episodic by nature —
# mostly quiet, occasionally scream — which is the shape a rare-trigger
# model needs (v1's continuous rolling stats are why runs 001–005 came
# out diffuse).
V3_FEATURES = [
    'ofi_z', 'flow_net_near_z', 'cancel_imbal_near',
    'pull_add_bid', 'pull_add_ask', 'flow_net_widex_z',
    'micro_dev_z', 'mid_rv_norm', 'mid_flips_norm', 'msg_rate_norm',
    'depl_imbal', 'depl_total_norm',
    'buy_tail_ratio', 'sell_tail_ratio',
    'liq_cnt_log', 'liq_imbal', 'liq_notional_log', 'liq_notional_max_log',
    'wall_imbal', 'bid_wall_dist', 'ask_wall_dist', 'wall_qty_norm',
    'batch_buy_rel', 'batch_sell_rel', 'sweep_buy_rel', 'sweep_sell_rel',
    'eth_ret_z', 'eth_lead_gap', 'lsr_z',
]

# ── run.012: v5 raw-event features ───────────────────────────────────────
# Raw per-bar aggregates are parsed from the v5 event stream by
# load_event_features() (bottom of this cell) and merged inside prepare();
# these are the ENGINEERED versions (z-scores / bounded shares) entering
# ALL_FEATURES. The raw ev_* columns are inputs, never features themselves.
EV_FEATURES = [
    # depth (fd): activity, per-message granularity, timing, feed integrity
    'ev_fd_nmsg_z', 'ev_fd_levels_z', 'ev_fd_maxq_z', 'ev_fd_pull_share',
    'ev_fd_gmin_z', 'ev_fd_last1s', 'ev_fd_time_ask_imb',
    'ev_fd_missed', 'ev_fd_resync',
    # trades (ft): count, wall-clock burst, sub-bar timing, exact tail
    'ev_ft_ntr_z', 'ev_ft_gmin_z', 'ev_ft_time_imb',
    'ev_ft_last1s', 'ev_ft_first1s', 'ev_ft_maxpos', 'ev_ft_sweep1s',
    'ev_ft_maxrel_z',
    # trades (st): spot lead-lag at sub-bar resolution
    'ev_st_ntr_z', 'ev_st_time_imb', 'ev_st_last1s',
]

ALL_FEATURES = [
    'book_imbalance', 'flow_imbalance', 'momentum', 'book_imbal_deep',
    'flow_imbal_roll4', 'flow_imbal_roll8', 'book_imbal_roll4', 'book_imbal_roll8',
    'vwap_spread', 'liq_flag', 'stochastic', 'spread_expansion', 'sample_imbalance',
    'flow_agreement', 'oi_change', 'size_imbalance', 'liq_conc_bid', 'liq_conc_ask',
    'hour_sin', 'hour_cos', 'minute_sin', 'minute_cos',
    'near_funding', 'funding_pressure', 'vol_norm',
    'trade_side_open', 'trade_side_close', 'trade_side_momentum',
    'largest_trade_side', 'largest_trade_rel',
    'buy_accel', 'sell_accel', 'flow_accel', 'buy_count_accel', 'late_imbalance',
] + NEW_FEATURES + V3_FEATURES + EV_FEATURES

# binary opportunity heads: column order is frozen here and reused everywhere
CLS_KEYS = [(h, s) for h in HORIZONS for s in ('up', 'dn')]
CLS_COLS = [f'l{s}_{h}' for h, s in CLS_KEYS]
SEL_UP_J = CLS_KEYS.index((H_SEL, 'up'))
SEL_DN_J = CLS_KEYS.index((H_SEL, 'dn'))


def load_files(files):
    all_needed = (COLS_NEEDED_BASE | set(COLS_NEEDED_LIQ_DEEP)
                  | set(COLS_NEEDED_LIQ_TOTAL) | set(COLS_NEEDED_V3))
    frames = []
    for path in files:
        try:
            hdr = pd.read_csv(path, sep=SEPARATOR, nrows=0)
            usecols = sorted(all_needed & set(hdr.columns))
            if 'spot_datetime' not in usecols:
                print(f'  SKIP {os.path.basename(path)}: missing spot_datetime')
                continue
            df = pd.read_csv(path, sep=SEPARATOR, usecols=usecols, low_memory=False)
            df = df[df['spot_datetime'] != 'spot_datetime']
            frames.append(df)
        except Exception as e:
            print(f'  SKIP {os.path.basename(path)}: {e}')
    if not frames:
        raise RuntimeError('No valid CSV files found.')
    print(f'  Loaded {len(frames)} files')
    return pd.concat(frames, ignore_index=True)


def prepare(df, horizons, vol_window, ev_df=None):
    df['dt'] = pd.to_datetime(df['spot_datetime'], errors='coerce')
    df = df.dropna(subset=['dt']).sort_values('dt').reset_index(drop=True)
    n_before = len(df)
    df = df.drop_duplicates(subset='dt', keep='first').reset_index(drop=True)
    if len(df) < n_before:
        print(f'  Dropped {n_before - len(df)} duplicate timestamps')

    skip = {'spot_datetime', 'future_datetime', 'dt'}
    for col in df.columns:
        if col not in skip:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    # ── run.012: merge per-bar event aggregates (key = collector epoch) ────
    # spot_timestamp IS the bar-start epoch written by the same machine clock
    # as the event receive times — the merge is tz-free by construction (the
    # v5 docstring forbids aligning on parsed datetime strings).
    if ev_df is not None and len(ev_df):
        df['_evk'] = pd.to_numeric(df['spot_timestamp'], errors='coerce').round().astype('Int64')
        ev = ev_df.copy()
        ev.index = ev.index.astype('Int64')
        df = df.merge(ev, left_on='_evk', right_index=True, how='left').drop(columns=['_evk'])
        # coverage marker BEFORE sentinel fill — the cell-5 era slice keys on it
        # (fd = most active stream; a bar with zero fd events in 5s essentially
        # means no event file covers that bar, not a genuinely silent book)
        df['ev_coverage'] = df['ev_fd_nmsg'].notna().astype(np.float32)
        # Sentinel fills: quiet bars are real (counts/shares → 0); an undefined
        # min-gap means "as quiet as measurable" → the bar length in ms; an
        # undefined max/median size ratio means uniform → 1 (log → 0).
        fills = {c: 0.0 for c in (
            'ev_fd_nmsg', 'ev_fd_levels', 'ev_fd_maxq', 'ev_fd_pull_share',
            'ev_fd_last1s', 'ev_fd_time_ask_imb', 'ev_fd_missed', 'ev_fd_resync',
            'ev_ft_ntr', 'ev_ft_last1s', 'ev_ft_first1s', 'ev_ft_sweep1s',
            'ev_ft_maxpos', 'ev_ft_time_imb',
            'ev_st_ntr', 'ev_st_last1s', 'ev_st_time_imb')}
        fills.update({'ev_fd_gmin': float(WINDOW_SEC * 1000),
                      'ev_ft_gmin': float(WINDOW_SEC * 1000),
                      'ev_ft_maxrel': 1.0})
        df = df.fillna(value={k: v for k, v in fills.items() if k in df.columns})

    for col in [c for c in df.columns if c.startswith('opt_')]:
        df[col] = df[col].replace(-1, np.nan)

    if 'future_bid_close' in df.columns and 'future_ask_close' in df.columns:
        df['close_price'] = (df['future_bid_close'] + df['future_ask_close']) / 2.0
    else:
        df['close_price'] = (df['future_bid_median'] + df['future_ask_median']) / 2.0

    # Gap structure: collector restarts / dropped bars break the 15s cadence.
    gap = df['dt'].diff().dt.total_seconds()
    n_breaks = int((gap != WINDOW_SEC).sum()) - 1
    big = gap[gap > 3600]
    print(f'  Cadence breaks: {n_breaks}  (gaps >1h: {len(big)}, largest: {gap.max()/3600:.1f}h)')

    eps = 1e-9
    df['flow_imbalance'] = ((df['future_buy_qty'] - df['future_sell_qty']) /
                            (df['future_buy_qty'] + df['future_sell_qty'] + eps))
    bid0 = df['future_bid_liq_0.0_median']
    ask0 = df['future_ask_liq_0.0_median']
    df['book_imbalance'] = (bid0 - ask0) / (bid0 + ask0 + eps)
    df['momentum'] = df['future_price_diff']

    deep_col = None
    for lvl in ['0.05', '0.04', '0.06']:
        b, a = f'future_bid_liq_{lvl}_median', f'future_ask_liq_{lvl}_median'
        if b in df.columns and a in df.columns:
            deep_col = (b, a); break
    df['book_imbal_deep'] = ((df[deep_col[0]] - df[deep_col[1]]) /
                             (df[deep_col[0]] + df[deep_col[1]] + eps)) if deep_col else np.nan

    # run.010 (5s): bar-count rollers ×3 to keep run.009's wall-clock
    # meaning (60s/120s); feature NAMES kept so ALL_FEATURES is untouched
    df['flow_imbal_roll4'] = df['flow_imbalance'].rolling(12, min_periods=6).mean()
    df['flow_imbal_roll8'] = df['flow_imbalance'].rolling(24, min_periods=12).mean()
    df['book_imbal_roll4'] = df['book_imbalance'].rolling(12, min_periods=6).mean()
    df['book_imbal_roll8'] = df['book_imbalance'].rolling(24, min_periods=12).mean()

    df['vwap_spread'] = (df['future_buy_vwap'] - df['future_sell_vwap']
                         if 'future_buy_vwap' in df.columns else np.nan)
    liq_long  = df.get('opt_long_force_exit_qty_sum',  pd.Series(0, index=df.index))
    liq_short = df.get('opt_short_force_exit_qty_sum', pd.Series(0, index=df.index))
    df['liq_flag'] = ((liq_long + liq_short) > 0).astype(float)

    if all(c in df.columns for c in ['future_bid_max', 'future_bid_min', 'future_bid_close']):
        rng = df['future_bid_max'] - df['future_bid_min']
        df['stochastic'] = np.where(rng > 0, (df['future_bid_close'] - df['future_bid_min']) / rng, 0.5)
    else:
        df['stochastic'] = np.nan

    df['spread_expansion'] = (df['future_spread_max'] - df['future_spread_open']
                              if all(c in df.columns for c in ['future_spread_max', 'future_spread_open'])
                              else np.nan)

    if all(c in df.columns for c in ['future_buy_samples', 'future_sell_samples']):
        bs, ss = df['future_buy_samples'], df['future_sell_samples']
        df['sample_imbalance'] = (bs - ss) / (bs + ss + eps)
    else:
        df['sample_imbalance'] = np.nan

    if all(c in df.columns for c in ['spot_buy_qty', 'spot_sell_qty']):
        spot_flow = ((df['spot_buy_qty'] - df['spot_sell_qty']) /
                     (df['spot_buy_qty'] + df['spot_sell_qty'] + eps))
        df['flow_agreement'] = df['flow_imbalance'] * spot_flow
    else:
        df['flow_agreement'] = np.nan

    df['oi_change'] = df['opt_open_interest_sample'].diff() if 'opt_open_interest_sample' in df.columns else np.nan

    if all(c in df.columns for c in ['future_buy_samples', 'future_sell_samples',
                                      'future_buy_qty', 'future_sell_qty']):
        df['size_imbalance'] = (df['future_buy_qty']  / (df['future_buy_samples']  + eps) -
                                df['future_sell_qty'] / (df['future_sell_samples'] + eps))
    else:
        df['size_imbalance'] = np.nan

    sub_cols = ['future_first_trade_side', 'future_last_trade_side',
                'future_largest_trade_qty', 'future_largest_trade_side',
                'future_buy_count_early', 'future_buy_count_late',
                'future_sell_count_early', 'future_sell_count_late',
                'future_buy_qty_early', 'future_buy_qty_late',
                'future_sell_qty_early', 'future_sell_qty_late']
    if all(c in df.columns for c in sub_cols):
        bqe, bql = df['future_buy_qty_early'],  df['future_buy_qty_late']
        sqe, sql = df['future_sell_qty_early'],  df['future_sell_qty_late']
        fts, lts = df['future_first_trade_side'], df['future_last_trade_side']
        lq,  ls  = df['future_largest_trade_qty'], df['future_largest_trade_side']
        bce, bcl = df['future_buy_count_early'], df['future_buy_count_late']
        total_vol = bqe + bql + sqe + sql
        df['trade_side_open']     = fts
        df['trade_side_close']    = lts
        df['trade_side_momentum'] = lts - fts
        df['largest_trade_side']  = ls
        df['largest_trade_rel']   = lq / (total_vol + eps)
        df['buy_accel']           = bql - bqe
        df['sell_accel']          = sql - sqe
        df['flow_accel']          = (bql - sql) - (bqe - sqe)
        df['buy_count_accel']     = bcl - bce
        df['late_imbalance']      = (bql - sql) / (bql + sql + eps)
    else:
        for c in ['trade_side_open','trade_side_close','trade_side_momentum',
                  'largest_trade_side','largest_trade_rel','buy_accel','sell_accel',
                  'flow_accel','buy_count_accel','late_imbalance']:
            df[c] = np.nan

    deep_bid = next((c for c in ['future_bid_liq_0.4_median','future_bid_liq_0.3_median',
                                  'future_bid_liq_0.2_median','future_bid_liq_0.1_median']
                     if c in df.columns), None)
    deep_ask = next((c for c in ['future_ask_liq_0.4_median','future_ask_liq_0.3_median',
                                  'future_ask_liq_0.2_median','future_ask_liq_0.1_median']
                     if c in df.columns), None)
    df['liq_conc_bid'] = (df['future_bid_liq_0.0_median'] / (df[deep_bid] + eps)
                          if deep_bid else np.nan)
    df['liq_conc_ask'] = (df['future_ask_liq_0.0_median'] / (df[deep_ask] + eps)
                          if deep_ask else np.nan)

    hour, minute = df['dt'].dt.hour, df['dt'].dt.minute
    df['hour_sin']   = np.sin(2 * np.pi * hour   / 24)
    df['hour_cos']   = np.cos(2 * np.pi * hour   / 24)
    df['minute_sin'] = np.sin(2 * np.pi * minute / 60)
    df['minute_cos'] = np.cos(2 * np.pi * minute / 60)

    secs = (hour * 3600 + minute * 60 + df['dt'].dt.second) % (8 * 3600)
    df['near_funding'] = ((8 * 3600 - secs) < 900).astype(float)
    if 'opt_funding_rate_sample' in df.columns:
        funding = df['opt_funding_rate_sample'].replace(-1, np.nan).fillna(0)
        df['funding_pressure'] = funding * df['near_funding']
    else:
        df['funding_pressure'] = np.nan

    # run.010 (5s): 4-min volatility (48 bars) vs its 24h mean (17280 bars)
    df['volatility'] = df['close_price'].diff().abs().rolling(48, min_periods=12).mean()
    df['vol_norm']   = (df['volatility'] /
                        df['volatility'].rolling(17280, min_periods=288).mean()
                       ).replace([np.inf, -np.inf], np.nan)

    # ── run.004: long-timescale context features ─────────────────────────
    # All rolling windows are TIME-based on the datetime index (rolling('24h')),
    # not row-count based: collector restarts land on arbitrary second offsets
    # and gaps would otherwise stretch a "1h" window over more wall time.
    # Everything is causal (past data only) and vol-normalised so the scale is
    # stationary across regimes; clipped at ±8 to bound scaler-era outliers.
    D = 24 * 3600 // WINDOW_SEC              # bars per 24h at full cadence
    lp = pd.Series(np.log(df['close_price'].values), index=df['dt'])

    def past(series, delta, tol_sec=2 * WINDOW_SEC):
        # value of `series` ~delta earlier (nearest bar within tol), aligned back
        p = series.reindex(series.index - delta, method='nearest',
                           tolerance=pd.Timedelta(seconds=tol_sec))
        return pd.Series(p.values, index=series.index)

    r1 = lp.diff()
    r1[gap.values != WINDOW_SEC] = np.nan    # 1-bar return across a gap is not 1-bar
    sigma24 = r1.rolling('24h', min_periods=D // 4).std()

    for name, td, W in [('1h', pd.Timedelta(hours=1),  D // 24),
                        ('4h', pd.Timedelta(hours=4),  D // 6),
                        ('24h', pd.Timedelta(hours=24), D)]:
        unit = sigma24 * np.sqrt(W) + eps
        df[f'ret_norm_{name}'] = ((lp - past(lp, td)) / unit).clip(-8, 8).values
        ma = lp.rolling(td, min_periods=int(W * 0.75)).mean()
        df[f'ma_gap_{name}'] = ((lp - ma) / unit).clip(-8, 8).values

    vol1h = r1.rolling('1h', min_periods=D // 48).std()
    df['vol_ratio_1h_24h'] = (vol1h / (sigma24 + eps)).clip(0, 5).values

    hi24 = lp.rolling('24h', min_periods=D // 4).max()
    lo24 = lp.rolling('24h', min_periods=D // 4).min()
    df['range_pos_24h'] = ((lp - lo24) / (hi24 - lo24 + eps)).clip(0, 1).values

    if all(c in df.columns for c in ['spot_bid_close', 'spot_ask_close']):
        spot_mid = (df['spot_bid_close'] + df['spot_ask_close']) / 2.0
        basis = pd.Series(((df['close_price'] - spot_mid) / (spot_mid + eps)).values,
                          index=df['dt'])
        b_ma = basis.rolling('4h', min_periods=D // 12).mean()
        b_sd = basis.rolling('4h', min_periods=D // 12).std()
        df['basis_z_4h'] = ((basis - b_ma) / (b_sd + eps)).clip(-8, 8).values
        b_mom = basis - past(basis, pd.Timedelta(hours=1))
        b_mom_sd = b_mom.rolling('4h', min_periods=D // 12).std()
        df['basis_mom_1h'] = (b_mom / (b_mom_sd + eps)).clip(-8, 8).values
    else:
        df['basis_z_4h'] = np.nan
        df['basis_mom_1h'] = np.nan

    dow = df['dt'].dt.dayofweek
    df['dow_sin'] = np.sin(2 * np.pi * dow / 7)
    df['dow_cos'] = np.cos(2 * np.pi * dow / 7)

    # ── run.006: schema-3/4 microstructure features ──────────────────────
    # Same conventions as the run.004 block: causal time-based rollers,
    # z-scores clipped ±8, ratios clipped [0, 10]. Every group is guarded on
    # column presence so pre-v3 files simply yield NaN (the era slice and the
    # coverage guard in the next cell handle the rest).
    mp1h = D // 24                                    # 1h of bars = min_periods

    def _ts(x):
        return pd.Series(np.asarray(x, dtype=np.float64), index=df['dt'])

    def roll_z(x, win='4h', mp=mp1h):
        s = _ts(x)
        return ((s - s.rolling(win, min_periods=mp).mean()) /
                (s.rolling(win, min_periods=mp).std() + eps)).clip(-8, 8).values

    def roll_ratio(x, win='4h', mp=mp1h, hi=10.0):
        s = _ts(x)
        return (s / (s.rolling(win, min_periods=mp).mean() + eps)).clip(0, hi).values

    have = set(df.columns)

    df['ofi_z'] = roll_z(df['future_ofi_sum']) if 'future_ofi_sum' in have else np.nan

    flow_near = ['future_add_bid_near_sum', 'future_cancel_bid_near_sum',
                 'future_add_ask_near_sum', 'future_cancel_ask_near_sum']
    if set(flow_near) <= have:
        ab, cb = df[flow_near[0]], df[flow_near[1]]
        aa, ca = df[flow_near[2]], df[flow_near[3]]
        df['flow_net_near_z']   = roll_z((ab - cb) - (aa - ca))
        df['cancel_imbal_near'] = ((cb - ca) / (cb + ca + eps)).values
        # bid pulled faster than replenished = support evaporating (log-diff
        # is scale-free, so no rolling normalisation needed)
        df['pull_add_bid'] = (np.log1p(cb) - np.log1p(ab)).clip(-8, 8)
        df['pull_add_ask'] = (np.log1p(ca) - np.log1p(aa)).clip(-8, 8)
    else:
        for c in ['flow_net_near_z', 'cancel_imbal_near', 'pull_add_bid', 'pull_add_ask']:
            df[c] = np.nan

    flow_wide = ['future_add_bid_wide_sum', 'future_cancel_bid_wide_sum',
                 'future_add_ask_wide_sum', 'future_cancel_ask_wide_sum']
    if set(flow_wide) <= have and set(flow_near) <= have:
        # the wide band INCLUDES the near band by construction — subtract to
        # get the 0.05–0.25% ring only (schema-4 files; NaN in out3 hours)
        abx = (df[flow_wide[0]] - df[flow_near[0]]).clip(lower=0)
        cbx = (df[flow_wide[1]] - df[flow_near[1]]).clip(lower=0)
        aax = (df[flow_wide[2]] - df[flow_near[2]]).clip(lower=0)
        cax = (df[flow_wide[3]] - df[flow_near[3]]).clip(lower=0)
        df['flow_net_widex_z'] = roll_z((abx - cbx) - (aax - cax))
    else:
        df['flow_net_widex_z'] = np.nan

    df['micro_dev_z'] = (roll_z(df['future_micro_dev_close'])
                         if 'future_micro_dev_close' in have else np.nan)
    df['mid_rv_norm']    = roll_ratio(df['future_mid_rv'])    if 'future_mid_rv'    in have else np.nan
    df['mid_flips_norm'] = roll_ratio(df['future_mid_flips']) if 'future_mid_flips' in have else np.nan
    df['msg_rate_norm']  = (roll_ratio(df['future_depth_msg_count'])
                            if 'future_depth_msg_count' in have else np.nan)

    if {'future_bid_depletion_count', 'future_ask_depletion_count'} <= have:
        bd, ad = df['future_bid_depletion_count'], df['future_ask_depletion_count']
        df['depl_imbal']      = ((bd - ad) / (bd + ad + 1.0)).values
        df['depl_total_norm'] = roll_ratio(bd + ad)
    else:
        df['depl_imbal'] = np.nan
        df['depl_total_norm'] = np.nan

    for side in ('buy', 'sell'):
        med, p90 = f'future_{side}_size_median', f'future_{side}_size_p90'
        if {med, p90} <= have:
            # fat right tail at equal volume = informed flow; log1p of the
            # ratio is scale-free across the BTC-qty drift
            df[f'{side}_tail_ratio'] = np.log1p((df[p90] / (df[med] + eps)).clip(0, 100))
        else:
            df[f'{side}_tail_ratio'] = np.nan

    # liquidations: an absent liquidation IS zero, so cnt/notional NaNs are
    # filled with 0 — but only inside the schema-3+ era, so the coverage
    # guard still sees pre-v3 rows as missing.
    m3 = df['future_ofi_sum'].notna() if 'future_ofi_sum' in have else pd.Series(False, index=df.index)
    liq_cols = ['opt_long_force_exit_cnt_sum', 'opt_short_force_exit_cnt_sum',
                'opt_long_force_exit_notional_sum', 'opt_short_force_exit_notional_sum',
                'opt_force_exit_notional_max']
    for c in liq_cols:
        if c in have:
            df.loc[m3, c] = df.loc[m3, c].fillna(0)
    if {'opt_long_force_exit_cnt_sum', 'opt_short_force_exit_cnt_sum'} <= have:
        df['liq_cnt_log'] = np.log1p(df['opt_long_force_exit_cnt_sum'] +
                                     df['opt_short_force_exit_cnt_sum'])
    else:
        df['liq_cnt_log'] = np.nan
    lqf = df.get('opt_long_force_exit_qty_sum',  pd.Series(np.nan, index=df.index)).fillna(0)
    sqf = df.get('opt_short_force_exit_qty_sum', pd.Series(np.nan, index=df.index)).fillna(0)
    df['liq_imbal'] = ((lqf - sqf) / (lqf + sqf + eps)).values
    if {'opt_long_force_exit_notional_sum', 'opt_short_force_exit_notional_sum'} <= have:
        df['liq_notional_log'] = np.log1p(df['opt_long_force_exit_notional_sum'] +
                                          df['opt_short_force_exit_notional_sum'])
    else:
        df['liq_notional_log'] = np.nan
    df['liq_notional_max_log'] = (np.log1p(df['opt_force_exit_notional_max'])
                                  if 'opt_force_exit_notional_max' in have else np.nan)

    wall_cols = ['future_bid_wall_qty_median', 'future_ask_wall_qty_median',
                 'future_bid_wall_dist_median', 'future_ask_wall_dist_median']
    if set(wall_cols) <= have:
        bq, aq = df[wall_cols[0]], df[wall_cols[1]]
        df['wall_imbal'] = ((bq - aq) / (bq + aq + eps)).values
        # dist −1 = no level in band → map to the band edge ("wall absent" =
        # "as far away as possible"); qty 0 already carries the absence signal
        df['bid_wall_dist'] = df[wall_cols[2]].where(df[wall_cols[2]] >= 0, WALL_BAND)
        df['ask_wall_dist'] = df[wall_cols[3]].where(df[wall_cols[3]] >= 0, WALL_BAND)
        df['wall_qty_norm'] = roll_ratio(bq + aq)
    else:
        for c in ['wall_imbal', 'bid_wall_dist', 'ask_wall_dist', 'wall_qty_norm']:
            df[c] = np.nan

    if {'future_max_batch_buy_qty', 'future_max_buy_run_qty'} <= have:
        # concentration of the bar's volume in one 200ms burst / one same-side
        # sweep run — bounded [0,1] per side, no normalisation needed
        df['batch_buy_rel']  = (df['future_max_batch_buy_qty']  / (df['future_buy_qty']  + eps)).clip(0, 1)
        df['batch_sell_rel'] = (df['future_max_batch_sell_qty'] / (df['future_sell_qty'] + eps)).clip(0, 1)
        df['sweep_buy_rel']  = (df['future_max_buy_run_qty']    / (df['future_buy_qty']  + eps)).clip(0, 1)
        df['sweep_sell_rel'] = (df['future_max_sell_run_qty']   / (df['future_sell_qty'] + eps)).clip(0, 1)
    else:
        for c in ['batch_buy_rel', 'batch_sell_rel', 'sweep_buy_rel', 'sweep_sell_rel']:
            df[c] = np.nan

    if {'opt_eth_mid_open', 'opt_eth_mid_close'} <= have:
        eo, ec = df['opt_eth_mid_open'], df['opt_eth_mid_close']
        eth_ret = pd.Series(np.where((eo > 0) & (ec > 0), np.log(ec / eo), np.nan),
                            index=df['dt'])
        df['eth_ret_z'] = (eth_ret / (eth_ret.rolling('4h', min_periods=mp1h).std() + eps)
                           ).clip(-8, 8).values
        # ETH ran but BTC has not (yet): 1-min cumulative z-gap
        # (run.010: 12 bars = 1 min at 5s)
        er4 = eth_ret.rolling(12, min_periods=12).sum()
        br4 = r1.rolling(12, min_periods=12).sum()
        er4z = er4 / (er4.rolling('4h', min_periods=mp1h).std() + eps)
        br4z = br4 / (br4.rolling('4h', min_periods=mp1h).std() + eps)
        df['eth_lead_gap'] = (er4z - br4z).clip(-8, 8).values
    else:
        df['eth_ret_z'] = np.nan
        df['eth_lead_gap'] = np.nan

    df['lsr_z'] = (roll_z(df['opt_long_short_ratio_sample'], '24h', D // 4)
                   if 'opt_long_short_ratio_sample' in have else np.nan)

    # ── run.012: v5 raw-event features (sub-bar timing + per-message detail) ─
    # Bars destroy WHEN inside the bar flow happened and smooth per-message
    # granularity; the event stream keeps both. Every aggregate uses only
    # events with receive time inside the bar's own [t, t+W) window → causal
    # by construction. Counts/magnitudes are log-z-scored vs 4h (episodic —
    # same convention as the run.006 block); shares/positions are bounded by
    # construction and used raw. Raw aggregates were sentinel-filled at merge
    # time, so the only NaNs here are pre-era rows, which the cell-5 events-era
    # slice removes.
    if 'ev_fd_nmsg' in have:
        df['ev_fd_nmsg_z']   = roll_z(np.log1p(df['ev_fd_nmsg']))
        df['ev_fd_levels_z'] = roll_z(df['ev_fd_levels'])
        df['ev_fd_maxq_z']   = roll_z(np.log1p(df['ev_fd_maxq']))
        df['ev_fd_pull_share'] = df['ev_fd_pull_share'].clip(0, 1)
        df['ev_fd_gmin_z']   = roll_z(np.log1p(df['ev_fd_gmin']))
        df['ev_fd_last1s']   = df['ev_fd_last1s'].clip(0, 1)
        df['ev_fd_time_ask_imb'] = df['ev_fd_time_ask_imb'].clip(-1, 1)
        df['ev_fd_missed']   = np.log1p(df['ev_fd_missed']).clip(0, 8)
        # ev_fd_resync: raw count (0/1 in practice), already stationary
        df['ev_fd_resync']   = df['ev_fd_resync'].clip(0, 10)
        df['ev_ft_ntr_z']    = roll_z(np.log1p(df['ev_ft_ntr']))
        df['ev_ft_gmin_z']   = roll_z(np.log1p(df['ev_ft_gmin']))
        df['ev_ft_time_imb'] = df['ev_ft_time_imb'].clip(-1, 1)
        df['ev_ft_last1s']   = df['ev_ft_last1s'].clip(0, 1)
        df['ev_ft_first1s']  = df['ev_ft_first1s'].clip(0, 1)
        df['ev_ft_maxpos']   = df['ev_ft_maxpos'].clip(0, 1)
        df['ev_ft_sweep1s']  = df['ev_ft_sweep1s'].clip(0, 1)
        df['ev_ft_maxrel_z'] = roll_z(np.log1p(df['ev_ft_maxrel']))
        df['ev_st_ntr_z']    = roll_z(np.log1p(df['ev_st_ntr']))
        df['ev_st_time_imb'] = df['ev_st_time_imb'].clip(-1, 1)
        df['ev_st_last1s']   = df['ev_st_last1s'].clip(0, 1)
    else:
        for c in EV_FEATURES:
            df[c] = np.nan

    # Scattered-NaN guard: a sample needs SEQ_LEN contiguous surviving rows behind
    # it and MAX_H ahead, so a feature with even ~2% RANDOMLY scattered NaNs
    # (an ETH bar with no data, a missing long/short-ratio sample, a 4-bar
    # rolling gap echo) would wipe out most valid samples via dropna. These
    # per-bar signals are neutral-at-0 by construction (z-scores / gaps), so
    # fill them with 0 inside the schema-3+ era; warmup and pre-era rows stay
    # NaN so the coverage guard still sees them.
    for c in ['eth_ret_z', 'eth_lead_gap', 'lsr_z']:
        bad = m3 & df[c].isna() & (df['dt'] > df.loc[m3, 'dt'].iloc[0] +
                                   pd.Timedelta('24h')) if m3.any() else None
        if bad is not None:
            df.loc[bad, c] = 0.0

    del lp, r1, sigma24, vol1h, hi24, lo24
    # ──────────────────────────────────────────────────────────────────────

    # Targets: volatility-normalised future return per horizon. A target is
    # valid only when the row h bars ahead really is h*WINDOW_SEC ahead — no labels
    # across collector gaps. vol uses only past prices (no leakage).
    # (datetime64[s] cast is robust to the pandas 2/3 resolution change)
    dt_sec = pd.Series(df['dt'].values.astype('datetime64[s]').astype(np.int64),
                       index=df.index)
    for h in horizons:
        vol   = df['close_price'].diff(h).rolling(vol_window, min_periods=vol_window // 4).std()
        delta = df['close_price'].shift(-h) - df['close_price']
        y     = (delta / (vol + eps)).clip(-TARGET_CLIP, TARGET_CLIP)
        valid = (dt_sec.shift(-h) - dt_sec) == h * WINDOW_SEC
        y[~valid.fillna(False)] = np.nan
        df[f'y_{h}'] = y

    # ── run.009: triple-barrier FIRST-TOUCH labels ───────────────────────
    # run.006/007/008 used a pure MFE-touch label (lup=1 if +θ reached
    # ANYWHERE in the next h bars, IGNORING whether −θ was hit first) —
    # mislabelling exactly the paths the TP/SL sim loses on (a dip to −θ is
    # a taker SL fill at −30 bp; a later recovery to +θ was still counted a
    # "win"). run.008's gate failed via adverse selection (hit_m ≫ hit_f);
    # this aligns label↔payoff: lup_h = 1 iff +θ is touched STRICTLY BEFORE
    # −θ within the next h bars; ldn_h mirrors. Neither-touched or a tie →
    # 0/0 ("no idea"). Same h·WINDOW_SEC gap-validity rule as the regression
    # targets (an exact h·WINDOW_SEC span to row i+h implies every intermediate bar
    # is present). Vectorized (n×h booleans, h≤24 → RAM-safe); validated ==
    # per-row brute force over 3000 randomized gapped paths (test_first_touch.py).
    cvals = df['close_price'].values.astype(np.float64)
    n_rows = len(cvals)
    for h in horizons:
        lup = np.full(n_rows, np.nan)
        ldn = np.full(n_rows, np.nan)
        if n_rows > h:
            wv   = np.lib.stride_tricks.sliding_window_view(cvals, h)[1:]  # wv[i]=cvals[i+1:i+1+h]
            base = cvals[:n_rows - h][:, None]
            th   = THETA_BY_H[h]
            up_hit = (wv / base - 1.0) >= th          # (n_win × h) booleans
            dn_hit = (1.0 - wv / base) >= th
            t_up = np.where(up_hit.any(1), up_hit.argmax(1), h)   # first touch bar; h = never
            t_dn = np.where(dn_hit.any(1), dn_hit.argmax(1), h)
            lup[:n_rows - h] = (t_up < t_dn).astype(np.float32)   # up strictly first
            ldn[:n_rows - h] = (t_dn < t_up).astype(np.float32)   # dn strictly first
        valid = ((dt_sec.shift(-h) - dt_sec) == h * WINDOW_SEC).fillna(False).values
        df[f'lup_{h}'] = np.where(valid, lup, np.nan)
        df[f'ldn_{h}'] = np.where(valid, ldn, np.nan)
    return df



# ── run.012: v5 raw-event loader ─────────────────────────────────────────
# Parses events.<tag>.w{W}.<YYMMDD_HH>.jsonl.gz (verbatim collector messages —
# see the v5 docstring) into per-bar aggregates aligned to the bar grid.
# Streams used: fd (future depth diffs + resync snapshots), ft (future
# trades), st (spot trades). sd (spot depth) is skipped on purpose: marginal
# value over fd, and skipping it halves parse time.
#
# Merge key: bar-start epoch = floor(r / W) * W — the SAME machine clock as
# the CSV spot_timestamp column, so the merge in prepare() is tz-free. Bars
# with no parsed events are ABSENT from the result; the merge + era logic
# downstream distinguishes quiet bars from file holes.
import gzip
try:
    import orjson
    _loads = orjson.loads
except ImportError:
    import json as _json
    _loads = _json.loads

EV_STREAMS = ('fd', 'ft', 'st')


def _sweep_1s(t, q, s, win=1.0):
    """Max same-side qty inside any `win`-second wall-clock window
    (two-pointer per side; t must be sorted ascending)."""
    best = 0.0
    for side in (1.0, -1.0):
        m = s == side
        if not m.any():
            continue
        ts, qs = t[m], q[m]
        lo = 0
        run = 0.0
        for hi in range(len(ts)):
            run += qs[hi]
            while ts[hi] - ts[lo] >= win:
                run -= qs[lo]
                lo += 1
            if run > best:
                best = run
    return best


def load_event_features(events_dir, window_sec):
    files = {}
    for tag in EV_STREAMS:
        fl = sorted(glob.glob(os.path.join(events_dir, '**',
                                           f'events.{tag}.w{window_sec}.*.jsonl.gz'),
                              recursive=True))
        if fl:
            files[tag] = fl
    if not files:
        print(f'  No event files under {events_dir} (w{window_sec}) — '
              f'event features disabled')
        return None
    for tag, fl in sorted(files.items()):
        print(f'  {tag}: {len(fl)} hourly files  '
              f'({os.path.basename(fl[0])} … {os.path.basename(fl[-1])})')

    W = float(window_sec)
    bars = {}   # bar-start epoch -> per-bar accumulator (created lazily)

    def _acc(b):
        a = bars.get(b)
        if a is None:
            a = bars[b] = {
                'fd_n': 0, 'fd_levels': 0, 'fd_maxq': 0.0, 'fd_pull': 0,
                'fd_tb': 0.0, 'fd_nb': 0, 'fd_ta': 0.0, 'fd_na': 0,
                'fd_t': [], 'fd_missed': 0, 'fd_resync': 0,
                'ft_t': [], 'ft_q': [], 'ft_s': [],
                'st_t': [], 'st_q': [], 'st_s': [],
            }
        return a

    bad = 0
    for tag, fl in sorted(files.items()):
        last_u = None   # depth final-update-id dedupe/gap state (ids increase per symbol)
        last_t = None   # trade-id dedupe state
        for path in fl:
            with gzip.open(path, 'rt', encoding='utf-8', errors='replace') as fh:
                for ln in fh:
                    try:
                        rec = _loads(ln)
                    except Exception:
                        bad += 1          # truncated tail line after a crash
                        continue
                    r = rec['r']
                    d = rec['d']
                    b = int(r // W) * W
                    acc = _acc(b)
                    if tag == 'fd':
                        if rec.get('k') == 'snapshot':
                            acc['fd_resync'] += 1
                            last_u = d.get('lastUpdateId', last_u)
                            continue
                        u = d.get('u')
                        if u is None:
                            continue
                        if last_u is not None:
                            if u <= last_u:
                                continue      # reconnect replay — dedupe on (s, u)
                            if d.get('U', u) > last_u + 1:
                                acc['fd_missed'] += 1   # sequence gap = lost msgs
                        last_u = u
                        bb, aa = d.get('b', ()), d.get('a', ())
                        acc['fd_n'] += 1
                        acc['fd_levels'] += len(bb) + len(aa)
                        acc['fd_t'].append(r)
                        if bb:
                            acc['fd_tb'] += r; acc['fd_nb'] += 1
                        if aa:
                            acc['fd_ta'] += r; acc['fd_na'] += 1
                        for _, qs_ in bb:
                            q = float(qs_)
                            if q == 0.0:
                                acc['fd_pull'] += 1
                            elif q > acc['fd_maxq']:
                                acc['fd_maxq'] = q
                        for _, qs_ in aa:
                            q = float(qs_)
                            if q == 0.0:
                                acc['fd_pull'] += 1
                            elif q > acc['fd_maxq']:
                                acc['fd_maxq'] = q
                    else:                        # ft / st trades
                        tid = d.get('t')
                        if tid is None:
                            continue
                        if last_t is not None and tid <= last_t:
                            continue                  # replay
                        last_t = tid
                        p = tag
                        acc[p + '_t'].append(r)
                        acc[p + '_q'].append(float(d['q']))
                        acc[p + '_s'].append(-1.0 if d['m'] else 1.0)  # m=True → taker SELL
    if bad:
        print(f'  skipped {bad} unparseable event lines (truncated tail / restart)')

    rows = []
    for b, a in bars.items():
        row = {'bar_ts': b}
        n = a['fd_n']
        row['ev_fd_nmsg'] = n
        row['ev_fd_missed'] = a['fd_missed']
        row['ev_fd_resync'] = a['fd_resync']
        if n:
            t = np.asarray(a['fd_t']); t.sort()
            row['ev_fd_levels'] = a['fd_levels'] / n
            row['ev_fd_maxq'] = a['fd_maxq']
            row['ev_fd_pull_share'] = a['fd_pull'] / max(a['fd_levels'], 1)
            row['ev_fd_gmin'] = float(np.diff(t).min() * 1e3) if n > 1 else W * 1000.0
            row['ev_fd_last1s'] = float((t >= b + W - 1.0).mean())
            row['ev_fd_time_ask_imb'] = ((a['fd_ta'] / a['fd_na'] - a['fd_tb'] / a['fd_nb']) / W
                                         if a['fd_nb'] and a['fd_na'] else 0.0)
        else:   # bucket exists via another stream; fd fields = quiet sentinels
            row['ev_fd_levels'] = 0.0; row['ev_fd_maxq'] = 0.0
            row['ev_fd_pull_share'] = 0.0; row['ev_fd_gmin'] = W * 1000.0
            row['ev_fd_last1s'] = 0.0; row['ev_fd_time_ask_imb'] = 0.0
        for p in ('ft', 'st'):
            tt = a[p + '_t']
            ntr = len(tt)
            row[f'ev_{p}_ntr'] = ntr
            row[f'ev_{p}_time_imb'] = 0.0
            row[f'ev_{p}_last1s'] = 0.0
            if p == 'ft':
                row['ev_ft_gmin'] = W * 1000.0
                row['ev_ft_first1s'] = 0.0
                row['ev_ft_maxpos'] = 0.0
                row['ev_ft_sweep1s'] = 0.0
                row['ev_ft_maxrel'] = 1.0
            if not ntr:
                continue
            t = np.asarray(tt); q = np.asarray(a[p + '_q']); s = np.asarray(a[p + '_s'])
            order = np.argsort(t)
            t, q, s = t[order], q[order], s[order]
            qsum = q.sum()
            qb, qs_ = q[s > 0].sum(), q[s < 0].sum()
            if qb > 0 and qs_ > 0:
                # signed flow timing: (qty-weighted mean time of SELLS − of BUYS)/W
                # (>0 = sell flow arrived LATER than buy flow inside the bar)
                row[f'ev_{p}_time_imb'] = float(
                    ((t[s < 0] * q[s < 0]).sum() / qs_ -
                     (t[s > 0] * q[s > 0]).sum() / qb) / W)
            row[f'ev_{p}_last1s'] = float(q[t >= b + W - 1.0].sum() / qsum)
            if p == 'ft':
                row['ev_ft_gmin'] = float(np.diff(t).min() * 1e3) if ntr > 1 else W * 1000.0
                row['ev_ft_first1s'] = float(q[t < b + 1.0].sum() / qsum)
                row['ev_ft_maxpos'] = float((t[np.argmax(q)] - b) / W)
                med = float(np.median(q))
                row['ev_ft_maxrel'] = float(q.max() / med) if med > 0 else 1.0
                row['ev_ft_sweep1s'] = float(_sweep_1s(t, q, s) / qsum) if qsum > 0 else 0.0
        rows.append(row)

    ev = pd.DataFrame(rows).set_index('bar_ts')
    ev.index = ev.index.astype(np.int64)
    ev = ev[~ev.index.duplicated(keep='first')].sort_index()
    span_h = (ev.index[-1] - ev.index[0]) / 3600.0 if len(ev) else 0.0
    print(f'  parsed {int(sum(a["fd_n"] for a in bars.values())):,} fd msgs; '
          f'{len(ev):,} covered bars over {span_h:.1f}h '
          f'({pd.Timestamp(ev.index[0], unit="s")} → {pd.Timestamp(ev.index[-1], unit="s")})')
    return ev

print('Feature pipeline loaded.')
print(f'Binary heads: {CLS_COLS}')
# Out:
# Feature pipeline loaded.
# Binary heads: ['lup_6', 'ldn_6', 'lup_9', 'ldn_9', 'lup_12', 'ldn_12', 'lup_15', 'ldn_15', 'lup_18', 'ldn_18', 'lup_24', 'ldn_24']

# %%
# ── Cell 5: Load data, era slice, coverage guard, build arrays ────────────
# run.010: ONLY the w{WINDOW_SEC}s stream — the v4.1 collector dual-writes
# w15 and w5 files; without this filter a mixed tar would silently interleave
# the two cadences (sorting by dt mixes 5s and 15s bars into garbage).
files = sorted(f for f in (glob.glob(os.path.join(DATA_DIR, '*.csv')) +
                           glob.glob(os.path.join(DATA_DIR, '*.csv.gz')))
               if f'.w{WINDOW_SEC}.' in os.path.basename(f))
print(f'Found {len(files)} files (w{WINDOW_SEC} only)')

raw = load_files(files)
print(f'Total rows loaded: {len(raw):,}')

# ── run.012: parse the v5 raw event stream into per-bar aggregates ──────
EV_DF = load_event_features(EVENTS_DIR, WINDOW_SEC)
if EV_DF is None:
    print('  *** no event files found — the events-era guard below will abort ***')

df = prepare(raw, HORIZONS, VOL_WINDOW, EV_DF)
del raw; gc.collect()

# ── run.006: restrict the analysis window to the schema-3+ era ───────────
# The v3 features only exist where the v3/v4 collector ran; over the full
# ~13-month range they would all fail the coverage guard. Features are
# computed on the FULL frame first (so the 24h rollers are warm at the era
# boundary), then the frame is sliced.
if V3_ERA_ONLY:
    mark = (df[V3_MARKER].notna() if V3_MARKER in df.columns
            else pd.Series(False, index=df.index))
    assert mark.any(), (
        f'No schema-3 data found ({V3_MARKER} entirely missing). Either the '
        f'out3/out4 files are not in btc_data.tar.xz — rebuild the tar — or '
        f'set V3_ERA_ONLY = False to run on v1 features only.')
    v3_start = df.loc[mark, 'dt'].iloc[0]
    era_days = (df['dt'].iloc[-1] - v3_start).total_seconds() / 86400
    n_pre = int((df['dt'] < v3_start).sum())
    print(f'\nSchema-3+ era starts {v3_start}  ({era_days:.1f} days, '
          f'dropping {n_pre:,} pre-era rows)')
    assert era_days >= MIN_ERA_DAYS, (
        f'Only {era_days:.1f} days of schema-3+ data (< {MIN_ERA_DAYS}). '
        f'Let the collector accumulate more before running run.006.')
    df = df[df['dt'] >= v3_start].reset_index(drop=True)
    if 'schema_version' in df.columns:
        sv = df['schema_version']
        print('  schema mix: ' + '  '.join(
            f'v{int(v)}: {(sv == v).mean()*100:.1f}%' for v in sorted(sv.dropna().unique())))

# ── run.012: restrict to the events era (stricter than the schema-3 slice) ──
# ev_* features exist only where the v5 event writer ran; outside that era
# they are sentinel-filled constants that would teach the model nothing and
# quietly break the era logic. Features/targets were computed on the FULL
# frame above, so the 24h rollers are warm at the era boundary.
if EVENTS_ERA_ONLY:
    assert 'ev_coverage' in df.columns, (
        'Event features were not merged — no event files were found under '
        f'{EVENTS_DIR}. Tar the events dir on the server (cell 2 comment), '
        're-run the transfer cells, or set EVENTS_ERA_ONLY = False to '
        'reproduce run.011 without ev_* features.')
    mark = df['ev_coverage'] > 0
    assert mark.any(), (
        'No event-covered bars found. The event tar and the bars tar do not '
        'overlap in time — check that both come from the same collector '
        'instance and window.')
    ev_start = df.loc[mark, 'dt'].iloc[0]
    era_days = (df['dt'].iloc[-1] - ev_start).total_seconds() / 86400
    span = df['dt'] >= ev_start
    print(f'\nEvents era starts {ev_start}  ({era_days:.1f} days, '
          f'dropping {int((df["dt"] < ev_start).sum()):,} pre-era rows)')
    # hole diagnostic: the BAR csv saw depth messages but no event file covers
    # the bar (event writer stalled/crashed while the bar writer lived)
    if 'future_depth_msg_count' in df.columns:
        hole = span & (df['ev_coverage'] == 0) & (df['future_depth_msg_count'] > 0)
        print(f'  in-span event coverage: {(df.loc[span, "ev_coverage"] > 0).mean()*100:.2f}% '
              f'of bars; holes with bar data present: {hole.mean()*100:.2f}%')
    assert era_days >= MIN_EVENTS_DAYS, (
        f'Only {era_days:.1f} days of event data (< {MIN_EVENTS_DAYS}). '
        f'Let the v5 collector accumulate more before running run.012 — '
        f'walk-forward folds need days, not hours.')
    df = df[mark].reset_index(drop=True)
    # ev_coverage is a marker, not a feature (never enters ALL_FEATURES)

# Coverage guard (within the analysis window): schema-4-only columns (wide
# band, walls, bursts, ETH) are NaN in out3 hours; anything below
# COVERAGE_MIN is excluded rather than letting dropna() eat the window.
features = []
for f_ in ALL_FEATURES:
    if f_ not in df.columns:
        continue
    cov = df[f_].notna().mean()
    if cov >= COVERAGE_MIN:
        features.append(f_)
    else:
        print(f'  EXCLUDED {f_:22s} coverage {cov*100:5.1f}% < {COVERAGE_MIN*100:.0f}%')
kept_v3 = [f_ for f_ in features if f_ in V3_FEATURES]
print(f'Features kept: {len(features)}/{len(ALL_FEATURES)} '
      f'(schema-3/4: {len(kept_v3)}/{len(V3_FEATURES)})')
# run.006 is built to test the schema-3/4 features, but it degrades to the
# v1 feature subset when those columns are absent (v1 collector files, or a
# btc_data.tar.xz that dropped the out3/out4 files) instead of aborting.
V3_AVAILABLE = len(kept_v3) >= 10
if not V3_AVAILABLE:
    print(f'\n*** v1-compat mode: only {len(kept_v3)}/{len(V3_FEATURES)} schema-3/4 '
          f'features present ***')
    print('    The loaded files predate the schema-3/4 collector (no future_ofi_sum, '
          'walls, ETH lead-lag, ...),')
    print('    so the selective/opportunity heads train on the v1 feature subset only. '
          'This does NOT')
    print('    test run.006\'s schema-3/4 hypothesis — it reruns the run.004/005 feature '
          'set under the')
    print('    selective objective. Feed out3/out4 files (rebuild btc_data.tar.xz) for '
          'the intended run.')

n0 = len(df)
clean = df[features + [f'y_{h}' for h in HORIZONS] + CLS_COLS + ['dt', 'close_price']] \
          .dropna(subset=features).reset_index(drop=True)
lost = n0 - len(clean)
print(f'Rows: {n0:,} → {len(clean):,} after dropna ({lost/max(n0,1)*100:.2f}% dropped)')
if lost > 0.05 * n0:
    print('\n*** WARNING: dropna removed >5% of rows — check per-feature NaN fractions: ***')
    print(df[features].isna().mean().sort_values(ascending=False).head(10))
del df; gc.collect()

X_raw  = clean[features].values.astype(np.float32)
Y_all  = np.stack([clean[f'y_{h}'].values for h in HORIZONS], axis=1).astype(np.float32)
L_all  = np.stack([clean[c].values for c in CLS_COLS], axis=1).astype(np.float32)
dt_s   = clean['dt'].values.astype('datetime64[s]').astype(np.int64)
dt_all = clean['dt'].values
close  = clean['close_price'].values.astype(np.float64)
n, F_DIM = X_raw.shape
del clean; gc.collect()

# A sample "ends" at row i: input window = rows [i-SEQ_LEN+1, i], targets and
# labels at/through i+h. Backward validity: the window must be contiguous
# WINDOW_SEC-spaced bars. Forward validity: row i+MAX_H exactly MAX_H·WINDOW_SEC ahead IN THIS
# (post-dropna) array — dropna can remove interior rows, and the evaluation
# below indexes close[e + h] positionally, so the check must hold here, not
# just in the pre-drop frame. (Improvement over run.005, which relied on the
# pre-drop check only.)
MAX_H = max(HORIZONS)
contig = np.zeros(n, dtype=bool)
span = (SEQ_LEN - 1) * WINDOW_SEC
contig[SEQ_LEN-1:] = (dt_s[SEQ_LEN-1:] - dt_s[:n-SEQ_LEN+1]) == span
fwd_ok = np.zeros(n, dtype=bool)
fwd_ok[:n-MAX_H] = (dt_s[MAX_H:] - dt_s[:n-MAX_H]) == MAX_H * WINDOW_SEC
sample_valid = (contig & fwd_ok &
                np.isfinite(Y_all).all(axis=1) & np.isfinite(L_all).all(axis=1))
assert sample_valid.sum() > 0, 'No valid samples — check bar cadence / targets'

print(f'\nRows: {n:,}   valid samples: {sample_valid.sum():,} ({sample_valid.mean()*100:.1f}%)')
print(f'Date range: {pd.Timestamp(dt_all[0])} → {pd.Timestamp(dt_all[-1])}')
H_TRADE_IDX = HORIZONS.index(H_TRADE)
yt = Y_all[sample_valid, H_TRADE_IDX]
print(f'Trading target y_{H_TRADE}: std={yt.std():.3f}   |y|>1σ: {(np.abs(yt) > 1).mean()*100:.1f}%   '
      f'up share: {(yt > 0).mean()*100:.1f}%')
print('\nOpportunity-label base rates (per-horizon θ, valid samples):')
for j, (h, s) in enumerate(CLS_KEYS):
    print(f'  {CLS_COLS[j]:8s} θ={THETA_BY_H[h]*1e4:2.0f}bp  '
          f'{L_all[sample_valid, j].mean()*100:6.2f}%')
# Out:
# Found 66 files (w5 only)
#   Loaded 66 files
# Total rows loaded: 189,777
#   fd: 264 hourly files  (events.fd.w5.260819_13.jsonl.gz … events.fd.w5.260830_12.jsonl.gz)
#   ft: 264 hourly files  (events.ft.w5.260819_13.jsonl.gz … events.ft.w5.260830_12.jsonl.gz)
#   st: 264 hourly files  (events.st.w5.260819_13.jsonl.gz … events.st.w5.260830_12.jsonl.gz)
#   parsed 9,264,956 fd msgs; 189,382 covered bars over 263.1h (2026-08-19 13:56:15 → 2026-08-30 12:59:55)
#   Cadence breaks: 44  (gaps >1h: 0, largest: 0.1h)
#
# Schema-3+ era starts 2026-08-19 16:56:20  (11.0 days, dropping 0 pre-era rows)
#   schema mix: v5: 100.0%
#
# Events era starts 2026-08-19 16:56:20  (11.0 days, dropping 0 pre-era rows)
#   in-span event coverage: 99.68% of bars; holes with bar data present: 0.32%
# Features kept: 96/96 (schema-3/4: 29/29)
# Rows: 189,175 → 171,483 after dropna (9.35% dropped)
#
# *** WARNING: dropna removed >5% of rows — check per-feature NaN fractions: ***
# ret_norm_24h        0.091968
# ma_gap_24h          0.068503
# ret_norm_1h         0.023534
# ret_norm_4h         0.023534
# ma_gap_1h           0.022841
# vol_ratio_1h_24h    0.022841
# ma_gap_4h           0.022841
# range_pos_24h       0.022831
# lsr_z               0.022831
# basis_mom_1h        0.012084
# dtype: float64
#
# Rows: 171,483   valid samples: 162,459 (94.7%)
# Date range: 2026-08-20 16:56:10 → 2026-08-30 15:59:55
# Trading target y_24: std=1.073   |y|>1σ: 28.5%   up share: 49.9%
#
# Opportunity-label base rates (per-horizon θ, valid samples):
#   lup_6    θ=15bp    0.88%
#   ldn_6    θ=15bp    0.89%
#   lup_9    θ=15bp    1.73%
#   ldn_9    θ=15bp    1.71%
#   lup_12   θ=20bp    1.14%
#   ldn_12   θ=20bp    1.17%
#   lup_15   θ=20bp    1.66%
#   ldn_15   θ=20bp    1.68%
#   lup_18   θ=20bp    2.20%
#   ldn_18   θ=20bp    2.18%
#   lup_24   θ=20bp    3.42%
#   ldn_24   θ=20bp    3.29%

# %%
# ── Cell 6: Walk-forward folds (expanding window, purged) ─────────────────
def ends_in(a, b):
    return np.flatnonzero(sample_valid[a:b]) + a

test_start = int(n * TEST_START_FRAC)
chunk = (n - test_start) // N_FOLDS
folds = []
for k in range(N_FOLDS):
    lo = test_start + k * chunk
    hi = n if k == N_FOLDS - 1 else lo + chunk
    boundary = lo - MAX_H                     # purge: val labels must not reach into test
    val_lo   = int(boundary * (1 - VAL_FRAC))
    folds.append({'k': k,
                  'train_hi': val_lo - MAX_H,  # purge: train labels must not reach into val
                  'val':  (val_lo, boundary),
                  'test': (lo, hi)})

print('Fold   n_train     n_val    n_test    test period')
for f_ in folds:
    t_lo, t_hi = f_['test']
    n_tr = len(ends_in(0, f_['train_hi']))
    n_va = len(ends_in(*f_['val']))
    n_te = len(ends_in(t_lo, t_hi))
    assert min(n_tr, n_va, n_te) > 0, f"fold {f_['k']} has an empty split"
    span_d = (dt_s[t_hi-1] - dt_s[t_lo]) / 86400
    warn = '   *** <7 days — treat this fold as indicative only ***' if span_d < 7 else ''
    print(f"  {f_['k']}  {n_tr:>9,}  {n_va:>8,}  {n_te:>8,}    "
          f"{pd.Timestamp(dt_all[t_lo])} → {pd.Timestamp(dt_all[t_hi-1])} "
          f"({span_d:.1f}d){warn}")
# Out:
# Fold   n_train     n_val    n_test    test period
#   0     57,754     6,119    23,504    2026-08-24 16:45:50 → 2026-08-26 04:47:00 (1.5d)   *** <7 days — treat this fold as indicative only ***
#   1     77,123    10,230    25,056    2026-08-26 04:47:05 → 2026-08-27 16:31:05 (1.5d)   *** <7 days — treat this fold as indicative only ***
#   2     98,222    14,187    24,862    2026-08-27 16:31:10 → 2026-08-29 04:15:40 (1.5d)   *** <7 days — treat this fold as indicative only ***
#   3    120,427    16,844    25,140    2026-08-29 04:15:45 → 2026-08-30 15:59:55 (1.5d)   *** <7 days — treat this fold as indicative only ***

# %%
# ── Cell 7: Model — frozen trunk, regression heads + opportunity heads ────
class BtcLSTMSel(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, dropout, n_reg, n_cls):
        super().__init__()
        self.input_norm = nn.LayerNorm(input_dim)
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers,
                            batch_first=True, dropout=dropout)
        self.drop = nn.Dropout(dropout)
        self.reg_head = nn.Linear(hidden_dim, n_reg)
        self.cls_head = nn.Linear(hidden_dim, n_cls)

    def forward(self, x):
        h, _ = self.lstm(self.input_norm(x))
        z = self.drop(h[:, -1])
        return self.reg_head(z), self.cls_head(z)

_tmp = BtcLSTMSel(F_DIM, HIDDEN_DIM, NUM_LAYERS, DROPOUT, len(HORIZONS), len(CLS_KEYS))
print(f'Model parameters: {sum(p.numel() for p in _tmp.parameters()):,}')
del _tmp
# Out:
# Model parameters: 250,322

# %%
# ── Cell 8: Training helpers (zero-copy window gathering, multi-seed) ─────
AMP = device.type == 'cuda'

def make_scheduler(opt, warmup, total):
    def fn(ep):
        if ep < warmup:
            return (ep + 1) / warmup
        prog = (ep - warmup) / max(total - warmup, 1)
        return 0.5 * (1 + math.cos(math.pi * prog))
    return torch.optim.lr_scheduler.LambdaLR(opt, fn)

def ic(a, b):
    v = spearmanr(a, b)[0]
    return float(v) if np.isfinite(v) else 0.0

def ap(y_true, p):
    # average precision with degenerate-label guards (tiny val slices can
    # have all-0 or all-1 labels; AP is undefined there)
    y = y_true > 0.5
    if y.sum() == 0 or y.all():
        return float(y.mean())
    return float(average_precision_score(y, p))

def predict(model, view, ends, batch=4096):
    model.eval()
    regs, probs = [], []
    with torch.no_grad():
        for s in range(0, len(ends), batch):
            e = ends[s:s+batch]
            xb = torch.from_numpy(view[e - (SEQ_LEN - 1)]).to(device, non_blocking=True)
            with torch.amp.autocast('cuda', enabled=AMP):
                r, lg = model(xb)
            regs.append(r.float().cpu())
            probs.append(torch.sigmoid(lg.float()).cpu())
    return torch.cat(regs).numpy(), torch.cat(probs).numpy()

def train_one_seed(seed, view, train_ends, val_ends, samp_p, pos_w):
    torch.manual_seed(seed)
    rng = np.random.default_rng(seed)

    model = BtcLSTMSel(F_DIM, HIDDEN_DIM, NUM_LAYERS, DROPOUT,
                       len(HORIZONS), len(CLS_KEYS)).to(device)
    pw = torch.tensor(pos_w, dtype=torch.float32, device=device)
    opt = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    sched = make_scheduler(opt, WARMUP, EPOCHS)
    scaler_amp = torch.amp.GradScaler('cuda', enabled=AMP)

    best_ap, best_state, best_epoch, wait = -9.0, None, 0, 0
    hist = []
    for epoch in range(1, EPOCHS + 1):
        model.train()
        # weighted draw WITH replacement (weighted w/o replacement is O(k·n)
        # in numpy); duplicates are just oversampling, which is the point
        ep_ends = rng.choice(train_ends,
                             min(len(train_ends), EPOCH_SAMPLE_CAP),
                             replace=True, p=samp_p)
        tot, m = 0.0, 0
        for s in range(0, len(ep_ends), BATCH_SIZE):
            e = ep_ends[s:s+BATCH_SIZE]
            xb = torch.from_numpy(view[e - (SEQ_LEN - 1)]).to(device, non_blocking=True)
            yb = torch.from_numpy(Y_all[e]).to(device, non_blocking=True)
            lb = torch.from_numpy(L_all[e]).to(device, non_blocking=True)
            with torch.amp.autocast('cuda', enabled=AMP):
                r, lg = model(xb)
                # regression part: frozen form from run.003/004
                per = F.smooth_l1_loss(r, yb, reduction='none').mean(dim=1)
                w = torch.clamp(1.0 + LOSS_W_ALPHA * yb[:, H_TRADE_IDX].abs(),
                                max=LOSS_W_CAP)
                huber = (w * per).sum() / w.sum()
                # run.006: opportunity heads (autocast runs BCE in fp32)
                bce = F.binary_cross_entropy_with_logits(lg, lb, pos_weight=pw)
                loss = huber + BCE_W * bce
            opt.zero_grad(set_to_none=True)
            scaler_amp.scale(loss).backward()
            scaler_amp.unscale_(opt)
            nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            scaler_amp.step(opt)
            scaler_amp.update()
            tot += loss.item() * len(e); m += len(e)
        sched.step()

        vr, vp = predict(model, view, val_ends)
        v_ic = [ic(vr[:, i], Y_all[val_ends, i]) for i in range(len(HORIZONS))]
        v_ap_up = ap(L_all[val_ends, SEL_UP_J], vp[:, SEL_UP_J])
        v_ap_dn = ap(L_all[val_ends, SEL_DN_J], vp[:, SEL_DN_J])
        cur = 0.5 * (v_ap_up + v_ap_dn)      # early-stop metric: the run's object
        hist.append({'train_loss': tot / m, 'val_ic': v_ic,
                     'val_ap_up': v_ap_up, 'val_ap_dn': v_ap_dn})
        if cur > best_ap:
            best_ap, best_epoch, wait = cur, epoch, 0
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            flag = '  ← best'
        else:
            wait += 1
            flag = f'  ({wait}/{PATIENCE})'
        print(f'    seed {seed}  ep {epoch:2d}  loss={tot/m:.4f}  '
              f'IC_h{H_SEL}={v_ic[H_TRADE_IDX]:+.4f}  '
              f'AP_up{H_SEL}={v_ap_up:.4f}  AP_dn{H_SEL}={v_ap_dn:.4f}{flag}')
        if wait >= PATIENCE:
            print('    early stop')
            break

    model.load_state_dict(best_state)
    return model, best_state, best_epoch, hist

def train_fold(fold):
    t_hi = fold['train_hi']
    v0, v1 = fold['val']
    s0, s1 = fold['test']

    scaler = StandardScaler().fit(X_raw[:t_hi])
    Xs = scaler.transform(X_raw).astype(np.float32)
    # (n-SEQ_LEN+1, SEQ_LEN, F) VIEW into Xs — no copy; batches materialise
    # only when fancy-indexed below. This is what keeps RAM under control.
    view = np.lib.stride_tricks.sliding_window_view(Xs, (SEQ_LEN, F_DIM))[:, 0]

    train_ends = ends_in(0, t_hi)
    val_ends   = ends_in(v0, v1)
    test_ends  = ends_in(s0, s1)

    # Importance sampling: bars with bigger vol-normalised moves are drawn
    # more often; SAMPLE_W_BASE keeps flat bars in the mix so the model still
    # learns what "nothing happening" looks like.
    samp_w = SAMPLE_W_BASE + np.abs(Y_all[train_ends, H_TRADE_IDX]).astype(np.float64)
    samp_p = samp_w / samp_w.sum()
    eff = 1.0 / np.sum(samp_p ** 2) / len(samp_p)
    print(f'  sampling tilt: effective sample fraction {eff*100:.1f}% '
          f'(100% = uniform)')

    # per-head pos_weight from TRAIN base rates only (no val/test peeking)
    pos = L_all[train_ends].mean(axis=0)
    pos_w = np.clip((1.0 - pos) / np.maximum(pos, 1e-6), 1.0, POS_W_CAP)
    print('  train base rates: ' + '  '.join(
        f'{c}={p*100:.1f}%(pw{w:.1f})' for c, p, w in zip(CLS_COLS, pos, pos_w)))

    states, best_epochs, hists = [], [], []
    val_preds, test_preds, seed_test_ic = [], [], []
    seed_val_probs, seed_test_probs = [], []
    for seed in SEEDS:
        model, best_state, best_epoch, hist = train_one_seed(
            seed, view, train_ends, val_ends, samp_p, pos_w)
        vr, vp = predict(model, view, val_ends)
        tr, tp = predict(model, view, test_ends)
        s_ic = [ic(tr[:, i], Y_all[test_ends, i]) for i in range(len(HORIZONS))]
        s_ap = [ap(L_all[test_ends, j], tp[:, j]) for j in (SEL_UP_J, SEL_DN_J)]
        print(f'    seed {seed} TEST: IC_h{H_SEL}={s_ic[H_TRADE_IDX]:+.4f}  '
              f'AP_up{H_SEL}={s_ap[0]:.4f}  AP_dn{H_SEL}={s_ap[1]:.4f}   '
              f'(best epoch {best_epoch})')
        states.append(best_state); best_epochs.append(best_epoch); hists.append(hist)
        val_preds.append(vr); test_preds.append(tr); seed_test_ic.append(s_ic)
        seed_val_probs.append(vp); seed_test_probs.append(tp)
        del model

    val_pred  = np.mean(val_preds, axis=0)          # seed-ensemble (regression)
    test_pred = np.mean(test_preds, axis=0)
    val_prob  = np.mean(seed_val_probs, axis=0)     # seed-ensemble (probability)
    test_prob = np.mean(seed_test_probs, axis=0)
    test_ic = [ic(test_pred[:, i], Y_all[test_ends, i]) for i in range(len(HORIZONS))]
    test_ap = [ap(L_all[test_ends, j], test_prob[:, j]) for j in range(len(CLS_KEYS))]
    out = {'scaler': scaler, 'states': states, 'best_epochs': best_epochs,
           'hist': hists[-1], 'val_ends': val_ends, 'val_pred': val_pred,
           'test_ends': test_ends, 'test_pred': test_pred,
           'test_ic': test_ic, 'seed_test_ic': seed_test_ic,
           'val_prob': val_prob, 'test_prob': test_prob,
           'seed_val_probs': seed_val_probs, 'seed_test_probs': seed_test_probs,
           'test_ap': test_ap}
    del Xs, view
    gc.collect()
    return out

# %%
# ── Cell 9: Run walk-forward ──────────────────────────────────────────────
results = []
for fold in folds:
    lo, hi = fold['test']
    print(f"\n════ Fold {fold['k']}: test {pd.Timestamp(dt_all[lo])} → {pd.Timestamp(dt_all[hi-1])} ════")
    res = train_fold(fold)
    results.append(res)
    ics = '  '.join(f'IC_h{h}={v:+.4f}' for h, v in zip(HORIZONS, res['test_ic']))
    print(f"  ENSEMBLE TEST ({len(res['test_ends']):,} samples): {ics}")

print('\n──── Regression reference (seed-ensemble; ± = per-seed spread) ────')
print('NOTE: this window differs from runs 003–005, so these ICs are context,')
print('not comparable numbers. run.004 per-seed noise floor was ±0.002–0.018.')
hdr = '  '.join(f"{'IC_h' + str(h):>16s}" for h in HORIZONS)
print(f'Fold    n_test   {hdr}')
for f_, r in zip(folds, results):
    cells = []
    for j in range(len(HORIZONS)):
        s_ics = [r['seed_test_ic'][s][j] for s in range(len(SEEDS))]
        cells.append(f"{r['test_ic'][j]:>+8.4f} ±{np.std(s_ics):.4f}")
    print(f"  {f_['k']}   {len(r['test_ends']):>8,}  " + '  '.join(cells))

ends_pool = np.concatenate([r['test_ends'] for r in results])
pred_pool = np.concatenate([r['test_pred'] for r in results])
prob_pool = np.concatenate([r['test_prob'] for r in results])
pooled_ic = [ic(pred_pool[:, i], Y_all[ends_pool, i]) for i in range(len(HORIZONS))]
print('Pooled ensemble:   ' + '  '.join(f'{v:>+9.4f}       ' for v in pooled_ic))

print('\n──── Opportunity-head test AP (seed-ensemble) vs base rate ────')
print('AP ≈ base rate = the head ranks no better than chance; the selective')
print('tables in the next cell are what actually matters — AP is a whole-')
print('distribution summary, and this run only cares about the extreme tail.')
print(f'{"head":8s}  ' + '  '.join(f'fold {k}' for k in range(N_FOLDS)) + '   pooled  base%')
for j, c in enumerate(CLS_COLS):
    aps = '  '.join(f"{r['test_ap'][j]:.4f}" for r in results)
    pooled_ap = ap(L_all[ends_pool, j], prob_pool[:, j])
    base = L_all[ends_pool, j].mean()
    print(f'{c:8s}  {aps}   {pooled_ap:.4f}  {base*100:5.2f}')

# Backtest/pooling score: per-fold predictions divided by that fold's
# VALIDATION score std, so "σ" thresholds mean the same thing in every fold
# and the score scale is chosen without touching test data.
score_pool = np.concatenate([r['test_pred'] / (r['val_pred'].std(axis=0) + 1e-9)
                             for r in results])

def daily_ic_stats(ends, score, y):
    days = dt_all[ends].astype('datetime64[D]')
    vals = []
    for d in np.unique(days):
        m = days == d
        if m.sum() >= MIN_DAY_SAMPLES:
            vals.append(ic(score[m], y[m]))
    vals = np.array(vals)
    se = vals.std(ddof=1) / np.sqrt(len(vals))
    return vals.mean(), se, vals.mean() / se, len(vals)

print('\n──── Daily-IC t-stats (pooled ensemble; |t|>2 ≈ significant) ────')
for j, h in enumerate(HORIZONS):
    mu, se, t, k = daily_ic_stats(ends_pool, score_pool[:, j], Y_all[ends_pool, j])
    print(f'  h{h:<4d}  mean daily IC {mu:+.4f} ± {se:.4f}   t = {t:+.2f}   ({k} days)')

# ── persist scores IMMEDIATELY — run.004's scores died with the VM ────────
# (rolling-threshold evaluation is fully reproducible offline from this npz:
#  it saves val probs + val/test timestamps per fold)
fold_of = np.concatenate([np.full(len(r['test_ends']), f_['k'])
                          for f_, r in zip(folds, results)])
val_ends_pool = np.concatenate([r['val_ends'] for r in results])
val_prob_pool = np.concatenate([r['val_prob'] for r in results])
val_fold_of   = np.concatenate([np.full(len(r['val_ends']), f_['k'])
                                for f_, r in zip(folds, results)])
seed_prob_pool     = np.concatenate([np.stack(r['seed_test_probs'], axis=2) for r in results])
seed_val_prob_pool = np.concatenate([np.stack(r['seed_val_probs'],  axis=2) for r in results])
scores_path = os.path.join(OUTPUT_DIR, 'run012_scores.npz')
np.savez_compressed(scores_path,
    ends=ends_pool, score=score_pool, prob=prob_pool, seed_prob=seed_prob_pool,
    labels=L_all[ends_pool], y=Y_all[ends_pool],
    horizons=np.array(HORIZONS), cls_cols=np.array(CLS_COLS),
    dt_s=dt_s[ends_pool], close=close[ends_pool], fold_of=fold_of,
    val_ends=val_ends_pool, val_prob=val_prob_pool, val_fold_of=val_fold_of,
    seed_val_prob=seed_val_prob_pool, val_dt_s=dt_s[val_ends_pool])
print(f'\nScores persisted → {scores_path}')
print('(copied to Drive in the final cell — if you plan to stop early, copy it now)')
# Out:
# ════ Fold 0: test 2026-08-24 16:45:50 → 2026-08-26 04:47:00 ════
#   sampling tilt: effective sample fraction 65.9% (100% = uniform)
#   train base rates: lup_6=1.6%(pw20.0)  ldn_6=1.5%(pw20.0)  lup_9=2.9%(pw20.0)  ldn_9=2.6%(pw20.0)  lup_12=2.1%(pw20.0)  ldn_12=1.8%(pw20.0)  lup_15=2.9%(pw20.0)  ldn_15=2.5%(pw20.0)  lup_18=3.8%(pw20.0)  ldn_18=3.2%(pw20.0)  lup_24=5.7%(pw16.5)  ldn_24=4.7%(pw20.0)
#     seed 0  ep  1  loss=2.2060  IC_h18=-0.0361  AP_up18=0.0735  AP_dn18=0.2311  ← best
#     seed 0  ep  2  loss=1.9018  IC_h18=-0.0333  AP_up18=0.0503  AP_dn18=0.1522  (1/5)
#     seed 0  ep  3  loss=1.6172  IC_h18=-0.0752  AP_up18=0.0568  AP_dn18=0.0836  (2/5)
#     seed 0  ep  4  loss=1.2301  IC_h18=+0.0079  AP_up18=0.0521  AP_dn18=0.0769  (3/5)
#     seed 0  ep  5  loss=0.9880  IC_h18=+0.0333  AP_up18=0.0518  AP_dn18=0.0955  (4/5)
#     seed 0  ep  6  loss=0.8392  IC_h18=+0.0533  AP_up18=0.0375  AP_dn18=0.0930  (5/5)
#     early stop
#     seed 0 TEST: IC_h18=+0.0273  AP_up18=0.1304  AP_dn18=0.1087   (best epoch 1)
#     seed 1  ep  1  loss=2.2250  IC_h18=-0.0368  AP_up18=0.0705  AP_dn18=0.2297  ← best
#     seed 1  ep  2  loss=1.9460  IC_h18=-0.0368  AP_up18=0.0457  AP_dn18=0.2029  (1/5)
#     seed 1  ep  3  loss=1.6005  IC_h18=+0.0183  AP_up18=0.0530  AP_dn18=0.1778  (2/5)
#     seed 1  ep  4  loss=1.2239  IC_h18=+0.1117  AP_up18=0.0593  AP_dn18=0.1303  (3/5)
#     seed 1  ep  5  loss=0.9803  IC_h18=+0.1029  AP_up18=0.0485  AP_dn18=0.0889  (4/5)
#     seed 1  ep  6  loss=0.8434  IC_h18=+0.1333  AP_up18=0.0332  AP_dn18=0.1042  (5/5)
#     early stop
#     seed 1 TEST: IC_h18=+0.0266  AP_up18=0.1305  AP_dn18=0.1093   (best epoch 1)
#     seed 2  ep  1  loss=2.1875  IC_h18=-0.0196  AP_up18=0.0634  AP_dn18=0.2427  ← best
#     seed 2  ep  2  loss=1.8957  IC_h18=-0.0427  AP_up18=0.0431  AP_dn18=0.1589  (1/5)
#     seed 2  ep  3  loss=1.5748  IC_h18=-0.0256  AP_up18=0.0568  AP_dn18=0.1276  (2/5)
#     seed 2  ep  4  loss=1.2056  IC_h18=+0.0101  AP_up18=0.0549  AP_dn18=0.1190  (3/5)
#     seed 2  ep  5  loss=0.9741  IC_h18=+0.0430  AP_up18=0.0521  AP_dn18=0.0729  (4/5)
#     seed 2  ep  6  loss=0.8397  IC_h18=+0.0298  AP_up18=0.0459  AP_dn18=0.1029  (5/5)
#     early stop
#     seed 2 TEST: IC_h18=+0.0252  AP_up18=0.1197  AP_dn18=0.1157   (best epoch 1)
#   ENSEMBLE TEST (23,504 samples): IC_h6=+0.0293  IC_h9=+0.0340  IC_h12=+0.0331  IC_h15=+0.0277  IC_h18=+0.0332  IC_h24=+0.0208
#
# ════ Fold 1: test 2026-08-26 04:47:05 → 2026-08-27 16:31:05 ════
#   sampling tilt: effective sample fraction 66.5% (100% = uniform)
#   train base rates: lup_6=1.5%(pw20.0)  ldn_6=1.5%(pw20.0)  lup_9=2.9%(pw20.0)  ldn_9=2.7%(pw20.0)  lup_12=2.0%(pw20.0)  ldn_12=1.9%(pw20.0)  lup_15=2.8%(pw20.0)  ldn_15=2.6%(pw20.0)  lup_18=3.7%(pw20.0)  ldn_18=3.4%(pw20.0)  lup_24=5.5%(pw17.1)  ldn_24=4.9%(pw19.3)
#     seed 0  ep  1  loss=2.1368  IC_h18=+0.0090  AP_up18=0.1123  AP_dn18=0.0839  ← best
#     seed 0  ep  2  loss=1.8140  IC_h18=+0.0136  AP_up18=0.1191  AP_dn18=0.0777  ← best
#     seed 0  ep  3  loss=1.3531  IC_h18=+0.0392  AP_up18=0.0739  AP_dn18=0.0793  (1/5)
#     seed 0  ep  4  loss=1.0257  IC_h18=+0.0179  AP_up18=0.0639  AP_dn18=0.0630  (2/5)
#     seed 0  ep  5  loss=0.8727  IC_h18=+0.0120  AP_up18=0.0502  AP_dn18=0.0683  (3/5)
#     seed 0  ep  6  loss=0.7668  IC_h18=+0.0195  AP_up18=0.0503  AP_dn18=0.0533  (4/5)
#     seed 0  ep  7  loss=0.6956  IC_h18=+0.0341  AP_up18=0.0519  AP_dn18=0.0651  (5/5)
#     early stop
#     seed 0 TEST: IC_h18=-0.0016  AP_up18=0.0944  AP_dn18=0.0411   (best epoch 2)
#     seed 1  ep  1  loss=2.1667  IC_h18=+0.0665  AP_up18=0.1115  AP_dn18=0.0826  ← best
#     seed 1  ep  2  loss=1.8305  IC_h18=+0.0116  AP_up18=0.1745  AP_dn18=0.0767  ← best
#     seed 1  ep  3  loss=1.4098  IC_h18=+0.0602  AP_up18=0.1216  AP_dn18=0.0808  (1/5)
#     seed 1  ep  4  loss=1.0426  IC_h18=+0.0371  AP_up18=0.1541  AP_dn18=0.0755  (2/5)
#     seed 1  ep  5  loss=0.8539  IC_h18=+0.0209  AP_up18=0.1441  AP_dn18=0.0715  (3/5)
#     seed 1  ep  6  loss=0.7398  IC_h18=+0.0166  AP_up18=0.1338  AP_dn18=0.0654  (4/5)
#     seed 1  ep  7  loss=0.6703  IC_h18=+0.0202  AP_up18=0.1104  AP_dn18=0.0574  (5/5)
#     early stop
#     seed 1 TEST: IC_h18=+0.0477  AP_up18=0.0944  AP_dn18=0.0614   (best epoch 2)
#     seed 2  ep  1  loss=2.1514  IC_h18=+0.0663  AP_up18=0.1106  AP_dn18=0.0864  ← best
#     seed 2  ep  2  loss=1.8202  IC_h18=+0.0474  AP_up18=0.1099  AP_dn18=0.0774  (1/5)
#     seed 2  ep  3  loss=1.3799  IC_h18=+0.0469  AP_up18=0.0925  AP_dn18=0.0770  (2/5)
#     seed 2  ep  4  loss=1.0148  IC_h18=+0.0248  AP_up18=0.1164  AP_dn18=0.0753  (3/5)
#     seed 2  ep  5  loss=0.8228  IC_h18=+0.0113  AP_up18=0.1592  AP_dn18=0.0642  ← best
#     seed 2  ep  6  loss=0.7239  IC_h18=-0.0127  AP_up18=0.1189  AP_dn18=0.0668  (1/5)
#     seed 2  ep  7  loss=0.6617  IC_h18=-0.0102  AP_up18=0.1073  AP_dn18=0.0630  (2/5)
#     seed 2  ep  8  loss=0.6124  IC_h18=-0.0244  AP_up18=0.0864  AP_dn18=0.0624  (3/5)
#     seed 2  ep  9  loss=0.5795  IC_h18=-0.0175  AP_up18=0.0751  AP_dn18=0.0674  (4/5)
#     seed 2  ep 10  loss=0.5550  IC_h18=-0.0238  AP_up18=0.0698  AP_dn18=0.0656  (5/5)
#     early stop
#     seed 2 TEST: IC_h18=+0.0180  AP_up18=0.0393  AP_dn18=0.0500   (best epoch 5)
#   ENSEMBLE TEST (25,056 samples): IC_h6=+0.0173  IC_h9=+0.0133  IC_h12=+0.0161  IC_h15=+0.0215  IC_h18=+0.0220  IC_h24=+0.0198
#
# ════ Fold 2: test 2026-08-27 16:31:10 → 2026-08-29 04:15:40 ════
#   sampling tilt: effective sample fraction 67.3% (100% = uniform)
#   train base rates: lup_6=1.3%(pw20.0)  ldn_6=1.3%(pw20.0)  lup_9=2.5%(pw20.0)  ldn_9=2.4%(pw20.0)  lup_12=1.6%(pw20.0)  ldn_12=1.6%(pw20.0)  lup_15=2.4%(pw20.0)  ldn_15=2.3%(pw20.0)  lup_18=3.1%(pw20.0)  ldn_18=3.0%(pw20.0)  lup_24=4.7%(pw20.0)  ldn_24=4.5%(pw20.0)
#     seed 0  ep  1  loss=2.0191  IC_h18=+0.0331  AP_up18=0.1230  AP_dn18=0.0585  ← best
#     seed 0  ep  2  loss=1.6883  IC_h18=+0.0619  AP_up18=0.0835  AP_dn18=0.0195  (1/5)
#     seed 0  ep  3  loss=1.2283  IC_h18=+0.0421  AP_up18=0.0560  AP_dn18=0.0419  (2/5)
#     seed 0  ep  4  loss=0.9323  IC_h18=+0.0306  AP_up18=0.0379  AP_dn18=0.0272  (3/5)
#     seed 0  ep  5  loss=0.7827  IC_h18=+0.0129  AP_up18=0.0351  AP_dn18=0.0217  (4/5)
#     seed 0  ep  6  loss=0.6889  IC_h18=+0.0262  AP_up18=0.0349  AP_dn18=0.0181  (5/5)
#     early stop
#     seed 0 TEST: IC_h18=+0.0330  AP_up18=0.0697  AP_dn18=0.1308   (best epoch 1)
#     seed 1  ep  1  loss=2.0326  IC_h18=+0.0151  AP_up18=0.1280  AP_dn18=0.0544  ← best
#     seed 1  ep  2  loss=1.6807  IC_h18=+0.0766  AP_up18=0.1115  AP_dn18=0.0710  ← best
#     seed 1  ep  3  loss=1.2450  IC_h18=+0.0239  AP_up18=0.1013  AP_dn18=0.0759  (1/5)
#     seed 1  ep  4  loss=0.9064  IC_h18=+0.0424  AP_up18=0.0559  AP_dn18=0.0428  (2/5)
#     seed 1  ep  5  loss=0.7622  IC_h18=+0.0303  AP_up18=0.0475  AP_dn18=0.0463  (3/5)
#     seed 1  ep  6  loss=0.6609  IC_h18=+0.0201  AP_up18=0.0511  AP_dn18=0.0467  (4/5)
#     seed 1  ep  7  loss=0.6033  IC_h18=+0.0264  AP_up18=0.0511  AP_dn18=0.0531  (5/5)
#     early stop
#     seed 1 TEST: IC_h18=-0.0111  AP_up18=0.0484  AP_dn18=0.0631   (best epoch 2)
#     seed 2  ep  1  loss=2.0227  IC_h18=+0.0349  AP_up18=0.1343  AP_dn18=0.0491  ← best
#     seed 2  ep  2  loss=1.6604  IC_h18=-0.0069  AP_up18=0.1384  AP_dn18=0.0611  ← best
#     seed 2  ep  3  loss=1.1925  IC_h18=+0.0277  AP_up18=0.0497  AP_dn18=0.0402  (1/5)
#     seed 2  ep  4  loss=0.9014  IC_h18=+0.0669  AP_up18=0.0724  AP_dn18=0.0372  (2/5)
#     seed 2  ep  5  loss=0.7594  IC_h18=+0.0659  AP_up18=0.0918  AP_dn18=0.0390  (3/5)
#     seed 2  ep  6  loss=0.6656  IC_h18=+0.0525  AP_up18=0.0449  AP_dn18=0.0369  (4/5)
#     seed 2  ep  7  loss=0.6058  IC_h18=+0.0539  AP_up18=0.0490  AP_dn18=0.0324  (5/5)
#     early stop
#     seed 2 TEST: IC_h18=+0.0158  AP_up18=0.0530  AP_dn18=0.0551   (best epoch 2)
#   ENSEMBLE TEST (24,862 samples): IC_h6=-0.0063  IC_h9=-0.0076  IC_h12=-0.0075  IC_h15=-0.0073  IC_h18=-0.0031  IC_h24=+0.0064
#
# ════ Fold 3: test 2026-08-29 04:15:45 → 2026-08-30 15:59:55 ════
#   sampling tilt: effective sample fraction 67.3% (100% = uniform)
#   train base rates: lup_6=1.1%(pw20.0)  ldn_6=1.1%(pw20.0)  lup_9=2.1%(pw20.0)  ldn_9=2.1%(pw20.0)  lup_12=1.4%(pw20.0)  ldn_12=1.4%(pw20.0)  lup_15=2.1%(pw20.0)  ldn_15=2.1%(pw20.0)  lup_18=2.7%(pw20.0)  ldn_18=2.7%(pw20.0)  lup_24=4.2%(pw20.0)  ldn_24=4.0%(pw20.0)
#     seed 0  ep  1  loss=1.9266  IC_h18=+0.0309  AP_up18=0.0675  AP_dn18=0.1819  ← best
#     seed 0  ep  2  loss=1.5362  IC_h18=-0.0509  AP_up18=0.0510  AP_dn18=0.1006  (1/5)
#     seed 0  ep  3  loss=1.0635  IC_h18=+0.0048  AP_up18=0.0546  AP_dn18=0.0884  (2/5)
#     seed 0  ep  4  loss=0.8305  IC_h18=-0.0137  AP_up18=0.0661  AP_dn18=0.0755  (3/5)
#     seed 0  ep  5  loss=0.6950  IC_h18=-0.0133  AP_up18=0.0683  AP_dn18=0.0693  (4/5)
#     seed 0  ep  6  loss=0.6170  IC_h18=+0.0204  AP_up18=0.0690  AP_dn18=0.0649  (5/5)
#     early stop
#     seed 0 TEST: IC_h18=+0.0396  AP_up18=0.0277  AP_dn18=0.0825   (best epoch 1)
#     seed 1  ep  1  loss=1.9340  IC_h18=+0.0265  AP_up18=0.0775  AP_dn18=0.1951  ← best
#     seed 1  ep  2  loss=1.5548  IC_h18=+0.0105  AP_up18=0.0652  AP_dn18=0.1492  (1/5)
#     seed 1  ep  3  loss=1.0823  IC_h18=+0.0362  AP_up18=0.0598  AP_dn18=0.1239  (2/5)
#     seed 1  ep  4  loss=0.8433  IC_h18=+0.0095  AP_up18=0.0633  AP_dn18=0.1190  (3/5)
#     seed 1  ep  5  loss=0.7079  IC_h18=+0.0039  AP_up18=0.0651  AP_dn18=0.1065  (4/5)
#     seed 1  ep  6  loss=0.6240  IC_h18=+0.0053  AP_up18=0.0566  AP_dn18=0.1188  (5/5)
#     early stop
#     seed 1 TEST: IC_h18=-0.0147  AP_up18=0.0300  AP_dn18=0.0501   (best epoch 1)
#     seed 2  ep  1  loss=1.9329  IC_h18=+0.0467  AP_up18=0.0730  AP_dn18=0.1884  ← best
#     seed 2  ep  2  loss=1.5062  IC_h18=+0.0125  AP_up18=0.0576  AP_dn18=0.1146  (1/5)
#     seed 2  ep  3  loss=1.0307  IC_h18=-0.0095  AP_up18=0.0487  AP_dn18=0.1298  (2/5)
#     seed 2  ep  4  loss=0.7940  IC_h18=-0.0174  AP_up18=0.0543  AP_dn18=0.0900  (3/5)
#     seed 2  ep  5  loss=0.6823  IC_h18=-0.0253  AP_up18=0.0625  AP_dn18=0.0789  (4/5)
#     seed 2  ep  6  loss=0.5987  IC_h18=-0.0221  AP_up18=0.0488  AP_dn18=0.0832  (5/5)
#     early stop
#     seed 2 TEST: IC_h18=-0.0010  AP_up18=0.0351  AP_dn18=0.0346   (best epoch 1)
#   ENSEMBLE TEST (25,140 samples): IC_h6=+0.0377  IC_h9=+0.0244  IC_h12=-0.0051  IC_h15=-0.0184  IC_h18=-0.0201  IC_h24=+0.0090
#
# ──── Regression reference (seed-ensemble; ± = per-seed spread) ────
# NOTE: this window differs from runs 003–005, so these ICs are context,
# not comparable numbers. run.004 per-seed noise floor was ±0.002–0.018.
# Fold    n_test              IC_h6             IC_h9            IC_h12            IC_h15            IC_h18            IC_h24
#   0     23,504   +0.0293 ±0.0104   +0.0340 ±0.0027   +0.0331 ±0.0031   +0.0277 ±0.0074   +0.0332 ±0.0088   +0.0208 ±0.0009
#   1     25,056   +0.0173 ±0.0065   +0.0133 ±0.0113   +0.0161 ±0.0108   +0.0215 ±0.0140   +0.0220 ±0.0164   +0.0198 ±0.0203
#   2     24,862   -0.0063 ±0.0040   -0.0076 ±0.0141   -0.0075 ±0.0105   -0.0073 ±0.0152   -0.0031 ±0.0132   +0.0064 ±0.0181
#   3     25,140   +0.0377 ±0.0271   +0.0244 ±0.0235   -0.0051 ±0.0219   -0.0184 ±0.0081   -0.0201 ±0.0077   +0.0090 ±0.0230
# Pooled ensemble:     +0.0130           +0.0084           +0.0055           +0.0055           +0.0091           +0.0128
#
# ──── Opportunity-head test AP (seed-ensemble) vs base rate ────
# AP ≈ base rate = the head ranks no better than chance; the selective
# tables in the next cell are what actually matters — AP is a whole-
# distribution summary, and this run only cares about the extreme tail.
# head      fold 0  fold 1  fold 2  fold 3   pooled  base%
# lup_6     0.0741  0.0500  0.0436  0.0061   0.0474   0.45
# ldn_6     0.0564  0.0171  0.0362  0.0305   0.0319   0.51
# lup_9     0.1173  0.0782  0.0724  0.0230   0.0783   0.99
# ldn_9     0.0892  0.0412  0.0656  0.0609   0.0629   1.13
# lup_12    0.0731  0.0981  0.0406  0.0076   0.0548   0.59
# ldn_12    0.0670  0.0332  0.0437  0.0228   0.0450   0.77
# lup_15    0.1087  0.1098  0.0519  0.0160   0.0771   0.90
# ldn_15    0.0887  0.0579  0.0581  0.0385   0.0631   1.14
# lup_18    0.1283  0.0995  0.0720  0.0297   0.0865   1.21
# ldn_18    0.1120  0.0647  0.0697  0.0496   0.0763   1.52
# lup_24    0.1665  0.1007  0.1019  0.0972   0.1149   2.04
# ldn_24    0.1364  0.0923  0.1008  0.0945   0.1031   2.37
#
# ──── Daily-IC t-stats (pooled ensemble; |t|>2 ≈ significant) ────
#   h6     mean daily IC +0.0256 ± 0.0078   t = +3.26   (7 days)
#   h9     mean daily IC +0.0260 ± 0.0108   t = +2.41   (7 days)
#   h12    mean daily IC +0.0181 ± 0.0104   t = +1.74   (7 days)
#   h15    mean daily IC +0.0120 ± 0.0090   t = +1.33   (7 days)
#   h18    mean daily IC +0.0168 ± 0.0126   t = +1.33   (7 days)
#   h24    mean daily IC +0.0216 ± 0.0056   t = +3.83   (7 days)
#
# Scores persisted → /root/btc_lstm_run012/run012_scores.npz
# (copied to Drive in the final cell — if you plan to stop early, copy it now)

# %%
# ── Cell 10: Selective evaluation — rolling-causal triggers + TP/SL exits ──
# Two pre-registered changes vs run.006:
#
# 1. TRIGGER RULE ('ens'/'unan'/'reg' variants): τ is recomputed once per test
#    DAY as the (1−rate)-quantile of the scores seen in the trailing
#    ROLL_CAL_DAYS window — val scores seed it, already-seen test scores join
#    it. Deployable (past data only) and immune to run.006's fold-1 pathology
#    (frozen val τ above every test prob → an entire fold with 0 triggers).
#    The frozen-val rule of run.006 is still printed ('val' variant).
#
# 2. EXIT: run.006 scored hold-to-horizon endpoints and the θ-touch had
#    reverted by bar 40 ("lift good but net ≤ 0" — its diagnosed failure).
#    Every trigger now also runs through a TP/SL simulator:
#      entry  taker at close[e]  (signal-bar close, zero latency assumed)
#      TP     limit at entry·(1 + sgn·tp): counted filled MAKER at the limit
#             price on the first bar whose CLOSE trades through it (fill then
#             guaranteed; queue position ignored)
#      SL     first close beyond −sl → exit TAKER at that bar's actual CLOSE
#             (gap-through conservative, not at the stop price)
#      else   time-stop TAKER at close[e+h]
#    Closes of the mid only: intra-bar SL-then-TP sequences are invisible and
#    intra-bar touches that closes miss are lost. No slippage model.
#
# hit%  = path-label rate among triggers (TP-order upper bound)
# sim   = TP/SL-simulated net bps  ← headline; the CI column belongs to it
# endpt = hold-to-horizon endpoint net bps (run.006's lower bound)

RT_BPS    = 2 * TAKER_FEE * 1e4              # taker in + taker out
TP_RT_BPS = (TAKER_FEE + MAKER_FEE) * 1e4    # taker in + maker TP out
DAY_S     = 86400

def day_of(e):
    return dt_all[e].astype('datetime64[D]')

def net_bps(e, side, h):
    fwd = close[e + h] / close[e] - 1.0
    sgn = 1.0 if side == 'up' else -1.0
    return sgn * fwd * 1e4 - RT_BPS

def sim_exit(e, side, h, tp, sl):
    # → (net bps per trade, exit offset in bars 1..h). Vectorised over triggers;
    # close[e+1 .. e+h] is guaranteed contiguous by the sample-validity mask.
    if len(e) == 0:
        return np.zeros(0), np.zeros(0, dtype=int)
    sgn  = 1.0 if side == 'up' else -1.0
    path = close[e[:, None] + np.arange(1, h + 1)[None, :]]
    ret  = sgn * (path / close[e][:, None] - 1.0)
    big  = h + 1
    hit_tp = ret >= tp
    k_tp = np.where(hit_tp.any(axis=1), hit_tp.argmax(axis=1), big)
    if np.isfinite(sl):
        hit_sl = ret <= -sl
        k_sl = np.where(hit_sl.any(axis=1), hit_sl.argmax(axis=1), big)
    else:
        k_sl = np.full(len(e), big)
    net    = ret[:, -1] * 1e4 - RT_BPS                 # default: time stop
    k_exit = np.full(len(e), h)
    rows = np.arange(len(e))
    m = k_sl < k_tp                                    # stop hit first
    net[m]    = ret[rows[m], k_sl[m]] * 1e4 - RT_BPS
    k_exit[m] = k_sl[m] + 1
    m = k_tp < k_sl                                    # TP hit first (a single
    net[m]    = tp * 1e4 - TP_RT_BPS                   # close cannot breach both)
    k_exit[m] = k_tp[m] + 1
    return net, k_exit

def rolling_triggers(cal_x, cal_t, test_x, test_t, rate, side='hi'):
    # τ per test day from the trailing ROLL_CAL_DAYS of scores (cal = val
    # seeds; test scores join as their day passes). side='lo' thresholds the
    # left tail (regression dn baseline).
    xs = np.concatenate([cal_x, test_x])
    ts = np.concatenate([cal_t, test_t])
    o = np.argsort(ts, kind='stable')
    xs, ts = xs[o], ts[o]
    q = 1 - rate if side == 'hi' else rate
    trig = np.zeros(len(test_x), dtype=bool)
    days = test_t // DAY_S
    for d in np.unique(days):
        lo = np.searchsorted(ts, (d - ROLL_CAL_DAYS) * DAY_S)
        hi = np.searchsorted(ts, d * DAY_S)
        if hi - lo < MIN_CAL_N:
            lo = 0                       # thin window → all past scores
        if hi - lo == 0:
            continue                     # nothing causal available: abstain
        tau = np.quantile(xs[lo:hi], q)
        m = days == d
        trig[m] = (test_x[m] >= tau) if side == 'hi' else (test_x[m] <= tau)
    return trig

def fold_triggers(r, j, rate, variant):
    h, side = CLS_KEYS[j]
    vt, tt = dt_s[r['val_ends']], dt_s[r['test_ends']]
    if variant == 'reg':                 # frozen-regression baseline, rolling τ
        ridx = HORIZONS.index(h)
        return rolling_triggers(r['val_pred'][:, ridx], vt,
                                r['test_pred'][:, ridx], tt, rate,
                                'hi' if side == 'up' else 'lo')
    if variant == 'val':                 # run.006's frozen-val rule (comparison)
        tau = np.quantile(r['val_prob'][:, j], 1 - rate)
        return r['test_prob'][:, j] >= tau
    trig = rolling_triggers(r['val_prob'][:, j], vt,
                            r['test_prob'][:, j], tt, rate)
    if variant == 'unan':                # all seeds beyond their own rolling τ
        for s in range(len(SEEDS)):
            trig &= rolling_triggers(r['seed_val_probs'][s][:, j], vt,
                                     r['seed_test_probs'][s][:, j], tt, rate)
    return trig

def boot_ci_mean(x, days, n_boot=N_BOOT, seed=0):
    if len(x) == 0:
        return (np.nan, np.nan)
    rng = np.random.default_rng(seed)
    uds, inv = np.unique(days, return_inverse=True)
    sums = np.bincount(inv, weights=x, minlength=len(uds))
    cnts = np.bincount(inv, minlength=len(uds)).astype(np.float64)
    idx = rng.integers(0, len(uds), size=(n_boot, len(uds)))
    bs = sums[idx].sum(axis=1) / np.maximum(cnts[idx].sum(axis=1), 1.0)
    return (float(np.percentile(bs, 2.5)), float(np.percentile(bs, 97.5)))

def trigger_stats(j, rate, variant='ens', tp_mult=TP_MULT, sl_mult=SL_MULT):
    h, side = CLS_KEYS[j]
    th = THETA_BY_H[h]
    per_fold, E, NB, SN, HT = [], [], [], [], []
    for f_, r in zip(folds, results):
        trig = fold_triggers(r, j, rate, variant)
        e = r['test_ends'][trig]
        base = float(L_all[r['test_ends'], j].mean())
        nb = net_bps(e, side, h)
        sn, _ = sim_exit(e, side, h, tp_mult * th, sl_mult * th)
        n_days = max(len(np.unique(day_of(r['test_ends']))), 1)
        hit = float(L_all[e, j].mean()) if len(e) else np.nan
        per_fold.append(dict(k=f_['k'], n=len(e), per_day=len(e) / n_days,
                             hit=hit, base=base,
                             lift=(hit / base) if (len(e) and base > 0) else np.nan,
                             net=float(nb.mean()) if len(e) else np.nan,
                             sim=float(sn.mean()) if len(e) else np.nan))
        E.append(e); NB.append(nb); SN.append(sn); HT.append(L_all[e, j])
    e = np.concatenate(E); nb = np.concatenate(NB)
    sn = np.concatenate(SN); ht = np.concatenate(HT)
    base_p = float(L_all[ends_pool, j].mean())
    n_days = max(len(np.unique(day_of(ends_pool))), 1)
    hit_p = float(ht.mean()) if len(e) else np.nan
    pooled = dict(n=len(e), per_day=len(e) / n_days, hit=hit_p, base=base_p,
                  lift=(hit_p / base_p) if (len(e) and base_p > 0) else np.nan,
                  net=float(nb.mean()) if len(e) else np.nan,
                  sim=float(sn.mean()) if len(e) else np.nan,
                  ci=boot_ci_mean(sn, day_of(e)))     # CI on the SIMULATED net
    return per_fold, pooled

def _fmt(v, spec, na='     —'):
    return format(v, spec) if np.isfinite(v) else na

def show(j, rate, variant='ens', with_folds=False):
    pf, p = trigger_stats(j, rate, variant)
    h, side = CLS_KEYS[j]
    print(f'  {side}{h:<3d} {rate*100:7.3f}%  {variant:4s}  {p["n"]:>6,}  '
          f'{p["per_day"]:>6.2f}  '
          f'{_fmt(p["hit"]*100 if np.isfinite(p["hit"]) else np.nan, "6.1f")}  '
          f'{p["base"]*100:6.2f}  {_fmt(p["lift"], "5.2f")}  '
          f'{_fmt(p["sim"], "+8.2f")}  [{_fmt(p["ci"][0], "+7.2f")}, {_fmt(p["ci"][1], "+7.2f")}]  '
          f'{_fmt(p["net"], "+8.2f")}')
    if with_folds:
        for r_ in pf:
            print(f'        fold {r_["k"]}: n={r_["n"]:<6,} '
                  f'hit={_fmt(r_["hit"]*100 if np.isfinite(r_["hit"]) else np.nan, "5.1f")}% '
                  f'lift={_fmt(r_["lift"], "5.2f")} '
                  f'sim={_fmt(r_["sim"], "+8.2f")} endpt={_fmt(r_["net"], "+8.2f")} bps')
    return pf, p

HDR = ('  head    rate     var       n    /day    hit%   base%   lift   '
       'sim bps  [95% CI, day-boot]  endpt bps')

print(f'════ h{H_SEL} opportunity heads (θ={THETA_BY_H[H_SEL]*1e4:.0f}bp) — '
      f'the run.007 headline ════')
print(HDR)
for j in (SEL_UP_J, SEL_DN_J):
    for rate in TRIGGER_RATES:
        show(j, rate, 'ens', with_folds=(rate == PRIMARY_RATE))

print('\n════ run.006 frozen-val trigger rule (comparison, not gated) ════')
print(HDR)
for j in (SEL_UP_J, SEL_DN_J):
    show(j, PRIMARY_RATE, 'val')

print('\n════ Seed-unanimity abstention (all 3 seeds beyond their own rolling τ) ════')
print('Realized trigger rate < nominal by design — disagreement = "no idea".')
print(HDR)
for j in (SEL_UP_J, SEL_DN_J):
    for rate in TRIGGER_RATES:
        show(j, rate, 'unan')

print('\n════ Baseline: frozen regression score, same rolling-τ rule ════')
print('If the opportunity heads do not beat this, the BCE heads added nothing')
print('over thresholding the run.004-style score.')
print(HDR)
for j in (SEL_UP_J, SEL_DN_J):
    for rate in TRIGGER_RATES:
        show(j, rate, 'reg')

print(f'\n════ Exploratory: all horizons at the primary rate ({PRIMARY_RATE*100:.1f}%) ════')
print('h6/h9 rows are upper bounds (30–45s trades at 5s: entry latency is first-order).')
print(HDR)
for j, (h, s) in enumerate(CLS_KEYS):
    if h != H_SEL:
        show(j, PRIMARY_RATE, 'ens')

print(f'\n════ Exploratory: TP/SL grid at the primary head+rate '
      f'(h{H_SEL} @ {PRIMARY_RATE*100:.1f}% ens) ════')
print('Gated cell 11 uses ONLY (TP_MULT, SL_MULT) = '
      f'({TP_MULT}, {SL_MULT}); the rest is hypothesis-generating.')
print('  head    tp·θ   sl·θ        n     sim bps   [95% CI, day-boot]')
for j in (SEL_UP_J, SEL_DN_J):
    h, side = CLS_KEYS[j]
    for tpm, slm in TP_SL_GRID:
        _, p = trigger_stats(j, PRIMARY_RATE, 'ens', tp_mult=tpm, sl_mult=slm)
        sl_txt = f'{slm:4.1f}' if np.isfinite(slm) else 'none'
        print(f'  {side}{h:<4d}  {tpm:4.1f}   {sl_txt}   {p["n"]:>6,}  '
              f'{_fmt(p["sim"], "+9.2f")}  [{_fmt(p["ci"][0], "+7.2f")}, '
              f'{_fmt(p["ci"][1], "+7.2f")}]')

# ── non-overlapping trade simulation at the primary setting ───────────────
# Per-signal stats above count overlapping triggers (bar i and i+1 both firing
# = the same move twice). This greedily takes one trade at a time with the
# TP/SL exits (an early TP exit frees the book sooner), ignores triggers while
# a trade is open — a floor on realizable activity. 1 BTC per trade.
def non_overlap(j, rate, variant='ens'):
    h, side = CLS_KEYS[j]
    th = THETA_BY_H[h]
    ends = np.concatenate([r['test_ends'][fold_triggers(r, j, rate, variant)]
                           for r in results])   # test ranges ordered, disjoint
    nets, kex = sim_exit(ends, side, h, TP_MULT * th, SL_MULT * th)
    usd, last_exit = [], -1
    for i, e in enumerate(ends):
        if e < last_exit:
            continue
        usd.append(close[e] * nets[i] / 1e4)
        last_exit = e + kex[i]
    usd = np.array(usd)
    tag = f'{side}{h} @{rate*100:.1f}% {variant}'
    if len(usd) == 0:
        print(f'  {tag:24s}  no trades')
        return
    print(f'  {tag:24s}  {len(usd):>5,} trades   total {usd.sum():+10.0f} $   '
          f'mean {usd.mean():+7.1f} $   win {100*(usd > 0).mean():.1f}%')

print(f'\n════ Non-overlapping 1-BTC trades, TP/SL exits '
      f'(tp={TP_MULT}·θ, sl={SL_MULT}·θ, time-stop h) ════')
for variant in ('ens', 'unan'):
    for j in (SEL_UP_J, SEL_DN_J):
        non_overlap(j, PRIMARY_RATE, variant)
# Out:
# ════ h18 opportunity heads (θ=20bp) — the run.007 headline ════
#   head    rate     var       n    /day    hit%   base%   lift   sim bps  [95% CI, day-boot]  endpt bps
#   up18    0.010%  ens    1,631  233.00     6.7    1.21   5.58     -8.50  [  -9.54,   +4.09]     -8.40
#   up18    0.100%  ens    1,910  272.86     6.6    1.21   5.50     -8.38  [ -10.51,   -4.09]     -8.30
#         fold 0: n=54     hit= 33.3% lift=12.93 sim=  -10.38 endpt=  -16.12 bps
#         fold 1: n=315    hit= 12.7% lift=14.60 sim=   -4.96 endpt=   -4.49 bps
#         fold 2: n=1,534  hit=  4.5% lift= 3.29 sim=   -9.00 endpt=   -8.79 bps
#         fold 3: n=7      hit=  0.0% lift= 0.00 sim=  -11.46 endpt=  -11.46 bps
#   up18    1.000%  ens    3,518  502.57     5.8    1.21   4.80     -9.51  [ -11.08,   -7.12]     -9.41
#   dn18    0.010%  ens    2,188  312.57     4.5    1.52   2.98    -10.60  [ -10.67,   +1.22]    -10.71
#   dn18    0.100%  ens    2,204  314.86     4.6    1.52   3.05    -10.64  [ -10.70,   -3.99]    -10.70
#         fold 0: n=20     hit= 60.0% lift=17.48 sim=   -3.99 endpt=   +9.29 bps
#         fold 1: n=0      hit=     —% lift=     — sim=     — endpt=     — bps
#         fold 2: n=2,184  hit=  4.1% lift= 2.32 sim=  -10.70 endpt=  -10.88 bps
#         fold 3: n=0      hit=     —% lift=     — sim=     — endpt=     — bps
#   dn18    1.000%  ens    3,099  442.71     4.5    1.52   2.93    -10.77  [ -13.33,   -9.23]    -10.79
#
# ════ run.006 frozen-val trigger rule (comparison, not gated) ════
#   head    rate     var       n    /day    hit%   base%   lift   sim bps  [95% CI, day-boot]  endpt bps
#   up18    0.100%  val      336   48.00    17.0    1.21  14.04     -5.34  [  -9.58,   -3.39]     -5.83
#   dn18    0.100%  val      154   22.00    12.3    1.52   8.13     -8.66  [  -9.35,   -3.99]     -6.95
#
# ════ Seed-unanimity abstention (all 3 seeds beyond their own rolling τ) ════
# Realized trigger rate < nominal by design — disagreement = "no idea".
#   head    rate     var       n    /day    hit%   base%   lift   sim bps  [95% CI, day-boot]  endpt bps
#   up18    0.010%  unan      57    8.14    15.8    1.21  13.07     -5.51  [  -5.51,   -5.51]     -4.93
#   up18    0.100%  unan     116   16.57    17.2    1.21  14.27     -7.01  [ -15.06,   -5.63]     -8.47
#   up18    1.000%  unan   1,508  215.43     7.6    1.21   6.26     -8.24  [ -10.50,   -8.04]     -8.07
#   dn18    0.010%  unan     682   97.43     4.7    1.52   3.09     -9.30  [  -9.30,   -9.30]     -9.44
#   dn18    0.100%  unan     749  107.00     5.6    1.52   3.69     -8.99  [  -9.06,   +7.97]     -9.07
#   dn18    1.000%  unan   2,248  321.14     4.6    1.52   3.05    -10.83  [ -13.02,  -10.79]    -10.86
#
# ════ Baseline: frozen regression score, same rolling-τ rule ════
# If the opportunity heads do not beat this, the BCE heads added nothing
# over thresholding the run.004-style score.
#   head    rate     var       n    /day    hit%   base%   lift   sim bps  [95% CI, day-boot]  endpt bps
#   up18    0.010%  reg      166   23.71    22.9    1.21  18.94     -1.44  [  -1.78,   -1.10]     -0.95
#   up18    0.100%  reg      242   34.57    17.4    1.21  14.36     -2.91  [  -3.02,   -0.31]     -2.67
#   up18    1.000%  reg    1,445  206.43     5.8    1.21   4.81     -9.04  [ -10.75,   -5.21]     -8.90
#   dn18    0.010%  reg      937  133.86     3.3    1.52   2.18     -9.59  [ -10.88,   -7.97]     -9.58
#   dn18    0.100%  reg      999  142.71     3.1    1.52   2.04     -9.60  [ -10.10,   -8.59]     -9.59
#   dn18    1.000%  reg    1,363  194.71     2.3    1.52   1.50     -9.74  [ -10.40,   -8.92]     -9.72
#
# ════ Exploratory: all horizons at the primary rate (0.1%) ════
# h6/h9 rows are upper bounds (30–45s trades at 5s: entry latency is first-order).
#   head    rate     var       n    /day    hit%   base%   lift   sim bps  [95% CI, day-boot]  endpt bps
#   up6     0.100%  ens    1,896  270.86     2.1    0.45   4.69     -9.70  [  -9.93,   -9.10]     -9.68
#   dn6     0.100%  ens    2,205  315.00     2.0    0.51   3.85    -10.12  [ -11.38,  -10.09]    -10.14
#   up9     0.100%  ens    2,074  296.29     4.6    0.99   4.66     -9.43  [ -11.14,   -8.34]     -9.36
#   dn9     0.100%  ens    2,152  307.43     3.7    1.13   3.29    -10.14  [ -10.17,   -5.60]    -10.26
#   up12    0.100%  ens    2,061  294.43     3.7    0.59   6.37     -9.08  [ -14.19,   -8.98]     -9.04
#   dn12    0.100%  ens    2,181  311.57     2.4    0.77   3.10    -10.20  [ -10.25,   -2.10]    -10.32
#   up15    0.100%  ens    2,027  289.57     5.2    0.90   5.78     -8.67  [  -9.87,   -7.74]     -8.59
#   dn15    0.100%  ens    2,111  301.57     3.5    1.14   3.02    -10.40  [ -10.45,   -2.14]    -10.53
#   up24    0.100%  ens    1,565  223.57    12.1    2.04   5.93     -7.87  [  -7.97,   +4.30]     -7.73
#   dn24    0.100%  ens    2,080  297.14     7.2    2.37   3.02    -10.82  [ -10.89,   -3.23]    -10.88
#
# ════ Exploratory: TP/SL grid at the primary head+rate (h18 @ 0.1% ens) ════
# Gated cell 11 uses ONLY (TP_MULT, SL_MULT) = (1.0, 1.0); the rest is hypothesis-generating.
#   head    tp·θ   sl·θ        n     sim bps   [95% CI, day-boot]
#   up18     1.0    1.0    1,910      -8.38  [ -10.51,   -4.09]
#   up18     1.0    0.5    1,910      -8.62  [  -9.70,   -4.02]
#   up18     1.0   none    1,910      -8.34  [ -11.96,   -4.09]
#   up18     1.5    1.0    1,910      -8.39  [ -12.81,   -4.09]
#   up18     1.5    0.5    1,910      -8.62  [ -11.92,   -4.02]
#   dn18     1.0    1.0    2,204     -10.64  [ -10.70,   -3.99]
#   dn18     1.0    0.5    2,204     -10.61  [ -10.62,   -9.56]
#   dn18     1.0   none    2,204     -10.68  [ -10.81,   +4.19]
#   dn18     1.5    1.0    2,204     -10.66  [ -10.76,   -0.40]
#   dn18     1.5    0.5    2,204     -10.64  [ -10.68,   -6.11]
#
# ════ Non-overlapping 1-BTC trades, TP/SL exits (tp=1.0·θ, sl=1.0·θ, time-stop h) ════
#   up18 @0.1% ens              144 trades   total     -10721 $   mean   -74.4 $   win 16.0%
#   dn18 @0.1% ens              141 trades   total     -11971 $   mean   -84.9 $   win 13.5%
#   up18 @0.1% unan              13 trades   total       -602 $   mean   -46.3 $   win 30.8%
#   dn18 @0.1% unan              54 trades   total      -3868 $   mean   -71.6 $   win 16.7%

# %%
# ── Cell 10M: maker-entry simulation — the run.008 headline ────────────────
# run.007's gate failed in pre-registered failure mode #2: "lift good, sim ≤ 0,
# TP-grid all ≤ 0 → fees eat the touches; the remaining lever is ENTRY price".
# The arithmetic: taker entry pays θ−7bp on a hit vs ≈−18bp on a non-hit →
# breakeven hit ≈ 58.5%; best achieved was 49.7% (unan up6 @0.01%). Full-maker
# RT (4bp) moves breakeven to ≈49% — within one hit-rate point. This cell
# measures whether that point survives an honest fill model.
#
# Fill model (same conservative close-trade-through convention as the TP fill
# in sim_exit): post a limit at close[e]·(1 − sgn·ENTRY_DELTA·θ) after
# ENTRY_DELAY bars; it fills AT THE LIMIT on the first of the next ENTRY_WAIT
# bars whose CLOSE trades through it; unfilled by then → cancel, NO trade.
# After the fill: TP limit at entry·(1+sgn·tp) maker; SL taker at the breaching
# bar's actual close (the fill bar's own close counts — a close that gapped
# through both limit and stop exits immediately); else time-stop taker at
# close[e+h]. The horizon stays anchored at the TRIGGER bar: waiting for a
# fill consumes move window, and the sim pays that cost.
#
# FILL-RATE-HONEST accounting — the three numbers that matter together:
#   sim bps   mean net over FILLED trades (per-trade economics; CI belongs here)
#   fill%     share of triggers that filled — a resting limit misses exactly
#             the moves that leave immediately (adverse selection)
#   EV/trig   sum(filled net)/n_triggers — per-SIGNAL expectation, unfilled = 0.
#             Compare directly against cell 10's taker "sim bps" column.
#   missed    gross endpoint move of UNFILLED triggers + their hit rate: if
#             hit% (missed) ≫ hit% (filled), the limit filters out the winners.

MK_MK_BPS = 2 * MAKER_FEE * 1e4              # maker in + maker TP out (4 bp)
MK_TK_BPS = (MAKER_FEE + TAKER_FEE) * 1e4    # maker in + taker out    (7 bp)
H2_IDX    = HORIZONS.index(6)   # run.010: h6@5s = 30s = run.009's h2 timing head

def sim_maker(e, side, h, tp, sl, wait=ENTRY_WAIT, delta=0.0, delay=ENTRY_DELAY):
    # → (net bps [NaN where unfilled], filled mask, exit offset 1..h,
    #    fill offset 1..h [h+1 where unfilled]) — all full trigger length.
    # tp/sl/delta are ABSOLUTE fractions (callers multiply θ). Vectorised;
    # close[e+1..e+h] contiguity is guaranteed by the sample-validity mask.
    n = len(e)
    if n == 0:
        z = np.zeros(0)
        return z, np.zeros(0, dtype=bool), np.zeros(0, dtype=int), np.zeros(0, dtype=int)
    sgn  = 1.0 if side == 'up' else -1.0
    path = close[e[:, None] + np.arange(1, h + 1)[None, :]]
    lim  = close[e] * (1.0 - sgn * delta)
    relf = sgn * (path / lim[:, None] - 1.0)       # signed return vs the limit
    cols = np.arange(1, h + 1)[None, :]
    big  = h + 1
    can  = (relf <= 0.0) & (cols >= delay + 1) & (cols <= min(delay + wait, h))
    k_fill = np.where(can.any(axis=1), can.argmax(axis=1) + 1, big)
    filled = k_fill <= h
    kf = k_fill[:, None]
    tp_ok = (relf >= tp) & (cols > kf)             # fill-bar close ≤ lim < TP,
    k_tp = np.where(tp_ok.any(axis=1), tp_ok.argmax(axis=1) + 1, big)  # so > kf
    if np.isfinite(sl):                            # loses nothing
        sl_ok = (relf <= -sl) & (cols >= kf)       # fill bar CAN stop out
        k_sl = np.where(sl_ok.any(axis=1), sl_ok.argmax(axis=1) + 1, big)
    else:
        k_sl = np.full(n, big)
    net    = relf[:, -1] * 1e4 - MK_TK_BPS         # default: time-stop at e+h
    k_exit = np.full(n, h)
    rows = np.arange(n)
    m = k_sl < k_tp
    net[m]    = relf[rows[m], k_sl[m] - 1] * 1e4 - MK_TK_BPS
    k_exit[m] = k_sl[m]
    m = k_tp < k_sl
    net[m]    = tp * 1e4 - MK_MK_BPS
    k_exit[m] = k_tp[m]
    net[~filled] = np.nan
    return net, filled, k_exit, k_fill

def maker_stats(j, rate, variant='ens', wait=ENTRY_WAIT, delta_mult=ENTRY_DELTA,
                delay=ENTRY_DELAY, timing=None, tp_mult=TP_MULT, sl_mult=SL_MULT):
    # timing='h2': triggers where the 30s regression head (h6 at 5s) agrees
    # with the trade direction (sgn·pred > 0 → the move is leaving NOW) enter TAKER at the
    # signal close; the rest post the maker limit into the predicted pullback.
    # run.007's IC_h2 (t=+12.9, fast-dying mean reversion) finally gets a job.
    h, side = CLS_KEYS[j]
    th  = THETA_BY_H[h]
    sgn = 1.0 if side == 'up' else -1.0
    per_fold, EF, NF, EM, n_trig, n_taker = [], [], [], [], 0, 0
    for f_, r in zip(folds, results):
        trig = fold_triggers(r, j, rate, variant)
        e = r['test_ends'][trig]
        if timing == 'h2':
            now = sgn * r['test_pred'][trig, H2_IDX] > 0
            nt, _  = sim_exit(e[now], side, h, tp_mult * th, sl_mult * th)
            nm, fm, _, _ = sim_maker(e[~now], side, h, tp_mult * th, sl_mult * th,
                                     wait, delta_mult * th, delay)
            netf   = np.concatenate([nt, nm[fm]])
            e_f    = np.concatenate([e[now], e[~now][fm]])
            e_m    = e[~now][~fm]
            n_taker += int(now.sum())
        else:
            nm, fm, _, _ = sim_maker(e, side, h, tp_mult * th, sl_mult * th,
                                     wait, delta_mult * th, delay)
            netf, e_f, e_m = nm[fm], e[fm], e[~fm]
        n_trig += len(e)
        EF.append(e_f); NF.append(netf); EM.append(e_m)
        per_fold.append(dict(
            k=f_['k'], n=len(e), n_fill=len(e_f),
            fill=len(e_f) / len(e) if len(e) else np.nan,
            hit_f=float(L_all[e_f, j].mean()) if len(e_f) else np.nan,
            sim=float(netf.mean()) if len(e_f) else np.nan))
    e_f = np.concatenate(EF); netf = np.concatenate(NF); e_m = np.concatenate(EM)
    base = float(L_all[ends_pool, j].mean())
    hit_f = float(L_all[e_f, j].mean()) if len(e_f) else np.nan
    missed = sgn * (close[e_m + h] / close[e_m] - 1.0) * 1e4
    pooled = dict(
        n=n_trig, n_fill=len(e_f), n_taker=n_taker,
        fill=len(e_f) / n_trig if n_trig else np.nan,
        hit_f=hit_f, base=base,
        lift_f=(hit_f / base) if (len(e_f) and base > 0) else np.nan,
        sim=float(netf.mean()) if len(e_f) else np.nan,
        ci=boot_ci_mean(netf, day_of(e_f)),
        ev=float(netf.sum()) / n_trig if n_trig else np.nan,
        miss_gross=float(missed.mean()) if len(e_m) else np.nan,
        hit_m=float(L_all[e_m, j].mean()) if len(e_m) else np.nan)
    return per_fold, pooled

def show_maker(j, rate, variant='ens', with_folds=False, **kw):
    pf, p = maker_stats(j, rate, variant, **kw)
    h, side = CLS_KEYS[j]
    print(f'  {side}{h:<3d} {rate*100:7.3f}%  {variant:4s}  {p["n"]:>6,}  '
          f'{_fmt(p["fill"]*100 if np.isfinite(p["fill"]) else np.nan, "5.1f")}  '
          f'{p["n_fill"]:>6,}  '
          f'{_fmt(p["hit_f"]*100 if np.isfinite(p["hit_f"]) else np.nan, "5.1f")}  '
          f'{_fmt(p["lift_f"], "5.2f")}  {_fmt(p["sim"], "+8.2f")}  '
          f'[{_fmt(p["ci"][0], "+7.2f")}, {_fmt(p["ci"][1], "+7.2f")}]  '
          f'{_fmt(p["ev"], "+7.2f")}  {_fmt(p["miss_gross"], "+7.1f")}  '
          f'{_fmt(p["hit_m"]*100 if np.isfinite(p["hit_m"]) else np.nan, "5.1f")}')
    if with_folds:
        for r_ in pf:
            print(f'        fold {r_["k"]}: n={r_["n"]:<6,} '
                  f'fill={_fmt(r_["fill"]*100 if np.isfinite(r_["fill"]) else np.nan, "5.1f")}% '
                  f'hit_f={_fmt(r_["hit_f"]*100 if np.isfinite(r_["hit_f"]) else np.nan, "5.1f")}% '
                  f'sim={_fmt(r_["sim"], "+8.2f")} bps  (n_fill={r_["n_fill"]:,})')
    return pf, p

MHDR = ('  head    rate     var   n_trig  fill%  n_fill  hit_f%  lift_f   '
        'sim bps  [95% CI, day-boot]  EV/trig   missed  hit_m%')

print(f'════ MAKER ENTRY, primary config (wait={ENTRY_WAIT} bars, '
      f'δ={ENTRY_DELTA}·θ, delay={ENTRY_DELAY}) — h{H_SEL} heads ════')
print('sim/CI = filled trades; EV/trig = per-signal, unfilled count 0;')
print('missed = gross endpoint bps of unfilled triggers, hit_m = their hit rate.')
print(MHDR)
for j in (SEL_UP_J, SEL_DN_J):
    for rate in TRIGGER_RATES:
        show_maker(j, rate, 'ens', with_folds=(rate == PRIMARY_RATE))

print('\n════ Seed-unanimity + maker entry (the 49.7%-hit heads) ════')
print(MHDR)
for j in (SEL_UP_J, SEL_DN_J):
    for rate in TRIGGER_RATES:
        show_maker(j, rate, 'unan')

print(f'\n════ 30s-timed hybrid @ {PRIMARY_RATE*100:.1f}% ens: taker when the 30s '
      f'reg head says "leaving now", maker limit otherwise ════')
print(MHDR)
for j in (SEL_UP_J, SEL_DN_J):
    _, p = show_maker(j, PRIMARY_RATE, 'ens', timing='h2')
    print(f'        (routed taker: {p["n_taker"]:,}/{p["n"]:,} = '
          f'{100*p["n_taker"]/max(p["n"],1):.1f}%)')

print(f'\n════ Exploratory: wait × δ grid, h{H_SEL} @ {PRIMARY_RATE*100:.1f}% ens '
      f'(only the primary config is gated) ════')
print('  head   wait   δ·θ    fill%   hit_f%    sim bps   EV/trig')
for j in (SEL_UP_J, SEL_DN_J):
    h, side = CLS_KEYS[j]
    for w in WAIT_GRID:
        for dm in DELTA_GRID:
            _, p = maker_stats(j, PRIMARY_RATE, 'ens', wait=w, delta_mult=dm)
            print(f'  {side}{h:<4d} {w:4d}  {dm:4.2f}  '
                  f'{_fmt(p["fill"]*100 if np.isfinite(p["fill"]) else np.nan, "6.1f")}  '
                  f'{_fmt(p["hit_f"]*100 if np.isfinite(p["hit_f"]) else np.nan, "6.1f")}  '
                  f'{_fmt(p["sim"], "+9.2f")}  {_fmt(p["ev"], "+8.2f")}')

print(f'\n════ Entry-delay stress @ {PRIMARY_RATE*100:.1f}% ens (the other run.008 '
      f'promise) ════')
print('taker+3bar: enter taker at close[e+3] — 15s later, the run.009 latency')
print('stress — instead of close[e] (sim_exit on the shifted anchor, time-stop')
print('still e+h). If the taker edge moves materially, zero-latency was working.')
print('  head    variant          n     sim bps   [95% CI, day-boot]')
for j in (SEL_UP_J, SEL_DN_J):
    h, side = CLS_KEYS[j]
    th = THETA_BY_H[h]
    for tag, delay_ in (('taker+0', 0), ('taker+3bar (15s)', 3)):
        E, S = [], []
        for r in results:
            e = r['test_ends'][fold_triggers(r, j, PRIMARY_RATE, 'ens')]
            sn, _ = sim_exit(e + delay_, side, h - delay_, TP_MULT * th, SL_MULT * th)
            E.append(e); S.append(sn)
        e, sn = np.concatenate(E), np.concatenate(S)
        ci = boot_ci_mean(sn, day_of(e))
        print(f'  {side}{h:<4d}  {tag:16s} {len(e):>6,}  {_fmt(sn.mean() if len(e) else np.nan, "+9.2f")}  '
              f'[{_fmt(ci[0], "+7.2f")}, {_fmt(ci[1], "+7.2f")}]')
    for tag, delay_ in (('maker delay=3 (15s)', 3),):
        _, p = maker_stats(j, PRIMARY_RATE, 'ens', delay=delay_)
        print(f'  {side}{h:<4d}  {tag:16s} {p["n_fill"]:>6,}  {_fmt(p["sim"], "+9.2f")}  '
              f'[{_fmt(p["ci"][0], "+7.2f")}, {_fmt(p["ci"][1], "+7.2f")}]  '
              f'(fill {_fmt(p["fill"]*100 if np.isfinite(p["fill"]) else np.nan, "4.1f")}%)')

print(f'\n════ Exploratory: all horizons, maker primary config @ '
      f'{PRIMARY_RATE*100:.1f}% ens ════')
print(MHDR)
for j, (h, s) in enumerate(CLS_KEYS):
    if h != H_SEL:
        show_maker(j, PRIMARY_RATE, 'ens')

# ── non-overlapping maker trades: one position at a time, 1 BTC ───────────
# A resting limit commits the book: unfilled triggers block new posts until
# cancel (delay+wait bars). Filled trades block until exit.
def non_overlap_maker(j, rate, variant='ens'):
    h, side = CLS_KEYS[j]
    th  = THETA_BY_H[h]
    sgn = 1.0 if side == 'up' else -1.0
    ends = np.concatenate([r['test_ends'][fold_triggers(r, j, rate, variant)]
                           for r in results])   # test ranges ordered, disjoint
    nets, fm, kex, _ = sim_maker(ends, side, h, TP_MULT * th, SL_MULT * th,
                                 ENTRY_WAIT, ENTRY_DELTA * th, ENTRY_DELAY)
    usd, busy, n_posted = [], -1, 0
    for i, e in enumerate(ends):
        if e < busy:
            continue
        n_posted += 1
        if fm[i]:
            lim = close[e] * (1.0 - sgn * ENTRY_DELTA * th)
            usd.append(lim * nets[i] / 1e4)
            busy = e + kex[i]
        else:
            busy = e + min(ENTRY_DELAY + ENTRY_WAIT, h)
    usd = np.array(usd)
    tag = f'{side}{h} @{rate*100:.1f}% {variant}'
    if len(usd) == 0:
        print(f'  {tag:24s}  {n_posted:>5,} posted   no fills')
        return
    print(f'  {tag:24s}  {n_posted:>5,} posted  {len(usd):>5,} filled   '
          f'total {usd.sum():+10.0f} $   mean {usd.mean():+7.1f} $   '
          f'win {100*(usd > 0).mean():.1f}%')

print(f'\n════ Non-overlapping 1-BTC maker trades (wait={ENTRY_WAIT}, '
      f'tp={TP_MULT}·θ, sl={SL_MULT}·θ, time-stop h) ════')
for variant in ('ens', 'unan'):
    for j in (SEL_UP_J, SEL_DN_J):
        non_overlap_maker(j, PRIMARY_RATE, variant)
# Out:
# ════ MAKER ENTRY, primary config (wait=6 bars, δ=0.0·θ, delay=0) — h18 heads ════
# sim/CI = filled trades; EV/trig = per-signal, unfilled count 0;
# missed = gross endpoint bps of unfilled triggers, hit_m = their hit rate.
#   head    rate     var   n_trig  fill%  n_fill  hit_f%  lift_f   sim bps  [95% CI, day-boot]  EV/trig   missed  hit_m%
#   up18    0.010%  ens    1,631   74.8   1,220    4.2   3.46     -7.49  [  -9.27,   +3.16]    -5.60     +7.5   14.4
#   up18    0.100%  ens    1,910   74.5   1,422    4.0   3.32     -7.37  [ -10.07,   -4.62]    -5.48     +7.4   14.3
#         fold 0: n=54     fill= 88.9% hit_f= 25.0% sim=  -10.31 bps  (n_fill=48)
#         fold 1: n=315    fill= 67.6% hit_f=  5.6% sim=   -4.54 bps  (n_fill=213)
#         fold 2: n=1,534  fill= 75.2% hit_f=  2.9% sim=   -7.76 bps  (n_fill=1,154)
#         fold 3: n=7      fill=100.0% hit_f=  0.0% sim=   -8.46 bps  (n_fill=7)
#   up18    1.000%  ens    3,518   74.5   2,622    3.5   2.90     -8.56  [ -10.58,   -6.93]    -6.38     +6.3   12.5
#   dn18    0.010%  ens    2,188   78.6   1,720    2.1   1.38     -9.24  [  -9.52,   -9.24]    -7.27     +5.5   13.5
#   dn18    0.100%  ens    2,204   78.8   1,736    2.2   1.48     -9.27  [ -10.13,   -9.27]    -7.30     +5.5   13.5
#         fold 0: n=20     fill= 65.0% hit_f= 38.5% sim=  -10.13 bps  (n_fill=13)
#         fold 1: n=0      fill=     —% hit_f=     —% sim=     — bps  (n_fill=0)
#         fold 2: n=2,184  fill= 78.9% hit_f=  2.0% sim=   -9.27 bps  (n_fill=1,723)
#         fold 3: n=0      fill=     —% hit_f=     —% sim=     — bps  (n_fill=0)
#   dn18    1.000%  ens    3,099   79.9   2,476    2.5   1.62     -9.26  [ -11.78,   -9.21]    -7.40     +5.2   12.4
#
# ════ Seed-unanimity + maker entry (the 49.7%-hit heads) ════
#   head    rate     var   n_trig  fill%  n_fill  hit_f%  lift_f   sim bps  [95% CI, day-boot]  EV/trig   missed  hit_m%
#   up18    0.010%  unan      57   68.4      39    5.1   4.24     -5.89  [  -5.89,   -5.89]    -4.03    +13.3   38.9
#   up18    0.100%  unan     116   71.6      83    7.2   5.98     -8.00  [ -18.07,   -5.95]    -5.72    +12.8   42.4
#   up18    1.000%  unan   1,508   72.8   1,098    4.9   4.07     -7.29  [ -10.27,   -7.10]    -5.31     +7.2   14.6
#   dn18    0.010%  unan     682   79.3     541    2.6   1.70     -7.72  [  -7.72,   -7.72]    -6.12     +5.8   12.8
#   dn18    0.100%  unan     749   78.4     587    2.7   1.80     -7.60  [  -7.62,   +0.91]    -5.96     +6.7   16.0
#   dn18    1.000%  unan   2,248   79.0   1,777    2.3   1.52     -9.45  [ -16.13,   -9.35]    -7.47     +5.4   13.4
#
# ════ 30s-timed hybrid @ 0.1% ens: taker when the 30s reg head says "leaving now", maker limit otherwise ════
#   head    rate     var   n_trig  fill%  n_fill  hit_f%  lift_f   sim bps  [95% CI, day-boot]  EV/trig   missed  hit_m%
#   up18    0.100%  ens    1,910   91.8   1,753    6.5   5.38     -7.96  [ -10.51,   -4.09]    -7.31     +5.8    8.3
#         (routed taker: 1,276/1,910 = 66.8%)
#   dn18    0.100%  ens    2,204   92.4   2,037    3.6   2.39    -10.13  [ -10.13,  -10.13]    -9.37     +5.7   16.8
#         (routed taker: 1,375/2,204 = 62.4%)
#
# ════ Exploratory: wait × δ grid, h18 @ 0.1% ens (only the primary config is gated) ════
#   head   wait   δ·θ    fill%   hit_f%    sim bps   EV/trig
#   up18      3  0.00    66.4     3.8      -7.47     -4.96
#   up18      3  0.25    12.9     2.4      -6.49     -0.84
#   up18      3  0.50     2.3     2.3      -8.05     -0.19
#   up18      6  0.00    74.5     4.0      -7.37     -5.48
#   up18      6  0.25    25.6     1.2      -7.62     -1.95
#   up18      6  0.50     7.2     0.7      -7.41     -0.54
#   up18     12  0.00    81.1     3.8      -7.42     -6.01
#   up18     12  0.25    39.8     0.9      -7.70     -3.07
#   up18     12  0.50    16.6     0.3      -7.29     -1.21
#   up18     18  0.00    84.0     3.7      -7.46     -6.27
#   up18     18  0.25    47.2     1.0      -7.66     -3.62
#   up18     18  0.50    23.3     0.7      -7.74     -1.80
#   dn18      3  0.00    70.6     2.3      -9.17     -6.47
#   dn18      3  0.25    12.9     0.7      -9.79     -1.27
#   dn18      3  0.50     1.6     5.7      -9.88     -0.16
#   dn18      6  0.00    78.8     2.2      -9.27     -7.30
#   dn18      6  0.25    25.9     0.4      -9.62     -2.49
#   dn18      6  0.50     6.7     1.4      -8.31     -0.56
#   dn18     12  0.00    85.7     2.3      -9.25     -7.92
#   dn18     12  0.25    41.7     0.4      -9.58     -4.00
#   dn18     12  0.50    17.2     0.8      -8.82     -1.52
#   dn18     18  0.00    88.2     2.2      -9.27     -8.18
#   dn18     18  0.25    49.8     0.4      -9.49     -4.73
#   dn18     18  0.50    26.4     0.5      -9.00     -2.37
#
# ════ Entry-delay stress @ 0.1% ens (the other run.008 promise) ════
# taker+3bar: enter taker at close[e+3] — 15s later, the run.009 latency
# stress — instead of close[e] (sim_exit on the shifted anchor, time-stop
# still e+h). If the taker edge moves materially, zero-latency was working.
#   head    variant          n     sim bps   [95% CI, day-boot]
#   up18    taker+0           1,910      -8.38  [ -10.51,   -4.09]
#   up18    taker+3bar (15s)  1,910      -8.59  [ -10.54,   -5.53]
#   up18    maker delay=3 (15s)  1,242      -9.13  [ -12.28,   -3.73]  (fill 65.0%)
#   dn18    taker+0           2,204     -10.64  [ -10.70,   -3.99]
#   dn18    taker+3bar (15s)  2,204     -10.46  [ -10.55,   -0.55]
#   dn18    maker delay=3 (15s)  1,578     -10.78  [ -10.79,  -10.02]  (fill 71.6%)
#
# ════ Exploratory: all horizons, maker primary config @ 0.1% ens ════
#   head    rate     var   n_trig  fill%  n_fill  hit_f%  lift_f   sim bps  [95% CI, day-boot]  EV/trig   missed  hit_m%
#   up6     0.100%  ens    1,896   75.5   1,432    1.1   2.49     -8.72  [  -9.26,   -6.10]    -6.59     +6.5    5.2
#   dn6     0.100%  ens    2,205   78.2   1,725    0.8   1.49     -8.83  [ -14.00,   -8.74]    -6.91     +5.9    6.2
#   up9     0.100%  ens    2,074   74.6   1,548    2.3   2.27     -8.58  [  -9.08,   -8.14]    -6.41     +6.8   11.6
#   dn9     0.100%  ens    2,152   78.1   1,681    1.7   1.47     -8.80  [ -25.19,   -8.76]    -6.87     +5.6   11.0
#   up12    0.100%  ens    2,061   75.4   1,553    2.2   3.73     -8.17  [ -11.84,   -8.03]    -6.16     +7.2    8.5
#   dn12    0.100%  ens    2,181   78.0   1,702    0.9   1.22     -8.88  [ -11.46,   -8.87]    -6.93     +5.6    7.5
#   up15    0.100%  ens    2,027   74.6   1,512    3.2   3.62     -7.73  [  -9.17,   -7.68]    -5.77     +7.3   10.9
#   dn15    0.100%  ens    2,111   78.4   1,656    1.6   1.37     -9.05  [ -13.64,   -9.03]    -7.10     +5.6   10.3
#   up24    0.100%  ens    1,565   73.4   1,149    9.0   4.40     -7.08  [  -7.17,   -0.49]    -5.20     +8.3   20.7
#   dn24    0.100%  ens    2,080   78.5   1,632    4.4   1.84     -9.52  [  -9.52,   -8.97]    -7.47     +5.4   17.4
#
# ════ Non-overlapping 1-BTC maker trades (wait=6, tp=1.0·θ, sl=1.0·θ, time-stop h) ════
#   up18 @0.1% ens              163 posted    128 filled   total      -8249 $   mean   -64.4 $   win 17.2%
#   dn18 @0.1% ens              170 posted    129 filled   total      -9964 $   mean   -77.2 $   win 15.5%
#   up18 @0.1% unan              15 posted     11 filled   total       -378 $   mean   -34.4 $   win 36.4%
#   dn18 @0.1% unan              63 posted     45 filled   total      -3447 $   mean   -76.6 $   win 13.3%

# %%
# ── Cell 10D: adverse-selection FILL-SPLIT diagnostic (run.010 next-step #1) ──
# hit_f << hit_m says the maker limit fills only when the move is failing.
# Question: can any OBSERVABLE feature at the TRIGGER bar separate
#   (A) filled vs unfilled triggers  (the mechanics), and
#   (B) FAVOURABLE fills (filled AND reached TP) vs everything else (the money)?
# If B is predictable OUT-OF-FOLD -> that's the execution/fill-timing signal the
#   project is missing -> build a maker/skip router on it (next run).
# If not -> the current feature set can't time fills -> the only lever left is
#   finer (sub-second) order-flow data, per the resolution discussion.
# run.012 note: the univariate top-6 now competes the ev_* sub-bar features
# against the whole bar-level set — whether any ev_* feature appears there is
# the pre-registered read on whether event-level data carries fill-timing signal.
# Pure post-hoc read on the PRIMARY config; reuses in-memory close/X_raw/results/
# sim_maker/fold_triggers/day_of -- run this AFTER cell 10M in the same session.
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import roc_auc_score

H  = H_SEL                                   # 18 = 90s primary head
th = THETA_BY_H[H]
FEATS = features                             # kept feature names (cell 6)

def _safe_auc(y, x):                         # per-feature separation, NaN-robust
    m = np.isfinite(x)
    if m.sum() < 20 or len(np.unique(y[m])) < 2:
        return np.nan
    a = roc_auc_score(y[m], x[m])
    return max(a, 1 - a)                      # direction-agnostic separability

for side in ('up', 'dn'):
    j = CLS_COLS.index(f'l{side}_{H}')
    E, FILLED, NET = [], [], []
    for r in results:
        e = r['test_ends'][fold_triggers(r, j, PRIMARY_RATE, 'ens')]
        if len(e) == 0:
            continue
        net, filled, _, _ = sim_maker(e, side, H, TP_MULT * th, SL_MULT * th)
        E.append(e); FILLED.append(filled); NET.append(net)
    e = np.concatenate(E); filled = np.concatenate(FILLED); net = np.concatenate(NET)
    fav = filled & (net > 0)                  # net>0 <=> TP maker exit <=> hit_f
    X   = X_raw[e]; grp = day_of(e)

    print(f'\n════ {side}{H} @ {PRIMARY_RATE:.1%} ens — fill-split diagnostic ════')
    print(f'  {len(e):,} triggers | fill {filled.mean()*100:5.1f}% | '
          f'favourable(all) {fav.mean()*100:4.1f}% | '
          f'hit_f(among fills) {fav[filled].mean()*100 if filled.any() else 0:4.1f}%')

    for name, y in (('FILLED (A)', filled.astype(int)), ('FAVOURABLE (B)', fav.astype(int))):
        if len(np.unique(y)) < 2:
            print(f'  {name}: only one class present — skip'); continue
        # (1) univariate: best single-feature separators
        aucs = np.array([_safe_auc(y, X[:, k]) for k in range(X.shape[1])])
        order = np.argsort(-np.nan_to_num(aucs))[:6]
        top = '  '.join(f'{FEATS[k]}={aucs[k]:.3f}' for k in order if np.isfinite(aucs[k]))
        # (2) multivariate, HONEST: day-grouped POOLED-OOF logistic (run.011 fix:
        # fold-averaged AUC returns nan when a day-fold has zero positives —
        # dn18 in run.010a. Manual splits: skip train folds with one class, pool
        # all held-out probabilities, ONE AUC over the pooled predictions).
        ng = len(np.unique(grp))
        oof = np.full(len(y), np.nan)
        if ng >= 2:
            cv = GroupKFold(n_splits=min(5, ng))
            for tri, tei in cv.split(X, y, grp):
                if len(np.unique(y[tri])) < 2:
                    continue
                pipe = make_pipeline(StandardScaler(),
                                     LogisticRegression(max_iter=2000, C=0.5,
                                                        class_weight='balanced'))
                pipe.fit(np.nan_to_num(X[tri]), y[tri])
                oof[tei] = pipe.predict_proba(np.nan_to_num(X[tei]))[:, 1]
        m_ = np.isfinite(oof)
        cvauc = (roc_auc_score(y[m_], oof[m_])
                 if m_.any() and len(np.unique(y[m_])) > 1 else np.nan)
        verdict = ('SIGNAL' if cvauc >= 0.58 else
                   'weak'   if cvauc >= 0.54 else 'NONE (~chance)')
        print(f'  {name:15s} OOF day-grouped CV AUC = {cvauc:.3f}  → {verdict}')
        print(f'      top single features: {top}')

print('\nRead-out: FAVOURABLE (B) OOF AUC is the one that matters. >=~0.58 = an '
      'executable fill-timing signal exists in the current features — run.011 '
      'cell 10R builds the maker/skip router on it and gates it causally. ~0.50 = it does not -> the constraint is data '
      'resolution, and sub-second order-flow is the only remaining lever.')
# Out:
# ════ up18 @ 0.1% ens — fill-split diagnostic ════
#   1,910 triggers | fill  74.5% | favourable(all) 16.8% | hit_f(among fills) 22.5%
#   FILLED (A)      OOF day-grouped CV AUC = 0.547  → weak
#       top single features: micro_dev_z=0.582  wall_qty_norm=0.562  ma_gap_1h=0.552  ma_gap_24h=0.548  ma_gap_4h=0.546  ret_norm_24h=0.544
#   FAVOURABLE (B)  OOF day-grouped CV AUC = 0.492  → NONE (~chance)
#       top single features: ret_norm_4h=0.582  lsr_z=0.575  ma_gap_24h=0.571  range_pos_24h=0.571  ev_ft_ntr_z=0.561  ev_ft_gmin_z=0.561
#
# ════ dn18 @ 0.1% ens — fill-split diagnostic ════
#   2,204 triggers | fill  78.8% | favourable(all) 12.6% | hit_f(among fills) 16.0%
#   FILLED (A)      OOF day-grouped CV AUC = 0.481  → NONE (~chance)
#       top single features: micro_dev_z=0.567  range_pos_24h=0.556  ma_gap_24h=0.554  pull_add_ask=0.546  eth_ret_z=0.545  flow_net_near_z=0.545
#   FAVOURABLE (B)  OOF day-grouped CV AUC = 0.510  → NONE (~chance)
#       top single features: ma_gap_1h=0.621  ma_gap_4h=0.614  range_pos_24h=0.611  ma_gap_24h=0.607  ret_norm_24h=0.594  book_imbal_roll4=0.594
#
# Read-out: FAVOURABLE (B) OOF AUC is the one that matters. >=~0.58 = an executable fill-timing signal exists in the current features — run.011 cell 10R builds the maker/skip router on it and gates it causally. ~0.50 = it does not -> the constraint is data resolution, and sub-second order-flow is the only remaining lever.

# %%
# ── Cell 10R: CAUSAL maker/skip router (run.011 design, carried unchanged — GATED) ──
# run.010a's cell 10D fired the pre-registered ≥0.58 branch → build the router.
# No-bias contract (cell 0): walk-forward training (test day d sees only val +
# completed days < d), τ frozen from VAL EV, scaler refit per step, 1%-trigger
# training pool / 0.1% application, starvation abstention. Gate A/B/C below.
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GroupKFold
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

def _rx(e, probs):                       # router inputs: trigger-bar row + head prob
    return np.column_stack([np.nan_to_num(X_raw[e]), probs])

def _fit_router(X, y):
    p = make_pipeline(StandardScaler(),
                      LogisticRegression(max_iter=2000, C=ROUTER_C,
                                         class_weight='balanced'))
    p.fit(X, y)
    return p

ROUT = {}
for side in ('up', 'dn'):
    j  = CLS_COLS.index(f'l{side}_{H_SEL}')
    th = THETA_BY_H[H_SEL]

    # ── per-fold causal pieces: val triggers (rolling-τ, 1%) + outcomes ──
    packs = []
    for r in results:
        vt = dt_s[r['val_ends']]
        vm = rolling_triggers(r['val_prob'][:, j], vt,
                              r['val_prob'][:, j], vt, ROUTER_TRAIN_RATE)
        ve = r['val_ends'][vm]
        vnet, vfill, _, _ = sim_maker(ve, side, H_SEL, TP_MULT * th, SL_MULT * th)
        vfav = vfill & (vnet > 0)
        # day-grouped OOF router scores on val triggers — τ SELECTION ONLY
        vday = day_of(ve); oof = np.full(len(ve), np.nan)
        if len(ve) and len(np.unique(vfav)) > 1 and len(np.unique(vday)) >= 2:
            Xv = _rx(ve, r['val_prob'][vm, j])
            gkf = GroupKFold(n_splits=min(5, len(np.unique(vday))))
            for tri, tei in gkf.split(Xv, vfav, vday):
                if len(np.unique(vfav[tri])) < 2:
                    continue
                oof[tei] = _fit_router(Xv[tri], vfav[tri]).predict_proba(Xv[tei])[:, 1]
        packs.append(dict(r=r, vm=vm, ve=ve, vfav=vfav, vnet=vnet, oof=oof))

    # ── τ on pooled val EV/trigger, then FROZEN ──
    n_ro = int(sum(np.isfinite(p['oof']).sum() for p in packs))
    tau, best_ev = 0.5, 0.0
    for t_ in ROUTER_TAU_GRID:
        num = sum(np.nansum(p['vnet'][np.isfinite(p['oof']) & (p['oof'] >= t_)])
                  for p in packs)
        ev = num / max(n_ro, 1)
        if ev > best_ev + 1e-12:
            best_ev, tau = ev, t_
    if best_ev <= 0:                     # val says nothing profitable → route nothing
        tau = 1.01
    val_note = (f'τ={tau:.2f} from val (best EV/trig {best_ev:+.2f} bps over '
                f'{n_ro:,} routable val triggers)')

    # ── walk-forward over test days: fit on val + completed past days only ──
    NET, DY, HIT, SKIP_TK = [], [], [], []
    fold_sims, fold_lifts = [], []
    n_prim = n_routed = n_abstain = 0
    for p in packs:
        r = p['r']
        vt = dt_s[r['val_ends']]; tt = dt_s[r['test_ends']]
        pm = fold_triggers(r, j, PRIMARY_RATE, 'ens')                # 0.1%, causal
        tm = rolling_triggers(r['val_prob'][:, j], vt,
                              r['test_prob'][:, j], tt, ROUTER_TRAIN_RATE)  # 1% pool
        pe, pprob = r['test_ends'][pm], r['test_prob'][pm, j]
        te, tprob = r['test_ends'][tm], r['test_prob'][tm, j]
        tnet, tfill, _, _ = sim_maker(te, side, H_SEL, TP_MULT * th, SL_MULT * th)
        tfav = tfill & (tnet > 0)
        Xv = _rx(p['ve'], r['val_prob'][p['vm'], j])
        n_prim += len(pe)
        fNET, fHIT = [], []
        for d in np.unique(day_of(pe)):
            d0 = d.astype('datetime64[s]').astype(np.int64)
            dm = day_of(pe) == d
            dp, dprob = pe[dm], pprob[dm]
            done = dt_s[te + H_SEL] < d0          # outcome COMPLETED before day d
            Xtr = np.vstack([Xv, _rx(te[done], tprob[done])]) if done.any() else Xv
            ytr = np.concatenate([p['vfav'], tfav[done]]) if done.any() else p['vfav']
            if len(np.unique(ytr)) < 2 or ytr.sum() < ROUTER_MIN_POS or tau > 1.0:
                n_abstain += 1                                      # pre-registered
                SKIP_TK.append(sim_exit(dp, side, H_SEL, TP_MULT * th, SL_MULT * th)[0])
                continue
            pr = _fit_router(Xtr, ytr).predict_proba(_rx(dp, dprob))[:, 1]
            routed = pr >= tau
            if (~routed).any():
                SKIP_TK.append(sim_exit(dp[~routed], side, H_SEL,
                                        TP_MULT * th, SL_MULT * th)[0])
            if not routed.any():
                continue
            n_routed += int(routed.sum())
            net, filled, _, _ = sim_maker(dp[routed], side, H_SEL,
                                          TP_MULT * th, SL_MULT * th)
            HIT.append(L_all[dp[routed], j].astype(float))
            fHIT.append(L_all[dp[routed], j].astype(float))
            if filled.any():
                NET.append(net[filled]); DY.append(day_of(dp[routed])[filled])
                fNET.append(net[filled])
        fold_sims.append(float(np.mean(np.concatenate(fNET))) if fNET else np.nan)
        if fHIT:
            base_f = float(L_all[r['test_ends'], j].mean())
            fold_lifts.append(float(np.concatenate(fHIT).mean() / base_f)
                              if base_f > 0 else np.nan)
        else:
            fold_lifts.append(np.nan)

    net  = np.concatenate(NET) if NET else np.zeros(0)
    days = np.concatenate(DY) if DY else np.zeros(0)
    hits = np.concatenate(HIT) if HIT else np.zeros(0)
    base = float(L_all[ends_pool, j].mean())
    skip = np.concatenate(SKIP_TK) if SKIP_TK else np.zeros(0)
    ROUT[side] = dict(
        tau=tau, val_note=val_note, n_prim=n_prim, n_routed=n_routed,
        n_fill=len(net), fill=(n_routed and len(net) / n_routed or 0.0),
        sim=float(net.mean()) if len(net) else np.nan,
        ci=boot_ci_mean(net, days),
        hit_f=float((net > 0).mean()) if len(net) else np.nan,
        lift=float(hits.mean() / base) if len(hits) and base > 0 else np.nan,
        fold_sims=fold_sims, fold_lifts=fold_lifts,
        coverage=(n_prim and n_routed / n_prim or 0.0), abstain=n_abstain,
        skip_taker=float(skip.mean()) if len(skip) else np.nan)

    print(f'════ {side}{H_SEL} router @ {PRIMARY_RATE:.1%} ens — causal walk-forward ════')
    print(f'  {val_note}')
    print(f'  primary triggers {n_prim:,} | routed {n_routed:,} '
          f'({ROUT[side]["coverage"]*100:.0f}% coverage) | abstain-days {n_abstain}')
    print(f'  fill {ROUT[side]["fill"]*100:.1f}%  hit_f(routed) '
          f'{_fmt(ROUT[side]["hit_f"]*100 if np.isfinite(ROUT[side]["hit_f"]) else np.nan, ".1f")}%  '
          f'lift {_fmt(ROUT[side]["lift"], ".2f")}x')
    print(f'  ROUTED maker sim {_fmt(ROUT[side]["sim"], "+.2f")} bps  '
          f'CI [{_fmt(ROUT[side]["ci"][0], "+.2f")}, {_fmt(ROUT[side]["ci"][1], "+.2f")}]')
    print(f'  per-fold routed sims: ' +
          '  '.join(_fmt(v, "+.2f") for v in fold_sims))
    print(f'  exploratory (NOT gated): skipped triggers as TAKER trades → '
          f'{_fmt(ROUT[side]["skip_taker"], "+.2f")} bps')

print('\nReference (un-routed, cell 10M): the cell above prints THIS window\'s '
      'un-routed maker numbers. run.011\'s −9.62 / −10.96 bps were on the OLD '
      '35-day bar-only window — NOT comparable (different era AND feature set).')
# Out:
# ════ up18 router @ 0.1% ens — causal walk-forward ════
#   τ=1.01 from val (best EV/trig +0.00 bps over 0 routable val triggers)
#   primary triggers 1,910 | routed 0 (0% coverage) | abstain-days 5
#   fill 0.0%  hit_f(routed)      —%  lift      —x
#   ROUTED maker sim      — bps  CI [     —,      —]
#   per-fold routed sims:      —       —       —       —
#   exploratory (NOT gated): skipped triggers as TAKER trades → -8.38 bps
# ════ dn18 router @ 0.1% ens — causal walk-forward ════
#   τ=1.01 from val (best EV/trig +0.00 bps over 0 routable val triggers)
#   primary triggers 2,204 | routed 0 (0% coverage) | abstain-days 2
#   fill 0.0%  hit_f(routed)      —%  lift      —x
#   ROUTED maker sim      — bps  CI [     —,      —]
#   per-fold routed sims:      —       —       —       —
#   exploratory (NOT gated): skipped triggers as TAKER trades → -10.64 bps
#
# Reference (un-routed, cell 10M): the cell above prints THIS window's un-routed maker numbers. run.011's −9.62 / −10.96 bps were on the OLD 35-day bar-only window — NOT comparable (different era AND feature set).

# %%
# ── Cell 11: GATE (pre-registered) — ROUTER edition ─────────────────────
# Gated object is cell 10R's CAUSAL router (no-bias contract in cell 0), at the
# h18 heads, primary maker config (wait=ENTRY_WAIT, δ=ENTRY_DELTA, delay=0),
# TP=SL=1.0·θ, for at least one side:
#   A. pooled ROUTED maker-sim net bps (FILLED trades) > 0 AND day-bootstrap
#      95% CI excludes 0
#   B. ROUTED-trigger label lift ≥ 3× pooled AND ≥ 2× in ≥ 3 of 4 folds
#   C. fill honesty: routed fill ≥ FILL_MIN AND per-fold routed sim > 0 in
#      ≥ 3 of 4 folds (a zero-fill / abstained fold counts as a fail)
#   D. (info only in run.012) un-routed neighbour rates from cell 10M
# Registered 2026-08-19, before seeing any run.012 test number. The window is
# the EVENTS ERA (cell 5) — NOT run.010a/011's 33-day window — so a PASS is a
# design signal on a SHORT window (see cell 0: <7-day folds are indicative
# only); the economic verdict stays with the long-window events run.
NEIGHBOUR_RATES = [r_ for r_ in TRIGGER_RATES if r_ != PRIMARY_RATE]

def gate_side_router(side):
    j = CLS_COLS.index(f'l{side}_{H_SEL}')
    q = ROUT[side]
    A = bool(q['n_fill'] > 0 and np.isfinite(q['sim']) and q['sim'] > 0
             and np.isfinite(q['ci'][0]) and q['ci'][0] > 0)
    ok_lift = sum(1 for v in q['fold_lifts'] if np.isfinite(v) and v >= 2.0)
    B = bool(np.isfinite(q['lift']) and q['lift'] >= 3.0
             and ok_lift >= N_FOLDS - 1)
    ok_sim = sum(1 for v in q['fold_sims'] if np.isfinite(v) and v > 0)
    C = bool(np.isfinite(q['fill']) and q['fill'] >= FILL_MIN
             and ok_sim >= N_FOLDS - 1)
    print(f'  {side}{H_SEL} @ {PRIMARY_RATE*100:.1f}% ROUTED (τ={q["tau"]:.2f} from val):')
    print(f'    A  routed maker sim {_fmt(q["sim"], "+.2f")} bps, CI '
          f'[{_fmt(q["ci"][0], "+.2f")}, {_fmt(q["ci"][1], "+.2f")}] '
          f'(need CI > 0)      → {"pass" if A else "fail"}')
    print(f'    B  lift {_fmt(q["lift"], ".2f")}x pooled (need ≥3), '
          f'folds ≥2x: {ok_lift}/{N_FOLDS} (need ≥{N_FOLDS-1})   '
          f'→ {"pass" if B else "fail"}')
    print(f'    C  fill {_fmt(q["fill"]*100, ".1f")}% (need ≥{FILL_MIN*100:.0f}%), '
          f'folds sim>0: {ok_sim}/{N_FOLDS} (need ≥{N_FOLDS-1}) '
          f'→ {"pass" if C else "fail"}')
    print(f'    coverage {q["coverage"]*100:.0f}% of primary triggers routed, '
          f'abstain-days {q["abstain"]} (info)')
    return A and B and C

print('GATE (pre-registered, causal router):')
up_pass = gate_side_router('up')
dn_pass = gate_side_router('dn')
GATE_PASS = up_pass or dn_pass

print('\n  D (info only, UN-ROUTED neighbour rates, cell 10M):')
for j, tag in ((SEL_UP_J, 'up'), (SEL_DN_J, 'dn')):
    for r_ in NEIGHBOUR_RATES:
        q = maker_stats(j, r_, 'ens')[1]
        print(f'    {tag}{H_SEL} @{r_*100:6.2f}%: n_fill={q["n_fill"]:<5,} '
              f'maker sim {_fmt(q["sim"], "+.2f")} bps')

print(f'\n  → GATE {"PASSED" if GATE_PASS else "FAILED"}')

# ── informational (NOT gated): primary-cell trigger fold-share ──────────
print('\n  Primary-cell trigger fold-share (run.009 reference: 97% in one fold;')
print('  run.010a: up18 49% / dn18 55%):')
for j in (SEL_UP_J, SEL_DN_J):
    h, side = CLS_KEYS[j]
    cnts = [int(fold_triggers(r, j, PRIMARY_RATE, 'ens').sum()) for r in results]
    tot = sum(cnts)
    share = f'{max(cnts)/tot*100:.0f}%' if tot else '—'
    print(f'    {side}{h}: folds {cnts}  max share {share}')

if GATE_PASS:
    print('  The causal router clears fees on this window. Before believing it:')
    print('  this is the SAME 33-day window as run.010a → a DESIGN signal, not')
    print('  trading evidence. Carry cell 10R unchanged into the ≥45-day run')
    print('  (~Aug 28) — the economic verdict lives there. Then freqtrade')
    print('  cross-check with a limit-order fill model (run.005\'s lesson).')
else:
    print('  Read the failure mode before concluding anything:')
    print('  - abstain-days dominate / coverage ≈ 0  → val+early-test starvation;')
    print('    the unbiased answer at 33 days. Fix = the 45-day window, NOT')
    print('    relaxing the no-bias contract.')
    print('  - trades but sim ≤ 0, hit_f(routed) ≈ un-routed → a 0.61-AUC router')
    print('    cannot separate fills causally; the 45-day run decides whether')
    print('    sub-second order-flow is the last lever.')
    print('  - A passes but C fails on folds → regime-dependent; do not trade it.')
    print('  - CI straddles 0 with few fills → not proven; more data.')
# Out:
# GATE (pre-registered, causal router):
#   up18 @ 0.1% ROUTED (τ=1.01 from val):
#     A  routed maker sim      — bps, CI [     —,      —] (need CI > 0)      → fail
#     B  lift      —x pooled (need ≥3), folds ≥2x: 0/4 (need ≥3)   → fail
#     C  fill 0.0% (need ≥25%), folds sim>0: 0/4 (need ≥3) → fail
#     coverage 0% of primary triggers routed, abstain-days 5 (info)
#   dn18 @ 0.1% ROUTED (τ=1.01 from val):
#     A  routed maker sim      — bps, CI [     —,      —] (need CI > 0)      → fail
#     B  lift      —x pooled (need ≥3), folds ≥2x: 0/4 (need ≥3)   → fail
#     C  fill 0.0% (need ≥25%), folds sim>0: 0/4 (need ≥3) → fail
#     coverage 0% of primary triggers routed, abstain-days 2 (info)
#
#   D (info only, UN-ROUTED neighbour rates, cell 10M):
#     up18 @  0.01%: n_fill=1,220 maker sim -7.49 bps
#     up18 @  1.00%: n_fill=2,622 maker sim -8.56 bps
#     dn18 @  0.01%: n_fill=1,720 maker sim -9.24 bps
#     dn18 @  1.00%: n_fill=2,476 maker sim -9.26 bps
#
#   → GATE FAILED
#
#   Primary-cell trigger fold-share (run.009 reference: 97% in one fold;
#   run.010a: up18 49% / dn18 55%):
#     up18: folds [54, 315, 1534, 7]  max share 80%
#     dn18: folds [20, 0, 2184, 0]  max share 99%
#   Read the failure mode before concluding anything:
#   - abstain-days dominate / coverage ≈ 0  → val+early-test starvation;
#     the unbiased answer at 33 days. Fix = the 45-day window, NOT
#     relaxing the no-bias contract.
#   - trades but sim ≤ 0, hit_f(routed) ≈ un-routed → a 0.61-AUC router
#     cannot separate fills causally; the 45-day run decides whether
#     sub-second order-flow is the last lever.
#   - A passes but C fails on folds → regime-dependent; do not trade it.
#   - CI straddles 0 with few fills → not proven; more data.

# %%
# ── Cell 12: Plots ──────────────────────────────────────────────────────────
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
sweep = np.geomspace(3e-5, 3e-2, 12)

def plot_finite(ax, x, y, *a, **k):
    # skip all-NaN series (e.g. lift when the base rate is 0) — plotting them
    # leaves the log axis without data and savefig dies on autoscale
    y = np.asarray(y, dtype=float)
    m = np.isfinite(y)
    if m.any():
        ax.plot(np.asarray(x)[m], y[m], *a, **k)
        return True
    return False

ax = axes[0, 0]
any_pts = False
for j, color in ((SEL_UP_J, 'tab:green'), (SEL_DN_J, 'tab:red')):
    h, side = CLS_KEYS[j]
    sims, ends_ = [], []
    for r_ in sweep:
        _, p = trigger_stats(j, r_, 'ens')
        sims.append(p['sim']); ends_.append(p['net'])
    any_pts |= plot_finite(ax, sweep * 100, sims, '-', color=color,
                           label=f'{side}{h} TP/SL sim')
    any_pts |= plot_finite(ax, sweep * 100, ends_, ':', color=color,
                           label=f'{side}{h} hold-to-h')
ax.axhline(0, color='k', lw=0.5)
ax.axvline(PRIMARY_RATE * 100, color='gray', lw=0.5, ls=':')
if any_pts:
    ax.set_xscale('log')
ax.set_xlabel('nominal trigger rate (%)')
ax.set_ylabel('pooled net bps / signal'); ax.legend(fontsize=8)
ax.set_title(f'h{H_SEL}: simulated exit vs run.006-style endpoint (dotted)')

ax = axes[0, 1]
any_pts = False
for j, color in ((SEL_UP_J, 'tab:green'), (SEL_DN_J, 'tab:red')):
    h, side = CLS_KEYS[j]
    lifts = [trigger_stats(j, r_, 'ens')[1]['lift'] for r_ in sweep]
    any_pts |= plot_finite(ax, sweep * 100, lifts, color=color, label=f'{side}{h}')
ax.axhline(1, color='k', lw=0.5)
if any_pts:
    ax.set_xscale('log')
ax.set_xlabel('nominal trigger rate (%)')
ax.set_ylabel('hit-rate lift vs base'); ax.legend(fontsize=8)
ax.set_title('does conviction actually concentrate hits?')

ax = axes[1, 0]
sims_by_h = {'up': [], 'dn': []}
for j, (h, side) in enumerate(CLS_KEYS):
    _, p = trigger_stats(j, PRIMARY_RATE, 'ens')
    sims_by_h[side].append((h, p['sim'], p['ci']))
for side, color in (('up', 'tab:green'), ('dn', 'tab:red')):
    hs   = [v[0] for v in sims_by_h[side]]
    mu   = [v[1] for v in sims_by_h[side]]
    lo   = np.clip([v[1] - v[2][0] for v in sims_by_h[side]], 0, None)
    hi   = np.clip([v[2][1] - v[1] for v in sims_by_h[side]], 0, None)
    ax.errorbar(hs, mu, yerr=[lo, hi], fmt='o-', color=color, capsize=3,
                label=f'{side} heads')
ax.axhline(0, color='k', lw=0.5)
ax.set_xlabel(f'horizon h (bars of {WINDOW_SEC}s)'); ax.set_ylabel('sim net bps / signal')
ax.legend(fontsize=8)
ax.set_title(f'sim net vs horizon @ {PRIMARY_RATE*100:.1f}% (day-boot 95% CI)')

ax = axes[1, 1]
step = max(len(ends_pool) // 5000, 1)
ax.plot(dt_all[ends_pool[::step]], close[ends_pool[::step]], color='0.7', lw=0.7)
for j, color, mk in ((SEL_UP_J, 'tab:green', '^'), (SEL_DN_J, 'tab:red', 'v')):
    e = np.concatenate([r['test_ends'][fold_triggers(r, j, PRIMARY_RATE, 'ens')]
                        for r in results])
    ax.scatter(dt_all[e], close[e], s=12, color=color, marker=mk,
               label=f'{CLS_KEYS[j][1]}{CLS_KEYS[j][0]} trigger', zorder=3)
ax.legend(fontsize=8)
ax.set_title(f'primary triggers ({PRIMARY_RATE*100:.1f}% nominal, rolling τ) on price')
ax.tick_params(axis='x', rotation=30)

plt.tight_layout()
plot_path = os.path.join(OUTPUT_DIR, 'run012_selective.png')
plt.savefig(plot_path, dpi=110, bbox_inches='tight')
plt.show()
print(f'Saved → {plot_path}')
# Out:
# Saved → /root/btc_lstm_run012/run012_selective.png

# %%
# ── Cell 13: Save to Drive + how to read this run ──────────────────────────
import shutil

model_path = os.path.join(OUTPUT_DIR, f'lstm_run012_h{H_SEL}.pt')
torch.save({
    'model_states': results[-1]['states'],     # all seeds, last (largest-train) fold
    'scaler':       results[-1]['scaler'],
    'features':     features,
    'horizons':     HORIZONS,
    'cls_keys':     CLS_KEYS,
    'seeds':        SEEDS,
    'config':       dict(seq_len=SEQ_LEN, hidden_dim=HIDDEN_DIM,
                         num_layers=NUM_LAYERS, dropout=DROPOUT,
                         vol_window=VOL_WINDOW, target_clip=TARGET_CLIP,
                         window_sec=WINDOW_SEC, h_trade=H_TRADE, h_sel=H_SEL,
                         theta_by_h=THETA_BY_H, pos_w_cap=POS_W_CAP, bce_w=BCE_W,
                         tp_mult=TP_MULT, sl_mult=SL_MULT,
                         roll_cal_days=ROLL_CAL_DAYS, min_cal_n=MIN_CAL_N,
                         entry_wait=ENTRY_WAIT, entry_delta=ENTRY_DELTA,
                         entry_delay=ENTRY_DELAY, fill_min=FILL_MIN,
                         sample_w_base=SAMPLE_W_BASE,
                         loss_w_alpha=LOSS_W_ALPHA, loss_w_cap=LOSS_W_CAP),
    'test_ic_per_fold':      [r['test_ic'] for r in results],
    'test_ap_per_fold':      [r['test_ap'] for r in results],
    # deployment note: live thresholds come from the ROLLING rule (trailing
    # ROLL_CAL_DAYS of live probs); these frozen val quantiles only seed it.
    'primary_tau_per_fold':  [{CLS_COLS[j]: float(np.quantile(r['val_prob'][:, j],
                                                              1 - PRIMARY_RATE))
                               for j in range(len(CLS_KEYS))} for r in results],
}, model_path)
print(f'Saved model → {model_path}')

from google.colab import drive
drive.mount('/content/drive')
os.makedirs(DRIVE_SAVE_DIR, exist_ok=True)
for p in [scores_path, model_path, os.path.join(OUTPUT_DIR, 'run012_selective.png')]:
    if os.path.exists(p):
        shutil.copy(p, DRIVE_SAVE_DIR)
        print(f'  → Drive: {os.path.join(DRIVE_SAVE_DIR, os.path.basename(p))}')
drive.flush_and_unmount()

print('\nHow to read this run:')
print(' 1. SANITY FIRST: per-wall-clock base rates must ≈ run.009/010a (90s/20bp:')
print('    lup_18 ≈ 0.43–0.45% / ldn_18 ≈ 0.36–0.43%). If far off, the tar or')
print('    the cadence handling is broken — stop, read nothing else.')
print(' 2. Cell 10D now prints POOLED OOF AUC for both sides (dn18 resolves;')
print('    run.010a was nan). Diagnostic only — NOT the gate.')
print(' 3. The gate is the ROUTER (cell 10R): A/B/C on routed trades. τ came')
print('    from val EV only; abstain-days are the pre-registered starvation')
print('    rule, not a bug. A τ=1.01 print means val found nothing profitable')
print('    and the router routed nothing — a vacuous fail, by design.')
print(' 4. Same 33-day window as run.010a → a PASS is a DESIGN signal; the')
print('    economic verdict stays with the ≥45-day run (~Aug 28) reusing this')
print('    exact cell.')
print(' 5. run012_scores.npz feeds the offline regime/meta-filter analysis')
print('    (trailing-IC gating study) without retraining.')
# Out:
# Saved model → /root/btc_lstm_run012/lstm_run012_h18.pt
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   → Drive: /content/drive/MyDrive/btc_lstm_run012/run012_scores.npz
#   → Drive: /content/drive/MyDrive/btc_lstm_run012/lstm_run012_h18.pt
#   → Drive: /content/drive/MyDrive/btc_lstm_run012/run012_selective.png
#
# How to read this run:
#  1. SANITY FIRST: per-wall-clock base rates must ≈ run.009/010a (90s/20bp:
#     lup_18 ≈ 0.43–0.45% / ldn_18 ≈ 0.36–0.43%). If far off, the tar or
#     the cadence handling is broken — stop, read nothing else.
#  2. Cell 10D now prints POOLED OOF AUC for both sides (dn18 resolves;
#     run.010a was nan). Diagnostic only — NOT the gate.
#  3. The gate is the ROUTER (cell 10R): A/B/C on routed trades. τ came
#     from val EV only; abstain-days are the pre-registered starvation
#     rule, not a bug. A τ=1.01 print means val found nothing profitable
#     and the router routed nothing — a vacuous fail, by design.
#  4. Same 33-day window as run.010a → a PASS is a DESIGN signal; the
#     economic verdict stays with the ≥45-day run (~Aug 28) reusing this
#     exact cell.
#  5. run012_scores.npz feeds the offline regime/meta-filter analysis
#     (trailing-IC gating study) without retraining.
